# %% [markdown]
# # EDA for Gas Fees
#
# In this notebook we perform Exploratory Data Analysis (EDA) on FIL's gas fee mechanism. The goal is to observe the gas fee as a signal and attempt to understand what may be driving it.
#
# Access was obtained to Sentinel from Filecoin, and based on previous Block Science data work, we believe the the gas information is in the `messages` or `message_gas_economy` tables. **Update**: based on discussion with Filecoin, the `derived_gas_outputs` table is used as the primary data gathering table.
#
# ## What are Gas Fees?
# Note: this description is copied from the [official Filecoin documentation](https://docs.filecoin.io/about-filecoin/how-filecoin-works/#gas-fees)
#
#
# Executing messages, for example by including transactions or proofs in the chain, consumes both computation and storage resources on the network. Gas is a measure of resources consumed by messages. The gas consumed by a message directly affects the cost that the sender has to pay for it to be included in a new block by a miner.
#
# Historically in other blockchains, miners specify a GasFee in a unit of native currency and then pay the block producing miners a priority fee based on how much gas is consumed by the message. Filecoin works similarly, except an amount of the fees is burned (sent to an irrecoverable address) to compensate for the network expenditure of resources, since all nodes need to validate the messages. The idea is based on Ethereum's EIP1559.
#
# The amount of fees burned in the Filecoin network comes given by a dynamic BaseFee which gets automatically adjusted according to the network congestion parameters (block sizes). The current value can be obtained from one of the block explorers or by inspecting the current head.
#
# Additionally, a number of gas-related parameters are attached to each message and determine the amount of rewards that miners get. Here's an overview of the terms and concepts:
#
# **GasUsage**: the amount of gas that a message's execution actually consumes. Current protocol does not know how much gas a message will exactly consume ahead of execution, but it can be estimated (see prices (opens new window)). GasUsage measured in units of Gas.
#
# **BaseFee**: the amount of FIL that gets burned per unit of gas consumed for the execution of every message. It is measured in units of attoFIL/Gas.
#
# **GasLimit**: the limit on the amount of gas that a message's execution can consume, estimated and specified by a message sender. It is measured in units of Gas. The sum of GasLimit for all messages included in a block must not exceed the BlockGasLimit. Messages will fail to execute if they run out of Gas, and any effects of the execution will be reverted.
#
# **GasFeeCap**: the maximum token amount that a sender is willing to pay per GasUnit for including a message in a block. It is measured in units of attoFIL/Gas. A message sender must have a minimum balance of GasFeeCap * GasLimit when sending a message, even though not all of that will be consumed. GasFeeCap can serve as a safeguard against high, unexpected BaseFee fluctuations.
#
# **GasPremium**: a priority fee that is paid to the block-producing miner. This is capped by GasFeeCap. The BaseFee has a higher priority. It is measured in units of attoFIL/Gas and can be as low as 1 attoFIL/Gas.
#
# **Overestimation burn**: an additional amount of gas to burn that grows larger when the difference between GasLimit and GasUsage is large.
#
# The total cost of a message for a sender will be:
#
# * GasUsage * BaseFee FIL (burned) +
# * GasLimit * GasPremium FIL (miner's reward) +
# * OverEstimationBurn * BaseFee FIL
#
# An important detail is that a message will always pay the burn fee, regardless of the GasFeeCap used. Thus, a low GasFeeCap may result in a reduced GasPremium or even a negative one! In that case, the miners that include a message will have to pay the needed amounts out of their own pockets, which means they are unlikely to include such messages in new blocks.
#
# Filecoin implementations may choose the heuristics of how their miners select messages for inclusion in new blocks, but they will usually attempt to maximize the miner's rewards.

# %% [markdown]
# ## Analysis
#
# We are performing a vector autoregression (VAR) to determine if a casual or multi-causal relationship exists between the gas signals moves. This will help us understand the system-level dynamics of Filecoin.
#
# ### Vector Autoregression
#
# Vector autoregression (VAR) is a type of statistical model used to capture the relationship between multiple time series signals as they change over time. VAR models are extensions of univariate autoregression models allowing for multivariate time series analysis.
#
# Autoregressive models use lagged past values of the variable and have an order based on how many times the variable has been lagged, i.e. VAR(2) means two lagged values. Lagged values help to determine if seasonality or reoccurring patterns exist in the data.
#
# A pth-order VAR model is written as:
# $$y_t = c + A_1 y_{t-1} + A_2 y_{t-2} + \cdots + A_p y_{t-p} + e_t,$$
#
# In vector notation, a VAR(1) with 2 variables is:
#
# $$\begin{bmatrix}y_{1,t} \\ y_{2,t}\end{bmatrix} = \begin{bmatrix}c_{1} \\ c_{2}\end{bmatrix} + \begin{bmatrix}a_{1,1}&a_{1,2} \\ a_{2,1}&a_{2,2}\end{bmatrix}\begin{bmatrix}y_{1,t-1} \\ y_{2,t-1}\end{bmatrix} + \begin{bmatrix}e_{1,t} \\ e_{2,t}\end{bmatrix}$$
#
# For our VAR model, we will have a vector of gas signals.
#
# #### Assumptions:
# * Every error term has a mean of zero and is normally distributed.
# * Variables are stationary. Differencing can be used to make the data stationary.
# * Data is on the same scale
# * Time sampling is consistent
#
# ### Other methods with fewer assumptions
#
# Non-parametric Bayesian VAR models have been under development and appear to perform well and can operate on nonlinear relationships, heteroscedasticity, and non-Gaussian error data[1,2].
#
# Another popular time series analysis modeling technique is the Autoregressive Integrated Moving Average (ARIMA) model. These models are often used in forecasting or when the data shows evidence of non-stationarity. For multiple time series vectors, as we have here, extensions of the ARIMA model are available, such ARIMAX model that has exogenous variable inputs. ARIMAX models do not have an assumption of Gaussian errors as it uses a maximum likelihood estimation function to fit.
#
# #### References
# - 1 Kalli, Maria & Griffin, Jim E., 2018. "Bayesian nonparametric vector autoregressive models," Journal of Econometrics, Elsevier, vol. 203(2), pages 267-282.
# - 2 Jeliazkov, Ivan. (2013). Nonparametric Vector Autoregressions: Specification, Estimation, and Inference. Advances in Econometrics. 33. 10.1108/S0731-9053(2013)0000031009.
#
#
# We have taken the trade-off in assumption for this first version correlation model vs a non-parametric approach for simplicity's sake, that current robust python VAR implementations exist, and for illustrative purposes around the concepts, we are addressing.

# %%
# import libraries
from sqlalchemy import create_engine
import pandas as pd
from datetime import datetime
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %%
# load connection string
CONN_STRING_PATH = 'sentinel_conn_string_andrew.txt'

with open(CONN_STRING_PATH, 'r') as fid:
    conn_string = fid.read()
    
# create database connection.
connection = create_engine(conn_string, pool_recycle=3600).connect()

# %% [markdown]
# ## Data EDA
#
# Below we download hourly averages from the `derived_gas_outputs` table from May 1st, 2021 to present (last refreshed 6/24/2021). After downloading the data, we few the first and lasts 5 rows, and perform basic statistics on the data.

# %%
QUERY = """
SELECT 
date_trunc('hour', 
to_timestamp(height_to_unix(d.height))) AS timestamp,
AVG(CAST(gas_fee_cap AS FLOAT)) AS mean_gas_fee_cap,
AVG(CAST(gas_premium AS FLOAT))  as mean_gas_premium,
AVG(CAST(gas_limit AS FLOAT))  as mean_gas_limit,
AVG(CAST(gas_used AS FLOAT))  as mean_gas_used,
AVG(CAST(parent_base_fee AS FLOAT))  as mean_parent_base_fee,
AVG(CAST(base_fee_burn AS FLOAT))  as mean_base_fee_burn,
AVG(CAST(over_estimation_burn AS FLOAT))  as mean_over_estimation_burn,
AVG(CAST(gas_refund AS FLOAT))  as mean_gas_refund,
AVG(CAST(gas_burned AS FLOAT))  as mean_gas_burned
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) > '2021-05-01'
GROUP BY
timestamp
"""
derived_gas_outputs = (pd.read_sql(QUERY, connection))

# %%
derived_gas_outputs.head()
# Out:
#                   timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 0 2021-05-01 00:00:00+00:00      1.560131e+10      1.482218e+07
# 1 2021-05-01 01:00:00+00:00      1.325130e+10      1.038786e+07
# 2 2021-05-01 02:00:00+00:00      1.566131e+10      6.501496e+06
# 3 2021-05-01 03:00:00+00:00      1.295362e+10      7.830208e+06
# 4 2021-05-01 04:00:00+00:00      1.392573e+10      9.203523e+06
#
#    mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 0    4.400210e+07   3.544539e+07          3.287172e+09        1.142042e+17
# 1    4.374094e+07   3.516687e+07          2.875746e+09        9.864674e+16
# 2    4.007360e+07   3.235859e+07          3.391013e+09        1.073700e+17
# 3    4.310044e+07   3.467378e+07          2.724790e+09        9.247733e+16
# 4    4.091478e+07   3.288442e+07          2.757795e+09        8.882479e+16
#
#    mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 0               7.885100e+15     6.147325e+06     2.409388e+06
# 1               7.128347e+15     6.033203e+06     2.540860e+06
# 2               6.432014e+15     5.813149e+06     1.901862e+06
# 3               6.693012e+15     5.940040e+06     2.486627e+06
# 4               6.161389e+15     5.792842e+06     2.237511e+06

# %%
derived_gas_outputs.tail()
# Out:
#                      timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 1307 2021-06-24 11:00:00+00:00      9.729310e+09     851020.913977
# 1308 2021-06-24 12:00:00+00:00      8.637132e+09     464515.963703
# 1309 2021-06-24 13:00:00+00:00      7.145448e+09     234726.809961
# 1310 2021-06-24 14:00:00+00:00      6.832892e+09     242936.034088
# 1311 2021-06-24 15:00:00+00:00      5.058075e+09     268630.042940
#
#       mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 1307    3.987854e+07   3.245945e+07          7.964253e+08        2.525638e+16
# 1308    3.895883e+07   3.173785e+07          5.710872e+08        1.782127e+16
# 1309    4.007577e+07   3.269123e+07          4.294112e+08        1.379294e+16
# 1310    3.942958e+07   3.222096e+07          3.808875e+08        1.209938e+16
# 1311    3.786314e+07   3.113169e+07          1.257613e+08        3.849926e+15
#
#       mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 1307               1.262756e+15     5.832535e+06     1.586561e+06
# 1308               8.403503e+14     5.744803e+06     1.476175e+06
# 1309               6.620091e+14     5.841058e+06     1.543480e+06
# 1310               5.651734e+14     5.775745e+06     1.432873e+06
# 1311               1.575087e+14     5.480057e+06     1.251389e+06

# %%
derived_gas_outputs.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count      1.312000e+03      1.312000e+03    1.312000e+03   1.312000e+03
# mean       8.983541e+09      2.328775e+06    3.997299e+07   3.246528e+07
# std        3.913167e+09      3.062147e+06    1.878227e+06   1.115837e+06
# min        1.401976e+09      1.010942e+05    3.511228e+07   2.811138e+07
# 25%        5.800953e+09      3.373181e+05    3.890736e+07   3.172702e+07
# 50%        9.306854e+09      1.181961e+06    3.982866e+07   3.240706e+07
# 75%        1.193741e+10      3.164546e+06    4.091489e+07   3.315566e+07
# max        2.352814e+10      3.093223e+07    7.809493e+07   3.595985e+07
#
#        mean_parent_base_fee  mean_base_fee_burn  mean_over_estimation_burn  \
# count          1.312000e+03        1.312000e+03               1.312000e+03
# mean           9.363878e+08        3.012481e+16               1.693705e+15
# std            8.594686e+08        2.793292e+16               1.703002e+15
# min            1.016643e+02        2.964737e+09               1.218508e+08
# 25%            2.480073e+08        7.846473e+15               3.674862e+14
# 50%            7.660756e+08        2.421060e+16               1.253736e+15
# 75%            1.242831e+09        3.911089e+16               2.165185e+15
# max            4.889421e+09        1.609283e+17               8.616813e+15
#
#        mean_gas_refund  mean_gas_burned
# count     1.312000e+03     1.312000e+03
# mean      5.785357e+06     1.722346e+06
# std       2.290373e+05     1.318959e+06
# min       4.851994e+06     1.068593e+06
# 25%       5.637719e+06     1.448649e+06
# 50%       5.779302e+06     1.631677e+06
# 75%       5.944722e+06     1.825624e+06
# max       6.683911e+06     4.397566e+07

# %% [markdown]
# We will plot each signal, save for the timestamp, below:

# %%
for i in derived_gas_outputs.columns[1:]:
    derived_gas_outputs.plot(x='timestamp',y=i,kind='line',title=i)

# %% [markdown]
# The data is pretty consistent, stochastic trend save for a several orders of magnitude spike one June 3rd.

# %%
derived_gas_outputs.query('mean_gas_burned > 4000000')
# Out:
#                     timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 795 2021-06-03 03:00:00+00:00      4.101927e+09      1.398642e+07
# 796 2021-06-03 04:00:00+00:00      3.096350e+09      9.181094e+06
# 798 2021-06-03 06:00:00+00:00      1.283277e+10      1.718752e+07
# 799 2021-06-03 07:00:00+00:00      1.594804e+10      7.254430e+06
# 802 2021-06-03 10:00:00+00:00      1.300655e+10      3.993850e+06
#
#      mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 795    7.809493e+07   2.926728e+07          6.466881e+07        1.815174e+15
# 796    5.600891e+07   3.113978e+07          4.549856e+07        1.366301e+15
# 798    4.712814e+07   3.518629e+07          8.726729e+08        3.021975e+16
# 799    4.227274e+07   3.224065e+07          6.913273e+08        2.202691e+16
# 802    4.066726e+07   3.136578e+07          5.078446e+08        1.554188e+16
#
#      mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 795               3.079097e+15     4.851994e+06     4.397566e+07
# 796               7.491868e+14     4.988144e+06     1.988099e+07
# 798               4.739215e+15     5.846984e+06     6.094867e+06
# 799               2.747635e+15     5.512047e+06     4.520038e+06
# 802               2.050818e+15     5.254736e+06     4.046744e+06

# %% [markdown]
# ### Messages calculation mapping
#
# Based on the message cost calculation outliend by Filecoin's official documentation, we will map the data obtained to this calculation.
#
# Filecoin:
# `message_cost_calculation =  GasUsage * BaseFee FIL (burned) + GasLimit * GasPremium FIL (miner reward) + OverEstimationBurn * BaseFee FIL`
#
#
# Our downloaded data:
# `message_cost = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn`

# %%
# create field
derived_gas_outputs['mean_message_cost'] = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_message_cost',kind='line',title='Mean Message Cost')
# Out:
# <AxesSubplot:title={'center':'Mean Message Cost'}, xlabel='timestamp'>

# %% [markdown]
# ### Data processing
#
# We will now remove the timestamp field and examine the data distributions and determine if any transformations are required prior to our VAR modeling.

# %%
timestamps = derived_gas_outputs.timestamp
del derived_gas_outputs['timestamp']
#mean_message_cost = derived_gas_outputs.mean_message_cost # removing because of zeros
#del derived_gas_outputs['mean_message_cost']

# %%
derived_gas_outputs.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We can see from the above historgrams that besides `mean_gas_used` and `mean_gas_refund` our data is not normally distributed and will need to be transformed prior to modeling. We will take the log of the data to reduce the skewness and take the first difference to make the data stationary.

# %%
log_differenced = pd.DataFrame()
## Difference and log values
for i in derived_gas_outputs.columns:
    log_differenced[i +'_log_differenced'] = np.log(derived_gas_outputs[i]).diff()

# %%
log_differenced.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost_log_differenced'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <!-- ### Data Transformations
#
# We will take the log of the data to reduce the skewness and take the first difference to make the data stationary, meaning that the distribution does not change when shifted by tie. -->

# %%
# replace any NA values with zero
log_differenced.dropna(inplace=True)

# %% [markdown]
# As a final check prior to modeling, we will run the Augmented Dickey-Fuller test to ensure that our data is stationary (non-unit root - A unit root is a stochastic trend in a time series). The test's hypothesis are:
#
#
# * $H_O: \textrm{Time series has a unit root}$
# * $H_A: \textrm{Time series does not have a unit root}$

# %%
for i in log_differenced.columns:
    print(i)
    result = adfuller(log_differenced[i].values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] > 0.05:
        decision = "fail to reject - unit root present"
    else:
        decision = "reject, no unit root present"
    print(decision)
    print('----------------------------------')
# Out:
# mean_gas_fee_cap_log_differenced
# ADF Statistic: -27.063839
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_premium_log_differenced
# ADF Statistic: -23.034373
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_limit_log_differenced
# ADF Statistic: -13.101243
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_used_log_differenced
# ADF Statistic: -12.405286
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_parent_base_fee_log_differenced
# ADF Statistic: -16.890696
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_base_fee_burn_log_differenced
# ADF Statistic: -16.868107
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_over_estimation_burn_log_differenced
# ADF Statistic: -15.754533
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_refund_log_differenced
# ADF Statistic: -12.534539
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_burned_log_differenced
# ADF Statistic: -13.535976
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_message_cost_log_differenced
# ADF Statistic: -16.694150
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------

# %% [markdown]
# Based on the Augmented Dickey-Fuller, our preprocessing was successful and none of our univariate time series signals as a unit root. We can now proceed to the VAR model.

# %% [markdown]
# ## Model Fit
#
# To determine the ideal number of lags for our model, we will perform a heuristic SVD. We will fit our model with an autocorrelation between 1 and 15 to ascertain which VAR order has the best Akaike information criterion(AIC) score.
#
# The **Akaike information criterion (AIC)** is an estimator of prediction error, rooted in information theory. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models as a means for model selection.
#
# When a statistical model is used to represent the process that generated the data, the representation will rarely be exact; so some information will be lost by using the model to represent the process. AIC estimates the relative amount of information lost by a given model: the less information a model loses, the higher the quality of that model.
#
# In estimating the amount of information lost by a model, AIC deals with the trade-off between the goodness of fit of the model and the simplicity of the model. In other words, AIC deals with both the risk of overfitting and the risk of underfitting.
#
# Below is the equation for AIC where $\hat L$ is the maximum value of the likelihood function for the model:
#
# $$\mathrm{AIC} \, = \, 2k - 2\ln(\hat L)$$
#
# Given a set of candidate models for the data, the **preferred model is the one with the minimum AIC value, the sign of the data does not matter**. AIC optimizes for the goodness of fit but also includes a penalty for each additional parameter, which discourages overfitting.
#
# <!-- The **Bayesian information criterion (BIC)** is a statistical method for model selection among a group of models; **the model with the lowest BIC is preferred, the sign of the data does not matter**. It is based, in part, on the likelihood function and it is closely related to the Akaike information criterion (AIC).
#
# When fitting models, it is possible to increase the likelihood by adding parameters, but doing so may result in overfitting. Both BIC and AIC attempt to resolve this problem by introducing a penalty term for the number of parameters in the model; the penalty term is larger in BIC than in AIC.
#
# $$\mathrm{BIC} = k\ln(n) - 2\ln(\widehat L)$$
# where
# $\hat L$ = the maximized value of the likelihood function of the model $M$
# $x$ = the observed data;
# $n$ = the number of data points in $x$,
# $k$ = the number of parameters estimated by the model.
#
#
# Several researchers that have studied the two metrics argue that BIC is appropriate for selecting the "true model" (i.e. the process that generated the data) from the set of candidate models, whereas AIC choices the best model amongst the alternatives. Proponents of AIC argue that this issue is negligible because the "true model" is virtually never in the candidate set. For our use cases, we will optimize for the AIC as we know the "true" model of the signal behavior is way too complex to be captured within a VAR model.
#  -->
# Paraphrased sources:
# * https://en.wikipedia.org/wiki/Akaike_information_criterion
# <!-- * https://en.wikipedia.org/wiki/Bayesian_information_criterion -->

# %%
aic = []
for i in range(1,16):
    model = VAR(log_differenced)
    results = model.fit(i)
    aic.append(results.aic)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
plt.figure(figsize=(10, 8))
plt.plot(aic, 'r+')
plt.legend(['AIC'])
plt.xlabel('Autocorrelation Lag')
plt.ylabel('AIC')
plt.title('Plot of sweeps over lag depths over AIC Loss function')
plt.show()

# %% [markdown]
# Based on our analysis, a lag of 10 appears to be the optimal.

# %%
# instantiate the var model object from statsmodels
model = VAR(log_differenced)

# fit model with determined lag values
results = model.fit(10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 24, Jun, 2021
# Time:                     14:20:26
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -60.4770
# Nobs:                     1301.00    HQIC:                  -62.9852
# Log likelihood:           24501.2    FPE:                9.84341e-29
# AIC:                     -64.4913    Det(Omega_mle):     4.66056e-29
# --------------------------------------------------------------------
# Results for equation mean_gas_fee_cap_log_differenced
# ================================================================================================================
#                                                    coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------------
# const                                                -0.000510         0.003972           -0.128           0.898
# L1.mean_gas_fee_cap_log_differenced                  -0.072376         0.042066           -1.721           0.085
# L1.mean_gas_premium_log_differenced                  -0.004461         0.008104           -0.550           0.582
# L1.mean_gas_limit_log_differenced                    -1.444247         0.353196           -4.089           0.000
# L1.mean_gas_used_log_differenced                      1.523412         1.011498            1.506           0.132
# L1.mean_parent_base_fee_log_differenced               0.194746         0.831169            0.234           0.815
# L1.mean_base_fee_burn_log_differenced                -0.083383         1.046845           -0.080           0.937
# L1.mean_over_estimation_burn_log_differenced         -0.995634         0.613420           -1.623           0.105
# L1.mean_gas_refund_log_differenced                    0.534732         0.301879            1.771           0.077
# L1.mean_gas_burned_log_differenced                    0.813021         0.248654            3.270           0.001
# L1.mean_message_cost_log_differenced                  0.476610         0.578795            0.823           0.410
# L2.mean_gas_fee_cap_log_differenced                  -0.084839         0.046274           -1.833           0.067
# L2.mean_gas_premium_log_differenced                  -0.011493         0.009440           -1.217           0.223
# L2.mean_gas_limit_log_differenced                     1.181484         0.443057            2.667           0.008
# L2.mean_gas_used_log_differenced                     -1.018568         1.244361           -0.819           0.413
# L2.mean_parent_base_fee_log_differenced               0.406044         1.012692            0.401           0.688
# L2.mean_base_fee_burn_log_differenced                -0.336519         1.240031           -0.271           0.786
# L2.mean_over_estimation_burn_log_differenced         -1.016388         0.681225           -1.492           0.136
# L2.mean_gas_refund_log_differenced                   -0.083219         0.327332           -0.254           0.799
# L2.mean_gas_burned_log_differenced                    0.634203         0.347261            1.826           0.068
# L2.mean_message_cost_log_differenced                  0.466620         0.593734            0.786           0.432
# L3.mean_gas_fee_cap_log_differenced                  -0.016658         0.046956           -0.355           0.723
# L3.mean_gas_premium_log_differenced                  -0.001007         0.010152           -0.099           0.921
# L3.mean_gas_limit_log_differenced                    -0.729315         0.484820           -1.504           0.133
# L3.mean_gas_used_log_differenced                     -0.745592         1.351233           -0.552           0.581
# L3.mean_parent_base_fee_log_differenced              -0.793022         1.080624           -0.734           0.463
# L3.mean_base_fee_burn_log_differenced                 1.281858         1.324399            0.968           0.333
# L3.mean_over_estimation_burn_log_differenced         -0.444976         0.721382           -0.617           0.537
# L3.mean_gas_refund_log_differenced                    0.680013         0.344364            1.975           0.048
# L3.mean_gas_burned_log_differenced                    0.690484         0.399729            1.727           0.084
# L3.mean_message_cost_log_differenced                 -0.018827         0.611121           -0.031           0.975
# L4.mean_gas_fee_cap_log_differenced                  -0.059367         0.047515           -1.249           0.212
# L4.mean_gas_premium_log_differenced                  -0.006248         0.010511           -0.594           0.552
# L4.mean_gas_limit_log_differenced                     0.540516         0.506788            1.067           0.286
# L4.mean_gas_used_log_differenced                     -1.588779         1.404988           -1.131           0.258
# L4.mean_parent_base_fee_log_differenced              -1.052601         1.128675           -0.933           0.351
# L4.mean_base_fee_burn_log_differenced                 1.449772         1.380657            1.050           0.294
# L4.mean_over_estimation_burn_log_differenced         -0.770401         0.725507           -1.062           0.288
# L4.mean_gas_refund_log_differenced                    0.120321         0.355404            0.339           0.735
# L4.mean_gas_burned_log_differenced                    0.631585         0.427651            1.477           0.140
# L4.mean_message_cost_log_differenced                  0.191129         0.609519            0.314           0.754
# L5.mean_gas_fee_cap_log_differenced                   0.020639         0.047715            0.433           0.665
# L5.mean_gas_premium_log_differenced                  -0.011316         0.010677           -1.060           0.289
# L5.mean_gas_limit_log_differenced                    -0.652295         0.520482           -1.253           0.210
# L5.mean_gas_used_log_differenced                     -1.263017         1.418016           -0.891           0.373
# L5.mean_parent_base_fee_log_differenced              -1.896918         1.145117           -1.657           0.098
# L5.mean_base_fee_burn_log_differenced                 1.898073         1.383072            1.372           0.170
# L5.mean_over_estimation_burn_log_differenced         -1.129852         0.741786           -1.523           0.128
# L5.mean_gas_refund_log_differenced                    0.394051         0.361807            1.089           0.276
# L5.mean_gas_burned_log_differenced                    0.716551         0.444047            1.614           0.107
# L5.mean_message_cost_log_differenced                  0.561696         0.612617            0.917           0.359
# L6.mean_gas_fee_cap_log_differenced                  -0.011586         0.047840           -0.242           0.809
# L6.mean_gas_premium_log_differenced                  -0.014021         0.010698           -1.311           0.190
# L6.mean_gas_limit_log_differenced                    -0.699867         0.518031           -1.351           0.177
# L6.mean_gas_used_log_differenced                     -1.289478         1.412862           -0.913           0.361
# L6.mean_parent_base_fee_log_differenced              -2.506332         1.143175           -2.192           0.028
# L6.mean_base_fee_burn_log_differenced                 2.348804         1.378675            1.704           0.088
# L6.mean_over_estimation_burn_log_differenced          0.197402         0.740555            0.267           0.790
# L6.mean_gas_refund_log_differenced                   -0.024785         0.361929           -0.068           0.945
# L6.mean_gas_burned_log_differenced                    0.043321         0.440032            0.098           0.922
# L6.mean_message_cost_log_differenced                 -0.017758         0.611167           -0.029           0.977
# L7.mean_gas_fee_cap_log_differenced                   0.006129         0.047631            0.129           0.898
# L7.mean_gas_premium_log_differenced                  -0.010800         0.010618           -1.017           0.309
# L7.mean_gas_limit_log_differenced                    -0.932830         0.501954           -1.858           0.063
# L7.mean_gas_used_log_differenced                      0.835675         1.387143            0.602           0.547
# L7.mean_parent_base_fee_log_differenced              -0.811269         1.119413           -0.725           0.469
# L7.mean_base_fee_burn_log_differenced                -0.503644         1.350485           -0.373           0.709
# L7.mean_over_estimation_burn_log_differenced          0.113275         0.717262            0.158           0.875
# L7.mean_gas_refund_log_differenced                    0.491417         0.355499            1.382           0.167
# L7.mean_gas_burned_log_differenced                   -0.544414         0.414929           -1.312           0.189
# L7.mean_message_cost_log_differenced                  0.600563         0.604393            0.994           0.320
# L8.mean_gas_fee_cap_log_differenced                   0.063918         0.047160            1.355           0.175
# L8.mean_gas_premium_log_differenced                  -0.009805         0.010219           -0.959           0.337
# L8.mean_gas_limit_log_differenced                    -0.766740         0.478155           -1.604           0.109
# L8.mean_gas_used_log_differenced                      0.190540         1.315357            0.145           0.885
# L8.mean_parent_base_fee_log_differenced              -0.913885         1.063312           -0.859           0.390
# L8.mean_base_fee_burn_log_differenced                 0.647701         1.289547            0.502           0.615
# L8.mean_over_estimation_burn_log_differenced          1.102450         0.701492            1.572           0.116
# L8.mean_gas_refund_log_differenced                    0.344608         0.345925            0.996           0.319
# L8.mean_gas_burned_log_differenced                   -0.513614         0.380696           -1.349           0.177
# L8.mean_message_cost_log_differenced                 -0.426379         0.603425           -0.707           0.480
# L9.mean_gas_fee_cap_log_differenced                  -0.019491         0.046521           -0.419           0.675
# L9.mean_gas_premium_log_differenced                  -0.008987         0.009531           -0.943           0.346
# L9.mean_gas_limit_log_differenced                    -0.885893         0.427966           -2.070           0.038
# L9.mean_gas_used_log_differenced                      0.213541         1.158728            0.184           0.854
# L9.mean_parent_base_fee_log_differenced              -0.834686         0.961900           -0.868           0.386
# L9.mean_base_fee_burn_log_differenced                -0.244626         1.177403           -0.208           0.835
# L9.mean_over_estimation_burn_log_differenced         -0.010625         0.663473           -0.016           0.987
# L9.mean_gas_refund_log_differenced                    0.347607         0.331042            1.050           0.294
# L9.mean_gas_burned_log_differenced                   -0.415120         0.337384           -1.230           0.219
# L9.mean_message_cost_log_differenced                  0.550364         0.590620            0.932           0.351
# L10.mean_gas_fee_cap_log_differenced                 -0.019773         0.043592           -0.454           0.650
# L10.mean_gas_premium_log_differenced                 -0.004493         0.008112           -0.554           0.580
# L10.mean_gas_limit_log_differenced                   -0.173332         0.362887           -0.478           0.633
# L10.mean_gas_used_log_differenced                    -1.062218         0.917082           -1.158           0.247
# L10.mean_parent_base_fee_log_differenced             -1.111834         0.783259           -1.419           0.156
# L10.mean_base_fee_burn_log_differenced                0.994499         1.001532            0.993           0.321
# L10.mean_over_estimation_burn_log_differenced         0.245796         0.615039            0.400           0.689
# L10.mean_gas_refund_log_differenced                   0.232503         0.298142            0.780           0.435
# L10.mean_gas_burned_log_differenced                  -0.157549         0.241010           -0.654           0.513
# L10.mean_message_cost_log_differenced                -0.065139         0.574427           -0.113           0.910
# ================================================================================================================
#
# Results for equation mean_gas_premium_log_differenced
# ================================================================================================================
#                                                    coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------------
# const                                                -0.004852         0.016405           -0.296           0.767
# L1.mean_gas_fee_cap_log_differenced                   1.110543         0.173721            6.393           0.000
# L1.mean_gas_premium_log_differenced                  -0.582735         0.033466          -17.413           0.000
# L1.mean_gas_limit_log_differenced                    -0.131631         1.458600           -0.090           0.928
# L1.mean_gas_used_log_differenced                     -0.178647         4.177206           -0.043           0.966
# L1.mean_parent_base_fee_log_differenced               0.129948         3.432496            0.038           0.970
# L1.mean_base_fee_burn_log_differenced                 0.092957         4.323178            0.022           0.983
# L1.mean_over_estimation_burn_log_differenced         -1.310970         2.533254           -0.518           0.605
# L1.mean_gas_refund_log_differenced                    0.859917         1.246678            0.690           0.490
# L1.mean_gas_burned_log_differenced                    1.648151         1.026872            1.605           0.108
# L1.mean_message_cost_log_differenced                  0.545653         2.390263            0.228           0.819
# L2.mean_gas_fee_cap_log_differenced                   0.612663         0.191100            3.206           0.001
# L2.mean_gas_premium_log_differenced                  -0.479366         0.038984          -12.296           0.000
# L2.mean_gas_limit_log_differenced                     1.060232         1.829703            0.579           0.562
# L2.mean_gas_used_log_differenced                     -0.088131         5.138866           -0.017           0.986
# L2.mean_parent_base_fee_log_differenced              -0.189959         4.182137           -0.045           0.964
# L2.mean_base_fee_burn_log_differenced                 2.069963         5.120983            0.404           0.686
# L2.mean_over_estimation_burn_log_differenced          2.969196         2.813271            1.055           0.291
# L2.mean_gas_refund_log_differenced                   -0.328414         1.351788           -0.243           0.808
# L2.mean_gas_burned_log_differenced                   -0.122305         1.434093           -0.085           0.932
# L2.mean_message_cost_log_differenced                 -2.406901         2.451955           -0.982           0.326
# L3.mean_gas_fee_cap_log_differenced                   0.803171         0.193914            4.142           0.000
# L3.mean_gas_premium_log_differenced                  -0.348565         0.041923           -8.314           0.000
# L3.mean_gas_limit_log_differenced                     0.530962         2.002173            0.265           0.791
# L3.mean_gas_used_log_differenced                      0.102048         5.580216            0.018           0.985
# L3.mean_parent_base_fee_log_differenced               3.867266         4.462678            0.867           0.386
# L3.mean_base_fee_burn_log_differenced                -3.610121         5.469402           -0.660           0.509
# L3.mean_over_estimation_burn_log_differenced         -5.317183         2.979108           -1.785           0.074
# L3.mean_gas_refund_log_differenced                   -0.040841         1.422126           -0.029           0.977
# L3.mean_gas_burned_log_differenced                    3.593528         1.650770            2.177           0.029
# L3.mean_message_cost_log_differenced                  2.462135         2.523760            0.976           0.329
# L4.mean_gas_fee_cap_log_differenced                   0.321349         0.196223            1.638           0.101
# L4.mean_gas_premium_log_differenced                  -0.252124         0.043406           -5.809           0.000
# L4.mean_gas_limit_log_differenced                    -2.339883         2.092895           -1.118           0.264
# L4.mean_gas_used_log_differenced                     -1.911122         5.802209           -0.329           0.742
# L4.mean_parent_base_fee_log_differenced              -2.305535         4.661116           -0.495           0.621
# L4.mean_base_fee_burn_log_differenced                 8.116616         5.701729            1.424           0.155
# L4.mean_over_estimation_burn_log_differenced          1.913505         2.996144            0.639           0.523
# L4.mean_gas_refund_log_differenced                    0.360059         1.467722            0.245           0.806
# L4.mean_gas_burned_log_differenced                    2.593188         1.766079            1.468           0.142
# L4.mean_message_cost_log_differenced                 -3.846698         2.517145           -1.528           0.126
# L5.mean_gas_fee_cap_log_differenced                   0.438888         0.197051            2.227           0.026
# L5.mean_gas_premium_log_differenced                  -0.203952         0.044094           -4.625           0.000
# L5.mean_gas_limit_log_differenced                    -2.102535         2.149445           -0.978           0.328
# L5.mean_gas_used_log_differenced                      0.014254         5.856012            0.002           0.998
# L5.mean_parent_base_fee_log_differenced              -2.070317         4.729015           -0.438           0.662
# L5.mean_base_fee_burn_log_differenced                 0.161211         5.711702            0.028           0.977
# L5.mean_over_estimation_burn_log_differenced         -3.829238         3.063371           -1.250           0.211
# L5.mean_gas_refund_log_differenced                   -0.331733         1.494161           -0.222           0.824
# L5.mean_gas_burned_log_differenced                    1.655104         1.833792            0.903           0.367
# L5.mean_message_cost_log_differenced                  2.830036         2.529937            1.119           0.263
# L6.mean_gas_fee_cap_log_differenced                   0.063968         0.197568            0.324           0.746
# L6.mean_gas_premium_log_differenced                  -0.126390         0.044178           -2.861           0.004
# L6.mean_gas_limit_log_differenced                    -3.549299         2.139326           -1.659           0.097
# L6.mean_gas_used_log_differenced                     -0.808698         5.834730           -0.139           0.890
# L6.mean_parent_base_fee_log_differenced              -4.185575         4.720998           -0.887           0.375
# L6.mean_base_fee_burn_log_differenced                 4.206727         5.693547            0.739           0.460
# L6.mean_over_estimation_burn_log_differenced          0.118112         3.058289            0.039           0.969
# L6.mean_gas_refund_log_differenced                    0.291903         1.494665            0.195           0.845
# L6.mean_gas_burned_log_differenced                    0.726328         1.817208            0.400           0.689
# L6.mean_message_cost_log_differenced                 -0.065727         2.523951           -0.026           0.979
# L7.mean_gas_fee_cap_log_differenced                   0.118599         0.196702            0.603           0.547
# L7.mean_gas_premium_log_differenced                  -0.105944         0.043849           -2.416           0.016
# L7.mean_gas_limit_log_differenced                    -4.887821         2.072930           -2.358           0.018
# L7.mean_gas_used_log_differenced                      7.653018         5.728517            1.336           0.182
# L7.mean_parent_base_fee_log_differenced               5.303821         4.622866            1.147           0.251
# L7.mean_base_fee_burn_log_differenced                -5.209819         5.577130           -0.934           0.350
# L7.mean_over_estimation_burn_log_differenced          0.673036         2.962095            0.227           0.820
# L7.mean_gas_refund_log_differenced                    2.364845         1.468111            1.611           0.107
# L7.mean_gas_burned_log_differenced                    0.456848         1.713542            0.267           0.790
# L7.mean_message_cost_log_differenced                 -0.374655         2.495976           -0.150           0.881
# L8.mean_gas_fee_cap_log_differenced                   0.053578         0.194759            0.275           0.783
# L8.mean_gas_premium_log_differenced                  -0.069244         0.042204           -1.641           0.101
# L8.mean_gas_limit_log_differenced                    -3.915230         1.974647           -1.983           0.047
# L8.mean_gas_used_log_differenced                      6.039890         5.432061            1.112           0.266
# L8.mean_parent_base_fee_log_differenced               2.859413         4.391183            0.651           0.515
# L8.mean_base_fee_burn_log_differenced                -6.436324         5.325473           -1.209           0.227
# L8.mean_over_estimation_burn_log_differenced         -1.746285         2.896969           -0.603           0.547
# L8.mean_gas_refund_log_differenced                    0.240990         1.428574            0.169           0.866
# L8.mean_gas_burned_log_differenced                   -0.451276         1.572169           -0.287           0.774
# L8.mean_message_cost_log_differenced                  2.699305         2.491979            1.083           0.279
# L9.mean_gas_fee_cap_log_differenced                  -0.049874         0.192118           -0.260           0.795
# L9.mean_gas_premium_log_differenced                  -0.038970         0.039362           -0.990           0.322
# L9.mean_gas_limit_log_differenced                    -3.571356         1.767380           -2.021           0.043
# L9.mean_gas_used_log_differenced                      0.214364         4.785227            0.045           0.964
# L9.mean_parent_base_fee_log_differenced              -1.662877         3.972379           -0.419           0.676
# L9.mean_base_fee_burn_log_differenced                 2.637068         4.862348            0.542           0.588
# L9.mean_over_estimation_burn_log_differenced          1.578412         2.739959            0.576           0.565
# L9.mean_gas_refund_log_differenced                    0.978613         1.367114            0.716           0.474
# L9.mean_gas_burned_log_differenced                    0.144325         1.393301            0.104           0.917
# L9.mean_message_cost_log_differenced                 -1.252505         2.439098           -0.514           0.608
# L10.mean_gas_fee_cap_log_differenced                  0.074193         0.180022            0.412           0.680
# L10.mean_gas_premium_log_differenced                 -0.016942         0.033501           -0.506           0.613
# L10.mean_gas_limit_log_differenced                    0.726894         1.498621            0.485           0.628
# L10.mean_gas_used_log_differenced                    -2.507536         3.787295           -0.662           0.508
# L10.mean_parent_base_fee_log_differenced             -2.968533         3.234642           -0.918           0.359
# L10.mean_base_fee_burn_log_differenced                5.399701         4.136049            1.306           0.192
# L10.mean_over_estimation_burn_log_differenced         1.171540         2.539940            0.461           0.645
# L10.mean_gas_refund_log_differenced                  -1.476444         1.231242           -1.199           0.230
# L10.mean_gas_burned_log_differenced                   0.305945         0.995306            0.307           0.759
# L10.mean_message_cost_log_differenced                -1.809751         2.372224           -0.763           0.446
# ================================================================================================================
#
# Results for equation mean_gas_limit_log_differenced
# ================================================================================================================
#                                                    coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------------
# const                                                -0.000140         0.000914           -0.153           0.878
# L1.mean_gas_fee_cap_log_differenced                   0.012840         0.009674            1.327           0.184
# L1.mean_gas_premium_log_differenced                   0.001954         0.001864            1.049           0.294
# L1.mean_gas_limit_log_differenced                    -0.580401         0.081224           -7.146           0.000
# L1.mean_gas_used_log_differenced                      0.154753         0.232614            0.665           0.506
# L1.mean_parent_base_fee_log_differenced               0.138799         0.191144            0.726           0.468
# L1.mean_base_fee_burn_log_differenced                -0.081769         0.240743           -0.340           0.734
# L1.mean_over_estimation_burn_log_differenced          0.010121         0.141068            0.072           0.943
# L1.mean_gas_refund_log_differenced                   -0.086427         0.069423           -1.245           0.213
# L1.mean_gas_burned_log_differenced                    0.075963         0.057183            1.328           0.184
# L1.mean_message_cost_log_differenced                 -0.033408         0.133106           -0.251           0.802
# L2.mean_gas_fee_cap_log_differenced                  -0.007571         0.010642           -0.711           0.477
# L2.mean_gas_premium_log_differenced                   0.003309         0.002171            1.524           0.127
# L2.mean_gas_limit_log_differenced                    -0.629424         0.101890           -6.177           0.000
# L2.mean_gas_used_log_differenced                      0.168674         0.286166            0.589           0.556
# L2.mean_parent_base_fee_log_differenced               0.136440         0.232889            0.586           0.558
# L2.mean_base_fee_burn_log_differenced                 0.011545         0.285170            0.040           0.968
# L2.mean_over_estimation_burn_log_differenced         -0.087018         0.156662           -0.555           0.579
# L2.mean_gas_refund_log_differenced                    0.027496         0.075277            0.365           0.715
# L2.mean_gas_burned_log_differenced                    0.113939         0.079860            1.427           0.154
# L2.mean_message_cost_log_differenced                 -0.028814         0.136541           -0.211           0.833
# L3.mean_gas_fee_cap_log_differenced                   0.001729         0.010798            0.160           0.873
# L3.mean_gas_premium_log_differenced                   0.002810         0.002335            1.204           0.229
# L3.mean_gas_limit_log_differenced                    -0.167148         0.111494           -1.499           0.134
# L3.mean_gas_used_log_differenced                     -0.051780         0.310743           -0.167           0.868
# L3.mean_parent_base_fee_log_differenced               0.313410         0.248511            1.261           0.207
# L3.mean_base_fee_burn_log_differenced                -0.240489         0.304573           -0.790           0.430
# L3.mean_over_estimation_burn_log_differenced         -0.375727         0.165896           -2.265           0.024
# L3.mean_gas_refund_log_differenced                   -0.026505         0.079193           -0.335           0.738
# L3.mean_gas_burned_log_differenced                    0.207894         0.091926            2.262           0.024
# L3.mean_message_cost_log_differenced                  0.150231         0.140540            1.069           0.285
# L4.mean_gas_fee_cap_log_differenced                  -0.001423         0.010927           -0.130           0.896
# L4.mean_gas_premium_log_differenced                   0.003271         0.002417            1.353           0.176
# L4.mean_gas_limit_log_differenced                    -0.309378         0.116546           -2.655           0.008
# L4.mean_gas_used_log_differenced                     -0.220608         0.323105           -0.683           0.495
# L4.mean_parent_base_fee_log_differenced               0.245971         0.259562            0.948           0.343
# L4.mean_base_fee_burn_log_differenced                 0.171324         0.317510            0.540           0.589
# L4.mean_over_estimation_burn_log_differenced         -0.278048         0.166845           -1.667           0.096
# L4.mean_gas_refund_log_differenced                    0.192115         0.081732            2.351           0.019
# L4.mean_gas_burned_log_differenced                    0.332750         0.098347            3.383           0.001
# L4.mean_message_cost_log_differenced                 -0.069991         0.140171           -0.499           0.618
# L5.mean_gas_fee_cap_log_differenced                   0.009008         0.010973            0.821           0.412
# L5.mean_gas_premium_log_differenced                  -0.000841         0.002455           -0.343           0.732
# L5.mean_gas_limit_log_differenced                    -0.197220         0.119695           -1.648           0.099
# L5.mean_gas_used_log_differenced                     -0.241236         0.326101           -0.740           0.459
# L5.mean_parent_base_fee_log_differenced               0.157059         0.263343            0.596           0.551
# L5.mean_base_fee_burn_log_differenced                 0.108762         0.318065            0.342           0.732
# L5.mean_over_estimation_burn_log_differenced         -0.313648         0.170589           -1.839           0.066
# L5.mean_gas_refund_log_differenced                    0.145635         0.083205            1.750           0.080
# L5.mean_gas_burned_log_differenced                    0.259409         0.102118            2.540           0.011
# L5.mean_message_cost_log_differenced                  0.023969         0.140884            0.170           0.865
# L6.mean_gas_fee_cap_log_differenced                   0.020158         0.011002            1.832           0.067
# L6.mean_gas_premium_log_differenced                  -0.004413         0.002460           -1.794           0.073
# L6.mean_gas_limit_log_differenced                    -0.105061         0.119132           -0.882           0.378
# L6.mean_gas_used_log_differenced                     -0.501721         0.324916           -1.544           0.123
# L6.mean_parent_base_fee_log_differenced              -0.070298         0.262896           -0.267           0.789
# L6.mean_base_fee_burn_log_differenced                 0.193738         0.317054            0.611           0.541
# L6.mean_over_estimation_burn_log_differenced         -0.245548         0.170306           -1.442           0.149
# L6.mean_gas_refund_log_differenced                    0.166693         0.083233            2.003           0.045
# L6.mean_gas_burned_log_differenced                    0.171404         0.101194            1.694           0.090
# L6.mean_message_cost_log_differenced                  0.060388         0.140550            0.430           0.667
# L7.mean_gas_fee_cap_log_differenced                   0.011083         0.010954            1.012           0.312
# L7.mean_gas_premium_log_differenced                  -0.000867         0.002442           -0.355           0.723
# L7.mean_gas_limit_log_differenced                    -0.233278         0.115434           -2.021           0.043
# L7.mean_gas_used_log_differenced                     -0.239293         0.319002           -0.750           0.453
# L7.mean_parent_base_fee_log_differenced              -0.022262         0.257432           -0.086           0.931
# L7.mean_base_fee_burn_log_differenced                 0.313959         0.310572            1.011           0.312
# L7.mean_over_estimation_burn_log_differenced          0.050241         0.164949            0.305           0.761
# L7.mean_gas_refund_log_differenced                    0.157982         0.081754            1.932           0.053
# L7.mean_gas_burned_log_differenced                    0.124521         0.095421            1.305           0.192
# L7.mean_message_cost_log_differenced                 -0.171902         0.138992           -1.237           0.216
# L8.mean_gas_fee_cap_log_differenced                  -0.000545         0.010845           -0.050           0.960
# L8.mean_gas_premium_log_differenced                  -0.000741         0.002350           -0.315           0.753
# L8.mean_gas_limit_log_differenced                    -0.273691         0.109961           -2.489           0.013
# L8.mean_gas_used_log_differenced                     -0.123529         0.302493           -0.408           0.683
# L8.mean_parent_base_fee_log_differenced              -0.051915         0.244530           -0.212           0.832
# L8.mean_base_fee_burn_log_differenced                 0.110077         0.296558            0.371           0.711
# L8.mean_over_estimation_burn_log_differenced         -0.108558         0.161322           -0.673           0.501
# L8.mean_gas_refund_log_differenced                    0.102507         0.079552            1.289           0.198
# L8.mean_gas_burned_log_differenced                    0.081621         0.087549            0.932           0.351
# L8.mean_message_cost_log_differenced                  0.029314         0.138770            0.211           0.833
# L9.mean_gas_fee_cap_log_differenced                   0.005092         0.010698            0.476           0.634
# L9.mean_gas_premium_log_differenced                   0.000203         0.002192            0.093           0.926
# L9.mean_gas_limit_log_differenced                    -0.126093         0.098419           -1.281           0.200
# L9.mean_gas_used_log_differenced                     -0.435421         0.266473           -1.634           0.102
# L9.mean_parent_base_fee_log_differenced              -0.197762         0.221208           -0.894           0.371
# L9.mean_base_fee_burn_log_differenced                 0.246884         0.270768            0.912           0.362
# L9.mean_over_estimation_burn_log_differenced         -0.194766         0.152579           -1.276           0.202
# L9.mean_gas_refund_log_differenced                    0.132291         0.076130            1.738           0.082
# L9.mean_gas_burned_log_differenced                    0.118155         0.077588            1.523           0.128
# L9.mean_message_cost_log_differenced                  0.070235         0.135825            0.517           0.605
# L10.mean_gas_fee_cap_log_differenced                 -0.027371         0.010025           -2.730           0.006
# L10.mean_gas_premium_log_differenced                  0.003678         0.001866            1.971           0.049
# L10.mean_gas_limit_log_differenced                   -0.232832         0.083453           -2.790           0.005
# L10.mean_gas_used_log_differenced                    -0.014140         0.210902           -0.067           0.947
# L10.mean_parent_base_fee_log_differenced             -0.062018         0.180126           -0.344           0.731
# L10.mean_base_fee_burn_log_differenced                0.064774         0.230323            0.281           0.779
# L10.mean_over_estimation_burn_log_differenced        -0.087702         0.141441           -0.620           0.535
# L10.mean_gas_refund_log_differenced                   0.068071         0.068564            0.993           0.321
# L10.mean_gas_burned_log_differenced                   0.027169         0.055425            0.490           0.624
# L10.mean_message_cost_log_differenced                 0.046752         0.132101            0.354           0.723
# ================================================================================================================
#
# Results for equation mean_gas_used_log_differenced
# ================================================================================================================
#                                                    coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------------------------------
# const                                                -0.000098         0.000718           -0.136           0.892
# L1.mean_gas_fee_cap_log_differenced                   0.006127         0.007602            0.806           0.420
# L1.mean_gas_premium_log_differenced                   0.002348         0.001464            1.603           0.109
# L1.mean_gas_limit_log_differenced                     0.225523         0.063828            3.533           0.000
# L1.mean_gas_used_log_differenced                     -0.546063         0.182794           -2.987           0.003
# L1.mean_parent_base_fee_log_differenced               0.160585         0.150205            1.069           0.285
# L1.mean_base_fee_burn_log_differenced                 0.011406         0.189181            0.060           0.952
# L1.mean_over_estimation_burn_log_differenced         -0.068174         0.110855           -0.615           0.539
# L1.mean_gas_refund_log_differenced                   -0.045563         0.054554           -0.835           0.404
# L1.mean_gas_burned_log_differenced                    0.071393         0.044936            1.589           0.112
# L1.mean_message_cost_log_differenced                 -0.050563         0.104597           -0.483           0.629
# L2.mean_gas_fee_cap_log_differenced                  -0.009706         0.008363           -1.161           0.246
# L2.mean_gas_premium_log_differenced                   0.005185         0.001706            3.039           0.002
# L2.mean_gas_limit_log_differenced                     0.140622         0.080067            1.756           0.079
# L2.mean_gas_used_log_differenced                     -0.436973         0.224876           -1.943           0.052
# L2.mean_parent_base_fee_log_differenced               0.210109         0.183009            1.148           0.251
# L2.mean_base_fee_burn_log_differenced                -0.043087         0.224093           -0.192           0.848
# L2.mean_over_estimation_burn_log_differenced         -0.136314         0.123108           -1.107           0.268
# L2.mean_gas_refund_log_differenced                   -0.034665         0.059154           -0.586           0.558
# L2.mean_gas_burned_log_differenced                    0.118355         0.062756            1.886           0.059
# L2.mean_message_cost_log_differenced                 -0.014904         0.107297           -0.139           0.890
# L3.mean_gas_fee_cap_log_differenced                  -0.002562         0.008486           -0.302           0.763
# L3.mean_gas_premium_log_differenced                   0.003662         0.001835            1.996           0.046
# L3.mean_gas_limit_log_differenced                     0.226468         0.087615            2.585           0.010
# L3.mean_gas_used_log_differenced                     -0.434951         0.244189           -1.781           0.075
# L3.mean_parent_base_fee_log_differenced               0.288829         0.195286            1.479           0.139
# L3.mean_base_fee_burn_log_differenced                -0.184452         0.239340           -0.771           0.441
# L3.mean_over_estimation_burn_log_differenced         -0.280910         0.130365           -2.155           0.031
# L3.mean_gas_refund_log_differenced                   -0.010519         0.062232           -0.169           0.866
# L3.mean_gas_burned_log_differenced                    0.166345         0.072237            2.303           0.021
# L3.mean_message_cost_log_differenced                  0.087618         0.110439            0.793           0.428
# L4.mean_gas_fee_cap_log_differenced                   0.001414         0.008587            0.165           0.869
# L4.mean_gas_premium_log_differenced                   0.003653         0.001899            1.923           0.054
# L4.mean_gas_limit_log_differenced                     0.108617         0.091585            1.186           0.236
# L4.mean_gas_used_log_differenced                     -0.545642         0.253904           -2.149           0.032
# L4.mean_parent_base_fee_log_differenced               0.119947         0.203969            0.588           0.556
# L4.mean_base_fee_burn_log_differenced                 0.180021         0.249506            0.722           0.471
# L4.mean_over_estimation_burn_log_differenced         -0.188831         0.131111           -1.440           0.150
# L4.mean_gas_refund_log_differenced                    0.111635         0.064227            1.738           0.082
# L4.mean_gas_burned_log_differenced                    0.226379         0.077283            2.929           0.003
# L4.mean_message_cost_log_differenced                 -0.056035         0.110150           -0.509           0.611
# L5.mean_gas_fee_cap_log_differenced                   0.007349         0.008623            0.852           0.394
# L5.mean_gas_premium_log_differenced                   0.001103         0.001930            0.572           0.567
# L5.mean_gas_limit_log_differenced                     0.057295         0.094059            0.609           0.542
# L5.mean_gas_used_log_differenced                     -0.398031         0.256258           -1.553           0.120
# L5.mean_parent_base_fee_log_differenced               0.100761         0.206941            0.487           0.626
# L5.mean_base_fee_burn_log_differenced                 0.091346         0.249943            0.365           0.715
# L5.mean_over_estimation_burn_log_differenced         -0.208504         0.134052           -1.555           0.120
# L5.mean_gas_refund_log_differenced                    0.101528         0.065384            1.553           0.120
# L5.mean_gas_burned_log_differenced                    0.186640         0.080246            2.326           0.020
# L5.mean_message_cost_log_differenced                  0.008190         0.110710            0.074           0.941
# L6.mean_gas_fee_cap_log_differenced                   0.013830         0.008646            1.600           0.110
# L6.mean_gas_premium_log_differenced                  -0.002143         0.001933           -1.108           0.268
# L6.mean_gas_limit_log_differenced                     0.099212         0.093616            1.060           0.289
# L6.mean_gas_used_log_differenced                     -0.529539         0.255327           -2.074           0.038
# L6.mean_parent_base_fee_log_differenced              -0.097468         0.206590           -0.472           0.637
# L6.mean_base_fee_burn_log_differenced                 0.217571         0.249148            0.873           0.383
# L6.mean_over_estimation_burn_log_differenced         -0.113329         0.133830           -0.847           0.397
# L6.mean_gas_refund_log_differenced                    0.084349         0.065406            1.290           0.197
# L6.mean_gas_burned_log_differenced                    0.111775         0.079521            1.406           0.160
# L6.mean_message_cost_log_differenced                 -0.004071         0.110448           -0.037           0.971
# L7.mean_gas_fee_cap_log_differenced                  -0.000797         0.008608           -0.093           0.926
# L7.mean_gas_premium_log_differenced                   0.000708         0.001919            0.369           0.712
# L7.mean_gas_limit_log_differenced                    -0.142582         0.090711           -1.572           0.116
# L7.mean_gas_used_log_differenced                     -0.276763         0.250679           -1.104           0.270
# L7.mean_parent_base_fee_log_differenced              -0.095212         0.202296           -0.471           0.638
# L7.mean_base_fee_burn_log_differenced                 0.276038         0.244054            1.131           0.258
# L7.mean_over_estimation_burn_log_differenced          0.045345         0.129621            0.350           0.726
# L7.mean_gas_refund_log_differenced                    0.112345         0.064244            1.749           0.080
# L7.mean_gas_burned_log_differenced                    0.089651         0.074984            1.196           0.232
# L7.mean_message_cost_log_differenced                 -0.113325         0.109223           -1.038           0.299
# L8.mean_gas_fee_cap_log_differenced                   0.004285         0.008523            0.503           0.615
# L8.mean_gas_premium_log_differenced                   0.000783         0.001847            0.424           0.671
# L8.mean_gas_limit_log_differenced                    -0.265599         0.086410           -3.074           0.002
# L8.mean_gas_used_log_differenced                     -0.045897         0.237706           -0.193           0.847
# L8.mean_parent_base_fee_log_differenced              -0.135960         0.192157           -0.708           0.479
# L8.mean_base_fee_burn_log_differenced                 0.261933         0.233042            1.124           0.261
# L8.mean_over_estimation_burn_log_differenced          0.100463         0.126771            0.792           0.428
# L8.mean_gas_refund_log_differenced                    0.014261         0.062514            0.228           0.820
# L8.mean_gas_burned_log_differenced                    0.035942         0.068798            0.522           0.601
# L8.mean_message_cost_log_differenced                 -0.113136         0.109049           -1.037           0.300
# L9.mean_gas_fee_cap_log_differenced                   0.000978         0.008407            0.116           0.907
# L9.mean_gas_premium_log_differenced                   0.000603         0.001722            0.350           0.726
# L9.mean_gas_limit_log_differenced                    -0.113715         0.077340           -1.470           0.141
# L9.mean_gas_used_log_differenced                     -0.276879         0.209401           -1.322           0.186
# L9.mean_parent_base_fee_log_differenced              -0.209155         0.173831           -1.203           0.229
# L9.mean_base_fee_burn_log_differenced                 0.172205         0.212775            0.809           0.418
# L9.mean_over_estimation_burn_log_differenced         -0.066028         0.119900           -0.551           0.582
# L9.mean_gas_refund_log_differenced                    0.063268         0.059825            1.058           0.290
# L9.mean_gas_burned_log_differenced                    0.028936         0.060971            0.475           0.635
# L9.mean_message_cost_log_differenced                  0.050518         0.106734            0.473           0.636
# L10.mean_gas_fee_cap_log_differenced                 -0.013425         0.007878           -1.704           0.088
# L10.mean_gas_premium_log_differenced                  0.001966         0.001466            1.341           0.180
# L10.mean_gas_limit_log_differenced                   -0.256840         0.065579           -3.916           0.000
# L10.mean_gas_used_log_differenced                    -0.087965         0.165731           -0.531           0.596
# L10.mean_parent_base_fee_log_differenced             -0.225323         0.141547           -1.592           0.111
# L10.mean_base_fee_burn_log_differenced                0.188584         0.180993            1.042           0.297
# L10.mean_over_estimation_burn_log_differenced         0.048652         0.111147            0.438           0.662
# L10.mean_gas_refund_log_differenced                   0.070885         0.053879            1.316           0.188
# ...
# ----------------------------------------------------------------------------------------------------------------
# const                                                -0.003357         0.024579           -0.137           0.891
# L1.mean_gas_fee_cap_log_differenced                  -2.597592         0.260278           -9.980           0.000
# L1.mean_gas_premium_log_differenced                   0.124961         0.050141            2.492           0.013
# L1.mean_gas_limit_log_differenced                    -9.042447         2.185354           -4.138           0.000
# L1.mean_gas_used_log_differenced                     14.493597         6.258520            2.316           0.021
# L1.mean_parent_base_fee_log_differenced               6.230094         5.142754            1.211           0.226
# L1.mean_base_fee_burn_log_differenced               -11.310098         6.477222           -1.746           0.081
# L1.mean_over_estimation_burn_log_differenced          6.584567         3.795460            1.735           0.083
# L1.mean_gas_refund_log_differenced                    8.813338         1.867842            4.718           0.000
# L1.mean_gas_burned_log_differenced                   -4.787493         1.538516           -3.112           0.002
# L1.mean_message_cost_log_differenced                 -0.089574         3.581224           -0.025           0.980
# L2.mean_gas_fee_cap_log_differenced                  -0.423541         0.286317           -1.479           0.139
# L2.mean_gas_premium_log_differenced                   0.056525         0.058408            0.968           0.333
# L2.mean_gas_limit_log_differenced                     3.400652         2.741361            1.240           0.215
# L2.mean_gas_used_log_differenced                      4.172908         7.699332            0.542           0.588
# L2.mean_parent_base_fee_log_differenced               7.716452         6.265908            1.231           0.218
# L2.mean_base_fee_burn_log_differenced               -24.041991         7.672537           -3.134           0.002
# L2.mean_over_estimation_burn_log_differenced        -10.261640         4.214998           -2.435           0.015
# L2.mean_gas_refund_log_differenced                    3.369431         2.025324            1.664           0.096
# L2.mean_gas_burned_log_differenced                   -2.837979         2.148637           -1.321           0.187
# L2.mean_message_cost_log_differenced                 13.205208         3.673654            3.595           0.000
# L3.mean_gas_fee_cap_log_differenced                  -0.657043         0.290533           -2.262           0.024
# L3.mean_gas_premium_log_differenced                   0.117449         0.062811            1.870           0.062
# L3.mean_gas_limit_log_differenced                    -1.302510         2.999766           -0.434           0.664
# L3.mean_gas_used_log_differenced                      4.549434         8.360586            0.544           0.586
# L3.mean_parent_base_fee_log_differenced               4.830403         6.686230            0.722           0.470
# L3.mean_base_fee_burn_log_differenced               -11.080365         8.194558           -1.352           0.176
# L3.mean_over_estimation_burn_log_differenced         -5.697799         4.463464           -1.277           0.202
# L3.mean_gas_refund_log_differenced                    3.351171         2.130707            1.573           0.116
# L3.mean_gas_burned_log_differenced                    0.434167         2.473274            0.176           0.861
# L3.mean_message_cost_log_differenced                  6.131592         3.781236            1.622           0.105
# L4.mean_gas_fee_cap_log_differenced                   0.087470         0.293992            0.298           0.766
# L4.mean_gas_premium_log_differenced                   0.035862         0.065033            0.551           0.581
# L4.mean_gas_limit_log_differenced                     1.343570         3.135690            0.428           0.668
# L4.mean_gas_used_log_differenced                      4.846279         8.693189            0.557           0.577
# L4.mean_parent_base_fee_log_differenced               7.119750         6.983539            1.020           0.308
# L4.mean_base_fee_burn_log_differenced                 0.604994         8.542643            0.071           0.944
# L4.mean_over_estimation_burn_log_differenced          4.751993         4.488987            1.059           0.290
# L4.mean_gas_refund_log_differenced                    3.140740         2.199021            1.428           0.153
# L4.mean_gas_burned_log_differenced                    1.507660         2.646036            0.570           0.569
# L4.mean_message_cost_log_differenced                 -6.312300         3.771325           -1.674           0.094
# L5.mean_gas_fee_cap_log_differenced                   0.143196         0.295233            0.485           0.628
# L5.mean_gas_premium_log_differenced                  -0.055548         0.066064           -0.841           0.400
# L5.mean_gas_limit_log_differenced                     1.458365         3.220416            0.453           0.651
# L5.mean_gas_used_log_differenced                      0.918580         8.773799            0.105           0.917
# L5.mean_parent_base_fee_log_differenced               3.228254         7.085270            0.456           0.649
# L5.mean_base_fee_burn_log_differenced                -0.980565         8.557586           -0.115           0.909
# L5.mean_over_estimation_burn_log_differenced         -1.077221         4.589710           -0.235           0.814
# L5.mean_gas_refund_log_differenced                    3.102236         2.238634            1.386           0.166
# L5.mean_gas_burned_log_differenced                    1.770286         2.747488            0.644           0.519
# L5.mean_message_cost_log_differenced                 -0.579218         3.790490           -0.153           0.879
# L6.mean_gas_fee_cap_log_differenced                  -0.063012         0.296007           -0.213           0.831
# L6.mean_gas_premium_log_differenced                  -0.069819         0.066190           -1.055           0.292
# L6.mean_gas_limit_log_differenced                    -0.641128         3.205256           -0.200           0.841
# L6.mean_gas_used_log_differenced                     -4.414760         8.741913           -0.505           0.614
# L6.mean_parent_base_fee_log_differenced              -7.195550         7.073258           -1.017           0.309
# L6.mean_base_fee_burn_log_differenced                 1.876134         8.530384            0.220           0.826
# L6.mean_over_estimation_burn_log_differenced         -0.867852         4.582096           -0.189           0.850
# L6.mean_gas_refund_log_differenced                    1.472694         2.239389            0.658           0.511
# L6.mean_gas_burned_log_differenced                   -1.796922         2.722641           -0.660           0.509
# L6.mean_message_cost_log_differenced                  3.114744         3.781522            0.824           0.410
# L7.mean_gas_fee_cap_log_differenced                   0.129229         0.294710            0.438           0.661
# L7.mean_gas_premium_log_differenced                  -0.047456         0.065697           -0.722           0.470
# L7.mean_gas_limit_log_differenced                    -1.295074         3.105777           -0.417           0.677
# L7.mean_gas_used_log_differenced                     11.352498         8.582779            1.323           0.186
# L7.mean_parent_base_fee_log_differenced               0.949240         6.926232            0.137           0.891
# L7.mean_base_fee_burn_log_differenced                -4.922201         8.355962           -0.589           0.556
# L7.mean_over_estimation_burn_log_differenced          6.197839         4.437973            1.397           0.163
# L7.mean_gas_refund_log_differenced                   -1.251309         2.199605           -0.569           0.569
# L7.mean_gas_burned_log_differenced                   -4.768253         2.567323           -1.857           0.063
# L7.mean_message_cost_log_differenced                 -1.109373         3.739609           -0.297           0.767
# L8.mean_gas_fee_cap_log_differenced                  -0.046831         0.291798           -0.160           0.872
# L8.mean_gas_premium_log_differenced                  -0.042511         0.063232           -0.672           0.501
# L8.mean_gas_limit_log_differenced                    -1.339684         2.958525           -0.453           0.651
# L8.mean_gas_used_log_differenced                     -1.390642         8.138612           -0.171           0.864
# L8.mean_parent_base_fee_log_differenced              -6.750375         6.579111           -1.026           0.305
# L8.mean_base_fee_burn_log_differenced                 2.734490         7.978917            0.343           0.732
# L8.mean_over_estimation_burn_log_differenced          4.877139         4.340398            1.124           0.261
# L8.mean_gas_refund_log_differenced                   -0.728407         2.140368           -0.340           0.734
# L8.mean_gas_burned_log_differenced                   -3.712827         2.355510           -1.576           0.115
# L8.mean_message_cost_log_differenced                 -0.399110         3.733620           -0.107           0.915
# L9.mean_gas_fee_cap_log_differenced                   0.158662         0.287842            0.551           0.581
# L9.mean_gas_premium_log_differenced                  -0.011853         0.058975           -0.201           0.841
# L9.mean_gas_limit_log_differenced                    -2.444320         2.647985           -0.923           0.356
# L9.mean_gas_used_log_differenced                     -5.679265         7.169490           -0.792           0.428
# L9.mean_parent_base_fee_log_differenced             -10.551676         5.951637           -1.773           0.076
# L9.mean_base_fee_burn_log_differenced                11.939459         7.285036            1.639           0.101
# L9.mean_over_estimation_burn_log_differenced          4.588971         4.105156            1.118           0.264
# L9.mean_gas_refund_log_differenced                   -1.054918         2.048285           -0.515           0.607
# L9.mean_gas_burned_log_differenced                   -1.359614         2.087519           -0.651           0.515
# L9.mean_message_cost_log_differenced                 -3.039420         3.654391           -0.832           0.406
# L10.mean_gas_fee_cap_log_differenced                  0.326470         0.269719            1.210           0.226
# L10.mean_gas_premium_log_differenced                  0.004764         0.050193            0.095           0.924
# L10.mean_gas_limit_log_differenced                    0.432528         2.245316            0.193           0.847
# L10.mean_gas_used_log_differenced                    -3.659554         5.674333           -0.645           0.519
# L10.mean_parent_base_fee_log_differenced             -4.436016         4.846318           -0.915           0.360
# L10.mean_base_fee_burn_log_differenced                6.274348         6.196856            1.013           0.311
# L10.mean_over_estimation_burn_log_differenced         1.832450         3.805477            0.482           0.630
# L10.mean_gas_refund_log_differenced                  -0.884515         1.844714           -0.479           0.632
# L10.mean_gas_burned_log_differenced                   0.128571         1.491223            0.086           0.931
# L10.mean_message_cost_log_differenced                -1.874209         3.554196           -0.527           0.598
# ================================================================================================================
#
# Correlation matrix of residuals
#                                              mean_gas_fee_cap_log_differenced  mean_gas_premium_log_differenced  mean_gas_limit_log_differenced  mean_gas_used_log_differenced  mean_parent_base_fee_log_differenced  mean_base_fee_burn_log_differenced  mean_over_estimation_burn_log_differenced  mean_gas_refund_log_differenced  mean_gas_burned_log_differenced  mean_message_cost_log_differenced
# mean_gas_fee_cap_log_differenced                                     1.000000                          0.447335                       -0.070600                       0.039035                              0.642497                            0.638899                                   0.584237                         0.086654                        -0.044855                           0.617648
# mean_gas_premium_log_differenced                                     0.447335                          1.000000                        0.121859                       0.034940                              0.341572                            0.340499                                   0.367677                         0.066487                         0.182916                           0.358132
# mean_gas_limit_log_differenced                                      -0.070600                          0.121859                        1.000000                       0.778630                              0.037146                            0.081876                                   0.244410                         0.671264                         0.758277                           0.167327
# mean_gas_used_log_differenced                                        0.039035                          0.034940                        0.778630                       1.000000                              0.106553                            0.164632                                   0.200097                         0.852667                         0.377128                           0.184682
# mean_parent_base_fee_log_differenced                                 0.642497                          0.341572                        0.037146                       0.106553                              1.000000                            0.998215                                   0.960958                         0.212182                         0.111706                           0.987654
# mean_base_fee_burn_log_differenced                                   0.638899                          0.340499                        0.081876                       0.164632                              0.998215                            1.000000                                   0.964893                         0.260706                         0.132195                           0.990577
# mean_over_estimation_burn_log_differenced                            0.584237                          0.367677                        0.244410                       0.200097                              0.960958                            0.964893                                   1.000000                         0.294660                         0.379670                           0.991706
# mean_gas_refund_log_differenced                                      0.086654                          0.066487                        0.671264                       0.852667                              0.212182                            0.260706                                   0.294660                         1.000000                         0.356650                           0.280883
# mean_gas_burned_log_differenced                                     -0.044855                          0.182916                        0.758277                       0.377128                              0.111706                            0.132195                                   0.379670                         0.356650                         1.000000                           0.262257
# mean_message_cost_log_differenced                                    0.617648                          0.358132                        0.167327                       0.184682                              0.987654                            0.990577                                   0.991706                         0.280883                         0.262257                           1.000000

# %%
results.plot()

# %% [markdown]
# ## Granger causality
#
# Granger causality is a hypothesis test for determining whether one-time series is useful in forecasting another. We can say that a variable X, or variables, evolves Granger-causes another evolving variable Y if predictions of the value of Y based on its past values and the past values of X are better than predictions of Y based only on Y's past values.
#
# Granger Causality is relationship based on the following principles:
#
# * The cause happens before its effect.
# * The cause has 'unique' information about the future values of its effect.
#
#
# Given these two assumptions about causality, Granger proposed to test the following hypothesis for identification of a causal effect of $X$ on $Y$:
# $${P}[Y(t+1) \in A\mid \mathcal{I}(t)] \neq \mathbb{P}[Y(t+1) \in A\mid \mathcal{I}_{-X}(t)]$$
# where $\mathbb{P}$ refers to probability, $A$ is an arbitrary non-empty set, and $\mathcal{I}(t)$ and $\mathcal{I}_{-X}(t)$ respectively denote the information available as of time $t$ in the entire universe, and that in the modified universe in which $X$ is excluded. If the above hypothesis is accepted, we say that $X$ Granger causes $Y$.
#
# In our analysis, we present the hypothesis that gas_used is a driver of message cost. In statistical parlance, we have the following:
#
# * $H_O: \textrm{Gas used does not Granger cause message cost}$
# * $H_A: \textrm{Gas used does Granger cause message cost}$
#
#
# Granger Causality assumes that the time series are non-stationary, which we checked and passed above, and autoregressive lags greater than 1.
#
# We will perform now perform the Granger Causality hypothesis test with an $\alpha = 0.05$ value using an F test to determine if the eth price has any casual component for predicting the Rai market price. If the p-value (the probability of obtaining test results at least as extreme as the results observed) of the test is less than or equal to $\alpha$ we will reject the null hypothesis and determine that gas used is a driver of message cost.
#
# ### Paraphrased source:
# * https://en.wikipedia.org/wiki/Granger_causality

# %% [markdown]
# As we have many signals with the analysis, we will loop through all the signals, perform the Granger Causality test, and save the results for analysis.

# %%
alpha = 0.05
result_dfs = []
variables = list(log_differenced.columns)
for i in variables:
    for j in variables:
        if i==j:
            pass
        else:
            results_summary = results.test_causality(i,j, 
                                                     kind='f',signif=alpha).summary()


            df = pd.read_html(results_summary.as_html(),header=0, index_col=0)[0]
            df['alpha'] = alpha
            df['caused'] = i
            df['causing'] = j
            result_dfs.append(df)
        
Grangers_df = pd.concat(result_dfs)
Grangers_df.reset_index(inplace=True)
Grangers_df['result'] = Grangers_df['p-value'].apply(lambda x: 'reject H0' if x < alpha else 'fail to reject H0' )
Grangers_df
# Out:
#     Test statistic  Critical value  p-value           df  alpha  \
# 0           0.4242           1.831    0.936  (10, 12000)   0.05
# 1           8.7380           1.831    0.000  (10, 12000)   0.05
# 2           1.4080           1.831    0.170  (10, 12000)   0.05
# 3           0.9634           1.831    0.473  (10, 12000)   0.05
# 4           0.8364           1.831    0.593  (10, 12000)   0.05
# ..             ...             ...      ...          ...    ...
# 85          1.2460           1.831    0.256  (10, 12000)   0.05
# 86          1.9950           1.831    0.030  (10, 12000)   0.05
# 87          2.1570           1.831    0.018  (10, 12000)   0.05
# 88          2.4710           1.831    0.006  (10, 12000)   0.05
# 89          2.5730           1.831    0.004  (10, 12000)   0.05
#
#                                caused  \
# 0    mean_gas_fee_cap_log_differenced
# 1    mean_gas_fee_cap_log_differenced
# 2    mean_gas_fee_cap_log_differenced
# 3    mean_gas_fee_cap_log_differenced
# 4    mean_gas_fee_cap_log_differenced
# ..                                ...
# 85  mean_message_cost_log_differenced
# 86  mean_message_cost_log_differenced
# 87  mean_message_cost_log_differenced
# 88  mean_message_cost_log_differenced
# 89  mean_message_cost_log_differenced
#
#                                       causing             result
# 0            mean_gas_premium_log_differenced  fail to reject H0
# 1              mean_gas_limit_log_differenced          reject H0
# 2               mean_gas_used_log_differenced  fail to reject H0
# 3        mean_parent_base_fee_log_differenced  fail to reject H0
# 4          mean_base_fee_burn_log_differenced  fail to reject H0
# ..                                        ...                ...
# 85       mean_parent_base_fee_log_differenced  fail to reject H0
# 86         mean_base_fee_burn_log_differenced          reject H0
# 87  mean_over_estimation_burn_log_differenced          reject H0
# 88            mean_gas_refund_log_differenced          reject H0
# 89            mean_gas_burned_log_differenced          reject H0
#
# [90 rows x 8 columns]

# %%
heatdf = Grangers_df.pivot(index='caused', columns=['causing'],values=['p-value'])

f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(heatdf, annot=True, linewidths=.5, ax=ax,cmap=['green','red'],center=0.05)
plt.suptitle('Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')
# Out:
# Text(0.5, 0.98, 'Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')

# %% [markdown]
# Based on the heatmap above, we can see that there are some granger causal relationships between signals. To see more granular specifics, we will examine the reject H0s below

# %%
Grangers_df.query("result == 'reject H0'").sort_values('p-value',ascending=True)
# Out:
#     Test statistic  Critical value  p-value           df  alpha  \
# 1            8.738           1.831    0.000  (10, 12000)   0.05
# 56           3.756           1.831    0.000  (10, 12000)   0.05
# 47           4.716           1.831    0.000  (10, 12000)   0.05
# 45          12.460           1.831    0.000  (10, 12000)   0.05
# 65           3.214           1.831    0.000  (10, 12000)   0.05
# 38           5.084           1.831    0.000  (10, 12000)   0.05
# 54          10.020           1.831    0.000  (10, 12000)   0.05
# 29           4.808           1.831    0.000  (10, 12000)   0.05
# 74           4.006           1.831    0.000  (10, 12000)   0.05
# 81          11.360           1.831    0.000  (10, 12000)   0.05
# 9            7.227           1.831    0.000  (10, 12000)   0.05
# 83           4.226           1.831    0.000  (10, 12000)   0.05
# 36          12.720           1.831    0.000  (10, 12000)   0.05
# 42           2.889           1.831    0.001  (10, 12000)   0.05
# 53           2.813           1.831    0.002  (10, 12000)   0.05
# 43           2.721           1.831    0.002  (10, 12000)   0.05
# 44           2.806           1.831    0.002  (10, 12000)   0.05
# 51           2.807           1.831    0.002  (10, 12000)   0.05
# 62           2.827           1.831    0.002  (10, 12000)   0.05
# 52           2.687           1.831    0.003  (10, 12000)   0.05
# 89           2.573           1.831    0.004  (10, 12000)   0.05
# 61           2.483           1.831    0.006  (10, 12000)   0.05
# 88           2.471           1.831    0.006  (10, 12000)   0.05
# 50           2.247           1.831    0.013  (10, 12000)   0.05
# 7            2.207           1.831    0.015  (10, 12000)   0.05
# 41           2.192           1.831    0.016  (10, 12000)   0.05
# 60           2.160           1.831    0.017  (10, 12000)   0.05
# 87           2.157           1.831    0.018  (10, 12000)   0.05
# 40           2.019           1.831    0.028  (10, 12000)   0.05
# 16           2.008           1.831    0.029  (10, 12000)   0.05
# 86           1.995           1.831    0.030  (10, 12000)   0.05
# 28           1.899           1.831    0.041  (10, 12000)   0.05
#
#                                        caused  \
# 1            mean_gas_fee_cap_log_differenced
# 56  mean_over_estimation_burn_log_differenced
# 47         mean_base_fee_burn_log_differenced
# 45         mean_base_fee_burn_log_differenced
# 65            mean_gas_refund_log_differenced
# 38       mean_parent_base_fee_log_differenced
# 54  mean_over_estimation_burn_log_differenced
# 29              mean_gas_used_log_differenced
# 74            mean_gas_burned_log_differenced
# 81          mean_message_cost_log_differenced
# 9            mean_gas_premium_log_differenced
# 83          mean_message_cost_log_differenced
# 36       mean_parent_base_fee_log_differenced
# 42       mean_parent_base_fee_log_differenced
# 53         mean_base_fee_burn_log_differenced
# 43       mean_parent_base_fee_log_differenced
# 44       mean_parent_base_fee_log_differenced
# 51         mean_base_fee_burn_log_differenced
# 62  mean_over_estimation_burn_log_differenced
# 52         mean_base_fee_burn_log_differenced
# 89          mean_message_cost_log_differenced
# 61  mean_over_estimation_burn_log_differenced
# 88          mean_message_cost_log_differenced
# 50         mean_base_fee_burn_log_differenced
# 7            mean_gas_fee_cap_log_differenced
# 41       mean_parent_base_fee_log_differenced
# 60  mean_over_estimation_burn_log_differenced
# 87          mean_message_cost_log_differenced
# 40       mean_parent_base_fee_log_differenced
# 16           mean_gas_premium_log_differenced
# 86          mean_message_cost_log_differenced
# 28              mean_gas_used_log_differenced
#
#                                       causing     result
# 1              mean_gas_limit_log_differenced  reject H0
# 56             mean_gas_limit_log_differenced  reject H0
# 47             mean_gas_limit_log_differenced  reject H0
# 45           mean_gas_fee_cap_log_differenced  reject H0
# 65             mean_gas_limit_log_differenced  reject H0
# 38             mean_gas_limit_log_differenced  reject H0
# 54           mean_gas_fee_cap_log_differenced  reject H0
# 29             mean_gas_limit_log_differenced  reject H0
# 74             mean_gas_limit_log_differenced  reject H0
# 81           mean_gas_fee_cap_log_differenced  reject H0
# 9            mean_gas_fee_cap_log_differenced  reject H0
# 83             mean_gas_limit_log_differenced  reject H0
# 36           mean_gas_fee_cap_log_differenced  reject H0
# 42            mean_gas_refund_log_differenced  reject H0
# 53          mean_message_cost_log_differenced  reject H0
# 43            mean_gas_burned_log_differenced  reject H0
# 44          mean_message_cost_log_differenced  reject H0
# 51            mean_gas_refund_log_differenced  reject H0
# 62          mean_message_cost_log_differenced  reject H0
# 52            mean_gas_burned_log_differenced  reject H0
# 89            mean_gas_burned_log_differenced  reject H0
# 61            mean_gas_burned_log_differenced  reject H0
# 88            mean_gas_refund_log_differenced  reject H0
# 50  mean_over_estimation_burn_log_differenced  reject H0
# 7             mean_gas_burned_log_differenced  reject H0
# 41  mean_over_estimation_burn_log_differenced  reject H0
# 60            mean_gas_refund_log_differenced  reject H0
# 87  mean_over_estimation_burn_log_differenced  reject H0
# 40         mean_base_fee_burn_log_differenced  reject H0
# 16            mean_gas_burned_log_differenced  reject H0
# 86         mean_base_fee_burn_log_differenced  reject H0
# 28           mean_gas_premium_log_differenced  reject H0

# %% [markdown]
# Based on the above table, we can see some Granger caused relationships between signals, such as mean_gas_fee_cap Granger causes mean_gas_limit.

# %% [markdown]
# ## Conclusion
# Based on our VAR analysis without interpolation, invalidating our hypothesis, gas used has an influence on the message cost.
#
# The complexity of the difference in time, underlying assumption, and the complex relationships between variables provide a great illustration for why a complex dynamical systems model is needed instead of relying on econometric techniques for analyzing economic information. The work we have provided here is a good jumping off point for validating system movements in order to refine our cadCAD models so they can better integrate with live data feeds and provide a robust, decision support environment to aid future decision making for the Filecoin team.
