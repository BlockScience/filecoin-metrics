# %% [markdown]
# # EDA for Gas Fees - Proof of workflow.
#
# In this notebook we perform Exploratory Data Analysis (EDA) on FIL's gas fee mechanism. The goal is to observe the gas fee as a signal and attempt to understand what may be driving it.
#
# Access was obtained to Sentinel from Filecoin, and based on previous Block Science data work, we believe the the gas information is in the `messages` or `message_gas_economy` tables. **Update**: based on discussion with Filecoin, the `derived_gas_outputs` table is used as the primary data gathering table. [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md) was obtained on 6/28/2021 and will drive subsquent analysis.
#
# ## What are Gas Fees?
# Note: this description is copied from the [official Filecoin documentation](https://docs.filecoin.io/about-filecoin/how-filecoin-works/#gas-fees)
#
# Executing messages, for example by including transactions or proofs in the chain, consumes both computation and storage resources on the network. Gas is a measure of resources consumed by messages. The gas consumed by a message directly affects the cost that the sender has to pay for it to be included in a new block by a miner.
#
# Historically in other blockchains, miners specify a GasFee in a unit of native currency and then pay the block producing miners a priority fee based on how much gas is consumed by the message. Filecoin works similarly, except an amount of the fees is burned (sent to an irrecoverable address) to compensate for the network expenditure of resources, since all nodes need to validate the messages. The idea is based on Ethereum's EIP1559.
#
# The amount of fees burned in the Filecoin network comes given by a dynamic BaseFee which gets automatically adjusted according to the network congestion parameters (block sizes). The current value can be obtained from one of the block explorers or by inspecting the current head.
#
# Additionally, a number of gas-related parameters are attached to each message and determine the amount of rewards that miners get. Here's an overview of the terms and concepts:
#
# **GasUsage**: the amount of gas that a message's execution actually consumes. Current protocol does not know how much gas a message will exactly consume ahead of execution, but it can be estimated (see prices (opens new window)). GasUsage measured in units of Gas.
#
# **BaseFee**: the amount of FIL that gets burned per unit of gas consumed for the execution of every message. It is measured in units of attoFIL/Gas.
#
# **GasLimit**: the limit on the amount of gas that a message's execution can consume, estimated and specified by a message sender. It is measured in units of Gas. The sum of GasLimit for all messages included in a block must not exceed the BlockGasLimit. Messages will fail to execute if they run out of Gas, and any effects of the execution will be reverted.
#
# **GasFeeCap**: the maximum token amount that a sender is willing to pay per GasUnit for including a message in a block. It is measured in units of attoFIL/Gas. A message sender must have a minimum balance of GasFeeCap * GasLimit when sending a message, even though not all of that will be consumed. GasFeeCap can serve as a safeguard against high, unexpected BaseFee fluctuations.
#
# **GasPremium**: a priority fee that is paid to the block-producing miner. This is capped by GasFeeCap. The BaseFee has a higher priority. It is measured in units of attoFIL/Gas and can be as low as 1 attoFIL/Gas.
#
# **Overestimation burn**: an additional amount of gas to burn that grows larger when the difference between GasLimit and GasUsage is large.
#
# The total cost of a message for a sender will be:
#
# * GasUsage * BaseFee FIL (burned) +
# * GasLimit * GasPremium FIL (miner's reward) +
# * OverEstimationBurn * BaseFee FIL
#
# An important detail is that a message will always pay the burn fee, regardless of the GasFeeCap used. Thus, a low GasFeeCap may result in a reduced GasPremium or even a negative one! In that case, the miners that include a message will have to pay the needed amounts out of their own pockets, which means they are unlikely to include such messages in new blocks.
#
# Filecoin implementations may choose the heuristics of how their miners select messages for inclusion in new blocks, but they will usually attempt to maximize the miner's rewards.
#
#
# ## Data Resources
# * https://hackmd.io/5leND7tITX--5NJsFCJyow # Existing Sentinel queries
# * https://github.com/filecoin-project/sentinel/blob/master/docs/sentinel_tables_purpose.csv # Sentinel Tables Purpose
#
#
# ### Sentinel Diagram
# ![](sentinel_diagram.png)

# %% [markdown]
# ## Analysis
#
# We are performing a vector autoregression (VAR) to determine if a casual or multi-causal relationship exists between the gas signals moves. This will help us understand the system-level dynamics of Filecoin.
#
# ### Vector Autoregression
#
# Vector autoregression (VAR) is a type of statistical model used to capture the relationship between multiple time series signals as they change over time. VAR models are extensions of univariate autoregression models allowing for multivariate time series analysis.
#
# Autoregressive models use lagged past values of the variable and have an order based on how many times the variable has been lagged, i.e. VAR(2) means two lagged values. Lagged values help to determine if seasonality or reoccurring patterns exist in the data.
#
# A pth-order VAR model is written as:
# $$y_t = c + A_1 y_{t-1} + A_2 y_{t-2} + \cdots + A_p y_{t-p} + e_t,$$
#
# In vector notation, a VAR(1) with 2 variables is:
#
# $$\begin{bmatrix}y_{1,t} \\ y_{2,t}\end{bmatrix} = \begin{bmatrix}c_{1} \\ c_{2}\end{bmatrix} + \begin{bmatrix}a_{1,1}&a_{1,2} \\ a_{2,1}&a_{2,2}\end{bmatrix}\begin{bmatrix}y_{1,t-1} \\ y_{2,t-1}\end{bmatrix} + \begin{bmatrix}e_{1,t} \\ e_{2,t}\end{bmatrix}$$
#
# For our VAR model, we will have a vector of gas signals.
#
# #### Assumptions:
# * Every error term has a mean of zero and is normally distributed.
# * Variables are stationary. Differencing can be used to make the data stationary.
# * Data is on the same scale
# * Time sampling is consistent
#
# ### Other methods with fewer assumptions
#
# Non-parametric Bayesian VAR models have been under development and appear to perform well and can operate on nonlinear relationships, heteroscedasticity, and non-Gaussian error data[1,2].
#
# Another popular time series analysis modeling technique is the Autoregressive Integrated Moving Average (ARIMA) model. These models are often used in forecasting or when the data shows evidence of non-stationarity. For multiple time series vectors, as we have here, extensions of the ARIMA model are available, such ARIMAX model that has exogenous variable inputs. ARIMAX models do not have an assumption of Gaussian errors as it uses a maximum likelihood estimation function to fit.
#
# #### References
# - 1 Kalli, Maria & Griffin, Jim E., 2018. "Bayesian nonparametric vector autoregressive models," Journal of Econometrics, Elsevier, vol. 203(2), pages 267-282.
# - 2 Jeliazkov, Ivan. (2013). Nonparametric Vector Autoregressions: Specification, Estimation, and Inference. Advances in Econometrics. 33. 10.1108/S0731-9053(2013)0000031009.
#
#
# We have taken the trade-off in assumption for this first version correlation model vs a non-parametric approach for simplicity's sake, that current robust python VAR implementations exist, and for illustrative purposes around the concepts, we are addressing.

# %%
# import libraries
from sqlalchemy import create_engine
import pandas as pd
from datetime import datetime
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

# %%
# load connection string
CONN_STRING_PATH = 'sentinel_conn_string_andrew.txt'

with open(CONN_STRING_PATH, 'r') as fid:
    conn_string = fid.read()
    
# create database connection.
connection = create_engine(conn_string, pool_recycle=3600).connect()

# %% [markdown]
# ## Data EDA
#
# Below we download hourly averages from the `derived_gas_outputs` table from May 1st, 2021 to present (last refreshed 6/28/2021). After downloading the data, we few the first and lasts 5 rows, and perform basic statistics on the data.
#
#
# ### `derived_gas_outputs` - coped from [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md)
# Derived gas costs resulting from execution of a message in the VM.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`actor_name`|`text`|NO|Human readable identifier for the type of the actor.|
# |`base_fee_burn`|`text`|NO|The amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.|
# |`cid`|`text`|NO|CID of the message.|
# |`exit_code`|`bigint`|NO|The exit code that was returned as a result of executing the message. Exit code 0 indicates success. Codes 0-15 are reserved for use by the runtime. Codes 16-31 are common codes shared by different actors. Codes 32+ are actor specific.|
# |`from`|`text`|NO|Address of actor that sent the message.|
# |`gas_burned`|`bigint`|NO|The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_fee_cap`|`text`|NO|The maximum price that the message sender is willing to pay per unit of gas.|
# |`gas_limit`|`bigint`|YES|A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.|
# |`gas_premium`|`text`|NO|The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.|
# |`gas_refund`|`bigint`|NO|The overestimated units of gas to refund. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_used`|`bigint`|NO|A measure of the amount of resources (or units of gas) consumed, in order to execute a message.|
# |`height`|`bigint`|NO|Epoch this message was executed at.|
# |`method`|`bigint`|YES|The method number to invoke. Only unique to the actor the method is being invoked on. A method number of 0 is a plain token transfer - no method exectution.|
# |`miner_penalty`|`text`|NO|Any penalty fees (in attoFIL) the miner incured while executing the message.|
# |`miner_tip`|`text`|NO|The amount of FIL (in attoFIL) the miner receives for executing the message. Typically it is gas_premium * gas_limit but may be lower if the total fees exceed the gas_fee_cap.|
# |`nonce`|`bigint`|YES|The message nonce, which protects against duplicate messages and multiple messages with the same values.|
# |`over_estimation_burn`|`text`|NO|The fee to pay (in attoFIL) for overestimating the gas used to execute a message. The overestimated gas to burn (gas_burned) is a portion of the difference between gas_limit and gas_used. The over_estimation_burn value is gas_burned * parent_base_fee.|
# |`parent_base_fee`|`text`|NO|The set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.|
# |`refund`|`text`|NO|The amount of FIL (in attoFIL) to refund to the message sender after base fee, miner tip and overestimation amounts have been deducted.|
# |`size_bytes`|`bigint`|YES|Size in bytes of the serialized message.|
# |`state_root`|`text`|NO|CID of the parent state root.|
# |`to`|`text`|NO|Address of actor that received the message.|
# |`value`|`text`|NO|The FIL value transferred (attoFIL) to the message receiver.|

# %%
QUERY = """
SELECT 
date_trunc('hour', 
to_timestamp(height_to_unix(d.height))) AS timestamp,
AVG(CAST(gas_fee_cap AS FLOAT)) AS mean_gas_fee_cap,
AVG(CAST(gas_premium AS FLOAT))  as mean_gas_premium,
AVG(CAST(gas_limit AS FLOAT))  as mean_gas_limit,
AVG(CAST(gas_used AS FLOAT))  as mean_gas_used,
AVG(CAST(parent_base_fee AS FLOAT))  as mean_parent_base_fee,
AVG(CAST(base_fee_burn AS FLOAT))  as mean_base_fee_burn,
AVG(CAST(over_estimation_burn AS FLOAT))  as mean_over_estimation_burn,
AVG(CAST(gas_refund AS FLOAT))  as mean_gas_refund,
AVG(CAST(gas_burned AS FLOAT))  as mean_gas_burned
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) > '2021-05-01'
GROUP BY
timestamp
"""
derived_gas_outputs = (pd.read_sql(QUERY, connection))

# %%
derived_gas_outputs.head()
# Out:
#                   timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 0 2021-05-01 00:00:00+00:00      1.560131e+10      1.482218e+07
# 1 2021-05-01 01:00:00+00:00      1.325130e+10      1.038786e+07
# 2 2021-05-01 02:00:00+00:00      1.566131e+10      6.501496e+06
# 3 2021-05-01 03:00:00+00:00      1.295362e+10      7.830208e+06
# 4 2021-05-01 04:00:00+00:00      1.392573e+10      9.203523e+06
#
#    mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 0    4.400210e+07   3.544539e+07          3.287172e+09        1.142042e+17
# 1    4.374094e+07   3.516687e+07          2.875746e+09        9.864674e+16
# 2    4.007360e+07   3.235859e+07          3.391013e+09        1.073700e+17
# 3    4.310044e+07   3.467378e+07          2.724790e+09        9.247733e+16
# 4    4.091478e+07   3.288442e+07          2.757795e+09        8.882479e+16
#
#    mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 0               7.885100e+15     6.147325e+06     2.409388e+06
# 1               7.128347e+15     6.033203e+06     2.540860e+06
# 2               6.432014e+15     5.813149e+06     1.901862e+06
# 3               6.693012e+15     5.940040e+06     2.486627e+06
# 4               6.161389e+15     5.792842e+06     2.237511e+06

# %%
derived_gas_outputs.tail()
# Out:
#                      timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 1337 2021-06-25 17:00:00+00:00      5.020299e+09     315874.316104
# 1338 2021-06-25 18:00:00+00:00      4.528957e+09     118026.606812
# 1339 2021-06-25 19:00:00+00:00      5.014644e+09     254320.472354
# 1340 2021-06-25 20:00:00+00:00      6.315006e+09     247058.814685
# 1341 2021-06-25 21:00:00+00:00      5.657777e+09     470410.314271
#
#       mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 1337    3.753990e+07   3.066023e+07          1.170075e+08        3.518761e+15
# 1338    3.656435e+07   2.990070e+07          5.534192e+07        1.623433e+15
# 1339    3.839476e+07   3.119200e+07          1.049332e+08        3.243115e+15
# 1340    3.904219e+07   3.176776e+07          2.675574e+08        8.360973e+15
# 1341    3.879011e+07   3.171930e+07          1.737686e+08        5.427558e+15
#
#       mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 1337               1.555417e+14     5.538000e+06     1.341666e+06
# 1338               7.071735e+13     5.394168e+06     1.269488e+06
# 1339               1.642748e+14     5.682264e+06     1.520495e+06
# 1340               4.108243e+14     5.749173e+06     1.525257e+06
# 1341               2.338489e+14     5.730747e+06     1.340059e+06

# %%
derived_gas_outputs.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count      1.342000e+03      1.342000e+03    1.342000e+03   1.342000e+03
# mean       8.922672e+09      2.291130e+06    3.994873e+07   3.244743e+07
# std        3.900477e+09      3.042393e+06    1.872213e+06   1.117551e+06
# min        1.401976e+09      1.010942e+05    3.511228e+07   2.811138e+07
# 25%        5.712867e+09      3.229073e+05    3.889298e+07   3.170565e+07
# 50%        9.219596e+09      1.143213e+06    3.979790e+07   3.239524e+07
# 75%        1.190024e+10      3.023696e+06    4.089810e+07   3.314708e+07
# max        2.352814e+10      3.093223e+07    7.809493e+07   3.595985e+07
#
#        mean_parent_base_fee  mean_base_fee_burn  mean_over_estimation_burn  \
# count          1.342000e+03        1.342000e+03               1.342000e+03
# mean           9.222688e+08        2.966535e+16               1.666373e+15
# std            8.559667e+08        2.781802e+16               1.694872e+15
# min            1.016643e+02        2.964737e+09               1.218508e+08
# 25%            2.365683e+08        7.542218e+15               3.556347e+14
# 50%            7.221332e+08        2.288581e+16               1.204481e+15
# 75%            1.222380e+09        3.874695e+16               2.131599e+15
# max            4.889421e+09        1.609283e+17               8.616813e+15
#
#        mean_gas_refund  mean_gas_burned
# count     1.342000e+03     1.342000e+03
# mean      5.783734e+06     1.717571e+06
# std       2.282593e+05     1.304658e+06
# min       4.851994e+06     1.068593e+06
# 25%       5.635584e+06     1.447565e+06
# 50%       5.775482e+06     1.627643e+06
# 75%       5.942185e+06     1.820102e+06
# max       6.683911e+06     4.397566e+07

# %% [markdown]
# We will plot each signal, save for the timestamp, below:

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_fee_cap',kind='line',title='Mean Gas Fee Cap')
print('The maximum price that the message sender is willing to pay per unit of gas')
# Out:
#  The maximum price that the message sender is willing to pay per unit of gas

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_premium',kind='line',title='Mean Gas Premium')
print('The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.')
# Out:
# The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_limit',kind='line',title='Mean Gas Limit')
print('A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.')
# Out:
# A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_used',kind='line',title='Mean Gas Used')
print('A measure of the amount of resources (or units of gas) consumed, in order to execute a message.')
# Out:
# A measure of the amount of resources (or units of gas) consumed, in order to execute a message.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_parent_base_fee',kind='line',title='Mean Parent Base Fee')
print('he set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.')
# Out:
# he set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_base_fee_burn',kind='line',title='Mean Base Fee Burn')
print('he amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.')
# Out:
# he amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_burned',kind='line',title='Mean Gas Burned')
print('The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.')
# Out:
# The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.

# %% [markdown]
# The data is a relatively consistent, stochastic trend save for several orders of magnitude spike one June 3rd. Mean_gas_burned shows the spike in gas burned the best, with mean_gas_burned being the hourly average of the overestimated units of gas. We will need to examine the meta-information from the messages to understand in more detail to understand why the spike occured. This will also mean querying disaggregated data to understand who the actors are and what transactions they are making.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_over_estimation_burn',kind='line',title='Mean Over Estimation Burn')
print('The fee to pay (in attoFIL) for overestimating the gas used to execute a message. The overestimated gas to burn (gas_burned) is a portion of the difference between gas_limit and gas_used. The over_estimation_burn value is gas_burned * parent_base_fee')
# Out:
# The fee to pay (in attoFIL) for overestimating the gas used to execute a message. The overestimated gas to burn (gas_burned) is a portion of the difference between gas_limit and gas_used. The over_estimation_burn value is gas_burned * parent_base_fee

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_refund',kind='line',title='Mean Gas Refund')
print('The overestimated units of gas to refund. It is a portion of the difference between gas_limit and gas_used.')
# Out:
# The overestimated units of gas to refund. It is a portion of the difference between gas_limit and gas_used.

# %%
derived_gas_outputs.query('mean_gas_burned > 4000000')
# Out:
#                     timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 795 2021-06-03 03:00:00+00:00      4.101927e+09      1.398642e+07
# 796 2021-06-03 04:00:00+00:00      3.096350e+09      9.181094e+06
# 798 2021-06-03 06:00:00+00:00      1.283277e+10      1.718752e+07
# 799 2021-06-03 07:00:00+00:00      1.594804e+10      7.254430e+06
# 802 2021-06-03 10:00:00+00:00      1.300655e+10      3.993850e+06
#
#      mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 795    7.809493e+07   2.926728e+07          6.466881e+07        1.815174e+15
# 796    5.600891e+07   3.113978e+07          4.549856e+07        1.366301e+15
# 798    4.712814e+07   3.518629e+07          8.726729e+08        3.021975e+16
# 799    4.227274e+07   3.224065e+07          6.913273e+08        2.202691e+16
# 802    4.066726e+07   3.136578e+07          5.078446e+08        1.554188e+16
#
#      mean_over_estimation_burn  mean_gas_refund  mean_gas_burned
# 795               3.079097e+15     4.851994e+06     4.397566e+07
# 796               7.491868e+14     4.988144e+06     1.988099e+07
# 798               4.739215e+15     5.846984e+06     6.094867e+06
# 799               2.747635e+15     5.512047e+06     4.520038e+06
# 802               2.050818e+15     5.254736e+06     4.046744e+06

# %%
QUERY = """
SELECT
date_trunc('hour', to_timestamp(height_to_unix(d.height))) AS timestamp,
d.actor_name,
d.from,
d.method,
d.to,
d.exit_code
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) = '2021-06-03'
"""
derived_gas_outputs_non_aggregated = (pd.read_sql(QUERY, connection))

# %% [markdown]
# ### Messages calculation mapping
#
# Based on the message cost calculation outliend by Filecoin's official documentation, we will map the data obtained to this calculation.
#
# Filecoin:
# `message_cost_calculation =  GasUsage * BaseFee FIL (burned) + GasLimit * GasPremium FIL (miner reward) + OverEstimationBurn * BaseFee FIL`
#
#
# Our downloaded data:
# `message_cost = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn`

# %%
# create field
derived_gas_outputs['mean_message_cost'] = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_message_cost',kind='line',title='Mean Message Cost')
# Out:
# <AxesSubplot:title={'center':'Mean Message Cost'}, xlabel='timestamp'>

# %% [markdown]
# ### Data processing
#
# We will now remove the timestamp field and examine the data distributions and determine if any transformations are required prior to our VAR modeling.

# %%
timestamps = derived_gas_outputs.timestamp
del derived_gas_outputs['timestamp']

# %%
derived_gas_outputs.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We can see from the above historgrams that besides `mean_gas_used` and `mean_gas_refund` our data is not normally distributed and will need to be transformed prior to modeling. We will take the log of the data to reduce the skewness and take the first difference to make the data stationary.

# %%
log_differenced = pd.DataFrame()
## Difference and log values
for i in derived_gas_outputs.columns:
    log_differenced[i +'_log_differenced'] = np.log(derived_gas_outputs[i]).diff()

# %%
log_differenced.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost_log_differenced'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <!-- ### Data Transformations
#
# We will take the log of the data to reduce the skewness and take the first difference to make the data stationary, meaning that the distribution does not change when shifted by tie. -->

# %%
# replace any NA values with zero
log_differenced.dropna(inplace=True)

# %% [markdown]
# As a final check prior to modeling, we will run the Augmented Dickey-Fuller test to ensure that our data is stationary (non-unit root - A unit root is a stochastic trend in a time series). The test's hypothesis are:
#
#
# * $H_O: \textrm{Time series has a unit root}$
# * $H_A: \textrm{Time series does not have a unit root}$

# %%
for i in log_differenced.columns:
    print(i)
    result = adfuller(log_differenced[i].values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] > 0.05:
        decision = "fail to reject - unit root present"
    else:
        decision = "reject, no unit root present"
    print(decision)
    print('----------------------------------')
# Out:
# mean_gas_fee_cap_log_differenced
# ADF Statistic: -27.512493
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_premium_log_differenced
# ADF Statistic: -23.397141
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_limit_log_differenced
# ADF Statistic: -13.340761
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_used_log_differenced
# ADF Statistic: -12.502743
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_parent_base_fee_log_differenced
# ADF Statistic: -17.401780
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_base_fee_burn_log_differenced
# ADF Statistic: -14.266826
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_over_estimation_burn_log_differenced
# ADF Statistic: -16.317868
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_refund_log_differenced
# ADF Statistic: -12.653787
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_burned_log_differenced
# ADF Statistic: -13.709325
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_message_cost_log_differenced
# ADF Statistic: -16.261226
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------

# %% [markdown]
# Based on the Augmented Dickey-Fuller, our preprocessing was successful and none of our univariate time series signals as a unit root. We can now proceed to the VAR model.

# %% [markdown]
# ## Model Fit
#
# To determine the ideal number of lags for our model, we will perform a heuristic SVD. We will fit our model with an autocorrelation between 1 and 15 to ascertain which VAR order has the best Akaike information criterion(AIC) score.
#
# The **Akaike information criterion (AIC)** is an estimator of prediction error, rooted in information theory. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models as a means for model selection.
#
# When a statistical model is used to represent the process that generated the data, the representation will rarely be exact; so some information will be lost by using the model to represent the process. AIC estimates the relative amount of information lost by a given model: the less information a model loses, the higher the quality of that model.
#
# In estimating the amount of information lost by a model, AIC deals with the trade-off between the goodness of fit of the model and the simplicity of the model. In other words, AIC deals with both the risk of overfitting and the risk of underfitting.
#
# Below is the equation for AIC where $\hat L$ is the maximum value of the likelihood function for the model:
#
# $$\mathrm{AIC} \, = \, 2k - 2\ln(\hat L)$$
#
# Given a set of candidate models for the data, the **preferred model is the one with the minimum AIC value, the sign of the data does not matter**. AIC optimizes for the goodness of fit but also includes a penalty for each additional parameter, which discourages overfitting.
#
# <!-- The **Bayesian information criterion (BIC)** is a statistical method for model selection among a group of models; **the model with the lowest BIC is preferred, the sign of the data does not matter**. It is based, in part, on the likelihood function and it is closely related to the Akaike information criterion (AIC).
#
# When fitting models, it is possible to increase the likelihood by adding parameters, but doing so may result in overfitting. Both BIC and AIC attempt to resolve this problem by introducing a penalty term for the number of parameters in the model; the penalty term is larger in BIC than in AIC.
#
# $$\mathrm{BIC} = k\ln(n) - 2\ln(\widehat L)$$
# where
# $\hat L$ = the maximized value of the likelihood function of the model $M$
# $x$ = the observed data;
# $n$ = the number of data points in $x$,
# $k$ = the number of parameters estimated by the model.
#
#
# Several researchers that have studied the two metrics argue that BIC is appropriate for selecting the "true model" (i.e. the process that generated the data) from the set of candidate models, whereas AIC choices the best model amongst the alternatives. Proponents of AIC argue that this issue is negligible because the "true model" is virtually never in the candidate set. For our use cases, we will optimize for the AIC as we know the "true" model of the signal behavior is way too complex to be captured within a VAR model.
#  -->
# Paraphrased sources:
# * https://en.wikipedia.org/wiki/Akaike_information_criterion
# <!-- * https://en.wikipedia.org/wiki/Bayesian_information_criterion -->

# %%
aic = []
for i in range(1,16):
    model = VAR(log_differenced)
    results = model.fit(i)
    aic.append(results.aic)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
plt.figure(figsize=(10, 8))
plt.plot(aic, 'r+')
plt.legend(['AIC'])
plt.xlabel('Autocorrelation Lag')
plt.ylabel('AIC')
plt.title('Plot of sweeps over lag depths over AIC Loss function')
plt.show()

# %% [markdown]
# Based on our analysis, a lag of 4 appears to be the optimal.

# %%
# instantiate the var model object from statsmodels
model = VAR(log_differenced)

# fit model with determined lag values
results = model.fit(4)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 28, Jun, 2021
# Time:                     14:06:04
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -62.8636
# Nobs:                     1337.00    HQIC:                  -63.8604
# Log likelihood:           24528.7    FPE:                1.01503e-28
# AIC:                     -64.4577    Det(Omega_mle):     7.50417e-29
# --------------------------------------------------------------------
# Results for equation mean_gas_fee_cap_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000442         0.003950           -0.112           0.911
# L1.mean_gas_fee_cap_log_differenced                 -0.059455         0.040711           -1.460           0.144
# L1.mean_gas_premium_log_differenced                 -0.002477         0.007654           -0.324           0.746
# L1.mean_gas_limit_log_differenced                   -1.268349         0.324795           -3.905           0.000
# L1.mean_gas_used_log_differenced                     1.355743         0.918812            1.476           0.140
# L1.mean_parent_base_fee_log_differenced              0.173352         0.754995            0.230           0.818
# L1.mean_base_fee_burn_log_differenced               -0.054062         0.964359           -0.056           0.955
# L1.mean_over_estimation_burn_log_differenced        -0.927626         0.577913           -1.605           0.108
# L1.mean_gas_refund_log_differenced                   0.564116         0.289419            1.949           0.051
# L1.mean_gas_burned_log_differenced                   0.730029         0.220296            3.314           0.001
# L1.mean_message_cost_log_differenced                 0.442235         0.551290            0.802           0.422
# L2.mean_gas_fee_cap_log_differenced                 -0.056924         0.044215           -1.287           0.198
# L2.mean_gas_premium_log_differenced                 -0.008850         0.008623           -1.026           0.305
# L2.mean_gas_limit_log_differenced                    1.436612         0.381715            3.764           0.000
# L2.mean_gas_used_log_differenced                    -1.114211         1.057923           -1.053           0.292
# L2.mean_parent_base_fee_log_differenced              0.605958         0.867131            0.699           0.485
# L2.mean_base_fee_burn_log_differenced               -0.651437         1.081526           -0.602           0.547
# L2.mean_over_estimation_burn_log_differenced        -1.026627         0.627402           -1.636           0.102
# L2.mean_gas_refund_log_differenced                  -0.092843         0.304468           -0.305           0.760
# L2.mean_gas_burned_log_differenced                   0.502628         0.274159            1.833           0.067
# L2.mean_message_cost_log_differenced                 0.526218         0.569779            0.924           0.356
# L3.mean_gas_fee_cap_log_differenced                 -0.028984         0.044488           -0.651           0.515
# L3.mean_gas_premium_log_differenced                  0.004250         0.008687            0.489           0.625
# L3.mean_gas_limit_log_differenced                   -0.528904         0.379216           -1.395           0.163
# L3.mean_gas_used_log_differenced                    -0.556919         1.038099           -0.536           0.592
# L3.mean_parent_base_fee_log_differenced             -0.276844         0.856949           -0.323           0.747
# L3.mean_base_fee_burn_log_differenced                0.711343         1.074777            0.662           0.508
# L3.mean_over_estimation_burn_log_differenced        -0.140856         0.629887           -0.224           0.823
# L3.mean_gas_refund_log_differenced                   0.686088         0.301708            2.274           0.023
# L3.mean_gas_burned_log_differenced                   0.425230         0.277144            1.534           0.125
# L3.mean_message_cost_log_differenced                -0.141188         0.575914           -0.245           0.806
# L4.mean_gas_fee_cap_log_differenced                 -0.024749         0.042266           -0.586           0.558
# L4.mean_gas_premium_log_differenced                  0.000575         0.007659            0.075           0.940
# L4.mean_gas_limit_log_differenced                    0.792225         0.338002            2.344           0.019
# L4.mean_gas_used_log_differenced                    -0.427959         0.872381           -0.491           0.624
# L4.mean_parent_base_fee_log_differenced              0.265647         0.736764            0.361           0.718
# L4.mean_base_fee_burn_log_differenced               -0.094330         0.954105           -0.099           0.921
# L4.mean_over_estimation_burn_log_differenced        -0.210031         0.590773           -0.356           0.722
# L4.mean_gas_refund_log_differenced                  -0.009325         0.279215           -0.033           0.973
# L4.mean_gas_burned_log_differenced                   0.120734         0.217930            0.554           0.580
# L4.mean_message_cost_log_differenced                 0.024163         0.556194            0.043           0.965
# ===============================================================================================================
#
# Results for equation mean_gas_premium_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.003924         0.016404           -0.239           0.811
# L1.mean_gas_fee_cap_log_differenced                  1.119981         0.169095            6.623           0.000
# L1.mean_gas_premium_log_differenced                 -0.575238         0.031789          -18.096           0.000
# L1.mean_gas_limit_log_differenced                    0.567608         1.349032            0.421           0.674
# L1.mean_gas_used_log_differenced                    -0.181860         3.816278           -0.048           0.962
# L1.mean_parent_base_fee_log_differenced              1.968238         3.135865            0.628           0.530
# L1.mean_base_fee_burn_log_differenced                0.153473         4.005457            0.038           0.969
# L1.mean_over_estimation_burn_log_differenced         0.200522         2.400354            0.084           0.933
# L1.mean_gas_refund_log_differenced                   1.716662         1.202098            1.428           0.153
# L1.mean_gas_burned_log_differenced                   1.694547         0.914995            1.852           0.064
# L1.mean_message_cost_log_differenced                -1.167416         2.289778           -0.510           0.610
# L2.mean_gas_fee_cap_log_differenced                  0.565580         0.183645            3.080           0.002
# L2.mean_gas_premium_log_differenced                 -0.418781         0.035816          -11.692           0.000
# L2.mean_gas_limit_log_differenced                    1.834837         1.585449            1.157           0.247
# L2.mean_gas_used_log_differenced                     1.116852         4.394073            0.254           0.799
# L2.mean_parent_base_fee_log_differenced              2.962447         3.601620            0.823           0.411
# L2.mean_base_fee_burn_log_differenced               -1.843202         4.492107           -0.410           0.682
# L2.mean_over_estimation_burn_log_differenced         1.825726         2.605906            0.701           0.484
# L2.mean_gas_refund_log_differenced                   0.537321         1.264605            0.425           0.671
# L2.mean_gas_burned_log_differenced                  -0.162305         1.138715           -0.143           0.887
# L2.mean_message_cost_log_differenced                -1.460666         2.366570           -0.617           0.537
# L3.mean_gas_fee_cap_log_differenced                  0.625527         0.184781            3.385           0.001
# L3.mean_gas_premium_log_differenced                 -0.264310         0.036083           -7.325           0.000
# L3.mean_gas_limit_log_differenced                    1.708251         1.575072            1.085           0.278
# L3.mean_gas_used_log_differenced                    -0.545142         4.311732           -0.126           0.899
# L3.mean_parent_base_fee_log_differenced              4.830433         3.559329            1.357           0.175
# L3.mean_base_fee_burn_log_differenced               -3.196052         4.464075           -0.716           0.474
# L3.mean_over_estimation_burn_log_differenced        -2.666047         2.616230           -1.019           0.308
# L3.mean_gas_refund_log_differenced                   0.553852         1.253143            0.442           0.659
# L3.mean_gas_burned_log_differenced                   2.637181         1.151113            2.291           0.022
# L3.mean_message_cost_log_differenced                 0.470162         2.392054            0.197           0.844
# L4.mean_gas_fee_cap_log_differenced                  0.165808         0.175551            0.944           0.345
# L4.mean_gas_premium_log_differenced                 -0.123251         0.031812           -3.874           0.000
# L4.mean_gas_limit_log_differenced                   -0.329862         1.403886           -0.235           0.814
# L4.mean_gas_used_log_differenced                     1.234442         3.623427            0.341           0.733
# L4.mean_parent_base_fee_log_differenced              2.689564         3.060141            0.879           0.379
# L4.mean_base_fee_burn_log_differenced                1.621011         3.962864            0.409           0.683
# L4.mean_over_estimation_burn_log_differenced         1.204545         2.453770            0.491           0.624
# L4.mean_gas_refund_log_differenced                   0.157220         1.159716            0.136           0.892
# L4.mean_gas_burned_log_differenced                   1.677354         0.905169            1.853           0.064
# L4.mean_message_cost_log_differenced                -2.759431         2.310145           -1.194           0.232
# ===============================================================================================================
#
# Results for equation mean_gas_limit_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000113         0.000924           -0.123           0.902
# L1.mean_gas_fee_cap_log_differenced                  0.007823         0.009525            0.821           0.411
# L1.mean_gas_premium_log_differenced                  0.002541         0.001791            1.419           0.156
# L1.mean_gas_limit_log_differenced                   -0.486149         0.075992           -6.397           0.000
# L1.mean_gas_used_log_differenced                     0.110377         0.214973            0.513           0.608
# L1.mean_parent_base_fee_log_differenced              0.097184         0.176645            0.550           0.582
# L1.mean_base_fee_burn_log_differenced               -0.055595         0.225630           -0.246           0.805
# L1.mean_over_estimation_burn_log_differenced         0.118893         0.135213            0.879           0.379
# L1.mean_gas_refund_log_differenced                  -0.061810         0.067715           -0.913           0.361
# L1.mean_gas_burned_log_differenced                   0.013158         0.051542            0.255           0.798
# L1.mean_message_cost_log_differenced                -0.080541         0.128985           -0.624           0.532
# L2.mean_gas_fee_cap_log_differenced                 -0.016117         0.010345           -1.558           0.119
# L2.mean_gas_premium_log_differenced                  0.004084         0.002018            2.024           0.043
# L2.mean_gas_limit_log_differenced                   -0.499096         0.089309           -5.588           0.000
# L2.mean_gas_used_log_differenced                     0.223724         0.247521            0.904           0.366
# L2.mean_parent_base_fee_log_differenced              0.090876         0.202881            0.448           0.654
# L2.mean_base_fee_burn_log_differenced               -0.109542         0.253043           -0.433           0.665
# L2.mean_over_estimation_burn_log_differenced         0.004607         0.146792            0.031           0.975
# L2.mean_gas_refund_log_differenced                   0.017324         0.071236            0.243           0.808
# L2.mean_gas_burned_log_differenced                  -0.025582         0.064144           -0.399           0.690
# L2.mean_message_cost_log_differenced                 0.008368         0.133310            0.063           0.950
# L3.mean_gas_fee_cap_log_differenced                 -0.008468         0.010409           -0.814           0.416
# L3.mean_gas_premium_log_differenced                  0.003781         0.002033            1.860           0.063
# L3.mean_gas_limit_log_differenced                   -0.000044         0.088725           -0.000           1.000
# L3.mean_gas_used_log_differenced                     0.045898         0.242882            0.189           0.850
# L3.mean_parent_base_fee_log_differenced              0.287762         0.200499            1.435           0.151
# L3.mean_base_fee_burn_log_differenced               -0.320575         0.251464           -1.275           0.202
# L3.mean_over_estimation_burn_log_differenced        -0.146742         0.147374           -0.996           0.319
# L3.mean_gas_refund_log_differenced                  -0.043019         0.070590           -0.609           0.542
# L3.mean_gas_burned_log_differenced                   0.045524         0.064843            0.702           0.483
# L3.mean_message_cost_log_differenced                 0.088299         0.134746            0.655           0.512
# L4.mean_gas_fee_cap_log_differenced                 -0.014994         0.009889           -1.516           0.129
# L4.mean_gas_premium_log_differenced                  0.004395         0.001792            2.453           0.014
# L4.mean_gas_limit_log_differenced                   -0.221205         0.079082           -2.797           0.005
# L4.mean_gas_used_log_differenced                     0.182013         0.204110            0.892           0.373
# L4.mean_parent_base_fee_log_differenced              0.249136         0.172379            1.445           0.148
# L4.mean_base_fee_burn_log_differenced               -0.166022         0.223230           -0.744           0.457
# L4.mean_over_estimation_burn_log_differenced        -0.043914         0.138222           -0.318           0.751
# L4.mean_gas_refund_log_differenced                   0.109367         0.065327            1.674           0.094
# L4.mean_gas_burned_log_differenced                   0.056781         0.050989            1.114           0.265
# L4.mean_message_cost_log_differenced                -0.019124         0.130132           -0.147           0.883
# ===============================================================================================================
#
# Results for equation mean_gas_used_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000094         0.000722           -0.130           0.897
# L1.mean_gas_fee_cap_log_differenced                  0.003204         0.007439            0.431           0.667
# L1.mean_gas_premium_log_differenced                  0.002701         0.001398            1.932           0.053
# L1.mean_gas_limit_log_differenced                    0.215769         0.059345            3.636           0.000
# L1.mean_gas_used_log_differenced                    -0.589046         0.167880           -3.509           0.000
# L1.mean_parent_base_fee_log_differenced              0.077269         0.137948            0.560           0.575
# L1.mean_base_fee_burn_log_differenced                0.133886         0.176202            0.760           0.447
# L1.mean_over_estimation_burn_log_differenced        -0.014981         0.105593           -0.142           0.887
# L1.mean_gas_refund_log_differenced                  -0.033352         0.052881           -0.631           0.528
# L1.mean_gas_burned_log_differenced                   0.069284         0.040251            1.721           0.085
# L1.mean_message_cost_log_differenced                -0.096766         0.100729           -0.961           0.337
# L2.mean_gas_fee_cap_log_differenced                 -0.012163         0.008079           -1.506           0.132
# L2.mean_gas_premium_log_differenced                  0.005570         0.001576            3.535           0.000
# L2.mean_gas_limit_log_differenced                    0.096728         0.069745            1.387           0.165
# L2.mean_gas_used_log_differenced                    -0.432895         0.193298           -2.240           0.025
# L2.mean_parent_base_fee_log_differenced              0.071580         0.158437            0.452           0.651
# L2.mean_base_fee_burn_log_differenced                0.037742         0.197610            0.191           0.849
# L2.mean_over_estimation_burn_log_differenced        -0.145721         0.114635           -1.271           0.204
# L2.mean_gas_refund_log_differenced                  -0.053823         0.055631           -0.968           0.333
# L2.mean_gas_burned_log_differenced                   0.098977         0.050093            1.976           0.048
# L2.mean_message_cost_log_differenced                 0.018104         0.104107            0.174           0.862
# L3.mean_gas_fee_cap_log_differenced                 -0.007562         0.008129           -0.930           0.352
# L3.mean_gas_premium_log_differenced                  0.003952         0.001587            2.490           0.013
# L3.mean_gas_limit_log_differenced                    0.164324         0.069288            2.372           0.018
# L3.mean_gas_used_log_differenced                    -0.316988         0.189675           -1.671           0.095
# L3.mean_parent_base_fee_log_differenced              0.183202         0.156577            1.170           0.242
# L3.mean_base_fee_burn_log_differenced               -0.136715         0.196377           -0.696           0.486
# L3.mean_over_estimation_burn_log_differenced        -0.221665         0.115089           -1.926           0.054
# L3.mean_gas_refund_log_differenced                  -0.030715         0.055126           -0.557           0.577
# L3.mean_gas_burned_log_differenced                   0.120342         0.050638            2.377           0.017
# L3.mean_message_cost_log_differenced                 0.086692         0.105228            0.824           0.410
# L4.mean_gas_fee_cap_log_differenced                 -0.006196         0.007723           -0.802           0.422
# L4.mean_gas_premium_log_differenced                  0.003830         0.001399            2.737           0.006
# L4.mean_gas_limit_log_differenced                   -0.021072         0.061758           -0.341           0.733
# L4.mean_gas_used_log_differenced                    -0.092610         0.159396           -0.581           0.561
# L4.mean_parent_base_fee_log_differenced              0.118504         0.134617            0.880           0.379
# L4.mean_base_fee_burn_log_differenced               -0.012507         0.174328           -0.072           0.943
# L4.mean_over_estimation_burn_log_differenced        -0.043853         0.107943           -0.406           0.685
# L4.mean_gas_refund_log_differenced                   0.031581         0.051016            0.619           0.536
# L4.mean_gas_burned_log_differenced                   0.071056         0.039819            1.784           0.074
# L4.mean_message_cost_log_differenced                -0.030862         0.101625           -0.304           0.761
# ===============================================================================================================
#
# Results for equation mean_parent_base_fee_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000939         0.011889           -0.079           0.937
# L1.mean_gas_fee_cap_log_differenced                 -1.292850         0.122554          -10.549           0.000
# L1.mean_gas_premium_log_differenced                  0.052067         0.023039            2.260           0.024
# L1.mean_gas_limit_log_differenced                   -4.576608         0.977730           -4.681           0.000
# L1.mean_gas_used_log_differenced                     6.472526         2.765901            2.340           0.019
# L1.mean_parent_base_fee_log_differenced              1.653867         2.272762            0.728           0.467
# L1.mean_base_fee_burn_log_differenced               -4.433573         2.903011           -1.527           0.127
# L1.mean_over_estimation_burn_log_differenced         3.141535         1.739690            1.806           0.071
# L1.mean_gas_refund_log_differenced                   4.608858         0.871238            5.290           0.000
# L1.mean_gas_burned_log_differenced                  -2.409336         0.663156           -3.633           0.000
# L1.mean_message_cost_log_differenced                 0.155492         1.659549            0.094           0.925
# L2.mean_gas_fee_cap_log_differenced                 -0.166090         0.133099           -1.248           0.212
# L2.mean_gas_premium_log_differenced                  0.028587         0.025958            1.101           0.271
# L2.mean_gas_limit_log_differenced                    2.291498         1.149077            1.994           0.046
# L2.mean_gas_used_log_differenced                     0.343263         3.184666            0.108           0.914
# L2.mean_parent_base_fee_log_differenced              2.015672         2.610325            0.772           0.440
# L2.mean_base_fee_burn_log_differenced              -10.433356         3.255717           -3.205           0.001
# L2.mean_over_estimation_burn_log_differenced        -5.563994         1.888667           -2.946           0.003
# L2.mean_gas_refund_log_differenced                   1.122872         0.916540            1.225           0.221
# L2.mean_gas_burned_log_differenced                  -1.288386         0.825299           -1.561           0.118
# L2.mean_message_cost_log_differenced                 6.940910         1.715205            4.047           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.361899         0.133922           -2.702           0.007
# L3.mean_gas_premium_log_differenced                  0.058145         0.026152            2.223           0.026
# L3.mean_gas_limit_log_differenced                   -1.226745         1.141555           -1.075           0.283
# L3.mean_gas_used_log_differenced                     1.031813         3.124988            0.330           0.741
# L3.mean_parent_base_fee_log_differenced              0.544475         2.579673            0.211           0.833
# L3.mean_base_fee_burn_log_differenced               -3.370623         3.235401           -1.042           0.298
# L3.mean_over_estimation_burn_log_differenced        -1.985698         1.896149           -1.047           0.295
# L3.mean_gas_refund_log_differenced                   1.410777         0.908233            1.553           0.120
# L3.mean_gas_burned_log_differenced                  -0.111431         0.834285           -0.134           0.894
# L3.mean_message_cost_log_differenced                 2.492878         1.733675            1.438           0.150
# L4.mean_gas_fee_cap_log_differenced                  0.055198         0.127233            0.434           0.664
# L4.mean_gas_premium_log_differenced                  0.022398         0.023056            0.971           0.331
# L4.mean_gas_limit_log_differenced                    0.474766         1.017486            0.467           0.641
# L4.mean_gas_used_log_differenced                     1.710518         2.626129            0.651           0.515
# L4.mean_parent_base_fee_log_differenced              1.862424         2.217880            0.840           0.401
# L4.mean_base_fee_burn_log_differenced                0.748560         2.872141            0.261           0.794
# L4.mean_over_estimation_burn_log_differenced         2.347312         1.778404            1.320           0.187
# L4.mean_gas_refund_log_differenced                   0.392723         0.840520            0.467           0.640
# L4.mean_gas_burned_log_differenced                   0.117299         0.656034            0.179           0.858
# L4.mean_message_cost_log_differenced                -2.507649         1.674310           -1.498           0.134
# ===============================================================================================================
#
# Results for equation mean_base_fee_burn_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.001023         0.011984           -0.085           0.932
# L1.mean_gas_fee_cap_log_differenced                 -1.289251         0.123530          -10.437           0.000
# L1.mean_gas_premium_log_differenced                  0.054661         0.023223            2.354           0.019
# L1.mean_gas_limit_log_differenced                   -4.365941         0.985516           -4.430           0.000
# L1.mean_gas_used_log_differenced                     6.526849         2.787926            2.341           0.019
# L1.mean_parent_base_fee_log_differenced              2.383844         2.290860            1.041           0.298
# L1.mean_base_fee_burn_log_differenced               -4.947721         2.926128           -1.691           0.091
# L1.mean_over_estimation_burn_log_differenced         3.154882         1.753544            1.799           0.072
# L1.mean_gas_refund_log_differenced                   4.605398         0.878176            5.244           0.000
# L1.mean_gas_burned_log_differenced                  -2.353312         0.668437           -3.521           0.000
# L1.mean_message_cost_log_differenced                 0.041810         1.672764            0.025           0.980
# L2.mean_gas_fee_cap_log_differenced                 -0.184779         0.134159           -1.377           0.168
# L2.mean_gas_premium_log_differenced                  0.034281         0.026165            1.310           0.190
# L2.mean_gas_limit_log_differenced                    2.340750         1.158227            2.021           0.043
# L2.mean_gas_used_log_differenced                     0.422172         3.210026            0.132           0.895
# L2.mean_parent_base_fee_log_differenced              2.541908         2.631112            0.966           0.334
# L2.mean_base_fee_burn_log_differenced              -10.884011         3.281644           -3.317           0.001
# L2.mean_over_estimation_burn_log_differenced        -5.705009         1.903707           -2.997           0.003
# L2.mean_gas_refund_log_differenced                   1.074752         0.923839            1.163           0.245
# L2.mean_gas_burned_log_differenced                  -1.209194         0.831872           -1.454           0.146
# L2.mean_message_cost_log_differenced                 6.974396         1.728863            4.034           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.369429         0.134989           -2.737           0.006
# L3.mean_gas_premium_log_differenced                  0.062480         0.026360            2.370           0.018
# L3.mean_gas_limit_log_differenced                   -1.079082         1.150646           -0.938           0.348
# L3.mean_gas_used_log_differenced                     1.069222         3.149873            0.339           0.734
# L3.mean_parent_base_fee_log_differenced              1.042830         2.600216            0.401           0.688
# L3.mean_base_fee_burn_log_differenced               -3.826465         3.261166           -1.173           0.241
# L3.mean_over_estimation_burn_log_differenced        -2.203355         1.911249           -1.153           0.249
# L3.mean_gas_refund_log_differenced                   1.359041         0.915465            1.485           0.138
# L3.mean_gas_burned_log_differenced                   0.008036         0.840929            0.010           0.992
# L3.mean_message_cost_log_differenced                 2.579403         1.747481            1.476           0.140
# L4.mean_gas_fee_cap_log_differenced                  0.051970         0.128246            0.405           0.685
# L4.mean_gas_premium_log_differenced                  0.026399         0.023240            1.136           0.256
# L4.mean_gas_limit_log_differenced                    0.450230         1.025588            0.439           0.661
# L4.mean_gas_used_log_differenced                     1.740278         2.647042            0.657           0.511
# L4.mean_parent_base_fee_log_differenced              2.126337         2.235542            0.951           0.342
# L4.mean_base_fee_burn_log_differenced                0.622683         2.895013            0.215           0.830
# L4.mean_over_estimation_burn_log_differenced         2.308765         1.792566            1.288           0.198
# L4.mean_gas_refund_log_differenced                   0.438264         0.847213            0.517           0.605
# L4.mean_gas_burned_log_differenced                   0.204119         0.661258            0.309           0.758
# L4.mean_message_cost_log_differenced                -2.557745         1.687643           -1.516           0.130
# ===============================================================================================================
#
# Results for equation mean_over_estimation_burn_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.001546         0.012735           -0.121           0.903
# L1.mean_gas_fee_cap_log_differenced                 -1.241247         0.131274           -9.455           0.000
# L1.mean_gas_premium_log_differenced                  0.062264         0.024679            2.523           0.012
# L1.mean_gas_limit_log_differenced                   -4.930356         1.047298           -4.708           0.000
# L1.mean_gas_used_log_differenced                     6.078441         2.962700            2.052           0.040
# L1.mean_parent_base_fee_log_differenced              1.879872         2.434474            0.772           0.440
# L1.mean_base_fee_burn_log_differenced               -4.352106         3.109566           -1.400           0.162
# L1.mean_over_estimation_burn_log_differenced         2.816047         1.863473            1.511           0.131
# L1.mean_gas_refund_log_differenced                   4.251348         0.933228            4.556           0.000
# L1.mean_gas_burned_log_differenced                  -2.131302         0.710341           -3.000           0.003
# L1.mean_message_cost_log_differenced                 0.152833         1.777629            0.086           0.931
# L2.mean_gas_fee_cap_log_differenced                 -0.216697         0.142569           -1.520           0.129
# L2.mean_gas_premium_log_differenced                  0.033165         0.027805            1.193           0.233
# L2.mean_gas_limit_log_differenced                    1.281804         1.230836            1.041           0.298
# L2.mean_gas_used_log_differenced                     0.617650         3.411261            0.181           0.856
# L2.mean_parent_base_fee_log_differenced              2.281660         2.796055            0.816           0.414
# L2.mean_base_fee_burn_log_differenced              -10.775577         3.487369           -3.090           0.002
# L2.mean_over_estimation_burn_log_differenced        -6.245396         2.023049           -3.087           0.002
# L2.mean_gas_refund_log_differenced                   1.475280         0.981754            1.503           0.133
# L2.mean_gas_burned_log_differenced                  -1.245535         0.884021           -1.409           0.159
# L2.mean_message_cost_log_differenced                 7.330796         1.837245            3.990           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.342653         0.143451           -2.389           0.017
# L3.mean_gas_premium_log_differenced                  0.066740         0.028012            2.383           0.017
# L3.mean_gas_limit_log_differenced                   -0.364537         1.222779           -0.298           0.766
# L3.mean_gas_used_log_differenced                     1.203014         3.347337            0.359           0.719
# L3.mean_parent_base_fee_log_differenced              1.707602         2.763223            0.618           0.537
# L3.mean_base_fee_burn_log_differenced               -4.192032         3.465607           -1.210           0.226
# L3.mean_over_estimation_burn_log_differenced        -2.555433         2.031064           -1.258           0.208
# L3.mean_gas_refund_log_differenced                   1.002434         0.972855            1.030           0.303
# L3.mean_gas_burned_log_differenced                   0.154508         0.893647            0.173           0.863
# L3.mean_message_cost_log_differenced                 2.599286         1.857029            1.400           0.162
# L4.mean_gas_fee_cap_log_differenced                  0.057063         0.136286            0.419           0.675
# L4.mean_gas_premium_log_differenced                  0.034968         0.024697            1.416           0.157
# L4.mean_gas_limit_log_differenced                    0.118204         1.089882            0.108           0.914
# L4.mean_gas_used_log_differenced                     2.054148         2.812984            0.730           0.465
# L4.mean_parent_base_fee_log_differenced              2.949301         2.375687            1.241           0.214
# L4.mean_base_fee_burn_log_differenced                0.454198         3.076500            0.148           0.883
# L4.mean_over_estimation_burn_log_differenced         1.938335         1.904942            1.018           0.309
# L4.mean_gas_refund_log_differenced                   0.822757         0.900325            0.914           0.361
# L4.mean_gas_burned_log_differenced                   0.611490         0.702712            0.870           0.384
# L4.mean_message_cost_log_differenced                -2.705770         1.793441           -1.509           0.131
# ===============================================================================================================
#
# Results for equation mean_gas_refund_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000055         0.000752           -0.074           0.941
# L1.mean_gas_fee_cap_log_differenced                 -0.002843         0.007756           -0.367           0.714
# L1.mean_gas_premium_log_differenced                  0.004079         0.001458            2.798           0.005
# L1.mean_gas_limit_log_differenced                    0.109826         0.061875            1.775           0.076
# L1.mean_gas_used_log_differenced                     0.030351         0.175038            0.173           0.862
# L1.mean_parent_base_fee_log_differenced              0.155294         0.143830            1.080           0.280
# L1.mean_base_fee_burn_log_differenced                0.052974         0.183715            0.288           0.773
# L1.mean_over_estimation_burn_log_differenced         0.072909         0.110095            0.662           0.508
# L1.mean_gas_refund_log_differenced                  -0.361015         0.055136           -6.548           0.000
# L1.mean_gas_burned_log_differenced                   0.027202         0.041967            0.648           0.517
# L1.mean_message_cost_log_differenced                -0.140361         0.105024           -1.336           0.181
# L2.mean_gas_fee_cap_log_differenced                 -0.016619         0.008423           -1.973           0.048
# L2.mean_gas_premium_log_differenced                  0.006063         0.001643            3.691           0.000
# L2.mean_gas_limit_log_differenced                   -0.006749         0.072719           -0.093           0.926
# L2.mean_gas_used_log_differenced                    -0.094761         0.201540           -0.470           0.638
# L2.mean_parent_base_fee_log_differenced             -0.041029         0.165193           -0.248           0.804
# L2.mean_base_fee_burn_log_differenced                0.011657         0.206036            0.057           0.955
# L2.mean_over_estimation_burn_log_differenced        -0.170261         0.119523           -1.424           0.154
# L2.mean_gas_refund_log_differenced                  -0.348768         0.058003           -6.013           0.000
# L2.mean_gas_burned_log_differenced                   0.050564         0.052229            0.968           0.333
# L2.mean_message_cost_log_differenced                 0.098694         0.108546            0.909           0.363
# L3.mean_gas_fee_cap_log_differenced                 -0.005621         0.008475           -0.663           0.507
# L3.mean_gas_premium_log_differenced                  0.004005         0.001655            2.420           0.016
# L3.mean_gas_limit_log_differenced                    0.060541         0.072243            0.838           0.402
# L3.mean_gas_used_log_differenced                    -0.064677         0.197763           -0.327           0.744
# L3.mean_parent_base_fee_log_differenced              0.059907         0.163253            0.367           0.714
# L3.mean_base_fee_burn_log_differenced               -0.100466         0.204751           -0.491           0.624
# L3.mean_over_estimation_burn_log_differenced        -0.221524         0.119997           -1.846           0.065
# L3.mean_gas_refund_log_differenced                  -0.247483         0.057477           -4.306           0.000
# L3.mean_gas_burned_log_differenced                   0.090344         0.052797            1.711           0.087
# L3.mean_message_cost_log_differenced                 0.129740         0.109715            1.183           0.237
# L4.mean_gas_fee_cap_log_differenced                 -0.003412         0.008052           -0.424           0.672
# L4.mean_gas_premium_log_differenced                  0.003565         0.001459            2.443           0.015
# L4.mean_gas_limit_log_differenced                   -0.030226         0.064391           -0.469           0.639
# L4.mean_gas_used_log_differenced                     0.077999         0.166193            0.469           0.639
# L4.mean_parent_base_fee_log_differenced              0.095323         0.140357            0.679           0.497
# L4.mean_base_fee_burn_log_differenced                0.030679         0.181762            0.169           0.866
# L4.mean_over_estimation_burn_log_differenced         0.057421         0.112545            0.510           0.610
# L4.mean_gas_refund_log_differenced                  -0.097625         0.053192           -1.835           0.066
# L4.mean_gas_burned_log_differenced                   0.029956         0.041517            0.722           0.471
# L4.mean_message_cost_log_differenced                -0.092985         0.105958           -0.878           0.380
# ===============================================================================================================
#
# Results for equation mean_gas_burned_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000633         0.003544           -0.179           0.858
# L1.mean_gas_fee_cap_log_differenced                  0.034012         0.036529            0.931           0.352
# L1.mean_gas_premium_log_differenced                  0.012881         0.006867            1.876           0.061
# L1.mean_gas_limit_log_differenced                   -0.133198         0.291429           -0.457           0.648
# L1.mean_gas_used_log_differenced                    -0.391679         0.824423           -0.475           0.635
# L1.mean_parent_base_fee_log_differenced             -0.350790         0.677435           -0.518           0.605
# L1.mean_base_fee_burn_log_differenced               -0.087549         0.865291           -0.101           0.919
# L1.mean_over_estimation_burn_log_differenced         0.487386         0.518544            0.940           0.347
# L1.mean_gas_refund_log_differenced                  -0.358790         0.259687           -1.382           0.167
# L1.mean_gas_burned_log_differenced                  -0.514098         0.197665           -2.601           0.009
# L1.mean_message_cost_log_differenced                -0.033229         0.494656           -0.067           0.946
# L2.mean_gas_fee_cap_log_differenced                 -0.046230         0.039672           -1.165           0.244
# L2.mean_gas_premium_log_differenced                  0.007554         0.007737            0.976           0.329
# L2.mean_gas_limit_log_differenced                   -0.944647         0.342502           -2.758           0.006
# L2.mean_gas_used_log_differenced                     0.266663         0.949243            0.281           0.779
# L2.mean_parent_base_fee_log_differenced             -0.198081         0.778051           -0.255           0.799
# L2.mean_base_fee_burn_log_differenced               -0.351156         0.970421           -0.362           0.717
# L2.mean_over_estimation_burn_log_differenced        -0.109375         0.562949           -0.194           0.846
# L2.mean_gas_refund_log_differenced                   0.347278         0.273190            1.271           0.204
# L2.mean_gas_burned_log_differenced                  -0.475644         0.245994           -1.934           0.053
# L2.mean_message_cost_log_differenced                 0.338795         0.511245            0.663           0.508
# L3.mean_gas_fee_cap_log_differenced                  0.008281         0.039918            0.207           0.836
# L3.mean_gas_premium_log_differenced                  0.009293         0.007795            1.192           0.233
# L3.mean_gas_limit_log_differenced                    1.081514         0.340260            3.178           0.001
# L3.mean_gas_used_log_differenced                     0.006762         0.931455            0.007           0.994
# L3.mean_parent_base_fee_log_differenced              0.893708         0.768915            1.162           0.245
# L3.mean_base_fee_burn_log_differenced               -0.992767         0.964366           -1.029           0.303
# L3.mean_over_estimation_burn_log_differenced        -0.318815         0.565179           -0.564           0.573
# L3.mean_gas_refund_log_differenced                  -0.399831         0.270714           -1.477           0.140
# L3.mean_gas_burned_log_differenced                  -0.095501         0.248673           -0.384           0.701
# L3.mean_message_cost_log_differenced                 0.203694         0.516751            0.394           0.693
# L4.mean_gas_fee_cap_log_differenced                 -0.001915         0.037924           -0.050           0.960
# L4.mean_gas_premium_log_differenced                  0.012750         0.006872            1.855           0.064
# L4.mean_gas_limit_log_differenced                   -0.088467         0.303279           -0.292           0.771
# L4.mean_gas_used_log_differenced                     0.226190         0.782762            0.289           0.773
# L4.mean_parent_base_fee_log_differenced              0.938799         0.661076            1.420           0.156
# L4.mean_base_fee_burn_log_differenced               -0.269547         0.856090           -0.315           0.753
# L4.mean_over_estimation_burn_log_differenced        -0.132965         0.530083           -0.251           0.802
# L4.mean_gas_refund_log_differenced                   0.377134         0.250531            1.505           0.132
# L4.mean_gas_burned_log_differenced                   0.270626         0.195542            1.384           0.166
# L4.mean_message_cost_log_differenced                -0.274930         0.499056           -0.551           0.582
# ===============================================================================================================
#
# Results for equation mean_message_cost_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.002570         0.024454           -0.105           0.916
# L1.mean_gas_fee_cap_log_differenced                 -2.527343         0.252064          -10.027           0.000
# L1.mean_gas_premium_log_differenced                  0.116498         0.047387            2.458           0.014
# L1.mean_gas_limit_log_differenced                   -9.288261         2.010961           -4.619           0.000
# L1.mean_gas_used_log_differenced                    12.623091         5.688808            2.219           0.026
# L1.mean_parent_base_fee_log_differenced              4.289167         4.674537            0.918           0.359
# L1.mean_base_fee_burn_log_differenced               -9.585028         5.970811           -1.605           0.108
# L1.mean_over_estimation_burn_log_differenced         5.676764         3.578134            1.587           0.113
# L1.mean_gas_refund_log_differenced                   8.827674         1.791931            4.926           0.000
# L1.mean_gas_burned_log_differenced                  -4.468336         1.363955           -3.276           0.001
# L1.mean_message_cost_log_differenced                 0.471323         3.413302            0.138           0.890
# L2.mean_gas_fee_cap_log_differenced                 -0.398224         0.273754           -1.455           0.146
# L2.mean_gas_premium_log_differenced                  0.067454         0.053390            1.263           0.206
# L2.mean_gas_limit_log_differenced                    3.625587         2.363381            1.534           0.125
# L2.mean_gas_used_log_differenced                     1.011569         6.550109            0.154           0.877
# L2.mean_parent_base_fee_log_differenced              4.815479         5.368825            0.897           0.370
# L2.mean_base_fee_burn_log_differenced              -21.367080         6.696246           -3.191           0.001
# L2.mean_over_estimation_burn_log_differenced       -11.693209         3.884544           -3.010           0.003
# L2.mean_gas_refund_log_differenced                   2.557230         1.885108            1.357           0.175
# L2.mean_gas_burned_log_differenced                  -2.440180         1.697447           -1.438           0.151
# L2.mean_message_cost_log_differenced                14.033397         3.527773            3.978           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.712224         0.275447           -2.586           0.010
# L3.mean_gas_premium_log_differenced                  0.128916         0.053788            2.397           0.017
# L3.mean_gas_limit_log_differenced                   -1.431288         2.347911           -0.610           0.542
# L3.mean_gas_used_log_differenced                     2.294979         6.427366            0.357           0.721
# L3.mean_parent_base_fee_log_differenced              2.767731         5.305782            0.522           0.602
# L3.mean_base_fee_burn_log_differenced               -8.056869         6.654460           -1.211           0.226
# L3.mean_over_estimation_burn_log_differenced        -4.788879         3.899933           -1.228           0.219
# L3.mean_gas_refund_log_differenced                   2.343621         1.868021            1.255           0.210
# L3.mean_gas_burned_log_differenced                   0.163356         1.715929            0.095           0.924
# L3.mean_message_cost_log_differenced                 5.204675         3.565762            1.460           0.144
# L4.mean_gas_fee_cap_log_differenced                  0.112452         0.261689            0.430           0.667
# L4.mean_gas_premium_log_differenced                  0.061533         0.047421            1.298           0.194
# L4.mean_gas_limit_log_differenced                    0.582854         2.092729            0.279           0.781
# L4.mean_gas_used_log_differenced                     3.743761         5.401331            0.693           0.488
# L4.mean_parent_base_fee_log_differenced              5.028712         4.561658            1.102           0.270
# L4.mean_base_fee_burn_log_differenced                1.288963         5.907320            0.218           0.827
# L4.mean_over_estimation_burn_log_differenced         4.412374         3.657760            1.206           0.228
# L4.mean_gas_refund_log_differenced                   1.261171         1.728752            0.730           0.466
# L4.mean_gas_burned_log_differenced                   0.815051         1.349308            0.604           0.546
# L4.mean_message_cost_log_differenced                -5.429604         3.443662           -1.577           0.115
# ===============================================================================================================
#
# Correlation matrix of residuals
#                                              mean_gas_fee_cap_log_differenced  mean_gas_premium_log_differenced  mean_gas_limit_log_differenced  mean_gas_used_log_differenced  mean_parent_base_fee_log_differenced  mean_base_fee_burn_log_differenced  mean_over_estimation_burn_log_differenced  mean_gas_refund_log_differenced  mean_gas_burned_log_differenced  mean_message_cost_log_differenced
# mean_gas_fee_cap_log_differenced                                     1.000000                          0.444128                       -0.064228                       0.050064                              0.650294                            0.647149                                   0.590575                         0.088848                        -0.051579                           0.625207
# mean_gas_premium_log_differenced                                     0.444128                          1.000000                        0.117953                       0.036643                              0.341257                            0.339985                                   0.362597                         0.066507                         0.164427                           0.355292
# mean_gas_limit_log_differenced                                      -0.064228                          0.117953                        1.000000                       0.776928                              0.034558                            0.079726                                   0.245565                         0.673782                         0.757489                           0.166815
# mean_gas_used_log_differenced                                        0.050064                          0.036643                        0.776928                       1.000000                              0.110537                            0.169259                                   0.206860                         0.858458                         0.381395                           0.190551
# mean_parent_base_fee_log_differenced                                 0.650294                          0.341257                        0.034558                       0.110537                              1.000000                            0.998168                                   0.959604                         0.205531                         0.101071                           0.987247
# mean_base_fee_burn_log_differenced                                   0.647149                          0.339985                        0.079726                       0.169259                              0.998168                            1.000000                                   0.963746                         0.255148                         0.122115                           0.990304
# mean_over_estimation_burn_log_differenced                            0.590575                          0.362597                        0.245565                       0.206860                              0.959604                            0.963746                                   1.000000                         0.291337                         0.374016                           0.991401
# mean_gas_refund_log_differenced                                      0.088848                          0.066507                        0.673782                       0.858458                              0.205531                            0.255148                                   0.291337                         1.000000                         0.359689                           0.276507
# mean_gas_burned_log_differenced                                     -0.051579                          0.164427                        0.757489                       0.381395                              0.101071                            0.122115                                   0.374016                         0.359689                         1.000000                           0.254249
# mean_message_cost_log_differenced                                    0.625207                          0.355292                        0.166815                       0.190551                              0.987247                            0.990304                                   0.991401                         0.276507                         0.254249                           1.000000

# %%
results.plot()

# %% [markdown]
# ## Granger causality
#
# Granger causality is a hypothesis test for determining whether one-time series is useful in forecasting another. We can say that a variable X, or variables, evolves Granger-causes another evolving variable Y if predictions of the value of Y based on its past values and the past values of X are better than predictions of Y based only on Y's past values.
#
# Granger Causality is relationship based on the following principles:
#
# * The cause happens before its effect.
# * The cause has 'unique' information about the future values of its effect.
#
#
# Given these two assumptions about causality, Granger proposed to test the following hypothesis for identification of a causal effect of $X$ on $Y$:
# $${P}[Y(t+1) \in A\mid \mathcal{I}(t)] \neq \mathbb{P}[Y(t+1) \in A\mid \mathcal{I}_{-X}(t)]$$
# where $\mathbb{P}$ refers to probability, $A$ is an arbitrary non-empty set, and $\mathcal{I}(t)$ and $\mathcal{I}_{-X}(t)$ respectively denote the information available as of time $t$ in the entire universe, and that in the modified universe in which $X$ is excluded. If the above hypothesis is accepted, we say that $X$ Granger causes $Y$.
#
# In our analysis, we present the hypothesis that gas_used is a driver of message cost. In statistical parlance, we have the following:
#
# * $H_O: \textrm{Gas used does not Granger cause message cost}$
# * $H_A: \textrm{Gas used does Granger cause message cost}$
#
#
# Granger Causality assumes that the time series are non-stationary, which we checked and passed above, and autoregressive lags greater than 1.
#
# We will perform now perform the Granger Causality hypothesis test with an $\alpha = 0.05$ value using an F test to determine if the gas used has any casual component for predicting the message cost. If the p-value (the probability of obtaining test results at least as extreme as the results observed) of the test is less than or equal to $\alpha$ we will reject the null hypothesis and determine that gas used is a driver of message cost.
#
# ### Paraphrased source:
# * https://en.wikipedia.org/wiki/Granger_causality

# %% [markdown]
# As we have many signals with the analysis, we will loop through all the signals, perform the Granger Causality test, and save the results for analysis.

# %%
alpha = 0.05
result_dfs = []
variables = list(log_differenced.columns)
for i in variables:
    for j in variables:
        if i==j:
            pass
        else:
            results_summary = results.test_causality(i,j, 
                                                     kind='f',signif=alpha).summary()


            df = pd.read_html(results_summary.as_html(),header=0, index_col=0)[0]
            df['alpha'] = alpha
            df['caused'] = i
            df['causing'] = j
            result_dfs.append(df)
        
Grangers_df = pd.concat(result_dfs)
Grangers_df.reset_index(inplace=True)
Grangers_df['result'] = Grangers_df['p-value'].apply(lambda x: 'reject H0' if x < alpha else 'fail to reject H0' )
Grangers_df
# Out:
#     Test statistic  Critical value  p-value          df  alpha  \
# 0           0.6569           2.373    0.622  (4, 12960)   0.05
# 1          20.5000           2.373    0.000  (4, 12960)   0.05
# 2           1.7600           2.373    0.134  (4, 12960)   0.05
# 3           0.4144           2.373    0.798  (4, 12960)   0.05
# 4           0.3121           2.373    0.870  (4, 12960)   0.05
# ..             ...             ...      ...         ...    ...
# 85          0.4789           2.373    0.751  (4, 12960)   0.05
# 86          3.1720           2.373    0.013  (4, 12960)   0.05
# 87          4.1780           2.373    0.002  (4, 12960)   0.05
# 88          6.0840           2.373    0.000  (4, 12960)   0.05
# 89          3.2340           2.373    0.012  (4, 12960)   0.05
#
#                                caused  \
# 0    mean_gas_fee_cap_log_differenced
# 1    mean_gas_fee_cap_log_differenced
# 2    mean_gas_fee_cap_log_differenced
# 3    mean_gas_fee_cap_log_differenced
# 4    mean_gas_fee_cap_log_differenced
# ..                                ...
# 85  mean_message_cost_log_differenced
# 86  mean_message_cost_log_differenced
# 87  mean_message_cost_log_differenced
# 88  mean_message_cost_log_differenced
# 89  mean_message_cost_log_differenced
#
#                                       causing             result
# 0            mean_gas_premium_log_differenced  fail to reject H0
# 1              mean_gas_limit_log_differenced          reject H0
# 2               mean_gas_used_log_differenced  fail to reject H0
# 3        mean_parent_base_fee_log_differenced  fail to reject H0
# 4          mean_base_fee_burn_log_differenced  fail to reject H0
# ..                                        ...                ...
# 85       mean_parent_base_fee_log_differenced  fail to reject H0
# 86         mean_base_fee_burn_log_differenced          reject H0
# 87  mean_over_estimation_burn_log_differenced          reject H0
# 88            mean_gas_refund_log_differenced          reject H0
# 89            mean_gas_burned_log_differenced          reject H0
#
# [90 rows x 8 columns]

# %%
heatdf = Grangers_df.pivot(index='caused', columns=['causing'],values=['p-value'])

f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(heatdf, annot=True, linewidths=.5, ax=ax,cmap=['green','red'],center=0.05)
plt.suptitle('Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')
# Out:
# Text(0.5, 0.98, 'Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')

# %% [markdown]
# Based on the heatmap above, we can see that there are some granger causal relationships between signals. To see more granular specifics, we will examine the reject H0s below

# %%
Grangers_df.query("result == 'reject H0'").sort_values('p-value',ascending=True)
# Out:
#     Test statistic  Critical value  p-value          df  alpha  \
# 1           20.500           2.373    0.000  (4, 12960)   0.05
# 56           9.713           2.373    0.000  (4, 12960)   0.05
# 74          10.200           2.373    0.000  (4, 12960)   0.05
# 54          24.740           2.373    0.000  (4, 12960)   0.05
# 53           7.002           2.373    0.000  (4, 12960)   0.05
# 88           6.084           2.373    0.000  (4, 12960)   0.05
# 51           7.008           2.373    0.000  (4, 12960)   0.05
# 47          12.340           2.373    0.000  (4, 12960)   0.05
# 45          29.820           2.373    0.000  (4, 12960)   0.05
# 44           7.009           2.373    0.000  (4, 12960)   0.05
# 60           5.203           2.373    0.000  (4, 12960)   0.05
# 62           6.820           2.373    0.000  (4, 12960)   0.05
# 81          27.650           2.373    0.000  (4, 12960)   0.05
# 38          13.390           2.373    0.000  (4, 12960)   0.05
# 36          30.230           2.373    0.000  (4, 12960)   0.05
# 9           16.910           2.373    0.000  (4, 12960)   0.05
# 83          11.010           2.373    0.000  (4, 12960)   0.05
# 42           7.139           2.373    0.000  (4, 12960)   0.05
# 29           4.818           2.373    0.001  (4, 12960)   0.05
# 41           4.199           2.373    0.002  (4, 12960)   0.05
# 50           4.335           2.373    0.002  (4, 12960)   0.05
# 16           4.117           2.373    0.002  (4, 12960)   0.05
# 87           4.178           2.373    0.002  (4, 12960)   0.05
# 64           4.142           2.373    0.002  (4, 12960)   0.05
# 28           3.864           2.373    0.004  (4, 12960)   0.05
# 43           3.708           2.373    0.005  (4, 12960)   0.05
# 52           3.584           2.373    0.006  (4, 12960)   0.05
# 89           3.234           2.373    0.012  (4, 12960)   0.05
# 40           3.187           2.373    0.013  (4, 12960)   0.05
# 86           3.172           2.373    0.013  (4, 12960)   0.05
# 79           2.933           2.373    0.020  (4, 12960)   0.05
# 61           2.906           2.373    0.020  (4, 12960)   0.05
# 59           2.882           2.373    0.021  (4, 12960)   0.05
# 7            2.859           2.373    0.022  (4, 12960)   0.05
# 55           2.527           2.373    0.039  (4, 12960)   0.05
# 6            2.529           2.373    0.039  (4, 12960)   0.05
# 82           2.419           2.373    0.046  (4, 12960)   0.05
#
#                                        caused  \
# 1            mean_gas_fee_cap_log_differenced
# 56  mean_over_estimation_burn_log_differenced
# 74            mean_gas_burned_log_differenced
# 54  mean_over_estimation_burn_log_differenced
# 53         mean_base_fee_burn_log_differenced
# 88          mean_message_cost_log_differenced
# 51         mean_base_fee_burn_log_differenced
# 47         mean_base_fee_burn_log_differenced
# 45         mean_base_fee_burn_log_differenced
# 44       mean_parent_base_fee_log_differenced
# 60  mean_over_estimation_burn_log_differenced
# 62  mean_over_estimation_burn_log_differenced
# 81          mean_message_cost_log_differenced
# 38       mean_parent_base_fee_log_differenced
# 36       mean_parent_base_fee_log_differenced
# 9            mean_gas_premium_log_differenced
# 83          mean_message_cost_log_differenced
# 42       mean_parent_base_fee_log_differenced
# 29              mean_gas_used_log_differenced
# 41       mean_parent_base_fee_log_differenced
# 50         mean_base_fee_burn_log_differenced
# 16           mean_gas_premium_log_differenced
# 87          mean_message_cost_log_differenced
# 64            mean_gas_refund_log_differenced
# 28              mean_gas_used_log_differenced
# 43       mean_parent_base_fee_log_differenced
# 52         mean_base_fee_burn_log_differenced
# 89          mean_message_cost_log_differenced
# 40       mean_parent_base_fee_log_differenced
# 86          mean_message_cost_log_differenced
# 79            mean_gas_burned_log_differenced
# 61  mean_over_estimation_burn_log_differenced
# 59  mean_over_estimation_burn_log_differenced
# 7            mean_gas_fee_cap_log_differenced
# 55  mean_over_estimation_burn_log_differenced
# 6            mean_gas_fee_cap_log_differenced
# 82          mean_message_cost_log_differenced
#
#                                       causing     result
# 1              mean_gas_limit_log_differenced  reject H0
# 56             mean_gas_limit_log_differenced  reject H0
# 74             mean_gas_limit_log_differenced  reject H0
# 54           mean_gas_fee_cap_log_differenced  reject H0
# 53          mean_message_cost_log_differenced  reject H0
# 88            mean_gas_refund_log_differenced  reject H0
# 51            mean_gas_refund_log_differenced  reject H0
# 47             mean_gas_limit_log_differenced  reject H0
# 45           mean_gas_fee_cap_log_differenced  reject H0
# 44          mean_message_cost_log_differenced  reject H0
# 60            mean_gas_refund_log_differenced  reject H0
# 62          mean_message_cost_log_differenced  reject H0
# 81           mean_gas_fee_cap_log_differenced  reject H0
# 38             mean_gas_limit_log_differenced  reject H0
# 36           mean_gas_fee_cap_log_differenced  reject H0
# 9            mean_gas_fee_cap_log_differenced  reject H0
# 83             mean_gas_limit_log_differenced  reject H0
# 42            mean_gas_refund_log_differenced  reject H0
# 29             mean_gas_limit_log_differenced  reject H0
# 41  mean_over_estimation_burn_log_differenced  reject H0
# 50  mean_over_estimation_burn_log_differenced  reject H0
# 16            mean_gas_burned_log_differenced  reject H0
# 87  mean_over_estimation_burn_log_differenced  reject H0
# 64           mean_gas_premium_log_differenced  reject H0
# 28           mean_gas_premium_log_differenced  reject H0
# 43            mean_gas_burned_log_differenced  reject H0
# 52            mean_gas_burned_log_differenced  reject H0
# 89            mean_gas_burned_log_differenced  reject H0
# 40         mean_base_fee_burn_log_differenced  reject H0
# 86         mean_base_fee_burn_log_differenced  reject H0
# 79            mean_gas_refund_log_differenced  reject H0
# 61            mean_gas_burned_log_differenced  reject H0
# 59         mean_base_fee_burn_log_differenced  reject H0
# 7             mean_gas_burned_log_differenced  reject H0
# 55           mean_gas_premium_log_differenced  reject H0
# 6             mean_gas_refund_log_differenced  reject H0
# 82           mean_gas_premium_log_differenced  reject H0

# %% [markdown]
# Based on the above table, we can see some Granger caused relationships between signals, such as mean_gas_fee_cap Granger causes mean_gas_limit. We can't fully use Granger until we understand what the signals are and what they represent better.

# %% [markdown]
# ## Conclusion
# In this notebook, we've provided proof of workflow for using VAR and Granger Causality to analyze the relationships between variables. In a subsequent notebook, we will examine the gas data more deeply to answer the following questions to use gained insight to improve Filecoin:
#
# * Understand data we have by performing a data baseline - event and aggregated data.
# * Reverse engineer June 3 spike - what happened and why? Can we generalize what drives burning?
# * Distribution of attributes of things people are willing to pay gas fees for. What types of transactions are individuals paying more for?
# * Are revenues over cost?
# * Create curated data signals for Digital Twin use
# * Obtain message metadata, try and predict cost from it (classifier or regressor). Which attributes are mapped to smaller or larger costs? Which messages are worth paying a lot for? The question is what people are they paying for and *why*?
# * Reperform Granger Causality when we have more data understanding
#
# ### Next steps from Filecoin sync:
# * ZX next steps: Spikes in burn and base fee movement might be a lag. What is the leading indicator?
# * Take different data aggregations instead of hourly. One week of data at 30 secs, for instance.
# * Look at a combination of messages.
# * From ZX: bad configuration file not from the code but a miner. Spamming the chain on June 3rd, a protective mechanism protects the chain
# * Explore weekly spikes - FT for periodic trend
# * Check for time-varying volatility. Compare to message types
# * Introduce exogenous variables such as delta network power (chain_powers, chain_economics, chain_rewards). Use state root and parent state root to combine, height if not available
