# %% [markdown]
# # EDA for Gas Fees
#
# In this notebook we perform Exploratory Data Analysis (EDA) on FIL's gas fee mechanism. The goal is to observe the gas fee as a signal and attempt to understand what may be driving it.
#
# Access was obtained to Sentinel from Filecoin, we will use the the `derived_gas_outputs` table as the primary data gathering table. [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md) was obtained on 6/28/2021 and will drive subsquent analysis.
#
#
# This notebook will do the following:
#
# 1. Analyze the `derived_gas_outputs` continuous signals for June 2021, mean aggregated by seconds.
# 2. Analyze the individual actors and methods for June 2021, and ascertain the most common methods, actors, and what drives gas usage.
# 3. Perform Fourier Analysis of the `derived_gas_outputs` continuous signals to understand phase shifts, periodicity, and leading indicators.
# 4. Combine the `derived_gas_outputs` with exogenous signals from the `chain_economics`, `chain_powers`, and `chain_rewards` tables.
# 5. Perform a VAR analysis and Granger Causality on the key signals combined from #4.
# 6. Generate conclusions from our research.
#
# ## Change Log
#
# ## TODO:
# * Decomposed Phase Shifts Overlay of specific exogenous chain signals with `derived_gas_outputs`
# * In-depth analysis of method distributions
#     ** Distribution of the gas_used by tuple (actor, method), with the “top 10” above a threshold being presented/visualized (threshold could be exogenous or backed out from quantile analysis).
# * In-depth Granger Causality analysis.
# * Conclusions
#
#
# ## What are Gas Fees?
# Note: this description is copied from the [official Filecoin documentation](https://docs.filecoin.io/about-filecoin/how-filecoin-works/#gas-fees)
#
# Executing messages, for example by including transactions or proofs in the chain, consumes both computation and storage resources on the network. Gas is a measure of resources consumed by messages. The gas consumed by a message directly affects the cost that the sender has to pay for it to be included in a new block by a miner.
#
# Historically in other blockchains, miners specify a GasFee in a unit of native currency and then pay the block producing miners a priority fee based on how much gas is consumed by the message. Filecoin works similarly, except an amount of the fees is burned (sent to an irrecoverable address) to compensate for the network expenditure of resources, since all nodes need to validate the messages. The idea is based on Ethereum's EIP1559.
#
# The amount of fees burned in the Filecoin network comes given by a dynamic BaseFee which gets automatically adjusted according to the network congestion parameters (block sizes). The current value can be obtained from one of the block explorers or by inspecting the current head.
#
# Additionally, a number of gas-related parameters are attached to each message and determine the amount of rewards that miners get. Here's an overview of the terms and concepts:
#
# **GasUsage**: the amount of gas that a message's execution actually consumes. Current protocol does not know how much gas a message will exactly consume ahead of execution, but it can be estimated (see prices (opens new window)). GasUsage measured in units of Gas.
#
# **BaseFee**: the amount of FIL that gets burned per unit of gas consumed for the execution of every message. It is measured in units of attoFIL/Gas.
#
# **GasLimit**: the limit on the amount of gas that a message's execution can consume, estimated and specified by a message sender. It is measured in units of Gas. The sum of GasLimit for all messages included in a block must not exceed the BlockGasLimit. Messages will fail to execute if they run out of Gas, and any effects of the execution will be reverted.
#
# **GasFeeCap**: the maximum token amount that a sender is willing to pay per GasUnit for including a message in a block. It is measured in units of attoFIL/Gas. A message sender must have a minimum balance of GasFeeCap * GasLimit when sending a message, even though not all of that will be consumed. GasFeeCap can serve as a safeguard against high, unexpected BaseFee fluctuations.
#
# **GasPremium**: a priority fee that is paid to the block-producing miner. This is capped by GasFeeCap. The BaseFee has a higher priority. It is measured in units of attoFIL/Gas and can be as low as 1 attoFIL/Gas.
#
# **Overestimation burn**: an additional amount of gas to burn that grows larger when the difference between GasLimit and GasUsage is large.
#
# The total cost of a message for a sender will be:
#
# * GasUsage * BaseFee FIL (burned) +
# * GasLimit * GasPremium FIL (miner's reward) +
# * OverEstimationBurn * BaseFee FIL
#
# An important detail is that a message will always pay the burn fee, regardless of the GasFeeCap used. Thus, a low GasFeeCap may result in a reduced GasPremium or even a negative one! In that case, the miners that include a message will have to pay the needed amounts out of their own pockets, which means they are unlikely to include such messages in new blocks.
#
# Filecoin implementations may choose the heuristics of how their miners select messages for inclusion in new blocks, but they will usually attempt to maximize the miner's rewards.
#
#
# ## Data Resources
# * https://hackmd.io/5leND7tITX--5NJsFCJyow # Existing Sentinel queries
# * https://github.com/filecoin-project/sentinel/blob/master/docs/sentinel_tables_purpose.csv # Sentinel Tables Purpose
#
#
# ### Sentinel Diagram
# ![](sentinel_diagram.png)

# %%
# import libraries
from sqlalchemy import create_engine
import pandas as pd
from datetime import datetime
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

from Cryptoeconomics_signal_processing import time_analysis, fourier_transform, phase_shift_overlay


# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %%
# load connection string
CONN_STRING_PATH = 'sentinel_conn_string_andrew.txt'

with open(CONN_STRING_PATH, 'r') as fid:
    conn_string = fid.read()
    
# create database connection.
connection = create_engine(conn_string, pool_recycle=3600).connect()

# %% [markdown]
# ## Data EDA
#
# Below we download minute averages from the `derived_gas_outputs` table from June 1st, 2021 to June 30th, 2021. After downloading the data, we few the first and lasts 5 rows, and perform basic statistics on the data.
#
# ### `derived_gas_outputs` - coped from [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md)
# Derived gas costs resulting from execution of a message in the VM.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`actor_name`|`text`|NO|Human readable identifier for the type of the actor.|
# |`base_fee_burn`|`text`|NO|The amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.|
# |`cid`|`text`|NO|CID of the message.|
# |`exit_code`|`bigint`|NO|The exit code that was returned as a result of executing the message. Exit code 0 indicates success. Codes 0-15 are reserved for use by the runtime. Codes 16-31 are common codes shared by different actors. Codes 32+ are actor specific.|
# |`from`|`text`|NO|Address of actor that sent the message.|
# |`gas_burned`|`bigint`|NO|The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_fee_cap`|`text`|NO|The maximum price that the message sender is willing to pay per unit of gas.|
# |`gas_limit`|`bigint`|YES|A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.|
# |`gas_premium`|`text`|NO|The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.|
# |`gas_refund`|`bigint`|NO|The overestimated units of gas to refund. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_used`|`bigint`|NO|A measure of the amount of resources (or units of gas) consumed, in order to execute a message.|
# |`height`|`bigint`|NO|Epoch this message was executed at.|
# |`method`|`bigint`|YES|The method number to invoke. Only unique to the actor the method is being invoked on. A method number of 0 is a plain token transfer - no method exectution.|
# |`miner_penalty`|`text`|NO|Any penalty fees (in attoFIL) the miner incured while executing the message.|
# |`miner_tip`|`text`|NO|The amount of FIL (in attoFIL) the miner receives for executing the message. Typically it is gas_premium * gas_limit but may be lower if the total fees exceed the gas_fee_cap.|
# |`nonce`|`bigint`|YES|The message nonce, which protects against duplicate messages and multiple messages with the same values.|
# |`over_estimation_burn`|`text`|NO|The fee to pay (in attoFIL) for overestimating the gas used to execute a message. The overestimated gas to burn (gas_burned) is a portion of the difference between gas_limit and gas_used. The over_estimation_burn value is gas_burned * parent_base_fee.|
# |`parent_base_fee`|`text`|NO|The set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.|
# |`refund`|`text`|NO|The amount of FIL (in attoFIL) to refund to the message sender after base fee, miner tip and overestimation amounts have been deducted.|
# |`size_bytes`|`bigint`|YES|Size in bytes of the serialized message.|
# |`state_root`|`text`|NO|CID of the parent state root.|
# |`to`|`text`|NO|Address of actor that received the message.|
# |`value`|`text`|NO|The FIL value transferred (attoFIL) to the message receiver.|

# %%
QUERY = """
SELECT 
date_trunc('second', 
to_timestamp(height_to_unix(d.height))) AS timestamp,
AVG(CAST(gas_fee_cap AS FLOAT)) AS mean_gas_fee_cap,
AVG(CAST(gas_premium AS FLOAT))  as mean_gas_premium,
AVG(CAST(gas_limit AS FLOAT))  as mean_gas_limit,
AVG(CAST(gas_used AS FLOAT))  as mean_gas_used,
AVG(CAST(parent_base_fee AS FLOAT))  as mean_parent_base_fee,
AVG(CAST(base_fee_burn AS FLOAT))  as mean_base_fee_burn,
AVG(CAST(over_estimation_burn AS FLOAT))  as mean_over_estimation_burn,
AVG(CAST(gas_refund AS FLOAT))  as mean_gas_refund,
AVG(CAST(gas_burned AS FLOAT))  as mean_gas_burned
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
GROUP BY
timestamp
"""
derived_gas_outputs_seconds = (pd.read_sql(QUERY, connection))
derived_gas_outputs_seconds
# Out:
#                       timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 0     2021-06-01 00:00:00+00:00      9.780685e+09      1.007070e+05
# 1     2021-06-01 00:00:30+00:00      5.766888e+09      1.030477e+05
# 2     2021-06-01 00:01:00+00:00      7.398405e+09      9.997686e+04
# 3     2021-06-01 00:01:30+00:00      3.868522e+09      1.020657e+05
# 4     2021-06-01 00:02:00+00:00      1.404787e+09      1.017654e+05
# ...                         ...               ...               ...
# 65431 2021-06-25 21:06:00+00:00      3.164766e+09      1.020460e+05
# 65432 2021-06-25 21:06:30+00:00      9.456574e+09      1.149751e+05
# 65433 2021-06-25 21:07:00+00:00      3.315390e+09      5.078945e+06
# 65434 2021-06-25 21:07:30+00:00      3.163443e+09      1.101461e+05
# 65435 2021-06-25 21:08:00+00:00      4.941351e+09      1.055196e+05
#
#        mean_gas_limit  mean_gas_used  mean_parent_base_fee  \
# 0        3.817361e+07   3.133535e+07                 111.0
# 1        3.901113e+07   3.181447e+07                 103.0
# 2        3.363575e+07   2.711274e+07                 102.0
# 3        3.715926e+07   3.069589e+07                 106.0
# 4        3.992063e+07   3.259273e+07                 107.0
# ...               ...            ...                   ...
# 65431    3.884412e+07   3.226553e+07           170023028.0
# 65432    3.902507e+07   3.182243e+07           168963696.0
# 65433    3.936482e+07   3.242953e+07           165428630.0
# 65434    3.738946e+07   3.073514e+07           158266476.0
# 65435    3.937116e+07   3.242696e+07           153245105.0
#
#        mean_base_fee_burn  mean_over_estimation_burn  mean_gas_refund  \
# 0            3.450383e+09               1.455183e+08     5.527290e+06
# 1            3.208506e+09               1.281268e+08     5.952711e+06
# 2            2.690713e+09               1.291310e+08     5.257021e+06
# 3            3.203752e+09               1.002643e+08     5.517480e+06
# 4            3.438982e+09               1.363375e+08     6.053718e+06
# ...                   ...                        ...              ...
# 65431        5.318526e+15               1.756533e+14     5.545477e+06
# 65432        5.303529e+15               2.279819e+14     5.853345e+06
# 65433        5.311727e+15               2.088412e+14     5.672865e+06
# 65434        4.832281e+15               1.742878e+14     5.553080e+06
# 65435        4.912118e+15               1.734196e+14     5.812553e+06
#
#        mean_gas_burned  mean_gas_burned
# 0         1.310976e+06         806640.0
# 1         1.243950e+06         806641.0
# 2         1.265990e+06         806642.0
# 3         9.458897e+05         806643.0
# 4         1.274183e+06         806644.0
# ...                ...              ...
# 65431     1.033115e+06         878292.0
# 65432     1.349295e+06         878293.0
# 65433     1.262425e+06         878294.0
# 65434     1.101230e+06         878295.0
# 65435     1.131648e+06         878296.0
#
# [65436 rows x 11 columns]

# %%
derived_gas_outputs_seconds.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count      6.543600e+04      6.543600e+04    6.543600e+04   6.543600e+04
# mean       9.357591e+09      1.508622e+06    3.995731e+07   3.225280e+07
# std        5.660231e+09      1.060948e+07    5.709517e+06   2.654426e+06
# min        5.746347e+08      7.597810e+04    2.102210e+07   1.250913e+07
# 25%        5.835170e+09      1.090498e+05    3.748555e+07   3.062374e+07
# 50%        8.523531e+09      2.938943e+05    3.925082e+07   3.196171e+07
# 75%        1.178597e+10      7.899887e+05    4.145283e+07   3.354076e+07
# max        4.005927e+11      1.491589e+09    3.333089e+08   1.403822e+08
#
#        mean_parent_base_fee  mean_base_fee_burn  mean_over_estimation_burn  \
# count          6.543600e+04        6.543600e+04               6.543600e+04
# mean           6.052492e+08        1.927083e+16               1.097841e+15
# std            5.232834e+08        1.686813e+16               1.752218e+15
# min            1.000000e+02        1.609273e+09               6.882097e+07
# 25%            1.980822e+08        6.249742e+15               2.816937e+14
# 50%            5.317592e+08        1.702560e+16               8.012988e+14
# 75%            9.407260e+08        3.025484e+16               1.501425e+15
# max            6.273926e+09        2.103278e+17               1.886474e+17
#
#        mean_gas_refund  mean_gas_burned  mean_gas_burned
# count     6.543600e+04     6.543600e+04     65436.000000
# mean      5.807281e+06     1.897236e+06    840389.136637
# std       6.029537e+05     4.701712e+06     20175.273372
# min       1.679725e+06     4.727735e+05    806640.000000
# 25%       5.430877e+06     1.178697e+06    823103.750000
# 50%       5.734689e+06     1.474088e+06    839597.500000
# 75%       6.096634e+06     1.927233e+06    856754.250000
# max       2.970918e+07     3.120059e+08    878296.000000

# %% [markdown]
# ### Messages calculation mapping
#
# Based on the message cost calculation outliend by Filecoin's official documentation, we will map the data obtained to this calculation.
#
# Filecoin:
# `message_cost_calculation =  GasUsage * BaseFee FIL (burned) + GasLimit * GasPremium FIL (miner reward) + OverEstimationBurn * BaseFee FIL`
#
#
# Our downloaded data:
# `message_cost = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn`

# %%
# create field
derived_gas_outputs_seconds['mean_message_cost'] = derived_gas_outputs_seconds.mean_gas_used * derived_gas_outputs_seconds.mean_base_fee_burn + derived_gas_outputs_seconds.mean_gas_limit * derived_gas_outputs_seconds.mean_gas_premium + derived_gas_outputs_seconds.mean_over_estimation_burn * derived_gas_outputs_seconds.mean_base_fee_burn

# %% [markdown]
# We will focus on analyzing the methods by actor type using the derived gas outputs table. The data is very large, so we will perform individul SQL queries in order to obtain all of the required data.

# %%
# # message level data
QUERY = """
SELECT DISTINCT
d.actor_name,
d.method
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
GROUP BY
d.actor_name,
d.method
"""
derived_gas_outputs_message_level_actors = (pd.read_sql(QUERY, connection))

# %% [markdown]
# Count of all actor types and methods used during June.

# %%
derived_gas_outputs_message_level_actors
# Out:
#                 actor_name  method
# 0            fil/4/account       0
# 1            fil/4/account       2
# 2            fil/4/account       3
# 3            fil/4/account       5
# 4               fil/4/init       2
# 5           fil/4/multisig       0
# 6           fil/4/multisig       2
# 7           fil/4/multisig       3
# 8     fil/4/paymentchannel       0
# 9      fil/4/storagemarket       2
# 10     fil/4/storagemarket       3
# 11     fil/4/storagemarket       4
# 12      fil/4/storageminer       0
# 13      fil/4/storageminer       3
# 14      fil/4/storageminer       4
# 15      fil/4/storageminer       5
# 16      fil/4/storageminer       6
# 17      fil/4/storageminer       7
# 18      fil/4/storageminer       8
# 19      fil/4/storageminer       9
# 20      fil/4/storageminer      10
# 21      fil/4/storageminer      11
# 22      fil/4/storageminer      15
# 23      fil/4/storageminer      16
# 24      fil/4/storageminer      18
# 25      fil/4/storageminer      20
# 26      fil/4/storageminer      21
# 27      fil/4/storageminer      22
# 28      fil/4/storageminer      23
# 29      fil/4/storageminer      24
# 30      fil/4/storagepower       2
# 31  fil/4/verifiedregistry       4
# 32               <unknown>       0
# 33               <unknown>       1

# %% [markdown]
# In order to understand what the specific methods signify, we have begun creating a mapping table from Filecoin's system code:
#
# https://docs.google.com/spreadsheets/d/13sfwHtT1YO94a37JmA956a1HcFJ_FtMQegu1oTE3WaQ/edit#gid=0
#
# Method types are not unique across actor types. Without having this formalized and connected to git commits, these values may be inaccurate.

# %%
# V1 - 6/27/2021
mapping = pd.read_csv('derived_gas_outputs_actor_name_methods_mapping - Mapping.csv')

# %% [markdown]
# Below we will query all Storage Market Actor transactions for June

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/account'
"""

derived_gas_outputs_message_level_account = (pd.read_sql(QUERY, connection))

# %%
derived_gas_outputs_message_level_account.groupby('method').mean()
# Out:
#         exit_code     gas_burned     gas_limit     gas_refund       gas_used  \
# method
# 0        0.048156  386066.199656  1.125480e+06  107376.948335  632036.795615
# 2        0.000000   24830.000000  6.099600e+05  110094.000000  475036.000000
#
#                height         nonce
# method
# 0       839688.493673  68801.032094
# 2       876589.000000      2.000000

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_account['Actor_name'] = 'Account'
method_analysis_account = derived_gas_outputs_message_level_account[['Actor_name','method','gas_used']]

# %%
# x is the number of occurrences relative to the number of transactions. Y is the amount
derived_gas_outputs_message_level_account.hist(column='gas_used', by='method', grid=True, legend=True)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'2'}>], dtype=object)

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/init'
"""

derived_gas_outputs_message_level_init = (pd.read_sql(QUERY, connection))

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_init['Actor_name'] = 'Init'
method_analysis_init = derived_gas_outputs_message_level_init[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_init.groupby('method').mean()
# Out:
#         exit_code     gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 2             0.0  501125.915825  1.447878e+07  2.471769e+06  1.150588e+07
#
#                height         nonce
# method
# 2       830846.138047  16144.882155

# %%
derived_gas_outputs_message_level_init.hist(column='gas_used', by='method', grid=True, legend=True)
# Out:
# <AxesSubplot:title={'center':'2'}>

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/multisig'
"""

derived_gas_outputs_message_level_multisig = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_multisig.groupby('method').mean()
# Out:
#         exit_code    gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 0        0.160000  3.488813e+05  9.141639e+05  9.319193e+04  4.720907e+05
# 2        0.004018  2.036784e+05  4.788744e+06  7.940924e+05  3.790973e+06
# 3        0.483541  3.238294e+06  1.280836e+07  1.780349e+06  7.789717e+06
#
#                height         nonce
# method
# 0       834170.826667  1.838881e+04
# 2       840257.946103  1.145058e+06
# 3       843223.340522  2.274213e+03

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_multisig['Actor_name'] = 'Multisig'
method_analysis_multisig = derived_gas_outputs_message_level_multisig[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_multisig.hist(column='gas_used', by='method', grid=True, legend=True,figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'2'}>],
#        [<AxesSubplot:title={'center':'3'}>, <AxesSubplot:>]], dtype=object)

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/paymentchannel'
"""

derived_gas_outputs_message_level_paymentchannel = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_paymentchannel.groupby('method').mean()
# Out:
#         exit_code    gas_burned      gas_limit    gas_refund       gas_used  \
# method
# 0             0.0  17172.955752  593422.389381  100130.99115  476118.442478
#
#                height       nonce
# method
# 0       823346.061947  811.353982

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_paymentchannel['Actor_name'] = 'Paych'
method_analysis_paymentchannel = derived_gas_outputs_message_level_paymentchannel[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_paymentchannel.hist(column='gas_used', by='method', grid=True, legend=True)
# Out:
# <AxesSubplot:title={'center':'0'}>

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/storagemarket'
"""

derived_gas_outputs_message_level_storage_market = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_storage_market.groupby('method').mean()
# Out:
#         exit_code    gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 2        0.000955  3.866017e+05  1.349397e+07  2.258054e+06  1.084931e+07
# 3        0.000000  1.272585e+07  2.623773e+07  2.286791e+06  1.122509e+07
# 4        0.030114  8.498993e+06  2.476325e+08  4.169819e+07  1.974353e+08
#
#                height         nonce
# method
# 2       836486.886581  41169.445971
# 3       831216.125000   2683.375000
# 4       843112.683866  43872.590225

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_storage_market['Actor_name'] = 'Market'
method_analysis_storage_market = derived_gas_outputs_message_level_storage_market[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_storage_market.hist(column='gas_used', by='method', grid=True, legend=True,figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>],
#        [<AxesSubplot:title={'center':'4'}>, <AxesSubplot:>]], dtype=object)

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/storageminer'
"""

derived_gas_outputs_message_level_storageminer = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_storageminer.groupby('method').mean()
# Out:
#         exit_code    gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 0        0.018462  1.172156e+05  6.237387e+05  6.090118e+04  4.456220e+05
# 3        0.045198  2.938107e+05  2.539031e+06  3.532886e+05  1.891932e+06
# 4        0.000000  4.360676e+04  2.090197e+06  3.176356e+05  1.728954e+06
# 5        0.052451  5.558300e+05  1.971669e+07  2.954045e+06  1.620682e+07
# 6        0.055100  6.718652e+05  1.977338e+07  3.074300e+06  1.602721e+07
# 7        0.089892  2.929378e+06  6.270802e+07  8.916632e+06  5.086201e+07
# 8        0.019830  7.437610e+07  2.483830e+09  4.212528e+08  1.988201e+09
# 9        0.074813  2.760740e+07  6.465330e+07  6.138717e+06  3.090718e+07
# 11       0.035007  2.940463e+06  2.198202e+07  3.101679e+06  1.593988e+07
# 15       2.388889  4.298549e+05  1.532378e+07  2.533131e+06  1.236079e+07
# 16       0.001275  2.420757e+06  1.391242e+07  1.907470e+06  9.584193e+06
# 18       0.000000  3.844134e+04  2.046858e+06  3.113173e+05  1.697099e+06
# 20       0.000000  1.439640e+05  9.168350e+06  1.256760e+06  7.767626e+06
# 21       0.000000  4.473285e+04  1.980709e+06  3.152494e+05  1.620726e+06
# 22       0.000000  2.181283e+04  1.525721e+06  2.213645e+05  1.282544e+06
# 23       0.024691  9.498679e+04  2.131708e+06  3.405317e+05  1.696189e+06
#
#                height          nonce
# method
# 0       839000.169231  243145.073846
# 3       833247.644068    7079.451977
# 4       844069.485915   17625.760563
# 5       840926.630017   32157.544676
# 6       840074.199393  431245.627770
# 7       840213.500386  432652.855976
# 8       844062.016997  162953.864023
# 9       853350.394846   12185.644638
# 11      837944.797043   24534.624423
# 15      839314.722222      37.333333
# 16      840182.515844   26061.253688
# 18      843710.422360   25664.018634
# 20      845832.415789  615218.605263
# 21      826849.925926   15576.518519
# 22      840974.666667   23625.333333
# 23      838317.185185   13688.895062

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_storageminer['Actor_name'] = 'Miner'
method_analysis_storageminer = derived_gas_outputs_message_level_storageminer[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_storageminer.hist(column='gas_used', by='method', grid=True, legend=True,figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'3'}>,
#         <AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'5'}>],
#        [<AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>,
#         <AxesSubplot:title={'center':'8'}>,
#         <AxesSubplot:title={'center':'9'}>],
#        [<AxesSubplot:title={'center':'11'}>,
#         <AxesSubplot:title={'center':'15'}>,
#         <AxesSubplot:title={'center':'16'}>,
#         <AxesSubplot:title={'center':'18'}>],
#        [<AxesSubplot:title={'center':'20'}>,
#         <AxesSubplot:title={'center':'21'}>,
#         <AxesSubplot:title={'center':'22'}>,
#         <AxesSubplot:title={'center':'23'}>]], dtype=object)

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/storagepower'
"""

derived_gas_outputs_message_level_storagepower = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_storagepower.groupby('method').mean()
# Out:
#         exit_code    gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 2        0.014085  1.242660e+06  3.364369e+07  5.546948e+06  2.685408e+07
#
#                height        nonce
# method
# 2       836996.287726  2191.961771

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_storagepower['Actor_name'] = 'Power'
method_analysis_storagepower = derived_gas_outputs_message_level_storagepower[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_storagepower.hist(column='gas_used', by='method')
# Out:
# <AxesSubplot:title={'center':'2'}>

# %%
# # message level data
QUERY = """
SELECT 
d.base_fee_burn,
d.exit_code,
d.gas_burned,
d.gas_fee_cap,
d.gas_limit,
d.gas_premium,
d.gas_refund,
d.gas_used,
d.height,
d.method,
d.miner_penalty,
d.miner_tip,
d.nonce,
d.over_estimation_burn,
d.parent_base_fee,
d.refund
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
AND d.actor_name = 'fil/4/verifiedregistry'
"""

derived_gas_outputs_message_level_verifiedregistry = (pd.read_sql(QUERY, connection))

derived_gas_outputs_message_level_verifiedregistry.groupby('method').mean()
# Out:
#         exit_code     gas_burned     gas_limit    gas_refund      gas_used  \
# method
# 4             0.0  210806.315789  7.106251e+06  1.204559e+06  5.690886e+06
#
#                height       nonce
# method
# 4       837596.763158  242.868421

# %%
# add column and subset dataframe
derived_gas_outputs_message_level_verifiedregistry['Actor_name'] = 'Verified Registry'
method_analysis_verifiedregistry = derived_gas_outputs_message_level_verifiedregistry[['Actor_name','method','gas_used']]

# %%
derived_gas_outputs_message_level_verifiedregistry.hist(column='gas_used', by='method', grid=True, legend=True)
plt.title('Verified Registry Actor')
# Out:
# Text(0.5, 1.0, 'Verified Registry Actor')

# %%
method_analysis = pd.concat([method_analysis_paymentchannel,method_analysis_multisig,
                             method_analysis_init,method_analysis_account,method_analysis_storagepower,
                             method_analysis_verifiedregistry,method_analysis_storageminer,
                             method_analysis_storage_market])

# %%
mapping.fillna(0,inplace=True)

mapping['Method number'] = mapping['Method number'].astype(int)

# %%
mapping.head()
# Out:
#   Actor_name Derived_gas_ouputs_name  Actor_description  Method number  \
# 0     Market     fil/4/storagemarket                0.0              0
# 1     Market     fil/4/storagemarket                0.0              2
# 2     Market     fil/4/storagemarket                0.0              3
# 3     Market     fil/4/storagemarket                0.0              4
# 4     Market     fil/4/storagemarket                0.0              5
#
#                      Method  Method_description  \
# 0               Constructor                 0.0
# 1                AddBalance                 0.0
# 2           WithdrawBalance                 0.0
# 3       PublishStorageDeals                 0.0
# 4  VerifyDealsForActivation                 0.0
#
#                                            Reference
# 0  https://github.com/filecoin-project/specs-acto...
# 1  https://github.com/filecoin-project/specs-acto...
# 2  https://github.com/filecoin-project/specs-acto...
# 3  https://github.com/filecoin-project/specs-acto...
# 4  https://github.com/filecoin-project/specs-acto...

# %%
method_analysis = pd.merge(method_analysis, mapping,  how='left', left_on=['Actor_name','method'], 
                           right_on = ['Actor_name','Method number'])

# %%
method_analysis.head()
# Out:
#   Actor_name  method  gas_used Derived_gas_ouputs_name  Actor_description  \
# 0      Paych       0    486668    fil/4/paymentchannel                0.0
# 1      Paych       0    481468    fil/4/paymentchannel                0.0
# 2      Paych       0    486668    fil/4/paymentchannel                0.0
# 3      Paych       0    486668    fil/4/paymentchannel                0.0
# 4      Paych       0    432068    fil/4/paymentchannel                0.0
#
#    Method number       Method  Method_description  \
# 0              0  Constructor                 0.0
# 1              0  Constructor                 0.0
# 2              0  Constructor                 0.0
# 3              0  Constructor                 0.0
# 4              0  Constructor                 0.0
#
#                                            Reference
# 0  https://github.com/filecoin-project/specs-acto...
# 1  https://github.com/filecoin-project/specs-acto...
# 2  https://github.com/filecoin-project/specs-acto...
# 3  https://github.com/filecoin-project/specs-acto...
# 4  https://github.com/filecoin-project/specs-acto...

# %%
method_analysis_subset = method_analysis[['gas_used','Method']] # Actor_name'

# %%
method_analysis_subset.hist(by='Method',bins=30, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:title={'center':'AddBalance'}>,
#         <AxesSubplot:title={'center':'AddVerifiedClient'}>,
#         <AxesSubplot:title={'center':'Approve'}>,
#         <AxesSubplot:title={'center':'ChangeMultiaddrs'}>,
#         <AxesSubplot:title={'center':'ChangeOwnerAddress'}>],
#        [<AxesSubplot:title={'center':'ChangePeerID'}>,
#         <AxesSubplot:title={'center':'ChangeWorkerAddress'}>,
#         <AxesSubplot:title={'center':'CompactSectorNumbers'}>,
#         <AxesSubplot:title={'center':'ConfirmUpdateWorkerKey'}>,
#         <AxesSubplot:title={'center':'Constructor'}>],
#        [<AxesSubplot:title={'center':'CreateMiner'}>,
#         <AxesSubplot:title={'center':'DeclareFaultsRecovered'}>,
#         <AxesSubplot:title={'center':'Exec'}>,
#         <AxesSubplot:title={'center':'ExtendSectorExpiration'}>,
#         <AxesSubplot:title={'center':'PreCommitSector'}>],
#        [<AxesSubplot:title={'center':'Propose'}>,
#         <AxesSubplot:title={'center':'ProveCommitSector'}>,
#         <AxesSubplot:title={'center':'PubkeyAddress'}>,
#         <AxesSubplot:title={'center':'PublishStorageDeals'}>,
#         <AxesSubplot:title={'center':'RepayDebt'}>],
#        [<AxesSubplot:title={'center':'ReportConsensusFault'}>,
#         <AxesSubplot:title={'center':'SubmitWindowedPoS'}>,
#         <AxesSubplot:title={'center':'TerminateSectors'}>,
#         <AxesSubplot:title={'center':'WithdrawBalance'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Time Analysis
#
# When examining the derived_gas_outputs_message_level, we developed the following two questions:
# 1. Is the distribution of intervals between data points consistent?
# 2. What type of samplimg time do we have?
#
# <!-- Write out workflow for analyzing blockchain dataset. Flow chart for what is natural, etc -->
# Workflow:
#     1. Verify sampling intervals
#     2. Verify distributions. If not normal, poisson, etc
#
# To answer these questions, we will calculate the timestamp difference and create a histogram of the time differences and determine if we have equal time sampling or not.

# %%
derived_gas_outputs_seconds['time'] = derived_gas_outputs_seconds['timestamp'].apply(lambda x: x.value)

# %%
time_analysis(derived_gas_outputs_seconds,'time')

# %% [markdown]
# ## Exogenous signals
#
# https://github.com/filecoin-project/sentinel/blob/master/docs/db.md
#
# ## `chain_economics`
# Economic summaries per state root CID.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`burnt_fil`|`text`|NO|Total FIL (attoFIL) burned as part of penalties and on-chain computations.|
# |`circulating_fil`|`text`|NO|The amount of FIL (attoFIL) circulating and tradeable in the economy. The basis for Market Cap calculations.|
# |`locked_fil`|`text`|NO|The amount of FIL (attoFIL) locked as part of mining, deals, and other mechanisms.|
# |`mined_fil`|`text`|NO|The amount of FIL (attoFIL) that has been mined by storage miners.|
# |`parent_state_root`|`text`|NO|CID of the parent state root.|
# |`vested_fil`|`text`|NO|Total amount of FIL (attoFIL) that is vested from genesis allocation.|
#
#
# ## `chain_powers`
# Power summaries from the Power actor.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`height`|`bigint`|NO|Epoch this power summary applies to.|
# |`miner_count`|`bigint`|YES|Total number of miners.|
# |`participating_miner_count`|`bigint`|YES|Total number of miners with power above the minimum miner threshold.|
# |`qa_smoothed_position_estimate`|`text`|NO|Total power smoothed position estimate - Alpha Beta Filter "position" (value) estimate in Q.128 format.|
# |`qa_smoothed_velocity_estimate`|`text`|NO|Total power smoothed velocity estimate - Alpha Beta Filter "velocity" (rate of change of value) estimate in Q.128 format.|
# |`state_root`|`text`|NO|CID of the parent state root.|
# |`total_pledge_collateral`|`text`|NO|Total locked FIL (attoFIL) miners have pledged as collateral in order to participate in the economy.|
# |`total_qa_bytes_committed`|`text`|NO|Total provably committed, quality adjusted storage power in bytes. Quality adjusted power is a weighted average of the quality of its space and it is based on the size, duration and quality of its deals.|
# |`total_qa_bytes_power`|`text`|NO|Total quality adjusted storage power in bytes in the network. Quality adjusted power is a weighted average of the quality of its space and it is based on the size, duration and quality of its deals.|
# |`total_raw_bytes_committed`|`text`|NO|Total provably committed storage power in bytes. Raw byte power is the size of a sector in bytes.|
# |`total_raw_bytes_power`|`text`|NO|Total storage power in bytes in the network. Raw byte power is the size of a sector in bytes.|
#
#
# ## `chain_rewards`
# Reward summaries from the Reward actor.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`cum_sum_baseline`|`text`|NO|Target that CumsumRealized needs to reach for EffectiveNetworkTime to increase. It is measured in byte-epochs (space * time) representing power committed to the network for some duration.|
# |`cum_sum_realized`|`text`|NO|Cumulative sum of network power capped by BaselinePower(epoch). It is measured in byte-epochs (space * time) representing power committed to the network for some duration.|
# |`effective_baseline_power`|`text`|NO|The baseline power (in bytes) at the EffectiveNetworkTime epoch.|
# |`effective_network_time`|`bigint`|YES|Ceiling of real effective network time "theta" based on CumsumBaselinePower(theta) == CumsumRealizedPower. Theta captures the notion of how much the network has progressed in its baseline and in advancing network time.|
# |`height`|`bigint`|NO|Epoch this rewards summary applies to.|
# |`new_baseline_power`|`text`|NO|The baseline power (in bytes) the network is targeting.|
# |`new_reward`|`text`|YES|The reward to be paid in per WinCount to block producers. The actual reward total paid out depends on the number of winners in any round. This value is recomputed every non-null epoch and used in the next non-null epoch.|
# |`new_reward_smoothed_position_estimate`|`text`|NO|Smoothed reward position estimate - Alpha Beta Filter "position" (value) estimate in Q.128 format.|
# |`new_reward_smoothed_velocity_estimate`|`text`|NO|Smoothed reward velocity estimate - Alpha Beta Filter "velocity" (rate of change of value) estimate in Q.128 format.|
# |`state_root`|`text`|NO|CID of the parent state root.|
# |`total_mined_reward`|`text`|NO|The total FIL (attoFIL) awarded to block miners.|

# %%
QUERY = """
SELECT 
date_trunc('second', 
to_timestamp(height_to_unix(cr.height))) AS timestamp,
AVG(CAST(cr.cum_sum_baseline AS FLOAT)) AS mean_cum_sum_baseline,
AVG(CAST(cr.cum_sum_realized AS FLOAT)) AS mean_cum_sum_realized,
AVG(CAST(cr.effective_baseline_power AS FLOAT)) AS mean_effective_baseline_power,
AVG(CAST(cr.effective_network_time AS FLOAT)) AS mean_effective_network_time,
AVG(CAST(cr.new_baseline_power AS FLOAT)) AS mean_new_baseline_power,
AVG(CAST(cr.new_reward AS FLOAT)) AS mean_new_reward,
AVG(CAST(cr.new_reward_smoothed_position_estimate AS FLOAT)) AS mean_new_reward_smoothed_position_estimate,
AVG(CAST(cr.new_reward_smoothed_velocity_estimate AS FLOAT)) AS mean_new_reward_smoothed_velocity_estimate,
AVG(CAST(cr.total_mined_reward AS FLOAT)) AS mean_total_mined_reward,
AVG(CAST(cp.miner_count AS FLOAT)) AS mean_miner_count,
AVG(CAST(cp.participating_miner_count AS FLOAT)) AS mean_participating_miner_count,
AVG(CAST(cp.qa_smoothed_position_estimate AS FLOAT)) AS mean_qa_smoothed_position_estimate,
AVG(CAST(cp.qa_smoothed_velocity_estimate AS FLOAT)) AS mean_qa_smoothed_velocity_estimate,
AVG(CAST(cp.total_pledge_collateral AS FLOAT)) AS mean_total_pledge_collateral,
AVG(CAST(cp.total_qa_bytes_committed AS FLOAT)) AS mean_total_qa_bytes_committed,
AVG(CAST(cp.total_qa_bytes_power AS FLOAT)) AS mean_total_qa_bytes_power,
AVG(CAST(cp.total_raw_bytes_committed AS FLOAT)) AS mean_total_raw_bytes_committed,
AVG(CAST(cp.total_raw_bytes_power AS FLOAT)) AS mean_total_raw_bytes_power,
AVG(CAST(ce.burnt_fil AS FLOAT)) AS mean_burnt_fil,
AVG(CAST(ce.circulating_fil AS FLOAT)) AS mean_circulating_fil,
AVG(CAST(ce.locked_fil AS FLOAT)) AS mean_locked_fil,
AVG(CAST(ce.mined_fil AS FLOAT)) AS mean_mined_fil,
AVG(CAST(ce.vested_fil AS FLOAT)) AS mean_vested_fil
FROM chain_rewards cr
LEFT JOIN chain_powers cp
ON cr.state_root = cp.state_root
LEFT JOIN chain_economics ce
ON cr.state_root = ce.parent_state_root
WHERE
to_timestamp(height_to_unix(cr.height)) BETWEEN '2021-06-01' AND '2021-06-30'
GROUP BY
timestamp
"""
chain_economics_seconds = (pd.read_sql(QUERY, connection))

# %%
chain_economics_seconds.describe()
# Out:
#        mean_cum_sum_baseline  mean_cum_sum_realized  \
# count           6.830200e+04           6.830200e+04
# mean            2.075731e+24           2.075729e+24
# std             1.030420e+23           1.030419e+23
# min             1.901761e+24           1.901758e+24
# 25%             1.986752e+24           1.986749e+24
# 50%             2.072819e+24           2.072819e+24
# 75%             2.162561e+24           2.162557e+24
# max             2.262577e+24           2.262574e+24
#
#        mean_effective_baseline_power  mean_effective_network_time  \
# count                   6.830200e+04                 68302.000000
# mean                    4.257598e+18                587979.695983
# std                     6.794448e+16                 24190.916211
# min                     4.142884e+18                546751.000000
# 25%                     4.198926e+18                567128.250000
# 50%                     4.255678e+18                587488.500000
# 75%                     4.314852e+18                608430.750000
# max                     4.380802e+18                631435.000000
#
#        mean_new_baseline_power  mean_new_reward  \
# count             6.830200e+04     6.830200e+04
# mean              5.032011e+18     1.266198e+20
# std               6.794446e+16     5.526398e+17
# min               4.917297e+18     1.256329e+20
# 25%               4.973338e+18     1.261517e+20
# 50%               5.030091e+18     1.266282e+20
# 75%               5.089264e+18     1.270956e+20
# max               5.155214e+18     1.275672e+20
#
#        mean_new_reward_smoothed_position_estimate  \
# count                                6.830200e+04
# mean                                 4.308646e+58
# std                                  1.880531e+56
# min                                  4.275064e+58
# 25%                                  4.292717e+58
# 50%                                  4.308934e+58
# 75%                                  4.324836e+58
# max                                  4.340886e+58
#
#        mean_new_reward_smoothed_velocity_estimate  mean_total_mined_reward  \
# count                                6.830200e+04             6.830200e+04
# mean                                -9.209495e+51             7.488879e+25
# std                                  1.148856e+50             2.543487e+24
# min                                 -9.407656e+51             7.054874e+25
# 25%                                 -9.308269e+51             7.269226e+25
# 50%                                 -9.210656e+51             7.484272e+25
# 75%                                 -9.111992e+51             7.704208e+25
# max                                 -9.005591e+51             7.944841e+25
#
#        mean_miner_count  ...  mean_total_pledge_collateral  \
# count      68302.000000  ...                  6.830200e+04
# mean      541428.969518  ...                  8.193583e+25
# std          112.127300  ...                  2.071724e+24
# min       541144.000000  ...                  7.830897e+25
# 25%       541320.000000  ...                  8.015821e+25
# 50%       541433.000000  ...                  8.194413e+25
# 75%       541522.000000  ...                  8.370614e+25
# max       541675.000000  ...                  8.555104e+25
#
#        mean_total_qa_bytes_committed  mean_total_qa_bytes_power  \
# count                   6.830200e+04               6.830200e+04
# mean                    7.279861e+18               7.279417e+18
# std                     3.038774e+17               3.039017e+17
# min                     6.721132e+18               6.720618e+18
# 25%                     7.029193e+18               7.028735e+18
# 50%                     7.278476e+18               7.278044e+18
# 75%                     7.540526e+18               7.540101e+18
# max                     7.811410e+18               7.810959e+18
#
#        mean_total_raw_bytes_committed  mean_total_raw_bytes_power  \
# count                    6.830200e+04                6.830200e+04
# mean                     7.277582e+18                7.277150e+18
# std                      3.037560e+17                3.037753e+17
# min                      6.719005e+18                6.718506e+18
# 25%                      7.027061e+18                7.026621e+18
# 50%                      7.276247e+18                7.275828e+18
# 75%                      7.538150e+18                7.537725e+18
# max                      7.808863e+18                7.808420e+18
#
#        mean_burnt_fil  mean_circulating_fil  mean_locked_fil  mean_mined_fil  \
# count    6.830200e+04          6.830200e+04     6.830200e+04    6.830200e+04
# mean     2.637642e+25          1.338597e+26     8.194477e+25    7.488879e+25
# std      2.614020e+23          2.807830e+24     2.072242e+24    2.543487e+24
# min      2.604027e+25          1.290679e+26     7.831719e+25    7.054874e+25
# 25%      2.611242e+25          1.314683e+26     8.016666e+25    7.269226e+25
# 50%      2.639213e+25          1.337339e+26     8.195301e+25    7.484272e+25
# 75%      2.661928e+25          1.361920e+26     8.371553e+25    7.704208e+25
# max      2.683840e+25          1.390086e+26     8.556099e+25    7.944841e+25
#
#        mean_vested_fil
# count     6.830200e+04
# mean      1.502255e+26
# std       2.594572e+24
# min       1.458100e+26
# 25%       1.479885e+26
# 50%       1.501697e+26
# 75%       1.524179e+26
# max       1.548930e+26
#
# [8 rows x 23 columns]

# %%
chain_economics_seconds.fillna(0,inplace=True)

# %%
chain_economics_seconds['time'] = chain_economics_seconds['timestamp'].apply(lambda x: x.value)

time_analysis(chain_economics_seconds,'time')

# %%
# remove duplicated columns 
del derived_gas_outputs_seconds['time']
del derived_gas_outputs_seconds['timestampDiff']

del chain_economics_seconds['time']
del chain_economics_seconds['timestampDiff']

# %%
# combine signals
combined = derived_gas_outputs_seconds.merge(chain_economics_seconds,how='left',on='timestamp')
combined.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count      6.543600e+04      6.543600e+04    6.543600e+04   6.543600e+04
# mean       9.357591e+09      1.508622e+06    3.995731e+07   3.225280e+07
# std        5.660231e+09      1.060948e+07    5.709517e+06   2.654426e+06
# min        5.746347e+08      7.597810e+04    2.102210e+07   1.250913e+07
# 25%        5.835170e+09      1.090498e+05    3.748555e+07   3.062374e+07
# 50%        8.523531e+09      2.938943e+05    3.925082e+07   3.196171e+07
# 75%        1.178597e+10      7.899887e+05    4.145283e+07   3.354076e+07
# max        4.005927e+11      1.491589e+09    3.333089e+08   1.403822e+08
#
#        mean_parent_base_fee  mean_base_fee_burn  mean_over_estimation_burn  \
# count          6.543600e+04        6.543600e+04               6.543600e+04
# mean           6.052492e+08        1.927083e+16               1.097841e+15
# std            5.232834e+08        1.686813e+16               1.752218e+15
# min            1.000000e+02        1.609273e+09               6.882097e+07
# 25%            1.980822e+08        6.249742e+15               2.816937e+14
# 50%            5.317592e+08        1.702560e+16               8.012988e+14
# 75%            9.407260e+08        3.025484e+16               1.501425e+15
# max            6.273926e+09        2.103278e+17               1.886474e+17
#
#        mean_gas_refund  mean_gas_burned  mean_gas_burned  ...  \
# count     6.543600e+04     6.543600e+04     65436.000000  ...
# mean      5.807281e+06     1.897236e+06    840389.136637  ...
# std       6.029537e+05     4.701712e+06     20175.273372  ...
# min       1.679725e+06     4.727735e+05    806640.000000  ...
# 25%       5.430877e+06     1.178697e+06    823103.750000  ...
# 50%       5.734689e+06     1.474088e+06    839597.500000  ...
# 75%       6.096634e+06     1.927233e+06    856754.250000  ...
# max       2.970918e+07     3.120059e+08    878296.000000  ...
#
#        mean_total_pledge_collateral  mean_total_qa_bytes_committed  \
# count                  6.543600e+04                   6.543600e+04
# mean                   8.182715e+25                   7.264035e+18
# std                    2.044182e+24                   2.999772e+17
# min                    7.830897e+25                   6.721132e+18
# 25%                    8.008303e+25                   7.008570e+18
# 50%                    8.179926e+25                   7.256822e+18
# 75%                    8.350048e+25                   7.507031e+18
# max                    8.555075e+25                   7.811410e+18
#
#        mean_total_qa_bytes_power  mean_total_raw_bytes_committed  \
# count               6.543600e+04                    6.543600e+04
# mean                7.263590e+18                    7.261762e+18
# std                 3.000021e+17                    2.998582e+17
# min                 6.720618e+18                    6.719005e+18
# 25%                 7.008116e+18                    7.006549e+18
# 50%                 7.256380e+18                    7.254549e+18
# 75%                 7.506603e+18                    7.504659e+18
# max                 7.810959e+18                    7.808863e+18
#
#        mean_total_raw_bytes_power  mean_burnt_fil  mean_circulating_fil  \
# count                6.543600e+04    6.543600e+04          6.543600e+04
# mean                 7.261330e+18    2.636235e+25          1.337101e+26
# std                  2.998782e+17    2.573888e+23          2.766095e+24
# min                  6.718506e+18    2.604027e+25          1.290679e+26
# 25%                  7.006113e+18    2.610745e+25          1.313683e+26
# 50%                  7.254122e+18    2.636385e+25          1.335452e+26
# 75%                  7.504232e+18    2.658460e+25          1.359249e+26
# max                  7.808420e+18    2.683839e+25          1.390085e+26
#
#        mean_locked_fil  mean_mined_fil  mean_vested_fil
# count     6.543600e+04    6.543600e+04     6.543600e+04
# mean      8.183607e+25    7.475401e+25     1.500879e+26
# std       2.044691e+24    2.507272e+24     2.557349e+24
# min       7.831719e+25    7.054874e+25     1.458100e+26
# 25%       8.009148e+25    7.260372e+25     1.478969e+26
# 50%       8.180813e+25    7.466295e+25     1.499876e+26
# 75%       8.350980e+25    7.679039e+25     1.521623e+26
# max       8.556070e+25    7.944809e+25     1.548929e+26
#
# [8 rows x 43 columns]

# %%
combined.head()
# Out:
#                   timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 0 2021-06-01 00:00:00+00:00      9.780685e+09     100706.952922
# 1 2021-06-01 00:00:30+00:00      5.766888e+09     103047.672956
# 2 2021-06-01 00:01:00+00:00      7.398405e+09      99976.861111
# 3 2021-06-01 00:01:30+00:00      3.868522e+09     102065.719647
# 4 2021-06-01 00:02:00+00:00      1.404787e+09     101765.362069
#
#    mean_gas_limit  mean_gas_used  mean_parent_base_fee  mean_base_fee_burn  \
# 0    3.817361e+07   3.133535e+07                 111.0        3.450383e+09
# 1    3.901113e+07   3.181447e+07                 103.0        3.208506e+09
# 2    3.363575e+07   2.711274e+07                 102.0        2.690713e+09
# 3    3.715926e+07   3.069589e+07                 106.0        3.203752e+09
# 4    3.992063e+07   3.259273e+07                 107.0        3.438982e+09
#
#    mean_over_estimation_burn  mean_gas_refund  mean_gas_burned  ...  \
# 0               1.455183e+08     5.527290e+06     1.310976e+06  ...
# 1               1.281268e+08     5.952711e+06     1.243950e+06  ...
# 2               1.291310e+08     5.257021e+06     1.265990e+06  ...
# 3               1.002643e+08     5.517480e+06     9.458897e+05  ...
# 4               1.363375e+08     6.053718e+06     1.274183e+06  ...
#
#    mean_total_pledge_collateral  mean_total_qa_bytes_committed  \
# 0                  7.830897e+25                   6.794697e+18
# 1                  7.830927e+25                   6.794700e+18
# 2                  7.830943e+25                   6.794702e+18
# 3                  7.830952e+25                   6.794849e+18
# 4                  7.830966e+25                   6.794849e+18
#
#    mean_total_qa_bytes_power  mean_total_raw_bytes_committed  \
# 0               6.794196e+18                    6.792564e+18
# 1               6.794199e+18                    6.792568e+18
# 2               6.794201e+18                    6.792570e+18
# 3               6.794348e+18                    6.792717e+18
# 4               6.794348e+18                    6.792717e+18
#
#    mean_total_raw_bytes_power  mean_burnt_fil  mean_circulating_fil  \
# 0                6.792079e+18    2.604027e+25          1.290679e+26
# 1                6.792083e+18    2.604027e+25          1.290680e+26
# 2                6.792085e+18    2.604028e+25          1.290680e+26
# 3                6.792231e+18    2.604028e+25          1.290681e+26
# 4                6.792231e+18    2.604028e+25          1.290682e+26
#
#    mean_locked_fil  mean_mined_fil  mean_vested_fil
# 0     7.831719e+25    7.054874e+25     1.458100e+26
# 1     7.831749e+25    7.054899e+25     1.458101e+26
# 2     7.831765e+25    7.054910e+25     1.458102e+26
# 3     7.831774e+25    7.054915e+25     1.458104e+26
# 4     7.831788e+25    7.054922e+25     1.458105e+26
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Fourier Transform Analysis
#
# We will plot each signal, save for the timestamp, below and perform Fourier transforms to search for periodicity.
#
# A Fourier transform (FT) is a mathematical method for decomposing a signal into a sum of periodic components. Used frequently in signal processing to understand trends and for filtering. we will use the common Fast Fourier Transform (FFT) algorithm to calculate discrete Fourier transform (DFT) of each signal.
#
# ### Resources:
# * https://github.com/Kommandat/seasonality-fourier-analysis/blob/master/notebooks/Part%201%20-%20Seasonality%20Analysis%20with%20scipy-fft.ipynb
# * https://github.com/manganganath/stock_price_trend_fft/blob/master/fourier_analysis.ipynb
# * https://www.ritchievink.com/blog/2017/04/23/understanding-the-fourier-transform-by-example/

# %%
derived_gas_outputs_seconds, mean_gas_fee_cap_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_gas_fee_cap',10)
# Out:
# Fourier Transform of mean_gas_fee_cap with 10 components.

# %%
derived_gas_outputs_seconds, mean_gas_premium_decomposed  = fourier_transform(derived_gas_outputs_seconds,'mean_gas_premium',10)
# Out:
# Fourier Transform of mean_gas_premium with 10 components.

# %%
derived_gas_outputs_seconds, mean_gas_limit_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_gas_limit',10)
# Out:
# Fourier Transform of mean_gas_limit with 10 components.

# %%
derived_gas_outputs_seconds, mean_gas_used_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_gas_used',10)
# Out:
# Fourier Transform of mean_gas_used with 10 components.

# %%
derived_gas_outputs_seconds, mean_parent_base_fee_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_parent_base_fee',10)
# Out:
# Fourier Transform of mean_parent_base_fee with 10 components.

# %%
derived_gas_outputs_seconds, mean_base_fee_burn_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_base_fee_burn',10)
# Out:
# Fourier Transform of mean_base_fee_burn with 10 components.

# %%
#derived_gas_outputs_seconds, mean_gas_burned_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_gas_burned',10)

# %%
derived_gas_outputs_seconds, mean_over_estimation_burn_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_over_estimation_burn',10)
# Out:
# Fourier Transform of mean_over_estimation_burn with 10 components.

# %%
derived_gas_outputs_seconds, mean_gas_refund_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_gas_refund',10)
# Out:
# Fourier Transform of mean_gas_refund with 10 components.

# %%
derived_gas_outputs_seconds, mean_message_cost_decomposed = fourier_transform(derived_gas_outputs_seconds,'mean_message_cost',10)
# Out:
# Fourier Transform of mean_message_cost with 10 components.

# %% [markdown]
# Based on the Fourier decompositions, it appears that there is some periodicity to the data, with two spikes a week, approximately on Monday and Thursday.
#
# ## Decomposed Phase Shifts Overlay
#
# To understand which signals may be leading or lagging indicators, we will overlay the fourier decomposed components, in pairs, for analysis.

# %%
phase_shift_overlay(derived_gas_outputs_seconds.timestamp,mean_gas_fee_cap_decomposed,mean_gas_premium_decomposed,
                    'mean_gas_fee_cap','mean_gas_premium')

# %% [markdown]
# Gas premium appears to be a leading indicator for gas fee cap. There is no phase shift (peak to peak distances line up).

# %%
phase_shift_overlay(derived_gas_outputs_seconds.timestamp,mean_gas_limit_decomposed,mean_gas_used_decomposed,
                   'mean_gas_limit','mean_gas_used')

# %% [markdown]
# Gas limit, at times, appears to be a slight leading indicator.

# %%
phase_shift_overlay(derived_gas_outputs_seconds.timestamp,mean_parent_base_fee_decomposed,mean_base_fee_burn_decomposed,
                   'mean_parent_base_fee','mean_base_fee')

# %%
phase_shift_overlay(derived_gas_outputs_seconds.timestamp,mean_message_cost_decomposed,mean_gas_refund_decomposed,
                   'mean_message_cost','mean_gas_refund')

# %% [markdown]
# Message cost, at times, appears to be a slight leading indicator.

# %%
# phase_shift_overlay(derived_gas_outputs_seconds.timestamp,mean_gas_burned_decomposed,mean_gas_fee_cap_decomposed,
#                    'mean_gas_burned','mean_gas_fee_Cap')

# %% [markdown]
# <!-- Gas burned appears to be a direct leading indicator. No phase shift present
#  -->
# Below we will normalize the signals by their individual max peaks so we can plot on one graph. We will use Matplotlib instead of Plotly due to the fact that Matplotlib handles complex numbers better.

# %%
def peak_normalization(array):
    '''
    '''
    
    normalized = array / np.max(array)
    
    return normalized

# normalize peaks    
mean_gas_fee_cap_decomposed_normalized = peak_normalization(mean_gas_fee_cap_decomposed) 
mean_gas_premium_decomposed_normalized = peak_normalization(mean_gas_premium_decomposed) 
mean_gas_limit_decomposed_normalized = peak_normalization(mean_gas_limit_decomposed)
mean_gas_used_decomposed_normalized = peak_normalization(mean_gas_used_decomposed)
mean_base_fee_burn_decomposed_normalized = peak_normalization(mean_base_fee_burn_decomposed)
mean_message_cost_decomposed = peak_normalization(mean_message_cost_decomposed)
mean_gas_refund_decomposed = peak_normalization(mean_gas_refund_decomposed)
#mean_gas_burned_decomposed = peak_normalization(mean_gas_burned_decomposed)
mean_gas_fee_cap_decomposed = peak_normalization(mean_gas_fee_cap_decomposed)

# %%
timestamps = derived_gas_outputs_seconds['timestamp'].values
plt.figure(figsize=(15, 8))
plt.plot(timestamps,mean_gas_fee_cap_decomposed_normalized,label = 'mean_gas_fee_cap_decomposed_normalized')
plt.plot(timestamps,mean_gas_premium_decomposed_normalized, label ='mean_gas_premium_decomposed_normalized')
plt.plot(timestamps,mean_gas_limit_decomposed_normalized, label ='mean_gas_limit_decomposed_normalized')
plt.plot(timestamps,mean_gas_used_decomposed_normalized, label ='mean_gas_used_decomposed_normalized')
plt.plot(timestamps,mean_base_fee_burn_decomposed_normalized, label ='mean_base_fee_burn_decomposed_normalized')
plt.plot(timestamps,mean_message_cost_decomposed, label ='mean_message_cost_decomposed')
plt.plot(timestamps,mean_gas_refund_decomposed, label ='mean_gas_refund_decomposed')
#plt.plot(timestamps,mean_gas_burned_decomposed, label ='mean_gas_burned_decomposed')
plt.plot(timestamps,mean_gas_fee_cap_decomposed, label ='mean_gas_fee_cap_decomposed')
plt.legend(bbox_to_anchor=(1.35, 1), loc='upper right', ncol=1)
plt.title('Decomposed Phase Shifts Overlay, normalize by max peaks')
# Out:
# Text(0.5, 1.0, 'Decomposed Phase Shifts Overlay, normalize by max peaks')

# %% [markdown]
# ### Data processing
#
# We will now remove the timestamp field and examine the data distributions and determine if any transformations are required prior to our VAR modeling.

# %%
timestamps = combined.timestamp
del combined['timestamp']

# %%
combined.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit'}>,
#         <AxesSubplot:title={'center':'mean_gas_used'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn'}>,
#         <AxesSubplot:title={'center':'mean_over_estimation_burn'}>],
#        [<AxesSubplot:title={'center':'mean_gas_refund'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>,
#         <AxesSubplot:title={'center':'mean_message_cost'}>,
#         <AxesSubplot:title={'center':'mean_gas_fee_cap_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit_decomposed'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_over_estimation_burn_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_message_cost_decomposed'}>,
#         <AxesSubplot:title={'center':'mean_cum_sum_baseline'}>],
#        [<AxesSubplot:title={'center':'mean_cum_sum_realized'}>,
#         <AxesSubplot:title={'center':'mean_effective_baseline_power'}>,
#         <AxesSubplot:title={'center':'mean_effective_network_time'}>,
#         <AxesSubplot:title={'center':'mean_new_baseline_power'}>,
#         <AxesSubplot:title={'center':'mean_new_reward'}>,
#         <AxesSubplot:title={'center':'mean_new_reward_smoothed_position_estimate'}>,
#         <AxesSubplot:title={'center':'mean_new_reward_smoothed_velocity_estimate'}>],
#        [<AxesSubplot:title={'center':'mean_total_mined_reward'}>,
#         <AxesSubplot:title={'center':'mean_miner_count'}>,
#         <AxesSubplot:title={'center':'mean_participating_miner_count'}>,
#         <AxesSubplot:title={'center':'mean_qa_smoothed_position_estimate'}>,
#         <AxesSubplot:title={'center':'mean_qa_smoothed_velocity_estimate'}>,
#         <AxesSubplot:title={'center':'mean_total_pledge_collateral'}>,
#         <AxesSubplot:title={'center':'mean_total_qa_bytes_committed'}>],
#        [<AxesSubplot:title={'center':'mean_total_qa_bytes_power'}>,
#         <AxesSubplot:title={'center':'mean_total_raw_bytes_committed'}>,
#         <AxesSubplot:title={'center':'mean_total_raw_bytes_power'}>,
#         <AxesSubplot:title={'center':'mean_burnt_fil'}>,
#         <AxesSubplot:title={'center':'mean_circulating_fil'}>,
#         <AxesSubplot:title={'center':'mean_locked_fil'}>,
#         <AxesSubplot:title={'center':'mean_mined_fil'}>],
#        [<AxesSubplot:title={'center':'mean_vested_fil'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We can see from the above historgrams that our data is not normally distributed and will need to be transformed prior to modeling. We will take the log of the data to reduce the skewness and take the first difference to make the data stationary.

# %%
np.random.seed(0)
log_differenced = pd.DataFrame()
## Difference and log values
for i in combined.columns:
    try:
        log_differenced[i +'_log_differenced'] = np.log(combined[i]).diff()
        log_differenced[i +'_log_differenced'].iat[0] = np.log(combined[i].iat[0])
    except:
        pass
# replace any NA values with zero
log_differenced.fillna(0,inplace=True)

# %%
#log_differenced.hist(bins=10, figsize=(25, 20))

# %% [markdown]
# The `derived_gas_outputs` data looks normally distributed, however the `chain_economics` and other chain signals are still non-normal. We will cautiously proceed.

# %% [markdown]
# As a final check prior to modeling, we will run the Augmented Dickey-Fuller test to ensure that our data is stationary (non-unit root - A unit root is a stochastic trend in a time series). The test's hypothesis are:
#
#
# * $H_O: \textrm{Time series has a unit root}$
# * $H_A: \textrm{Time series does not have a unit root}$

# %%
for i in log_differenced.columns:
    print(i)
    result = adfuller(log_differenced[i].values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] > 0.05:
        decision = "fail to reject - unit root present"
    else:
        decision = "reject, no unit root present"
    print(decision)
    print('----------------------------------')
# Out:
# mean_gas_fee_cap_log_differenced
# ADF Statistic: -49.339616
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_premium_log_differenced
# ADF Statistic: -51.059758
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_limit_log_differenced
# ADF Statistic: -46.974583
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_used_log_differenced
# ADF Statistic: -52.295040
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_parent_base_fee_log_differenced
# ADF Statistic: -68.617947
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_base_fee_burn_log_differenced
# ADF Statistic: -68.856622
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_over_estimation_burn_log_differenced
# ADF Statistic: -49.258574
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_refund_log_differenced
# ADF Statistic: -50.621017
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_message_cost_log_differenced
# ADF Statistic: -32.941306
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_fee_cap_decomposed_log_differenced
# ADF Statistic: -2.534735
# p-value: 0.107250
# fail to reject - unit root present
# ----------------------------------
# mean_gas_premium_decomposed_log_differenced
# ADF Statistic: -2.499737
# p-value: 0.115538
# fail to reject - unit root present
# ----------------------------------
# mean_gas_limit_decomposed_log_differenced
# ADF Statistic: -15.913038
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_used_decomposed_log_differenced
# ADF Statistic: -2.752770
# p-value: 0.065343
# fail to reject - unit root present
# ----------------------------------
# mean_parent_base_fee_decomposed_log_differenced
# ADF Statistic: -3.147318
# p-value: 0.023244
# reject, no unit root present
# ----------------------------------
# mean_base_fee_burn_decomposed_log_differenced
# ADF Statistic: -1.058360
# p-value: 0.731389
# fail to reject - unit root present
# ----------------------------------
# mean_over_estimation_burn_decomposed_log_differenced
# ADF Statistic: -0.800355
# p-value: 0.819018
# fail to reject - unit root present
# ----------------------------------
# mean_gas_refund_decomposed_log_differenced
# ADF Statistic: -0.533374
# p-value: 0.885338
# fail to reject - unit root present
# ----------------------------------
# mean_message_cost_decomposed_log_differenced
# ADF Statistic: -11.624087
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_cum_sum_baseline_log_differenced
# ADF Statistic: -12.459710
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_cum_sum_realized_log_differenced
# ADF Statistic: -12.440770
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_effective_baseline_power_log_differenced
# ADF Statistic: -10.308871
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_effective_network_time_log_differenced
# ADF Statistic: -12.996763
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_new_baseline_power_log_differenced
# ADF Statistic: -10.164434
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_new_reward_log_differenced
# ADF Statistic: -10.614803
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_new_reward_smoothed_position_estimate_log_differenced
# ADF Statistic: -10.627617
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_new_reward_smoothed_velocity_estimate_log_differenced
# ADF Statistic: nan
# p-value: nan
# reject, no unit root present
# ----------------------------------
# mean_total_mined_reward_log_differenced
# ADF Statistic: -18.021431
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_miner_count_log_differenced
# ADF Statistic: -48.640474
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_participating_miner_count_log_differenced
# ADF Statistic: -254.426119
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_qa_smoothed_position_estimate_log_differenced
# ADF Statistic: -2.856318
# p-value: 0.050669
# fail to reject - unit root present
# ----------------------------------
# mean_qa_smoothed_velocity_estimate_log_differenced
# ADF Statistic: -37.503028
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_total_pledge_collateral_log_differenced
# ADF Statistic: -30.127799
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_total_qa_bytes_committed_log_differenced
# ADF Statistic: -11.674464
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_total_qa_bytes_power_log_differenced
# ADF Statistic: -11.677476
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_total_raw_bytes_committed_log_differenced
# ADF Statistic: -11.680777
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_total_raw_bytes_power_log_differenced
# ADF Statistic: -11.683798
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_burnt_fil_log_differenced
# ADF Statistic: -7.055433
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_circulating_fil_log_differenced
# ADF Statistic: -26.196868
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_locked_fil_log_differenced
# ADF Statistic: -30.127115
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_mined_fil_log_differenced
# ADF Statistic: -18.021431
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_vested_fil_log_differenced
# ADF Statistic: -11.198383
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------

# %% [markdown]
# Based on the Augmented Dickey-Fuller, our preprocessing was successful and none of our univariate time series signals as a unit root. We can now proceed to the VAR model.

# %% [markdown]
# ## Model Fit
#
# To determine the ideal number of lags for our model, we will perform a heuristic SVD. We will fit our model with an autocorrelation between 1 and 15 to ascertain which VAR order has the best Akaike information criterion(AIC) score.
#
# The **Akaike information criterion (AIC)** is an estimator of prediction error, rooted in information theory. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models as a means for model selection.
#
# When a statistical model is used to represent the process that generated the data, the representation will rarely be exact; so some information will be lost by using the model to represent the process. AIC estimates the relative amount of information lost by a given model: the less information a model loses, the higher the quality of that model.
#
# In estimating the amount of information lost by a model, AIC deals with the trade-off between the goodness of fit of the model and the simplicity of the model. In other words, AIC deals with both the risk of overfitting and the risk of underfitting.
#
# Below is the equation for AIC where $\hat L$ is the maximum value of the likelihood function for the model:
#
# $$\mathrm{AIC} \, = \, 2k - 2\ln(\hat L)$$
#
# Given a set of candidate models for the data, the **preferred model is the one with the minimum AIC value, the sign of the data does not matter**. AIC optimizes for the goodness of fit but also includes a penalty for each additional parameter, which discourages overfitting.
#
# <!-- The **Bayesian information criterion (BIC)** is a statistical method for model selection among a group of models; **the model with the lowest BIC is preferred, the sign of the data does not matter**. It is based, in part, on the likelihood function and it is closely related to the Akaike information criterion (AIC).
#
# When fitting models, it is possible to increase the likelihood by adding parameters, but doing so may result in overfitting. Both BIC and AIC attempt to resolve this problem by introducing a penalty term for the number of parameters in the model; the penalty term is larger in BIC than in AIC.
#
# $$\mathrm{BIC} = k\ln(n) - 2\ln(\widehat L)$$
# where
# $\hat L$ = the maximized value of the likelihood function of the model $M$
# $x$ = the observed data;
# $n$ = the number of data points in $x$,
# $k$ = the number of parameters estimated by the model.
#
#
# Several researchers that have studied the two metrics argue that BIC is appropriate for selecting the "true model" (i.e. the process that generated the data) from the set of candidate models, whereas AIC choices the best model amongst the alternatives. Proponents of AIC argue that this issue is negligible because the "true model" is virtually never in the candidate set. For our use cases, we will optimize for the AIC as we know the "true" model of the signal behavior is way too complex to be captured within a VAR model.
#  -->
# Paraphrased sources:
# * https://en.wikipedia.org/wiki/Akaike_information_criterion
# <!-- * https://en.wikipedia.org/wiki/Bayesian_information_criterion -->

# %%
# removed several columns because of VAR errors - mean_mined_fil_log_differenced
log_differenced_subset = log_differenced[['mean_gas_fee_cap_log_differenced', 'mean_gas_premium_log_differenced',
                                         'mean_gas_limit_log_differenced','mean_gas_used_log_differenced',
                                         'mean_parent_base_fee_log_differenced','mean_base_fee_burn_log_differenced',
                                         'mean_over_estimation_burn_log_differenced','mean_gas_refund_log_differenced',
                                         'mean_cum_sum_baseline_log_differenced','mean_cum_sum_realized_log_differenced',
                                         'mean_effective_baseline_power_log_differenced','mean_effective_network_time_log_differenced',
                                         'mean_new_baseline_power_log_differenced','mean_new_reward_log_differenced',
                                         'mean_new_reward_smoothed_position_estimate_log_differenced','mean_total_mined_reward_log_differenced',
                                         'mean_miner_count_log_differenced','mean_participating_miner_count_log_differenced',
                                         'mean_qa_smoothed_position_estimate_log_differenced','mean_qa_smoothed_velocity_estimate_log_differenced',
                                         'mean_total_pledge_collateral_log_differenced','mean_total_qa_bytes_committed_log_differenced',
                                         'mean_total_qa_bytes_power_log_differenced','mean_total_raw_bytes_committed_log_differenced',
                                         'mean_total_raw_bytes_power_log_differenced','mean_burnt_fil_log_differenced','mean_circulating_fil_log_differenced',
                                         'mean_locked_fil_log_differenced','mean_vested_fil_log_differenced']]

# %%
aic = []
for i in range(1,16):
    model = VAR(log_differenced_subset)
    results = model.fit(i)
    aic.append(results.aic)

# %%
plt.figure(figsize=(10, 8))
plt.plot(aic, 'r+')
plt.legend(['AIC'])
plt.xlabel('Autocorrelation Lag')
plt.ylabel('AIC')
plt.title('Plot of sweeps over lag depths over AIC Loss function')
plt.show()

# %% [markdown]
# Based on our analysis, a lag of 10 appears to be the optimal.

# %%
# instantiate the var model object from statsmodels
model = VAR(log_differenced_subset)

# fit model with determined lag values
results = model.fit(10)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 26, Jul, 2021
# Time:                     15:20:51
# --------------------------------------------------------------------
# No. of Equations:         29.0000    BIC:                   -716.837
# Nobs:                     65426.0    HQIC:                  -717.647
# Log likelihood:       2.08045e+07    FPE:               1.48729e-312
# AIC:                     -718.010    Det(Omega_mle):    1.30768e-312
# --------------------------------------------------------------------
# Results for equation mean_gas_fee_cap_log_differenced
# ====================================================================================================================================
#                                                                       coefficient        std. error           t-stat            prob
# ------------------------------------------------------------------------------------------------------------------------------------
# const                                                                    0.030119          0.017709            1.701           0.089
# L1.mean_gas_fee_cap_log_differenced                                     -1.031387          0.003931         -262.357           0.000
# L1.mean_gas_premium_log_differenced                                     -0.001731          0.001788           -0.968           0.333
# L1.mean_gas_limit_log_differenced                                        0.015151          0.062418            0.243           0.808
# L1.mean_gas_used_log_differenced                                         0.601333          0.135436            4.440           0.000
# L1.mean_parent_base_fee_log_differenced                                  1.258223          0.136988            9.185           0.000
# L1.mean_base_fee_burn_log_differenced                                   -0.648403          0.115813           -5.599           0.000
# L1.mean_over_estimation_burn_log_differenced                            -0.042155          0.007558           -5.577           0.000
# L1.mean_gas_refund_log_differenced                                      -0.133807          0.031600           -4.234           0.000
# L1.mean_cum_sum_baseline_log_differenced                         275072112.847398  211147677.680876            1.303           0.193
# L1.mean_cum_sum_realized_log_differenced                          -9499423.842384    4039438.165862           -2.352           0.019
# L1.mean_effective_baseline_power_log_differenced                -155804402.555064  119131105.367109           -1.308           0.191
# L1.mean_effective_network_time_log_differenced                  -271425082.550898  208533732.963305           -1.302           0.193
# L1.mean_new_baseline_power_log_differenced                      -109702394.256689   50012503.281827           -2.193           0.028
# L1.mean_new_reward_log_differenced                                  -32761.950648     278753.048214           -0.118           0.906
# L1.mean_new_reward_smoothed_position_estimate_log_differenced   -447532739.188651  200624280.385039           -2.231           0.026
# L1.mean_total_mined_reward_log_differenced                          249842.812962     109871.791535            2.274           0.023
# L1.mean_miner_count_log_differenced                                 -10540.708219       6146.109474           -1.715           0.086
# L1.mean_participating_miner_count_log_differenced                       -4.213570         39.256887           -0.107           0.915
# L1.mean_qa_smoothed_position_estimate_log_differenced                10315.311669       5209.902365            1.980           0.048
# L1.mean_qa_smoothed_velocity_estimate_log_differenced                   -0.320867          0.202654           -1.583           0.113
# L1.mean_total_pledge_collateral_log_differenced                     -43033.257152     953117.594376           -0.045           0.964
# L1.mean_total_qa_bytes_committed_log_differenced                    -27170.985113     190911.695182           -0.142           0.887
# L1.mean_total_qa_bytes_power_log_differenced                         20111.857255     188291.702146            0.107           0.915
# L1.mean_total_raw_bytes_committed_log_differenced                    29179.539069     192937.518383            0.151           0.880
# L1.mean_total_raw_bytes_power_log_differenced                       -22144.508296     190306.881358           -0.116           0.907
# L1.mean_burnt_fil_log_differenced                                   -61592.123638      38998.793297           -1.579           0.114
# L1.mean_circulating_fil_log_differenced                            -440070.062525     196812.969885           -2.236           0.025
# L1.mean_locked_fil_log_differenced                                 -226705.622815     959688.954869           -0.236           0.813
# L1.mean_vested_fil_log_differenced                                  312330.184216     222183.791455            1.406           0.160
# L2.mean_gas_fee_cap_log_differenced                                     -0.980960          0.005656         -173.425           0.000
# L2.mean_gas_premium_log_differenced                                      0.000152          0.002406            0.063           0.950
# L2.mean_gas_limit_log_differenced                                       -0.000065          0.077613           -0.001           0.999
# L2.mean_gas_used_log_differenced                                         1.096821          0.175139            6.263           0.000
# L2.mean_parent_base_fee_log_differenced                                  2.065152          0.166318           12.417           0.000
# L2.mean_base_fee_burn_log_differenced                                   -1.164290          0.149487           -7.789           0.000
# L2.mean_over_estimation_burn_log_differenced                            -0.061190          0.009786           -6.253           0.000
# L2.mean_gas_refund_log_differenced                                      -0.112467          0.042667           -2.636           0.008
# L2.mean_cum_sum_baseline_log_differenced                         165598675.062118  283622835.374084            0.584           0.559
# L2.mean_cum_sum_realized_log_differenced                         -10199193.637605    4924072.827380           -2.071           0.038
# L2.mean_effective_baseline_power_log_differenced                 -93593516.471111  160028093.811583           -0.585           0.559
# L2.mean_effective_network_time_log_differenced                  -163487889.389998  280109325.374364           -0.584           0.559
# L2.mean_new_baseline_power_log_differenced                      -120159351.516457   61532437.107304           -1.953           0.051
# L2.mean_new_reward_log_differenced                                   84484.978765     386896.978324            0.218           0.827
# L2.mean_new_reward_smoothed_position_estimate_log_differenced   -487997990.845694  246330256.630522           -1.981           0.048
# L2.mean_total_mined_reward_log_differenced                          -24514.042180     109958.108754           -0.223           0.824
# L2.mean_miner_count_log_differenced                                  -4975.008785       6148.276098           -0.809           0.418
# L2.mean_participating_miner_count_log_differenced                      -19.867733         39.262502           -0.506           0.613
# L2.mean_qa_smoothed_position_estimate_log_differenced                  729.116698       5184.527062            0.141           0.888
# L2.mean_qa_smoothed_velocity_estimate_log_differenced                   -0.087181          0.215289           -0.405           0.686
# L2.mean_total_pledge_collateral_log_differenced                   -1610584.506565     955396.997796           -1.686           0.092
# L2.mean_total_qa_bytes_committed_log_differenced                    -59613.127099     190910.512547           -0.312           0.755
# L2.mean_total_qa_bytes_power_log_differenced                         59642.022653     188290.157158            0.317           0.751
# L2.mean_total_raw_bytes_committed_log_differenced                    58414.283597     192934.779533            0.303           0.762
# L2.mean_total_raw_bytes_power_log_differenced                       -58439.989584     190303.829175           -0.307           0.759
# L2.mean_burnt_fil_log_differenced                                    24887.860550      39011.806767            0.638           0.524
# L2.mean_circulating_fil_log_differenced                              39962.515947     196967.806554            0.203           0.839
# L2.mean_locked_fil_log_differenced                                 1634771.081011     961881.206235            1.700           0.089
# L2.mean_vested_fil_log_differenced                                 -203983.837796     224275.963990           -0.910           0.363
# L3.mean_gas_fee_cap_log_differenced                                     -0.897189          0.006793         -132.085           0.000
# L3.mean_gas_premium_log_differenced                                     -0.000933          0.002778           -0.336           0.737
# L3.mean_gas_limit_log_differenced                                        0.013207          0.085819            0.154           0.878
# L3.mean_gas_used_log_differenced                                         0.893835          0.196563            4.547           0.000
# L3.mean_parent_base_fee_log_differenced                                  1.874929          0.182560           10.270           0.000
# L3.mean_base_fee_burn_log_differenced                                   -1.034248          0.167391           -6.179           0.000
# L3.mean_over_estimation_burn_log_differenced                            -0.043156          0.011033           -3.911           0.000
# L3.mean_gas_refund_log_differenced                                      -0.112074          0.049099           -2.283           0.022
# L3.mean_cum_sum_baseline_log_differenced                         519649106.672400  354163575.064308            1.467           0.142
# L3.mean_cum_sum_realized_log_differenced                          -4373394.078722    5834717.902721           -0.750           0.454
# L3.mean_effective_baseline_power_log_differenced                -293521587.786743  199816212.777696           -1.469           0.142
# L3.mean_effective_network_time_log_differenced                  -513084931.456389  349781243.693944           -1.467           0.142
# L3.mean_new_baseline_power_log_differenced                       -58054859.939887   73427281.497311           -0.791           0.429
# L3.mean_new_reward_log_differenced                                   63397.836854     475134.971635            0.133           0.894
# L3.mean_new_reward_smoothed_position_estimate_log_differenced   -229668692.399859  293503296.784166           -0.783           0.434
# L3.mean_total_mined_reward_log_differenced                          -77616.846479     110012.570619           -0.706           0.480
# L3.mean_miner_count_log_differenced                                  11826.753096       6253.678659            1.891           0.059
# L3.mean_participating_miner_count_log_differenced                       88.792361         39.265681            2.261           0.024
# L3.mean_qa_smoothed_position_estimate_log_differenced                 1888.920215       5164.453528            0.366           0.715
# L3.mean_qa_smoothed_velocity_estimate_log_differenced                    0.576162          0.216188            2.665           0.008
# L3.mean_total_pledge_collateral_log_differenced                     533665.369788     955555.120992            0.558           0.577
# L3.mean_total_qa_bytes_committed_log_differenced                    156173.420316     190889.165683            0.818           0.413
# L3.mean_total_qa_bytes_power_log_differenced                       -145403.150402     188269.495834           -0.772           0.440
# L3.mean_total_raw_bytes_committed_log_differenced                  -106894.286336     192911.139324           -0.554           0.580
# L3.mean_total_raw_bytes_power_log_differenced                        96195.900296     190281.042831            0.506           0.613
# L3.mean_burnt_fil_log_differenced                                    27747.755663      39028.457458            0.711           0.477
# L3.mean_circulating_fil_log_differenced                             135312.393379     197069.534163            0.687           0.492
# L3.mean_locked_fil_log_differenced                                 -450605.956921     962022.856172           -0.468           0.640
# L3.mean_vested_fil_log_differenced                                 -235273.629816     226233.145501           -1.040           0.298
# L4.mean_gas_fee_cap_log_differenced                                     -0.788755          0.007501         -105.148           0.000
# L4.mean_gas_premium_log_differenced                                     -0.001613          0.002985           -0.540           0.589
# L4.mean_gas_limit_log_differenced                                        0.007252          0.091183            0.080           0.937
# L4.mean_gas_used_log_differenced                                         1.100539          0.209125            5.263           0.000
# L4.mean_parent_base_fee_log_differenced                                  2.007500          0.191541           10.481           0.000
# L4.mean_base_fee_burn_log_differenced                                   -1.172807          0.177327           -6.614           0.000
# L4.mean_over_estimation_burn_log_differenced                            -0.031703          0.011792           -2.689           0.007
# L4.mean_gas_refund_log_differenced                                      -0.112976          0.052755           -2.142           0.032
# L4.mean_cum_sum_baseline_log_differenced                         488656865.503477  412255851.693587            1.185           0.236
# L4.mean_cum_sum_realized_log_differenced                         -12207446.092964    6568198.775906           -1.859           0.063
# L4.mean_effective_baseline_power_log_differenced                -276018872.455615  232577825.694515           -1.187           0.235
# L4.mean_effective_network_time_log_differenced                  -482480576.080176  407159992.538720           -1.185           0.236
# L4.mean_new_baseline_power_log_differenced                      -151433083.119890   83047649.309411           -1.823           0.068
# L4.mean_new_reward_log_differenced                                   70605.406478     548836.742326            0.129           0.898
# L4.mean_new_reward_smoothed_position_estimate_log_differenced   -607339237.398091  331635585.330919           -1.831           0.067
# L4.mean_total_mined_reward_log_differenced                          -54080.621070     110051.865175           -0.491           0.623
# L4.mean_miner_count_log_differenced                                   4872.859339       6254.221645            0.779           0.436
# L4.mean_participating_miner_count_log_differenced                      -22.605740         39.263380           -0.576           0.565
# L4.mean_qa_smoothed_position_estimate_log_differenced                -2551.746675       5111.717116           -0.499           0.618
# L4.mean_qa_smoothed_velocity_estimate_log_differenced                   -0.343027          0.216406           -1.585           0.113
# L4.mean_total_pledge_collateral_log_differenced                     262792.217926     957516.653667            0.274           0.784
# L4.mean_total_qa_bytes_committed_log_differenced                    162073.909885     190896.272542            0.849           0.396
# L4.mean_total_qa_bytes_power_log_differenced                       -158305.471602     188274.567948           -0.841           0.400
# L4.mean_total_raw_bytes_committed_log_differenced                  -194302.263429     192917.529075           -1.007           0.314
# L4.mean_total_raw_bytes_power_log_differenced                       190835.226718     190285.434701            1.003           0.316
# L4.mean_burnt_fil_log_differenced                                     9278.073588      39031.894840            0.238           0.812
# L4.mean_circulating_fil_log_differenced                             111070.033614     197142.588566            0.563           0.573
# L4.mean_locked_fil_log_differenced                                 -194741.151829     963992.071332           -0.202           0.840
# L4.mean_vested_fil_log_differenced                                 -198744.759730     228203.818071           -0.871           0.384
# L5.mean_gas_fee_cap_log_differenced                                     -0.679084          0.007844          -86.573           0.000
# L5.mean_gas_premium_log_differenced                                     -0.002177          0.003078           -0.707           0.479
# L5.mean_gas_limit_log_differenced                                       -0.029756          0.094182           -0.316           0.752
# L5.mean_gas_used_log_differenced                                         0.876980          0.214421            4.090           0.000
# L5.mean_parent_base_fee_log_differenced                                  1.622421          0.195224            8.311           0.000
# L5.mean_base_fee_burn_log_differenced                                   -0.943550          0.181377           -5.202           0.000
# L5.mean_over_estimation_burn_log_differenced                            -0.012315          0.012164           -1.012           0.311
# L5.mean_gas_refund_log_differenced                                      -0.080244          0.054405           -1.475           0.140
# L5.mean_cum_sum_baseline_log_differenced                         486133223.422350  446097671.033910            1.090           0.276
# L5.mean_cum_sum_realized_log_differenced                          -2871236.267093    6995026.938559           -0.410           0.681
# L5.mean_effective_baseline_power_log_differenced                -274678424.516275  251679884.485160           -1.091           0.275
# L5.mean_effective_network_time_log_differenced                  -479962339.165601  440579699.411803           -1.089           0.276
# L5.mean_new_baseline_power_log_differenced                       -41634673.000349   88595013.921425           -0.470           0.638
# L5.mean_new_reward_log_differenced                                  -18114.468888     593070.029731           -0.031           0.976
# L5.mean_new_reward_smoothed_position_estimate_log_differenced   -161706616.557199  353669166.090042           -0.457           0.648
# L5.mean_total_mined_reward_log_differenced                           -7652.370429     110086.728790           -0.070           0.945
# L5.mean_miner_count_log_differenced                                 -11110.529096       6269.558584           -1.772           0.076
# L5.mean_participating_miner_count_log_differenced                       27.391000         39.266291            0.698           0.485
# L5.mean_qa_smoothed_position_estimate_log_differenced                 2736.555098       5146.852550            0.532           0.595
# L5.mean_qa_smoothed_velocity_estimate_log_differenced                   -0.003929          0.216476           -0.018           0.986
# L5.mean_total_pledge_collateral_log_differenced                     329887.121522     957940.319634            0.344           0.731
# L5.mean_total_qa_bytes_committed_log_differenced                   -387760.085544     190873.255747           -2.032           0.042
# L5.mean_total_qa_bytes_power_log_differenced                        384094.019513     188253.250714            2.040           0.041
# L5.mean_total_raw_bytes_committed_log_differenced                   416438.259670     192897.130335            2.159           0.031
# L5.mean_total_raw_bytes_power_log_differenced                      -412936.219773     190266.684818           -2.170           0.030
# L5.mean_burnt_fil_log_differenced                                    10362.803071      39042.354059            0.265           0.791
# L5.mean_circulating_fil_log_differenced                              28371.682306     197207.416191            0.144           0.886
# L5.mean_locked_fil_log_differenced                                 -313093.190706     964420.427670           -0.325           0.745
# L5.mean_vested_fil_log_differenced                                 -100001.959269     229230.614209           -0.436           0.663
# L6.mean_gas_fee_cap_log_differenced                                     -0.557102          0.007848          -70.985           0.000
# L6.mean_gas_premium_log_differenced                                     -0.001682          0.003077           -0.547           0.585
# L6.mean_gas_limit_log_differenced                                        0.156963          0.094141            1.667           0.095
# L6.mean_gas_used_log_differenced                                         0.640568          0.214568            2.985           0.003
# L6.mean_parent_base_fee_log_differenced                                  1.348480          0.194989            6.916           0.000
# L6.mean_base_fee_burn_log_differenced                                   -0.861406          0.181534           -4.745           0.000
# L6.mean_over_estimation_burn_log_differenced                            -0.006427          0.012148           -0.529           0.597
# L6.mean_gas_refund_log_differenced                                      -0.078750          0.054418           -1.447           0.148
# L6.mean_cum_sum_baseline_log_differenced                         319945195.674883  445700146.762769            0.718           0.473
# L6.mean_cum_sum_realized_log_differenced                          -3638671.825253    6998890.211281           -0.520           0.603
# L6.mean_effective_baseline_power_log_differenced                -180301551.361783  251453132.726946           -0.717           0.473
# L6.mean_effective_network_time_log_differenced                  -316076315.948311  440188102.457333           -0.718           0.473
# L6.mean_new_baseline_power_log_differenced                       -46872288.695944   88652025.369213           -0.529           0.597
# L6.mean_new_reward_log_differenced                                    3323.243545     591578.549835            0.006           0.996
# L6.mean_new_reward_smoothed_position_estimate_log_differenced   -186461980.763313  353885529.062510           -0.527           0.598
# L6.mean_total_mined_reward_log_differenced                           37897.536388     110077.871560            0.344           0.731
# L6.mean_miner_count_log_differenced                                 -13985.004916       6269.791105           -2.231           0.026
# L6.mean_participating_miner_count_log_differenced                       38.144566         39.268508            0.971           0.331
# L6.mean_qa_smoothed_position_estimate_log_differenced                  -90.859938       5146.687679           -0.018           0.986
# L6.mean_qa_smoothed_velocity_estimate_log_differenced                    0.122816          0.216449            0.567           0.570
# L6.mean_total_pledge_collateral_log_differenced                    -977733.712746     957792.161613           -1.021           0.307
# L6.mean_total_qa_bytes_committed_log_differenced                   -252616.811811     190848.090656           -1.324           0.186
# L6.mean_total_qa_bytes_power_log_differenced                        248420.919420     188227.847181            1.320           0.187
# L6.mean_total_raw_bytes_committed_log_differenced                   259707.655321     192871.724403            1.347           0.178
# L6.mean_total_raw_bytes_power_log_differenced                      -255368.305933     190240.936642           -1.342           0.179
# L6.mean_burnt_fil_log_differenced                                   -11963.965333      39028.566558           -0.307           0.759
# L6.mean_circulating_fil_log_differenced                             -54870.328717     197199.548683           -0.278           0.781
# L6.mean_locked_fil_log_differenced                                  943723.134260     964302.056495            0.979           0.328
# L6.mean_vested_fil_log_differenced                                   16167.853037     229525.686193            0.070           0.944
# L7.mean_gas_fee_cap_log_differenced                                     -0.440923          0.007512          -58.695           0.000
# L7.mean_gas_premium_log_differenced                                     -0.000935          0.002982           -0.314           0.754
# L7.mean_gas_limit_log_differenced                                        0.096713          0.091202            1.060           0.289
# L7.mean_gas_used_log_differenced                                         0.523246          0.209846            2.493           0.013
# L7.mean_parent_base_fee_log_differenced                                  0.996226          0.191359            5.206           0.000
# L7.mean_base_fee_burn_log_differenced                                   -0.724518          0.177804           -4.075           0.000
# L7.mean_over_estimation_burn_log_differenced                             0.007957          0.011755            0.677           0.498
# L7.mean_gas_refund_log_differenced                                      -0.037107          0.052802           -0.703           0.482
# L7.mean_cum_sum_baseline_log_differenced                          91153152.850100  406469473.339691            0.224           0.823
# L7.mean_cum_sum_realized_log_differenced                           3890907.762712    6531460.316175            0.596           0.551
# L7.mean_effective_baseline_power_log_differenced                 -51507748.944830  229315823.591007           -0.225           0.822
# L7.mean_effective_network_time_log_differenced                   -90011679.477409  401444101.311916           -0.224           0.823
# L7.mean_new_baseline_power_log_differenced                        43976110.228065   82557060.489552            0.533           0.594
# L7.mean_new_reward_log_differenced                                 -462085.813707     549356.736399           -0.841           0.400
# L7.mean_new_reward_smoothed_position_estimate_log_differenced    180346462.744825  329699928.165362            0.547           0.584
# L7.mean_total_mined_reward_log_differenced                          -40775.965954     110044.930651           -0.371           0.711
# L7.mean_miner_count_log_differenced                                  -4795.975991       6251.802898           -0.767           0.443
# L7.mean_participating_miner_count_log_differenced                       -3.224160         39.269935           -0.082           0.935
# L7.mean_qa_smoothed_position_estimate_log_differenced                -4845.611982       5111.563002           -0.948           0.343
# L7.mean_qa_smoothed_velocity_estimate_log_differenced                    0.021267          0.216381            0.098           0.922
# L7.mean_total_pledge_collateral_log_differenced                    -859510.816852     957313.107152           -0.898           0.369
# L7.mean_total_qa_bytes_committed_log_differenced                    151840.842269     190844.389945            0.796           0.426
# L7.mean_total_qa_bytes_power_log_differenced                       -146128.367843     188224.701517           -0.776           0.438
# L7.mean_total_raw_bytes_committed_log_differenced                  -166113.010182     192868.013217           -0.861           0.389
# L7.mean_total_raw_bytes_power_log_differenced                       160467.546602     190237.760740            0.844           0.399
# L7.mean_burnt_fil_log_differenced                                     7833.984365      39011.457207            0.201           0.841
# L7.mean_circulating_fil_log_differenced                              71141.575214     197148.319429            0.361           0.718
# L7.mean_locked_fil_log_differenced                                  903304.404185     963889.590654            0.937           0.349
# L7.mean_vested_fil_log_differenced                                  -81133.327042     229181.598150           -0.354           0.723
# L8.mean_gas_fee_cap_log_differenced                                     -0.321868          0.006808          -47.281           0.000
# L8.mean_gas_premium_log_differenced                                      0.000541          0.002775            0.195           0.845
# L8.mean_gas_limit_log_differenced                                        0.146578          0.085899            1.706           0.088
# L8.mean_gas_used_log_differenced                                         0.123835          0.197969            0.626           0.532
# L8.mean_parent_base_fee_log_differenced                                  0.627033          0.182356            3.439           0.001
# L8.mean_base_fee_burn_log_differenced                                   -0.335389          0.168244           -1.993           0.046
# L8.mean_over_estimation_burn_log_differenced                             0.011906          0.010965            1.086           0.278
# L8.mean_gas_refund_log_differenced                                      -0.024132          0.049168           -0.491           0.624
# L8.mean_cum_sum_baseline_log_differenced                         134406907.102697  348502801.699641            0.386           0.700
# L8.mean_cum_sum_realized_log_differenced                           1433983.076160    5771544.007340            0.248           0.804
# L8.mean_effective_baseline_power_log_differenced                 -76046639.293915  196628386.353927           -0.387           0.699
# L8.mean_effective_network_time_log_differenced                  -132674369.097806  344188114.006699           -0.385           0.700
# L8.mean_new_baseline_power_log_differenced                        14982745.856567   72622059.637798            0.206           0.837
# L8.mean_new_reward_log_differenced                                 -400006.048518     482021.963563           -0.830           0.407
# L8.mean_new_reward_smoothed_position_estimate_log_differenced     62798631.755347  290302616.501765            0.216           0.829
# L8.mean_total_mined_reward_log_differenced                         -179308.563133     110042.491483           -1.629           0.103
# L8.mean_miner_count_log_differenced                                   9822.725414       6250.459164            1.572           0.116
# L8.mean_participating_miner_count_log_differenced                      -26.206393         39.269434           -0.667           0.505
# L8.mean_qa_smoothed_position_estimate_log_differenced                 2525.312941       5161.199642            0.489           0.625
# L8.mean_qa_smoothed_velocity_estimate_log_differenced                    0.129522          0.216159            0.599           0.549
# L8.mean_total_pledge_collateral_log_differenced                    -351981.368073     955227.068488           -0.368           0.713
# L8.mean_total_qa_bytes_committed_log_differenced                    -59705.207350     190845.683066           -0.313           0.754
# L8.mean_total_qa_bytes_power_log_differenced                         47747.084805     188223.903726            0.254           0.800
# L8.mean_total_raw_bytes_committed_log_differenced                    54371.102348     192869.641573            0.282           0.778
# L8.mean_total_raw_bytes_power_log_differenced                       -42653.673116     190237.536070           -0.224           0.823
# L8.mean_burnt_fil_log_differenced                                    62659.467704      39012.242259            1.606           0.108
# L8.mean_circulating_fil_log_differenced                             328768.241919     197145.726155            1.668           0.095
# L8.mean_locked_fil_log_differenced                                  553642.991489     961792.175573            0.576           0.565
# L8.mean_vested_fil_log_differenced                                 -390070.852054     228029.987177           -1.711           0.087
# L9.mean_gas_fee_cap_log_differenced                                     -0.213316          0.005680          -37.554           0.000
# L9.mean_gas_premium_log_differenced                                      0.000392          0.002404            0.163           0.871
# L9.mean_gas_limit_log_differenced                                        0.070829          0.077678            0.912           0.362
# L9.mean_gas_used_log_differenced                                         0.076463          0.177267            0.431           0.666
# L9.mean_parent_base_fee_log_differenced                                  0.445773          0.166150            2.683           0.007
# L9.mean_base_fee_burn_log_differenced                                   -0.189621          0.150884           -1.257           0.209
# L9.mean_over_estimation_burn_log_differenced                             0.023615          0.009673            2.441           0.015
# L9.mean_gas_refund_log_differenced                                      -0.012960          0.042847           -0.302           0.762
# L9.mean_cum_sum_baseline_log_differenced                          57544961.119948  282111004.877475            0.204           0.838
# L9.mean_cum_sum_realized_log_differenced                           -223550.337553    4867060.672973           -0.046           0.963
# L9.mean_effective_baseline_power_log_differenced                 -32328073.000017  159172078.111343           -0.203           0.839
# L9.mean_effective_network_time_log_differenced                   -56894680.977131  278617387.742314           -0.204           0.838
# L9.mean_new_baseline_power_log_differenced                        -3248647.077989   60879683.477741           -0.053           0.957
# L9.mean_new_reward_log_differenced                                 -125927.494858     383222.163891           -0.329           0.742
# L9.mean_new_reward_smoothed_position_estimate_log_differenced    -12588840.164380  243659958.261228           -0.052           0.959
# L9.mean_total_mined_reward_log_differenced                         -107393.948910     110037.847927           -0.976           0.329
# L9.mean_miner_count_log_differenced                                   2972.432218       6144.275146            0.484           0.629
# L9.mean_participating_miner_count_log_differenced                       -2.107082         39.268662           -0.054           0.957
# L9.mean_qa_smoothed_position_estimate_log_differenced                 2224.213638       5179.496268            0.429           0.668
# L9.mean_qa_smoothed_velocity_estimate_log_differenced                    0.032518          0.215285            0.151           0.880
# L9.mean_total_pledge_collateral_log_differenced                    1046129.058921     954616.880961            1.096           0.273
# L9.mean_total_qa_bytes_committed_log_differenced                    -29454.669927     190846.418157           -0.154           0.877
# L9.mean_total_qa_bytes_power_log_differenced                         53389.806473     188224.254146            0.284           0.777
# L9.mean_total_raw_bytes_committed_log_differenced                    46537.003022     192871.325952            0.241           0.809
# L9.mean_total_raw_bytes_power_log_differenced                       -70720.833632     190238.659826           -0.372           0.710
# L9.mean_burnt_fil_log_differenced                                    31527.808840      39006.412063            0.808           0.419
# L9.mean_circulating_fil_log_differenced                             189583.848175     197128.877322            0.962           0.336
# L9.mean_locked_fil_log_differenced                                 -929792.522318     961203.384633           -0.967           0.333
# L9.mean_vested_fil_log_differenced                                 -229814.280660     226881.335031           -1.013           0.311
# L10.mean_gas_fee_cap_log_differenced                                    -0.100617          0.003966          -25.372           0.000
# L10.mean_gas_premium_log_differenced                                     0.000068          0.001788            0.038           0.969
# L10.mean_gas_limit_log_differenced                                      -0.018162          0.062403           -0.291           0.771
# L10.mean_gas_used_log_differenced                                        0.033316          0.138430            0.241           0.810
# L10.mean_parent_base_fee_log_differenced                                 0.094788          0.136434            0.695           0.487
# L10.mean_base_fee_burn_log_differenced                                   0.014277          0.118455            0.121           0.904
# L10.mean_over_estimation_burn_log_differenced                            0.020953          0.007379            2.840           0.005
# L10.mean_gas_refund_log_differenced                                     -0.033176          0.031872           -1.041           0.298
# L10.mean_cum_sum_baseline_log_differenced                        298843716.762552  209508509.973937            1.426           0.154
# L10.mean_cum_sum_realized_log_differenced                         -3271584.331521    3979597.232030           -0.822           0.411
# L10.mean_effective_baseline_power_log_differenced               -168664141.497567  118206065.778629           -1.427           0.154
# L10.mean_effective_network_time_log_differenced                 -295130059.620270  206915065.848058           -1.426           0.154
# L10.mean_new_baseline_power_log_differenced                      -42832038.061950   49317948.207037           -0.868           0.385
# L10.mean_new_reward_log_differenced                                 -95049.704374     243854.975269           -0.390           0.697
# L10.mean_new_reward_smoothed_position_estimate_log_differenced  -169797971.641159  197771427.150378           -0.859           0.391
# L10.mean_total_mined_reward_log_differenced                        -121786.087872     110024.917477           -1.107           0.268
# L10.mean_miner_count_log_differenced                                 11516.007820       6142.339920            1.875           0.061
# L10.mean_participating_miner_count_log_differenced                     -17.302253         39.264650           -0.441           0.659
# L10.mean_qa_smoothed_position_estimate_log_differenced              -12302.321112       5201.817847           -2.365           0.018
# L10.mean_qa_smoothed_velocity_estimate_log_differenced                  -0.027267          0.202652           -0.135           0.893
# L10.mean_total_pledge_collateral_log_differenced                    939781.141840     952826.148802            0.986           0.324
# L10.mean_total_qa_bytes_committed_log_differenced                    77573.009002     190747.857634            0.407           0.684
# L10.mean_total_qa_bytes_power_log_differenced                       -59727.881825     188125.252988           -0.317           0.751
# L10.mean_total_raw_bytes_committed_log_differenced                 -106192.951091     192775.195651           -0.551           0.582
# L10.mean_total_raw_bytes_power_log_differenced                       88280.284642     190142.111276            0.464           0.642
# L10.mean_burnt_fil_log_differenced                                   35872.694027      38970.087688            0.921           0.357
# L10.mean_circulating_fil_log_differenced                            211449.923960     197071.976023            1.073           0.283
# L10.mean_locked_fil_log_differenced                                -810760.247921     959417.359814           -0.845           0.398
# L10.mean_vested_fil_log_differenced                                -246445.529149     224731.727885           -1.097           0.273
# ====================================================================================================================================
#
# Results for equation mean_gas_premium_log_differenced
# =====================================================================================================================================
#                                                                        coefficient        std. error           t-stat            prob
# -------------------------------------------------------------------------------------------------------------------------------------
# const                                                                    -0.039830          0.038934           -1.023           0.306
# L1.mean_gas_fee_cap_log_differenced                                      -0.022820          0.008643           -2.640           0.008
# L1.mean_gas_premium_log_differenced                                      -0.919749          0.003931         -233.980           0.000
# L1.mean_gas_limit_log_differenced                                         0.510955          0.137231            3.723           0.000
# L1.mean_gas_used_log_differenced                                         -1.120338          0.297766           -3.762           0.000
# L1.mean_parent_base_fee_log_differenced                                   0.144043          0.301177            0.478           0.632
# L1.mean_base_fee_burn_log_differenced                                     0.485866          0.254623            1.908           0.056
# L1.mean_over_estimation_burn_log_differenced                             -0.041302          0.016617           -2.485           0.013
# L1.mean_gas_refund_log_differenced                                        0.087718          0.069476            1.263           0.207
# L1.mean_cum_sum_baseline_log_differenced                         -394606850.666637  464222853.289568           -0.850           0.395
# L1.mean_cum_sum_realized_log_differenced                            9326209.995578    8880985.723544            1.050           0.294
# L1.mean_effective_baseline_power_log_differenced                  223256859.291287  261918019.920843            0.852           0.394
# L1.mean_effective_network_time_log_differenced                    389480265.356365  458475914.045624            0.850           0.396
# L1.mean_new_baseline_power_log_differenced                        113437450.879566  109955966.500059            1.032           0.302
# L1.mean_new_reward_log_differenced                                  -700048.704491     612857.961907           -1.142           0.253
# L1.mean_new_reward_smoothed_position_estimate_log_differenced     458632671.525535  441086432.502803            1.040           0.298
# L1.mean_total_mined_reward_log_differenced                           385426.087534     241560.774537            1.596           0.111
# L1.mean_miner_count_log_differenced                                    -532.992183      13512.649100           -0.039           0.969
# L1.mean_participating_miner_count_log_differenced                       -74.927709         86.308996           -0.868           0.385
# L1.mean_qa_smoothed_position_estimate_log_differenced                  3529.736803      11454.332663            0.308           0.758
# L1.mean_qa_smoothed_velocity_estimate_log_differenced                     0.703938          0.445549            1.580           0.114
# L1.mean_total_pledge_collateral_log_differenced                    -3840411.365545    2095495.314186           -1.833           0.067
# L1.mean_total_qa_bytes_committed_log_differenced                     655189.902017     419732.638489            1.561           0.119
# L1.mean_total_qa_bytes_power_log_differenced                        -692157.669036     413972.401597           -1.672           0.095
# L1.mean_total_raw_bytes_committed_log_differenced                   -691718.241025     424186.551679           -1.631           0.103
# L1.mean_total_raw_bytes_power_log_differenced                        727691.166983     418402.913235            1.739           0.082
# L1.mean_burnt_fil_log_differenced                                   -127352.605257      85741.559169           -1.485           0.137
# L1.mean_circulating_fil_log_differenced                             -720972.534011     432707.001318           -1.666           0.096
# L1.mean_locked_fil_log_differenced                                  3398011.949784    2109942.907225            1.610           0.107
# L1.mean_vested_fil_log_differenced                                  1163702.801745     488486.516911            2.382           0.017
# L2.mean_gas_fee_cap_log_differenced                                      -0.005971          0.012436           -0.480           0.631
# L2.mean_gas_premium_log_differenced                                      -0.811436          0.005289         -153.408           0.000
# L2.mean_gas_limit_log_differenced                                         0.600560          0.170637            3.520           0.000
# L2.mean_gas_used_log_differenced                                          0.311360          0.385056            0.809           0.419
# L2.mean_parent_base_fee_log_differenced                                   1.593625          0.365662            4.358           0.000
# L2.mean_base_fee_burn_log_differenced                                    -1.014289          0.328657           -3.086           0.002
# L2.mean_over_estimation_burn_log_differenced                             -0.042460          0.021515           -1.973           0.048
# L2.mean_gas_refund_log_differenced                                        0.029929          0.093807            0.319           0.750
# L2.mean_cum_sum_baseline_log_differenced                         -810645210.516157  623564527.640361           -1.300           0.194
# L2.mean_cum_sum_realized_log_differenced                           17504398.683973   10825916.547313            1.617           0.106
# L2.mean_effective_baseline_power_log_differenced                  458022624.309045  351832893.127917            1.302           0.193
# L2.mean_effective_network_time_log_differenced                    800351731.274300  615839831.564867            1.300           0.194
# L2.mean_new_baseline_power_log_differenced                        211871292.715239  135283342.149687            1.566           0.117
# L2.mean_new_reward_log_differenced                                 -1863147.087650     850619.912941           -2.190           0.028
# L2.mean_new_reward_smoothed_position_estimate_log_differenced     857031162.526055  541574199.823318            1.582           0.114
# L2.mean_total_mined_reward_log_differenced                           221077.692623     241750.548947            0.914           0.360
# L2.mean_miner_count_log_differenced                                    2921.007027      13517.412573            0.216           0.829
# L2.mean_participating_miner_count_log_differenced                        50.005012         86.321340            0.579           0.562
# L2.mean_qa_smoothed_position_estimate_log_differenced                 -2591.600943      11398.543294           -0.227           0.820
# L2.mean_qa_smoothed_velocity_estimate_log_differenced                     0.609937          0.473327            1.289           0.198
# L2.mean_total_pledge_collateral_log_differenced                     1115877.217743    2100506.741123            0.531           0.595
# L2.mean_total_qa_bytes_committed_log_differenced                     434596.031446     419730.038382            1.035           0.300
# L2.mean_total_qa_bytes_power_log_differenced                        -353329.745186     413969.004832           -0.854           0.393
# L2.mean_total_raw_bytes_committed_log_differenced                   -456884.448757     424180.530127           -1.077           0.281
# L2.mean_total_raw_bytes_power_log_differenced                        374997.021259     418396.202800            0.896           0.370
# L2.mean_burnt_fil_log_differenced                                    -55506.963393      85770.170186           -0.647           0.518
# ...
# mean_participating_miner_count_log_differenced                                        0.004053                         -0.006191                       -0.002679                      -0.005360                             -0.004234                           -0.004454                                   0.003027                        -0.002140                              -0.001010                               0.000039                                      -0.000948                                    -0.001024                                 0.000094                        -0.000778                                                   -0.000082                                 0.006647                         -0.000832                                        1.000000                                            0.004437                                           -0.000665                                      0.002425                                       0.060738                                   0.064504                                        0.059305                                    0.063002                       -0.001626                             -0.000480                         0.002421                        -0.000228
# mean_qa_smoothed_position_estimate_log_differenced                                    0.003428                          0.006013                        0.007062                       0.002676                              0.145692                            0.076095                                   0.036578                         0.009774                               0.841453                               0.906407                                       0.845257                                     0.840517                                 0.907210                        -0.901767                                                   -0.907050                                 0.547414                          0.011652                                        0.004437                                            1.000000                                            0.003993                                      0.129350                                       0.089776                                   0.089700                                        0.089694                                    0.089624                        0.501980                              0.199957                         0.129391                         0.885171
# mean_qa_smoothed_velocity_estimate_log_differenced                                   -0.003386                          0.004017                       -0.001186                      -0.002054                             -0.009101                           -0.006011                                  -0.002962                         0.002149                              -0.000838                              -0.000181                                      -0.000831                                    -0.000840                                -0.000177                         0.000188                                                    0.000178                                 0.001581                          0.000041                                       -0.000665                                            0.003993                                            1.000000                                      0.003834                                      -0.011407                                  -0.011402                                       -0.011407                                   -0.011402                        0.005043                             -0.003559                         0.003834                        -0.000124
# mean_total_pledge_collateral_log_differenced                                          0.009298                         -0.006692                       -0.003808                      -0.010819                             -0.102745                           -0.061140                                   0.009617                        -0.000642                               0.132207                               0.142805                                       0.132662                                     0.132093                                 0.142777                        -0.141409                                                   -0.142787                                 0.213978                         -0.001143                                        0.002425                                            0.129350                                            0.003834                                      1.000000                                       0.023817                                   0.023818                                        0.023759                                    0.023759                        0.093859                             -0.906947                         1.000000                         0.138717
# mean_total_qa_bytes_committed_log_differenced                                         0.004792                          0.002494                        0.005214                       0.003021                             -0.022567                           -0.007622                                   0.007905                         0.009927                               0.070576                               0.077472                                       0.070894                                     0.070497                                 0.077468                        -0.076769                                                   -0.077470                                 0.082057                         -0.001194                                        0.060738                                            0.089776                                           -0.011407                                      0.023817                                       1.000000                                   0.999966                                        0.999922                                    0.999893                        0.050257                              0.014662                         0.023819                         0.077374
# mean_total_qa_bytes_power_log_differenced                                             0.004740                          0.002456                        0.005219                       0.003013                             -0.022586                           -0.007645                                   0.007926                         0.009917                               0.070494                               0.077385                                       0.070812                                     0.070415                                 0.077380                        -0.076684                                                   -0.077383                                 0.082021                         -0.001203                                        0.064504                                            0.089700                                           -0.011402                                      0.023818                                       0.999966                                   1.000000                                        0.999883                                    0.999920                        0.050162                              0.014636                         0.023820                         0.077289
# mean_total_raw_bytes_committed_log_differenced                                        0.004802                          0.002581                        0.005258                       0.003040                             -0.022500                           -0.007577                                   0.007949                         0.009961                               0.070534                               0.077395                                       0.070851                                     0.070456                                 0.077391                        -0.076696                                                   -0.077393                                 0.081967                         -0.001181                                        0.059305                                            0.089694                                           -0.011407                                      0.023759                                       0.999922                                   0.999883                                        1.000000                                    0.999967                        0.050239                              0.014684                         0.023760                         0.077325
# mean_total_raw_bytes_power_log_differenced                                            0.004751                          0.002544                        0.005263                       0.003031                             -0.022524                           -0.007603                                   0.007971                         0.009952                               0.070457                               0.077311                                       0.070774                                     0.070379                                 0.077307                        -0.076615                                                   -0.077309                                 0.081936                         -0.001190                                        0.063002                                            0.089624                                           -0.011402                                      0.023759                                       0.999893                                   0.999920                                        0.999967                                    1.000000                        0.050145                              0.014661                         0.023761                         0.077245
# mean_burnt_fil_log_differenced                                                        0.012552                         -0.012936                       -0.000350                      -0.010405                              0.002245                           -0.008199                                   0.043648                        -0.000343                               0.523879                               0.562574                                       0.525202                                     0.523540                                 0.561855                        -0.559972                                                   -0.562035                                 0.462228                          0.008834                                       -0.001626                                            0.501980                                            0.005043                                      0.093859                                       0.050257                                   0.050162                                        0.050239                                    0.050145                        1.000000                              0.119135                         0.093889                         0.548733
# mean_circulating_fil_log_differenced                                                  0.001835                          0.001098                        0.000561                      -0.000048                             -0.029457                           -0.015425                                  -0.007411                        -0.001883                               0.204550                               0.219723                                       0.205313                                     0.204360                                 0.219770                        -0.219382                                                   -0.219763                                 0.185572                          0.006961                                       -0.000480                                            0.199957                                           -0.003559                                     -0.906947                                       0.014662                                   0.014636                                        0.014684                                    0.014661                        0.119135                              1.000000                        -0.906927                         0.225882
# mean_locked_fil_log_differenced                                                       0.009298                         -0.006692                       -0.003809                      -0.010823                             -0.102749                           -0.061145                                   0.009620                        -0.000638                               0.132247                               0.142850                                       0.132702                                     0.132133                                 0.142823                        -0.141454                                                   -0.142832                                 0.214018                         -0.001142                                        0.002421                                            0.129391                                            0.003834                                      1.000000                                       0.023819                                   0.023820                                        0.023760                                    0.023761                        0.093889                             -0.906927                         1.000000                         0.138763
# mean_vested_fil_log_differenced                                                      -0.000626                          0.019586                        0.006943                       0.005478                              0.153361                            0.083298                                   0.030314                         0.005207                               0.906436                               0.975765                                       0.909717                                     0.905616                                 0.975779                        -0.970755                                                   -0.975795                                 0.590692                          0.010198                                       -0.000228                                            0.885171                                           -0.000124                                      0.138717                                       0.077374                                   0.077289                                        0.077325                                    0.077245                        0.548733                              0.225882                         0.138763                         1.000000

# %% [markdown]
# ## Granger causality
#
# Granger causality is a hypothesis test for determining whether one-time series is useful in forecasting another. We can say that a variable X, or variables, evolves Granger-causes another evolving variable Y if predictions of the value of Y based on its past values and the past values of X are better than predictions of Y based only on Y's past values.
#
# Granger Causality is relationship based on the following principles:
#
# * The cause happens before its effect.
# * The cause has 'unique' information about the future values of its effect.
#
#
# Given these two assumptions about causality, Granger proposed to test the following hypothesis for identification of a causal effect of $X$ on $Y$:
# $${P}[Y(t+1) \in A\mid \mathcal{I}(t)] \neq \mathbb{P}[Y(t+1) \in A\mid \mathcal{I}_{-X}(t)]$$
# where $\mathbb{P}$ refers to probability, $A$ is an arbitrary non-empty set, and $\mathcal{I}(t)$ and $\mathcal{I}_{-X}(t)$ respectively denote the information available as of time $t$ in the entire universe, and that in the modified universe in which $X$ is excluded. If the above hypothesis is accepted, we say that $X$ Granger causes $Y$.
#
# In our analysis, we present the hypothesis that gas_used is a driver of message cost. In statistical parlance, we have the following:
#
# * $H_O: \textrm{Gas used does not Granger cause message cost}$
# * $H_A: \textrm{Gas used does Granger cause message cost}$
#
#
# Granger Causality assumes that the time series are non-stationary, which we checked and passed above, and autoregressive lags greater than 1.
#
# We will perform now perform the Granger Causality hypothesis test with an $\alpha = 0.05$ value using an F test to determine if the gas used has any casual component for predicting the message cost. If the p-value (the probability of obtaining test results at least as extreme as the results observed) of the test is less than or equal to $\alpha$ we will reject the null hypothesis and determine that gas used is a driver of message cost.
#
# ### Paraphrased source:
# * https://en.wikipedia.org/wiki/Granger_causality

# %% [markdown]
# As we have many signals with the analysis, we will loop through all the signals, perform the Granger Causality test, and save the results for analysis.

# %%
alpha = 0.05
result_dfs = []
variables = list(log_differenced_subset.columns)
for i in variables:
    for j in variables:
        if i==j:
            pass
        else:
            results_summary = results.test_causality(i,j, 
                                                     kind='f',signif=alpha).summary()


            df = pd.read_html(results_summary.as_html(),header=0, index_col=0)[0]
            df['alpha'] = alpha
            df['caused'] = i
            df['causing'] = j
            result_dfs.append(df)
        
Grangers_df = pd.concat(result_dfs)
Grangers_df.reset_index(inplace=True)
Grangers_df['result'] = Grangers_df['p-value'].apply(lambda x: 'reject H0' if x < alpha else 'fail to reject H0' )
Grangers_df
# Out:
#      Test statistic  Critical value  p-value             df  alpha  \
# 0            0.3606           1.831    0.963  (10, 1888915)   0.05
# 1            1.2250           1.831    0.268  (10, 1888915)   0.05
# 2            5.1760           1.831    0.000  (10, 1888915)   0.05
# 3           20.4000           1.831    0.000  (10, 1888915)   0.05
# 4            7.7580           1.831    0.000  (10, 1888915)   0.05
# ..              ...             ...      ...            ...    ...
# 807          0.3924           1.831    0.951  (10, 1888915)   0.05
# 808          0.3552           1.831    0.965  (10, 1888915)   0.05
# 809         14.8300           1.831    0.000  (10, 1888915)   0.05
# 810         13.8300           1.831    0.000  (10, 1888915)   0.05
# 811          3.2790           1.831    0.000  (10, 1888915)   0.05
#
#                                caused  \
# 0    mean_gas_fee_cap_log_differenced
# 1    mean_gas_fee_cap_log_differenced
# 2    mean_gas_fee_cap_log_differenced
# 3    mean_gas_fee_cap_log_differenced
# 4    mean_gas_fee_cap_log_differenced
# ..                                ...
# 807   mean_vested_fil_log_differenced
# 808   mean_vested_fil_log_differenced
# 809   mean_vested_fil_log_differenced
# 810   mean_vested_fil_log_differenced
# 811   mean_vested_fil_log_differenced
#
#                                             causing             result
# 0                  mean_gas_premium_log_differenced  fail to reject H0
# 1                    mean_gas_limit_log_differenced  fail to reject H0
# 2                     mean_gas_used_log_differenced          reject H0
# 3              mean_parent_base_fee_log_differenced          reject H0
# 4                mean_base_fee_burn_log_differenced          reject H0
# ..                                              ...                ...
# 807  mean_total_raw_bytes_committed_log_differenced  fail to reject H0
# 808      mean_total_raw_bytes_power_log_differenced  fail to reject H0
# 809                  mean_burnt_fil_log_differenced          reject H0
# 810            mean_circulating_fil_log_differenced          reject H0
# 811                 mean_locked_fil_log_differenced          reject H0
#
# [812 rows x 8 columns]

# %%
heatdf = Grangers_df.pivot(index='caused', columns=['causing'],values=['p-value'])

f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(heatdf, annot=True, linewidths=.5, ax=ax,cmap=['green','red'],center=0.05)
plt.suptitle('Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')
# Out:
# Text(0.5, 0.98, 'Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')

# %% [markdown]
# Based on the heatmap above, we can see that there are some granger causal relationships between signals. To see more granular specifics, we will examine the reject H0s below

# %%
Grangers_df.query("result == 'reject H0'").sort_values('p-value',ascending=True)
# Out:
#      Test statistic  Critical value  p-value             df  alpha  \
# 2             5.176           1.831    0.000  (10, 1888915)   0.05
# 377           9.114           1.831    0.000  (10, 1888915)   0.05
# 378          13.950           1.831    0.000  (10, 1888915)   0.05
# 388          15.660           1.831    0.000  (10, 1888915)   0.05
# 389          14.620           1.831    0.000  (10, 1888915)   0.05
# ..              ...             ...      ...            ...    ...
# 504           1.860           1.831    0.046  (10, 1888915)   0.05
# 152           1.843           1.831    0.048  (10, 1888915)   0.05
# 500           1.839           1.831    0.049  (10, 1888915)   0.05
# 696           1.839           1.831    0.049  (10, 1888915)   0.05
# 612           1.835           1.831    0.049  (10, 1888915)   0.05
#
#                                                 caused  \
# 2                     mean_gas_fee_cap_log_differenced
# 377                    mean_new_reward_log_differenced
# 378                    mean_new_reward_log_differenced
# 388                    mean_new_reward_log_differenced
# 389                    mean_new_reward_log_differenced
# ..                                                 ...
# 504  mean_qa_smoothed_position_estimate_log_differe...
# 152                 mean_base_fee_burn_log_differenced
# 500     mean_participating_miner_count_log_differenced
# 696         mean_total_raw_bytes_power_log_differenced
# 612      mean_total_qa_bytes_committed_log_differenced
#
#                                                causing     result
# 2                        mean_gas_used_log_differenced  reject H0
# 377  mean_new_reward_smoothed_position_estimate_log...  reject H0
# 378            mean_total_mined_reward_log_differenced  reject H0
# 388                     mean_burnt_fil_log_differenced  reject H0
# 389               mean_circulating_fil_log_differenced  reject H0
# ..                                                 ...        ...
# 504                   mean_gas_fee_cap_log_differenced  reject H0
# 152                    mean_new_reward_log_differenced  reject H0
# 500                     mean_burnt_fil_log_differenced  reject H0
# 696                     mean_burnt_fil_log_differenced  reject H0
# 612                     mean_burnt_fil_log_differenced  reject H0
#
# [333 rows x 8 columns]

# %% [markdown]
# Based on the above table, we can see some Granger caused relationships between signals, such as mean_gas_fee_cap Granger causes mean_gas_limit. We can't fully use Granger until we understand what the signals are and what they represent better.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Behavior Model
#
# For our Digital Twin of the Filecoin system, we need to construct a behavior model to forecast daily values. Very rough V1.

# %%
QUERY = """
SELECT 
date_trunc('day', 
to_timestamp(height_to_unix(d.height))) AS timestamp,
AVG(CAST(gas_fee_cap AS FLOAT)) AS mean_gas_fee_cap,
AVG(CAST(gas_premium AS FLOAT))  as mean_gas_premium,
AVG(CAST(gas_limit AS FLOAT))  as mean_gas_limit,
AVG(CAST(gas_used AS FLOAT))  as mean_gas_used,
AVG(CAST(parent_base_fee AS FLOAT))  as mean_parent_base_fee,
AVG(CAST(base_fee_burn AS FLOAT))  as mean_base_fee_burn,
AVG(CAST(over_estimation_burn AS FLOAT))  as mean_over_estimation_burn,
AVG(CAST(gas_refund AS FLOAT))  as mean_gas_refund,
AVG(CAST(gas_burned AS FLOAT))  as mean_gas_burned
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-01-01' AND '2021-07-28'
GROUP BY
timestamp
"""
derived_gas_outputs_day = (pd.read_sql(QUERY, connection))

# %%
QUERY = """
SELECT 
date_trunc('day', 
to_timestamp(height_to_unix(cr.height))) AS timestamp,
AVG(CAST(cr.cum_sum_baseline AS FLOAT)) AS mean_cum_sum_baseline,
AVG(CAST(cr.cum_sum_realized AS FLOAT)) AS mean_cum_sum_realized,
AVG(CAST(cr.effective_baseline_power AS FLOAT)) AS mean_effective_baseline_power,
AVG(CAST(cr.effective_network_time AS FLOAT)) AS mean_effective_network_time,
AVG(CAST(cr.new_baseline_power AS FLOAT)) AS mean_new_baseline_power,
AVG(CAST(cr.new_reward AS FLOAT)) AS mean_new_reward,
AVG(CAST(cr.new_reward_smoothed_position_estimate AS FLOAT)) AS mean_new_reward_smoothed_position_estimate,
AVG(CAST(cr.new_reward_smoothed_velocity_estimate AS FLOAT)) AS mean_new_reward_smoothed_velocity_estimate,
AVG(CAST(cr.total_mined_reward AS FLOAT)) AS mean_total_mined_reward,
AVG(CAST(cp.miner_count AS FLOAT)) AS mean_miner_count,
AVG(CAST(cp.participating_miner_count AS FLOAT)) AS mean_participating_miner_count,
AVG(CAST(cp.qa_smoothed_position_estimate AS FLOAT)) AS mean_qa_smoothed_position_estimate,
AVG(CAST(cp.qa_smoothed_velocity_estimate AS FLOAT)) AS mean_qa_smoothed_velocity_estimate,
AVG(CAST(cp.total_pledge_collateral AS FLOAT)) AS mean_total_pledge_collateral,
AVG(CAST(cp.total_qa_bytes_committed AS FLOAT)) AS mean_total_qa_bytes_committed,
AVG(CAST(cp.total_qa_bytes_power AS FLOAT)) AS mean_total_qa_bytes_power,
AVG(CAST(cp.total_raw_bytes_committed AS FLOAT)) AS mean_total_raw_bytes_committed,
AVG(CAST(cp.total_raw_bytes_power AS FLOAT)) AS mean_total_raw_bytes_power,
AVG(CAST(ce.burnt_fil AS FLOAT)) AS mean_burnt_fil,
AVG(CAST(ce.circulating_fil AS FLOAT)) AS mean_circulating_fil,
AVG(CAST(ce.locked_fil AS FLOAT)) AS mean_locked_fil,
AVG(CAST(ce.mined_fil AS FLOAT)) AS mean_mined_fil,
AVG(CAST(ce.vested_fil AS FLOAT)) AS mean_vested_fil
FROM chain_rewards cr
LEFT JOIN chain_powers cp
ON cr.state_root = cp.state_root
LEFT JOIN chain_economics ce
ON cr.state_root = ce.parent_state_root
WHERE
to_timestamp(height_to_unix(cr.height)) BETWEEN '2021-01-01' AND '2021-07-28'
GROUP BY
timestamp
"""
chain_economics_day = (pd.read_sql(QUERY, connection))

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# combine signals
combined_day = derived_gas_outputs_day.merge(chain_economics_day,how='left',on='timestamp')
combined_day.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count          59.00000          59.00000        59.00000       59.00000
# mean   5513764599.27085      779567.86457  42796538.21884 34785567.76599
# std    3684484772.96472      870938.96647   3602577.13853  2973285.20602
# min    1435953211.88763      100750.11059  37277468.82593 30214119.92849
# 25%    2518722674.45341      245250.55322  39492829.37820 32184388.22712
# 50%    2820050774.36324      340598.82305  41983029.37938 33377061.44188
# 75%    8779641266.38300      992241.97860  46409521.25946 37704892.72420
# max   13948241946.81982     4876887.81949  49142218.09421 39685622.85690
#
#        mean_parent_base_fee      mean_base_fee_burn  \
# count              59.00000                59.00000
# mean        324497584.52827 10702441437204500.00000
# std         364251457.33417 11517642841690658.00000
# min               102.90795        3120658409.62568
# 25%         126920875.02017  4319455509135423.00000
# 50%         157547108.47885  5834867675979699.00000
# 75%         393457302.14625 12611152216045038.00000
# max        1448219388.20665 45827824053141656.00000
#
#        mean_over_estimation_burn  mean_gas_refund  mean_gas_burned  \
# count                   59.00000         59.00000         59.00000
# mean       574911659488438.50000    6236081.25181    1774889.20104
# std        666689380078855.62500     508835.99344     434658.19433
# min              171439423.16412    5480787.27241    1319441.62411
# 25%        209884231122116.68750    5754182.12158    1550820.24453
# 50%        263696901668051.71875    6090883.33983    1693245.31151
# 75%        776976050677638.75000    6724390.74650    1803421.51694
# max       2667938987872354.50000    7131652.03176    4047044.35432
#
#                 mean_cum_sum_baseline  ...     mean_total_pledge_collateral  \
# count                        58.00000  ...                         58.00000
# mean  2327819556277354149969920.00000  ... 86821733576156731592933376.00000
# std    252554170584497708335104.00000  ...  4979964280915180497403904.00000
# min   1908857373855166047977472.00000  ... 78458853397837202401001472.00000
# 25%   2113606728848293457035264.00000  ... 82749400220976877108461568.00000
# 50%   2323978528983292038873088.00000  ... 86604157442057554733563904.00000
# 75%   2540120339522715148877824.00000  ... 90934286232874768146628608.00000
# max   2754293985595333294424064.00000  ... 95484730224346023396900864.00000
#
#        mean_total_qa_bytes_committed  mean_total_qa_bytes_power  \
# count                       58.00000                   58.00000
# mean       8018422700315115520.00000  8017973781821209600.00000
# std         764412148993667840.00000   764409584587408384.00000
# min        6755098031297460224.00000  6754589830064675840.00000
# 25%        7403331097903893504.00000  7402935466629052416.00000
# 50%        7943631143157463040.00000  7943201918081941504.00000
# 75%        8646171788466951168.00000  8645719248644021248.00000
# max        9433791232083787776.00000  9433339819393220608.00000
#
#        mean_total_raw_bytes_committed  mean_total_raw_bytes_power  \
# count                        58.00000                    58.00000
# mean        8015668284604048384.00000   8015229091141893120.00000
# std          763884555966834688.00000    763878423698116480.00000
# min         6752989031858666496.00000   6752497531198137344.00000
# 25%         7400994986570546176.00000   7400614135808150528.00000
# 50%         7941000364339126272.00000   7940585443748105216.00000
# 75%         8643025059546769408.00000   8642577749019783168.00000
# max         9429896089038749696.00000   9429447350855663616.00000
#
#                         mean_burnt_fil              mean_circulating_fil  \
# count                         58.00000                          58.00000
# mean  26715685944095654736297984.00000 140782685485477002634854400.00000
# std     343194487670754039037952.00000   6827838961405847777837056.00000
# min   26041012965313313660469248.00000 129281449575053823743885312.00000
# 25%   26475501575103443793608704.00000 134870374020500809203056640.00000
# 50%   26850147131516603074609152.00000 140906713427771273133424640.00000
# 75%   26959393679700636565766144.00000 146684769814511451549728768.00000
# max   27141664085021777725489152.00000 151762749972865654944956416.00000
#
#                        mean_locked_fil                   mean_mined_fil  \
# count                         58.00000                         58.00000
# mean  86831343052147418332135424.00000 80869563268025749841379328.00000
# std    4980518631971248433790976.00000  5966288740640552176844800.00000
# min   78467087855590307253977088.00000 70730120556838999577067520.00000
# 25%   82758528548923414899851264.00000 75843116551862091130077184.00000
# 50%   86614260680302555840905216.00000 80907780830561943569825792.00000
# 75%   90944395121881435986722816.00000 85923136653312624842244096.00000
# max   95494718508828444227272704.00000 90714172733606828282216448.00000
#
#                         mean_vested_fil
# count                          58.00000
# mean  156393532251920891285340160.00000
# std     6159324709164492957679616.00000
# min   145992810877345001914761216.00000
# 25%   151194668630892172254642176.00000
# 50%   156396721447254955118297088.00000
# 75%   161598803001007468978372608.00000
# max   166618340871335631218802688.00000
#
# [8 rows x 32 columns]

# %%
# split into train and test
combined_day_test = combined_day.tail(10)
combined_day = combined_day.head(len(combined_day)-10)

del combined_day['timestamp']
combined_day.fillna(0,inplace=True)

# %%
combined_day.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit'}>,
#         <AxesSubplot:title={'center':'mean_gas_used'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>,
#         <AxesSubplot:title={'center':'mean_cum_sum_baseline'}>,
#         <AxesSubplot:title={'center':'mean_cum_sum_realized'}>,
#         <AxesSubplot:title={'center':'mean_effective_baseline_power'}>],
#        [<AxesSubplot:title={'center':'mean_effective_network_time'}>,
#         <AxesSubplot:title={'center':'mean_new_baseline_power'}>,
#         <AxesSubplot:title={'center':'mean_new_reward'}>,
#         <AxesSubplot:title={'center':'mean_new_reward_smoothed_position_estimate'}>,
#         <AxesSubplot:title={'center':'mean_new_reward_smoothed_velocity_estimate'}>,
#         <AxesSubplot:title={'center':'mean_total_mined_reward'}>],
#        [<AxesSubplot:title={'center':'mean_miner_count'}>,
#         <AxesSubplot:title={'center':'mean_participating_miner_count'}>,
#         <AxesSubplot:title={'center':'mean_qa_smoothed_position_estimate'}>,
#         <AxesSubplot:title={'center':'mean_qa_smoothed_velocity_estimate'}>,
#         <AxesSubplot:title={'center':'mean_total_pledge_collateral'}>,
#         <AxesSubplot:title={'center':'mean_total_qa_bytes_committed'}>],
#        [<AxesSubplot:title={'center':'mean_total_qa_bytes_power'}>,
#         <AxesSubplot:title={'center':'mean_total_raw_bytes_committed'}>,
#         <AxesSubplot:title={'center':'mean_total_raw_bytes_power'}>,
#         <AxesSubplot:title={'center':'mean_burnt_fil'}>,
#         <AxesSubplot:title={'center':'mean_circulating_fil'}>,
#         <AxesSubplot:title={'center':'mean_locked_fil'}>],
#        [<AxesSubplot:title={'center':'mean_mined_fil'}>,
#         <AxesSubplot:title={'center':'mean_vested_fil'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# from sklearn.preprocessing import PowerTransformer
# pt = PowerTransformer(standardize=False)
# yeo = pt.fit_transform(combined_day)
# yeo_df = pd.DataFrame(yeo,columns=combined_day.columns)
# yeo_df_stochastic.fillna(0,inplace=True)
# yeo_df.hist(bins=30, figsize=(15, 15))

# %%
np.random.seed(0)
log_differenced_day = pd.DataFrame()
## Difference and log values
for i in combined_day.columns:
    try:
        log_differenced_day[i +'_log_differenced'] = np.log(combined_day[i]).diff()
        log_differenced_day[i +'_log_differenced'].iat[0] = np.log(combined_day[i].iat[0])
    except:
        pass
# replace any NA values with zero
log_differenced_day.fillna(0,inplace=True)

# %%
# log_differenced_day.hist(bins=30, figsize=(15, 15))

# %% [markdown]
# # Behavior next steps
# * Bag of records. Bootstrap sample for v1.
# * Eventually split into static and non-static. Non-static VAR and static boostrap
#
#
# Based on the histograms above, we have some stochastic signals, such as *mean_base_fee_burn_log_differenced* and some close to constant values, such as *mean_vested_fil_log_differenced*. We will divide the dataset into two groups, stochastic and constants (some of which are not, but are highly skewed), and perform different manipulations on each to create a behavior model.

# %%
# yeo_df_stochastic = yeo_df[['mean_parent_base_fee','mean_gas_limit']]#,'mean_participating_miner_count','mean_qa_smoothed_velocity_estimate']]
# yeo_df_constant = yeo_df[yeo_df.columns[~yeo_df.columns.isin(['mean_parent_base_fee','mean_gas_limit'])]]

# %%
log_differenced_day_stochastic = log_differenced_day[['mean_parent_base_fee_log_differenced','mean_base_fee_burn_log_differenced',
                                                     ]]

log_differenced_day_constant = log_differenced_day[['mean_gas_fee_cap_log_differenced','mean_gas_premium_log_differenced',
                                                   'mean_gas_limit_log_differenced','mean_gas_used_log_differenced',
                                                   'mean_over_estimation_burn_log_differenced','mean_gas_refund_log_differenced',
                                                   'mean_gas_burned_log_differenced','mean_cum_sum_baseline_log_differenced',
                                                   'mean_cum_sum_realized_log_differenced','mean_effective_baseline_power_log_differenced',
                                                   'mean_effective_network_time_log_differenced','mean_new_baseline_power_log_differenced',
                                                   'mean_new_reward_log_differenced','mean_new_reward_smoothed_position_estimate_log_differenced',
                                                   'mean_new_reward_smoothed_velocity_estimate_log_differenced','mean_total_mined_reward_log_differenced',
                                                   'mean_miner_count_log_differenced','mean_participating_miner_count_log_differenced',
                                                   'mean_qa_smoothed_position_estimate_log_differenced','mean_qa_smoothed_velocity_estimate_log_differenced',
                                                   'mean_total_pledge_collateral_log_differenced','mean_total_qa_bytes_committed_log_differenced',
                                                   'mean_total_qa_bytes_power_log_differenced','mean_total_raw_bytes_committed_log_differenced',
                                                   'mean_total_raw_bytes_power_log_differenced','mean_burnt_fil_log_differenced',
                                                   'mean_circulating_fil_log_differenced','mean_locked_fil_log_differenced',
                                                   'mean_mined_fil_log_differenced','mean_vested_fil_log_differenced']]

# %% [markdown]
# <!-- ## Stochastic Signal Component Model -->

# %%
aic = []
for i in range(1,16):
    model = VAR(log_differenced_day_stochastic)
    results = model.fit(i)
    aic.append(results.aic)

# %%
plt.figure(figsize=(10, 8))
plt.plot(aic, 'r+')
plt.legend(['AIC'])
plt.xlabel('Autocorrelation Lag')
plt.ylabel('AIC')
plt.title('Plot of sweeps over lag depths over AIC Loss function')
plt.show()

# %%
# instantiate the var model object from statsmodels
model = VAR(log_differenced_day_stochastic)

# fit model with determined lag values
results = model.fit(5)

# %%
# results.summary()

# %% [markdown]
# <!-- ## Constant Signal Component Model -->

# %%
# yeo_df_constant_ewm = yeo_df_constant.ewm(alpha=0.5).mean()

# %%
log_differenced_day_constant_ewm_forcast=log_differenced_day_constant_ewm.tail(steps)
log_differenced_day_constant_ewm_forcast.reset_index(inplace=True)
del log_differenced_day_constant_ewm_forcast['index']
log_differenced_day_constant_ewm_forcast

# yeo_df_constant_ewm_forcast=yeo_df_constant_ewm.tail(steps)
# yeo_df_constant_ewm_forcast.reset_index(inplace=True)
# del yeo_df_constant_ewm_forcast['index']
# Out:
#    mean_gas_fee_cap_log_differenced  mean_gas_premium_log_differenced  \
# 0                           0.03258                           0.06351
# 1                           0.00606                           0.07646
# 2                          -0.04047                          -0.04822
# 3                          -0.04809                          -0.11437
# 4                          -0.02517                          -0.04691
#
#    mean_gas_limit_log_differenced  mean_gas_used_log_differenced  \
# 0                         0.00361                        0.00352
# 1                         0.01324                        0.01261
# 2                         0.00539                        0.00571
# 3                         0.01869                        0.01938
# 4                         0.01200                        0.01205
#
#    mean_over_estimation_burn_log_differenced  mean_gas_refund_log_differenced  \
# 0                                    0.08334                          0.00704
# 1                                    0.13901                          0.00815
# 2                                   -0.01965                          0.00400
# 3                                   -0.05986                          0.01439
# 4                                   -0.03420                          0.00748
#
#    mean_gas_burned_log_differenced  mean_cum_sum_baseline_log_differenced  \
# 0                         -0.00784                                0.00609
# 1                          0.04789                                0.00606
# 2                          0.00428                                0.00603
# 3                          0.02060                                0.00601
# 4                          0.02857                                0.00598
#
#    mean_cum_sum_realized_log_differenced  \
# 0                                0.00609
# 1                                0.00606
# 2                                0.00603
# 3                                0.00601
# 4                                0.00598
#
#    mean_effective_baseline_power_log_differenced  ...  \
# 0                                        0.00222  ...
# 1                                        0.00222  ...
# 2                                        0.00222  ...
# 3                                        0.00222  ...
# 4                                        0.00222  ...
#
#    mean_total_pledge_collateral_log_differenced  \
# 0                                       0.00375
# 1                                       0.00379
# 2                                       0.00381
# 3                                       0.00371
# 4                                       0.00369
#
#    mean_total_qa_bytes_committed_log_differenced  \
# 0                                        0.00715
# 1                                        0.00697
# 2                                        0.00544
# 3                                        0.00104
# 4                                        0.00994
#
#    mean_total_qa_bytes_power_log_differenced  \
# 0                                    0.00715
# 1                                    0.00697
# 2                                    0.00544
# 3                                    0.00104
# 4                                    0.00994
#
#    mean_total_raw_bytes_committed_log_differenced  \
# 0                                         0.00714
# 1                                         0.00696
# 2                                         0.00543
# 3                                         0.00103
# 4                                         0.00994
#
#    mean_total_raw_bytes_power_log_differenced  mean_burnt_fil_log_differenced  \
# 0                                     0.00714                         0.00042
# 1                                     0.00696                         0.00048
# 2                                     0.00543                         0.00052
# 3                                     0.00103                         0.00073
# 4                                     0.00994                         0.00058
#
#    mean_circulating_fil_log_differenced  mean_locked_fil_log_differenced  \
# 0                               0.00249                          0.00375
# 1                               0.00244                          0.00379
# 2                               0.00240                          0.00381
# 3                               0.00239                          0.00371
# 4                               0.00243                          0.00369
#
#    mean_mined_fil_log_differenced  mean_vested_fil_log_differenced
# 0                         0.00410                          0.00227
# 1                         0.00408                          0.00226
# 2                         0.00405                          0.00226
# 3                         0.00401                          0.00225
# 4                         0.00401                          0.00225
#
# [5 rows x 30 columns]

# %%
lag_order = results.k_ar
steps = 5

five_step_forecast_stochastic = results.forecast(log_differenced_day_stochastic.values[-lag_order:], steps)

# %%
# five_step_forecast_df
# Out:
#    mean_parent_base_fee  mean_gas_limit  mean_gas_fee_cap  mean_gas_premium  \
# 0               0.53759         0.55238           0.00000           0.00000
# 1               0.49470         0.50202           0.00000           0.00000
# 2               0.46688         0.46160           0.00000           0.00000
# 3              -0.13681        -0.13645           0.00000           0.00000
# 4              -0.36765        -0.36348           0.00000           0.00000
#
#    mean_gas_used  mean_base_fee_burn  mean_over_estimation_burn  \
# 0        0.00000             0.00000                    0.00000
# 1        0.00000             0.00000                    0.00000
# 2        0.00000             0.00000                    0.00000
# 3        0.00000             0.00000                    0.00000
# 4        0.00000             0.00000                    0.00000
#
#    mean_gas_refund  mean_gas_burned  mean_cum_sum_baseline  ...  \
# 0          0.00000          0.00000                0.00000  ...
# 1          0.00000          0.00000                0.00000  ...
# 2          0.00000          0.00000                0.00000  ...
# 3          0.00000          0.00000                0.00000  ...
# 4          0.00000          0.00000                0.00000  ...
#
#    mean_total_pledge_collateral  mean_total_qa_bytes_committed  \
# 0                       0.00000                        0.00000
# 1                       0.00000                        0.00000
# 2                       0.00000                        0.00000
# 3                       0.00000                        0.00000
# 4                       0.00000                        0.00000
#
#    mean_total_qa_bytes_power  mean_total_raw_bytes_committed  \
# 0                    0.00000                         0.00000
# 1                    0.00000                         0.00000
# 2                    0.00000                         0.00000
# 3                    0.00000                         0.00000
# 4                    0.00000                         0.00000
#
#    mean_total_raw_bytes_power  mean_burnt_fil  mean_circulating_fil  \
# 0                     0.00000         0.00000               0.00000
# 1                     0.00000         0.00000               0.00000
# 2                     0.00000         0.00000               0.00000
# 3                     0.00000         0.00000               0.00000
# 4                     0.00000         0.00000               0.00000
#
#    mean_locked_fil  mean_mined_fil  mean_vested_fil
# 0          0.00000         0.00000          0.00000
# 1          0.00000         0.00000          0.00000
# 2          0.00000         0.00000          0.00000
# 3          0.00000         0.00000          0.00000
# 4          0.00000         0.00000          0.00000
#
# [5 rows x 32 columns]

# %%
five_step_forecast_df = pd.DataFrame(five_step_forecast,columns=log_differenced_day_stochastic.columns)
five_step_forecast_df = pd.concat([five_step_forecast_df,log_differenced_day_constant_ewm_forcast],axis=1)
five_step_forecast_df
# Out:
#    mean_parent_base_fee_log_differenced  mean_base_fee_burn_log_differenced  \
# 0                               0.53759                             0.55238
# 1                               0.49470                             0.50202
# 2                               0.46688                             0.46160
# 3                              -0.13681                            -0.13645
# 4                              -0.36765                            -0.36348
#
#    mean_gas_fee_cap_log_differenced  mean_gas_premium_log_differenced  \
# 0                           0.03258                           0.06351
# 1                           0.00606                           0.07646
# 2                          -0.04047                          -0.04822
# 3                          -0.04809                          -0.11437
# 4                          -0.02517                          -0.04691
#
#    mean_gas_limit_log_differenced  mean_gas_used_log_differenced  \
# 0                         0.00361                        0.00352
# 1                         0.01324                        0.01261
# 2                         0.00539                        0.00571
# 3                         0.01869                        0.01938
# 4                         0.01200                        0.01205
#
#    mean_over_estimation_burn_log_differenced  mean_gas_refund_log_differenced  \
# 0                                    0.08334                          0.00704
# 1                                    0.13901                          0.00815
# 2                                   -0.01965                          0.00400
# 3                                   -0.05986                          0.01439
# 4                                   -0.03420                          0.00748
#
#    mean_gas_burned_log_differenced  mean_cum_sum_baseline_log_differenced  \
# 0                         -0.00784                                0.00609
# 1                          0.04789                                0.00606
# 2                          0.00428                                0.00603
# 3                          0.02060                                0.00601
# 4                          0.02857                                0.00598
#
#    ...  mean_total_pledge_collateral_log_differenced  \
# 0  ...                                       0.00375
# 1  ...                                       0.00379
# 2  ...                                       0.00381
# 3  ...                                       0.00371
# 4  ...                                       0.00369
#
#    mean_total_qa_bytes_committed_log_differenced  \
# 0                                        0.00715
# 1                                        0.00697
# 2                                        0.00544
# 3                                        0.00104
# 4                                        0.00994
#
#    mean_total_qa_bytes_power_log_differenced  \
# 0                                    0.00715
# 1                                    0.00697
# 2                                    0.00544
# 3                                    0.00104
# 4                                    0.00994
#
#    mean_total_raw_bytes_committed_log_differenced  \
# 0                                         0.00714
# 1                                         0.00696
# 2                                         0.00543
# 3                                         0.00103
# 4                                         0.00994
#
#    mean_total_raw_bytes_power_log_differenced  mean_burnt_fil_log_differenced  \
# 0                                     0.00714                         0.00042
# 1                                     0.00696                         0.00048
# 2                                     0.00543                         0.00052
# 3                                     0.00103                         0.00073
# 4                                     0.00994                         0.00058
#
#    mean_circulating_fil_log_differenced  mean_locked_fil_log_differenced  \
# 0                               0.00249                          0.00375
# 1                               0.00244                          0.00379
# 2                               0.00240                          0.00381
# 3                               0.00239                          0.00371
# 4                               0.00243                          0.00369
#
#    mean_mined_fil_log_differenced  mean_vested_fil_log_differenced
# 0                         0.00410                          0.00227
# 1                         0.00408                          0.00226
# 2                         0.00405                          0.00226
# 3                         0.00401                          0.00225
# 4                         0.00401                          0.00225
#
# [5 rows x 32 columns]

# %%
np.random.seed(0)
five_step_forecast_inversed = pd.DataFrame()
## Difference and log values
for i in five_step_forecast_df.columns:
    try:
        five_step_forecast_inversed[i.replace('_log_differenced','')] = np.exp(five_step_forecast_df[i].cumsum())
    except:
        print(i)

# %%
# five_step_forecast_inversed = pd.DataFrame(pt.inverse_transform(five_step_forecast_df),columns=five_step_forecast_df.columns)
five_step_forecast_inversed
# Out:
#    mean_parent_base_fee  mean_base_fee_burn  mean_gas_fee_cap  \
# 0               1.71188             1.73738           1.03312
# 1               2.80750             2.87025           1.03940
# 2               4.47797             4.55398           0.99818
# 3               3.90538             3.97314           0.95132
# 4               2.70393             2.76234           0.92767
#
#    mean_gas_premium  mean_gas_limit  mean_gas_used  mean_over_estimation_burn  \
# 0           1.06557         1.00362        1.00353                    1.08691
# 1           1.15024         1.01700        1.01627                    1.24900
# 2           1.09609         1.02250        1.02209                    1.22469
# 3           0.97763         1.04179        1.04209                    1.15353
# 4           0.93283         1.05436        1.05472                    1.11475
#
#    mean_gas_refund  mean_gas_burned  mean_cum_sum_baseline  ...  \
# 0          1.00706          0.99219                1.00610  ...
# 1          1.01530          1.04086                1.01222  ...
# 2          1.01937          1.04532                1.01835  ...
# 3          1.03414          1.06707                1.02448  ...
# 4          1.04190          1.09800                1.03063  ...
#
#    mean_total_pledge_collateral  mean_total_qa_bytes_committed  \
# 0                       1.00376                        1.00717
# 1                       1.00757                        1.01422
# 2                       1.01142                        1.01975
# 3                       1.01519                        1.02081
# 4                       1.01894                        1.03101
#
#    mean_total_qa_bytes_power  mean_total_raw_bytes_committed  \
# 0                    1.00718                         1.00716
# 1                    1.01422                         1.01420
# 2                    1.01975                         1.01972
# 3                    1.02081                         1.02077
# 4                    1.03102                         1.03097
#
#    mean_total_raw_bytes_power  mean_burnt_fil  mean_circulating_fil  \
# 0                     1.00717         1.00042               1.00250
# 1                     1.01420         1.00090               1.00494
# 2                     1.01972         1.00141               1.00736
# 3                     1.02078         1.00214               1.00977
# 4                     1.03097         1.00272               1.01223
#
#    mean_locked_fil  mean_mined_fil  mean_vested_fil
# 0          1.00376         1.00410          1.00227
# 1          1.00757         1.00821          1.00454
# 2          1.01142         1.01230          1.00681
# 3          1.01518         1.01637          1.00907
# 4          1.01894         1.02045          1.01134
#
# [5 rows x 32 columns]

# %%
combined_day_test.tail(5)
# Out:
#                    timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 54 2021-07-24 00:00:00+00:00  2622955770.41831      304599.85401
# 55 2021-07-25 00:00:00+00:00  2446283802.89546      266195.99052
# 56 2021-07-26 00:00:00+00:00  2393196723.40942      196044.76745
# 57 2021-07-27 00:00:00+00:00  2504705531.98125     1614544.24443
# 58 2021-07-28 00:00:00+00:00  2183638105.66438      110709.42009
#
#     mean_gas_limit  mean_gas_used  mean_parent_base_fee  \
# 54  47392719.82073 38671762.59468       180810470.00474
# 55  47390879.50345 38717254.82918       154515924.92369
# 56  46624717.96157 38145239.27062       147652158.63544
# 57  45149876.83043 36900509.14196       167373440.57843
# 58  45049889.94064 37292989.07534       133407921.00000
#
#        mean_base_fee_burn  mean_over_estimation_burn  mean_gas_refund  \
# 54 6940577920974136.00000      305346164751407.37500    7007854.24171
# 55 5958227991119708.00000      266688839285041.12500    6938913.98786
# 56 5603323040318283.00000      246283533154831.40625    6801257.78310
# 57 6156126791804198.00000      258814799616791.34375    6695158.43183
# 58 4975180140417151.00000      196990101730574.90625    6280301.12329
#
#     mean_gas_burned  ...     mean_total_pledge_collateral  \
# 54    1713102.98434  ... 94346482770155182376353792.00000
# 55    1734710.68641  ... 94682778008720712417673216.00000
# 56    1678220.90785  ... 95008152710739223633723392.00000
# 57    1554209.25663  ... 95328262823314438741819392.00000
# 58    1476599.74201  ... 95484730224346023396900864.00000
#
#     mean_total_qa_bytes_committed  mean_total_qa_bytes_power  \
# 54      9225569682273728512.00000  9225081290404569088.00000
# 55      9288372157855967232.00000  9287872565229381632.00000
# 56      9337686232896153600.00000  9337216396259704832.00000
# 57      9401802305545275392.00000  9401346469632698368.00000
# 58      9433791232083787776.00000  9433339819393220608.00000
#
#     mean_total_raw_bytes_committed  mean_total_raw_bytes_power  \
# 54       9221928069689658368.00000   9221441000807003136.00000
# 55       9284590189669863424.00000   9284092215372390400.00000
# 56       9334027620506691584.00000   9333560354922708992.00000
# 57       9397927561395439616.00000   9397473795526346752.00000
# 58       9429896089038749696.00000   9429447350855663616.00000
#
#                      mean_burnt_fil              mean_circulating_fil  \
# 54 27098189129746783930417152.00000 150452145811104886440329216.00000
# 55 27111075343361991342292992.00000 150816828065114060610338816.00000
# 56 27123065852793603271688192.00000 151190831711184506650099712.00000
# 57 27135350892033292980191232.00000 151571752208471350700933120.00000
# 58 27141664085021777725489152.00000 151762749972865654944956416.00000
#
#                     mean_locked_fil                   mean_mined_fil  \
# 54 94356501215163132825042944.00000 89499346614489173754642432.00000
# 55 94692785622242856603222016.00000 89848542557444291472392192.00000
# 56 95018151192707743113805824.00000 90194623815292039530020864.00000
# 57 95338254194983446010396672.00000 90542845364978884248862720.00000
# 58 95494718508828444227272704.00000 90714172733606828282216448.00000
#
#                      mean_vested_fil
# 54 165340870579752177684709376.00000
# 55 165705527511501053657874432.00000
# 56 166070805979620404698808320.00000
# 57 166435892968735599067398144.00000
# 58 166618340871335631218802688.00000
#
# [5 rows x 33 columns]

# %%
df_constant_ewm = combined_day.ewm(alpha=0.5).mean()
df_constant_ewm_forcast=df_constant_ewm.tail(5)
df_constant_ewm_forcast
# Out:
#     mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# 44  2732356539.50904      261145.83031  45255348.87697 37005874.29837
# 45  2747649927.22924      280548.76107  45860986.26412 37477397.28160
# 46  2640194872.07740      266437.61287  46106702.56588 37690541.92502
# 47  2517848759.34573      238545.51710  46983017.42562 38433971.86576
# 48  2453988117.76371      226785.40467  47548564.34263 38898444.59239
#
#     mean_parent_base_fee     mean_base_fee_burn  mean_over_estimation_burn  \
# 44       164051224.55974 6028826412339251.00000      258744265023881.34375
# 45       180663175.50393 6644252196549943.00000      298781482238526.12500
# 46       175052062.86664 6512229820418684.00000      291132695768003.37500
# 47       161051959.45845 6121728871494346.00000      273810344740945.59375
# 48       151301717.90839 5828900865863392.00000      264058732771010.34375
#
#     mean_gas_refund  mean_gas_burned           mean_cum_sum_baseline  ...  \
# 44    6647900.66755    1601573.91104 2528621301156422860406784.00000  ...
# 45    6702210.60149    1681378.38103 2543988526739389673373696.00000  ...
# 46    6728848.79460    1687311.84627 2559385441849544653406208.00000  ...
# 47    6826927.45038    1722118.10948 2574805775383754268737536.00000  ...
# 48    6877903.06763    1772216.68261 2590261034509493682044928.00000  ...
#
#        mean_total_pledge_collateral  mean_total_qa_bytes_committed  \
# 44 90679722047058521398181888.00000      8601095243007523840.00000
# 45 91024451110779434349625344.00000      8661265901367565312.00000
# 46 91372328469102211308191744.00000      8708399349249811456.00000
# 47 91712247685417879637852160.00000      8717311797108127744.00000
# 48 92051180767644526030356480.00000      8804757070074508288.00000
#
#     mean_total_qa_bytes_power  mean_total_raw_bytes_committed  \
# 44  8600629806463353856.00000       8598015419021267968.00000
# 45  8660804064529650688.00000       8658089261133445120.00000
# 46  8707936997482605568.00000       8705132103627981824.00000
# 47  8716850432725883904.00000       8713960289807292416.00000
# 48  8804311517808989184.00000       8801325962658778112.00000
#
#     mean_total_raw_bytes_power                   mean_burnt_fil  \
# 44   8597555726751974400.00000 26951125181659506815270912.00000
# 45   8657634726629037056.00000 26964044900408740301242368.00000
# 46   8704681935111097344.00000 26977970803473012966293504.00000
# 47   8713511713026955264.00000 26997639146913341254926336.00000
# 48   8800889444151747584.00000 27013262041947826313756672.00000
#
#                 mean_circulating_fil                  mean_locked_fil  \
# 44 146411160856716684765954048.00000 90689836921406440417001472.00000
# 45 146768566168089997091012608.00000 91034561855901007075082240.00000
# 46 147121038894800307249741824.00000 91382433772548684412616704.00000
# 47 147473620687615222398058496.00000 91722346099678862259519488.00000
# 48 147832143854080233578692608.00000 92061270030168664391548928.00000
#
#                      mean_mined_fil                   mean_vested_fil
# 44 85660567800731454064820224.00000 161324936197277726176968704.00000
# 45 86010549584485036452741120.00000 161690004378141209013518336.00000
# 46 86359740510235590081380352.00000 162055083998812949905932288.00000
# 47 86706961641790729271377920.00000 162420025330643227704819712.00000
# 48 87054957851741581175947264.00000 162785099112681725711351808.00000
#
# [5 rows x 32 columns]
