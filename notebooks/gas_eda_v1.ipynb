# %% [markdown]
# # EDA for Gas Fees - Proof of workflow.
#
# In this notebook we perform Exploratory Data Analysis (EDA) on FIL's gas fee mechanism. The goal is to observe the gas fee as a signal and attempt to understand what may be driving it.
#
# Access was obtained to Sentinel from Filecoin, and based on previous Block Science data work, we believe the the gas information is in the `messages` or `message_gas_economy` tables. **Update**: based on discussion with Filecoin, the `derived_gas_outputs` table is used as the primary data gathering table. [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md) was obtained on 6/28/2021 and will drive subsquent analysis.
#
# ## Change Log
# ### Changes since 6/29/2021:
# * Fourier Transform added to signals
# ### Changes since 7/6/2021
# * Moved data from hourly to minutes for all of June
# * Overlayed decomposed Fourier transforms to understand phase shifts
#
# ## What are Gas Fees?
# Note: this description is copied from the [official Filecoin documentation](https://docs.filecoin.io/about-filecoin/how-filecoin-works/#gas-fees)
#
# Executing messages, for example by including transactions or proofs in the chain, consumes both computation and storage resources on the network. Gas is a measure of resources consumed by messages. The gas consumed by a message directly affects the cost that the sender has to pay for it to be included in a new block by a miner.
#
# Historically in other blockchains, miners specify a GasFee in a unit of native currency and then pay the block producing miners a priority fee based on how much gas is consumed by the message. Filecoin works similarly, except an amount of the fees is burned (sent to an irrecoverable address) to compensate for the network expenditure of resources, since all nodes need to validate the messages. The idea is based on Ethereum's EIP1559.
#
# The amount of fees burned in the Filecoin network comes given by a dynamic BaseFee which gets automatically adjusted according to the network congestion parameters (block sizes). The current value can be obtained from one of the block explorers or by inspecting the current head.
#
# Additionally, a number of gas-related parameters are attached to each message and determine the amount of rewards that miners get. Here's an overview of the terms and concepts:
#
# **GasUsage**: the amount of gas that a message's execution actually consumes. Current protocol does not know how much gas a message will exactly consume ahead of execution, but it can be estimated (see prices (opens new window)). GasUsage measured in units of Gas.
#
# **BaseFee**: the amount of FIL that gets burned per unit of gas consumed for the execution of every message. It is measured in units of attoFIL/Gas.
#
# **GasLimit**: the limit on the amount of gas that a message's execution can consume, estimated and specified by a message sender. It is measured in units of Gas. The sum of GasLimit for all messages included in a block must not exceed the BlockGasLimit. Messages will fail to execute if they run out of Gas, and any effects of the execution will be reverted.
#
# **GasFeeCap**: the maximum token amount that a sender is willing to pay per GasUnit for including a message in a block. It is measured in units of attoFIL/Gas. A message sender must have a minimum balance of GasFeeCap * GasLimit when sending a message, even though not all of that will be consumed. GasFeeCap can serve as a safeguard against high, unexpected BaseFee fluctuations.
#
# **GasPremium**: a priority fee that is paid to the block-producing miner. This is capped by GasFeeCap. The BaseFee has a higher priority. It is measured in units of attoFIL/Gas and can be as low as 1 attoFIL/Gas.
#
# **Overestimation burn**: an additional amount of gas to burn that grows larger when the difference between GasLimit and GasUsage is large.
#
# The total cost of a message for a sender will be:
#
# * GasUsage * BaseFee FIL (burned) +
# * GasLimit * GasPremium FIL (miner's reward) +
# * OverEstimationBurn * BaseFee FIL
#
# An important detail is that a message will always pay the burn fee, regardless of the GasFeeCap used. Thus, a low GasFeeCap may result in a reduced GasPremium or even a negative one! In that case, the miners that include a message will have to pay the needed amounts out of their own pockets, which means they are unlikely to include such messages in new blocks.
#
# Filecoin implementations may choose the heuristics of how their miners select messages for inclusion in new blocks, but they will usually attempt to maximize the miner's rewards.
#
#
# ## Data Resources
# * https://hackmd.io/5leND7tITX--5NJsFCJyow # Existing Sentinel queries
# * https://github.com/filecoin-project/sentinel/blob/master/docs/sentinel_tables_purpose.csv # Sentinel Tables Purpose
#
#
# ### Sentinel Diagram
# ![](sentinel_diagram.png)

# %% [markdown]
# ## Analysis
#
# We are performing a vector autoregression (VAR) to determine if a casual or multi-causal relationship exists between the gas signals moves. This will help us understand the system-level dynamics of Filecoin.
#
# ### Vector Autoregression
#
# Vector autoregression (VAR) is a type of statistical model used to capture the relationship between multiple time series signals as they change over time. VAR models are extensions of univariate autoregression models allowing for multivariate time series analysis.
#
# Autoregressive models use lagged past values of the variable and have an order based on how many times the variable has been lagged, i.e. VAR(2) means two lagged values. Lagged values help to determine if seasonality or reoccurring patterns exist in the data.
#
# A pth-order VAR model is written as:
# $$y_t = c + A_1 y_{t-1} + A_2 y_{t-2} + \cdots + A_p y_{t-p} + e_t,$$
#
# In vector notation, a VAR(1) with 2 variables is:
#
# $$\begin{bmatrix}y_{1,t} \\ y_{2,t}\end{bmatrix} = \begin{bmatrix}c_{1} \\ c_{2}\end{bmatrix} + \begin{bmatrix}a_{1,1}&a_{1,2} \\ a_{2,1}&a_{2,2}\end{bmatrix}\begin{bmatrix}y_{1,t-1} \\ y_{2,t-1}\end{bmatrix} + \begin{bmatrix}e_{1,t} \\ e_{2,t}\end{bmatrix}$$
#
# For our VAR model, we will have a vector of gas signals.
#
# #### Assumptions:
# * Every error term has a mean of zero and is normally distributed.
# * Variables are stationary. Differencing can be used to make the data stationary.
# * Data is on the same scale
# * Time sampling is consistent
#
# ### Other methods with fewer assumptions
#
# Non-parametric Bayesian VAR models have been under development and appear to perform well and can operate on nonlinear relationships, heteroscedasticity, and non-Gaussian error data[1,2].
#
# Another popular time series analysis modeling technique is the Autoregressive Integrated Moving Average (ARIMA) model. These models are often used in forecasting or when the data shows evidence of non-stationarity. For multiple time series vectors, as we have here, extensions of the ARIMA model are available, such ARIMAX model that has exogenous variable inputs. ARIMAX models do not have an assumption of Gaussian errors as it uses a maximum likelihood estimation function to fit.
#
# #### References
# - 1 Kalli, Maria & Griffin, Jim E., 2018. "Bayesian nonparametric vector autoregressive models," Journal of Econometrics, Elsevier, vol. 203(2), pages 267-282.
# - 2 Jeliazkov, Ivan. (2013). Nonparametric Vector Autoregressions: Specification, Estimation, and Inference. Advances in Econometrics. 33. 10.1108/S0731-9053(2013)0000031009.
#
#
# We have taken the trade-off in assumption for this first version correlation model vs a non-parametric approach for simplicity's sake, that current robust python VAR implementations exist, and for illustrative purposes around the concepts, we are addressing.

# %%
# import libraries
from sqlalchemy import create_engine
import pandas as pd
from datetime import datetime
from statsmodels.tsa.api import VAR
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import adfuller
from math import sqrt
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import numpy as np

from Cryptoeconomics_signal_processing import time_analysis, fourier_transform, phase_shift_overlay


# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %%
# load connection string
CONN_STRING_PATH = 'sentinel_conn_string_andrew.txt'

with open(CONN_STRING_PATH, 'r') as fid:
    conn_string = fid.read()
    
# create database connection.
connection = create_engine(conn_string, pool_recycle=3600).connect()

# %% [markdown]
# ## Data EDA
#
# Below we download hourly averages from the `derived_gas_outputs` table from May 1st, 2021 to present (last refreshed 6/28/2021). After downloading the data, we few the first and lasts 5 rows, and perform basic statistics on the data.
#
#
# ### `derived_gas_outputs` - coped from [Sentinel's Data Dictionary](https://github.com/filecoin-project/sentinel/blob/master/docs/db.md)
# Derived gas costs resulting from execution of a message in the VM.
#
# |Name|Type|Nullable|Description|
# |---|---|---|---|
# |`actor_name`|`text`|NO|Human readable identifier for the type of the actor.|
# |`base_fee_burn`|`text`|NO|The amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.|
# |`cid`|`text`|NO|CID of the message.|
# |`exit_code`|`bigint`|NO|The exit code that was returned as a result of executing the message. Exit code 0 indicates success. Codes 0-15 are reserved for use by the runtime. Codes 16-31 are common codes shared by different actors. Codes 32+ are actor specific.|
# |`from`|`text`|NO|Address of actor that sent the message.|
# |`gas_burned`|`bigint`|NO|The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_fee_cap`|`text`|NO|The maximum price that the message sender is willing to pay per unit of gas.|
# |`gas_limit`|`bigint`|YES|A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.|
# |`gas_premium`|`text`|NO|The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.|
# |`gas_refund`|`bigint`|NO|The overestimated units of gas to refund. It is a portion of the difference between gas_limit and gas_used.|
# |`gas_used`|`bigint`|NO|A measure of the amount of resources (or units of gas) consumed, in order to execute a message.|
# |`height`|`bigint`|NO|Epoch this message was executed at.|
# |`method`|`bigint`|YES|The method number to invoke. Only unique to the actor the method is being invoked on. A method number of 0 is a plain token transfer - no method exectution.|
# |`miner_penalty`|`text`|NO|Any penalty fees (in attoFIL) the miner incured while executing the message.|
# |`miner_tip`|`text`|NO|The amount of FIL (in attoFIL) the miner receives for executing the message. Typically it is gas_premium * gas_limit but may be lower if the total fees exceed the gas_fee_cap.|
# |`nonce`|`bigint`|YES|The message nonce, which protects against duplicate messages and multiple messages with the same values.|
# |`over_estimation_burn`|`text`|NO|The fee to pay (in attoFIL) for overestimating the gas used to execute a message. The overestimated gas to burn (gas_burned) is a portion of the difference between gas_limit and gas_used. The over_estimation_burn value is gas_burned * parent_base_fee.|
# |`parent_base_fee`|`text`|NO|The set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.|
# |`refund`|`text`|NO|The amount of FIL (in attoFIL) to refund to the message sender after base fee, miner tip and overestimation amounts have been deducted.|
# |`size_bytes`|`bigint`|YES|Size in bytes of the serialized message.|
# |`state_root`|`text`|NO|CID of the parent state root.|
# |`to`|`text`|NO|Address of actor that received the message.|
# |`value`|`text`|NO|The FIL value transferred (attoFIL) to the message receiver.|

# %%
QUERY = """
SELECT 
date_trunc('minute', 
to_timestamp(height_to_unix(d.height))) AS timestamp,
AVG(CAST(gas_fee_cap AS FLOAT)) AS mean_gas_fee_cap,
AVG(CAST(gas_premium AS FLOAT))  as mean_gas_premium,
AVG(CAST(gas_limit AS FLOAT))  as mean_gas_limit,
AVG(CAST(gas_used AS FLOAT))  as mean_gas_used,
AVG(CAST(parent_base_fee AS FLOAT))  as mean_parent_base_fee,
AVG(CAST(base_fee_burn AS FLOAT))  as mean_base_fee_burn,
AVG(CAST(over_estimation_burn AS FLOAT))  as mean_over_estimation_burn,
AVG(CAST(gas_refund AS FLOAT))  as mean_gas_refund,
AVG(CAST(gas_burned AS FLOAT))  as mean_gas_burned
FROM derived_gas_outputs d
WHERE
to_timestamp(height_to_unix(d.height)) BETWEEN '2021-06-01' AND '2021-06-30'
GROUP BY
timestamp
"""
derived_gas_outputs_minutes = (pd.read_sql(QUERY, connection))
derived_gas_outputs_minutes
# Out:
#                       timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 0     2021-06-01 00:00:00+00:00      8.029010e+09      1.017285e+05
# 1     2021-06-01 00:01:00+00:00      5.514969e+09      1.010914e+05
# 2     2021-06-01 00:02:00+00:00      1.391597e+09      1.016669e+05
# 3     2021-06-01 00:03:00+00:00      1.757485e+10      9.744047e+04
# 4     2021-06-01 00:04:00+00:00      6.449984e+09      1.002700e+05
# ...                         ...               ...               ...
# 34268 2021-06-25 21:03:00+00:00      5.237974e+09      1.090883e+05
# 34269 2021-06-25 21:04:00+00:00      6.282274e+09      1.122319e+05
# 34270 2021-06-25 21:06:00+00:00      6.061794e+09      1.079991e+05
# 34271 2021-06-25 21:07:00+00:00      3.245141e+09      2.781742e+06
# 34272 2021-06-25 21:08:00+00:00      4.941351e+09      1.055196e+05
#
#        mean_gas_limit  mean_gas_used  mean_parent_base_fee  \
# 0        3.853911e+07   3.154444e+07          1.075087e+02
# 1        3.551579e+07   2.902460e+07          1.041343e+02
# 2        3.925006e+07   3.176285e+07          1.062889e+02
# 3        3.993927e+07   3.258712e+07          1.071225e+02
# 4        3.896426e+07   3.207390e+07          1.000000e+02
# ...               ...            ...                   ...
# 34268    3.823607e+07   3.128294e+07          1.908826e+08
# 34269    3.810373e+07   3.152892e+07          1.777791e+08
# 34270    3.892744e+07   3.206151e+07          1.695353e+08
# 34271    3.845156e+07   3.164617e+07          1.621174e+08
# 34272    3.937116e+07   3.242696e+07          1.532451e+08
#
#        mean_base_fee_burn  mean_over_estimation_burn  mean_gas_refund  \
# 0            3.344824e+09               1.379284e+08     5.712949e+06
# 1            2.964455e+09               1.137286e+08     5.395994e+06
# 2            3.336958e+09               1.693683e+08     5.889824e+06
# 3            3.442124e+09               1.394680e+08     6.046530e+06
# 4            3.121567e+09               1.184643e+08     5.705719e+06
# ...                   ...                        ...              ...
# 34268        5.883117e+15               2.491660e+14     5.645897e+06
# 34269        5.529089e+15               1.826172e+14     5.548940e+06
# 34270        5.311621e+15               1.997477e+14     5.687233e+06
# 34271        5.090067e+15               1.928663e+14     5.617486e+06
# 34272        4.912118e+15               1.734196e+14     5.812553e+06
#
#        mean_gas_burned
# 0         1.281725e+06
# 1         1.095194e+06
# 2         1.597390e+06
# 3         1.305622e+06
# 4         1.184643e+06
# ...                ...
# 34268     1.307233e+06
# 34269     1.025864e+06
# 34270     1.178698e+06
# 34271     1.187900e+06
# 34272     1.131648e+06
#
# [34273 rows x 10 columns]

# %%
derived_gas_outputs = derived_gas_outputs_minutes

# %%
derived_gas_outputs.describe()
# Out:
#        mean_gas_fee_cap  mean_gas_premium  mean_gas_limit  mean_gas_used  \
# count      3.427300e+04      3.427300e+04    3.427300e+04   3.427300e+04
# mean       9.332010e+09      1.497482e+06    3.989642e+07   3.226650e+07
# std        4.525614e+09      8.109318e+06    4.347213e+06   2.210611e+06
# min        5.746347e+08      8.200945e+04    2.428070e+07   1.408784e+07
# 25%        6.363798e+09      1.114223e+05    3.779839e+07   3.087624e+07
# 50%        8.880672e+09      3.657263e+05    3.932166e+07   3.202065e+07
# 75%        1.162421e+10      8.884868e+05    4.124140e+07   3.338107e+07
# max        2.011381e+11      7.990103e+08    1.974523e+08   5.744429e+07
#
#        mean_parent_base_fee  mean_base_fee_burn  mean_over_estimation_burn  \
# count          3.427300e+04        3.427300e+04               3.427300e+04
# mean           6.106657e+08        1.944904e+16               1.086866e+15
# std            5.208931e+08        1.674395e+16               1.332562e+15
# min            1.000000e+02        2.016133e+09               7.553782e+07
# 25%            1.999907e+08        6.337284e+15               2.936702e+14
# 50%            5.404110e+08        1.728121e+16               8.453976e+14
# 75%            9.484614e+08        3.055251e+16               1.536348e+15
# max            6.147238e+09        1.944513e+17               9.875548e+16
#
#        mean_gas_refund  mean_gas_burned
# count     3.427300e+04     3.427300e+04
# mean      5.800183e+06     1.829740e+06
# std       4.845310e+05     3.401566e+06
# min       2.687929e+06     6.165379e+05
# 25%       5.491961e+06     1.240027e+06
# 50%       5.752933e+06     1.498004e+06
# 75%       6.052404e+06     1.892188e+06
# max       1.029855e+07     1.746765e+08

# %% [markdown]
# We will plot each signal, save for the timestamp, below and perform Fourier transforms to search for periodicity.
#
# A Fourier transform (FT) is a mathematical method for decomposing a signal into a sum of periodic components. Used frequently in signal processing to understand trends and for filtering. we will use the common Fast Fourier Transform (FFT) algorithm to calculate discrete Fourier transform (DFT) of each signal.
#
# ### Resources:
# * https://github.com/Kommandat/seasonality-fourier-analysis/blob/master/notebooks/Part%201%20-%20Seasonality%20Analysis%20with%20scipy-fft.ipynb
# * https://github.com/manganganath/stock_price_trend_fft/blob/master/fourier_analysis.ipynb
# * https://www.ritchievink.com/blog/2017/04/23/understanding-the-fourier-transform-by-example/

# %%
derived_gas_outputs, mean_gas_fee_cap_decomposed = fourier_transform(derived_gas_outputs,'mean_gas_fee_cap',10)
# Out:
# Fourier Transform of mean_gas_fee_cap with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_fee_cap',kind='line',title='Mean Gas Fee Cap')
print('The maximum price that the message sender is willing to pay per unit of gas')
# Out:
# The maximum price that the message sender is willing to pay per unit of gas

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_premium',kind='line',title='Mean Gas Premium')
print('The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.')
# Out:
# The price per unit of gas (measured in attoFIL/gas) that the message sender is willing to pay (on top of the BaseFee) to "tip" the miner that will include this message in a block.

# %%
derived_gas_outputs, mean_gas_premium_decomposed  = fourier_transform(derived_gas_outputs,'mean_gas_premium',10)
# Out:
# Fourier Transform of mean_gas_premium with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_limit',kind='line',title='Mean Gas Limit')
print('A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.')
# Out:
# A hard limit on the amount of gas (i.e., number of units of gas) that a message’s execution should be allowed to consume on chain. It is measured in units of gas.

# %%
derived_gas_outputs, mean_gas_limit_decomposed = fourier_transform(derived_gas_outputs,'mean_gas_limit',10)
# Out:
# Fourier Transform of mean_gas_limit with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_used',kind='line',title='Mean Gas Used')
print('A measure of the amount of resources (or units of gas) consumed, in order to execute a message.')
# Out:
# A measure of the amount of resources (or units of gas) consumed, in order to execute a message.

# %%
derived_gas_outputs, mean_gas_used_decomposed = fourier_transform(derived_gas_outputs,'mean_gas_used',10)
# Out:
# Fourier Transform of mean_gas_used with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_parent_base_fee',kind='line',title='Mean Parent Base Fee')
print('he set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.')
# Out:
# he set price per unit of gas (measured in attoFIL/gas unit) to be burned (sent to an unrecoverable address) for every message execution.

# %%
derived_gas_outputs, mean_parent_base_fee_decomposed = fourier_transform(derived_gas_outputs,'mean_parent_base_fee',10)
# Out:
# Fourier Transform of mean_parent_base_fee with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_base_fee_burn',kind='line',title='Mean Base Fee Burn')
print('he amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.')
# Out:
# he amount of FIL (in attoFIL) to burn as a result of the base fee. It is parent_base_fee (or gas_fee_cap if smaller) multiplied by gas_used. Note: successfull window PoSt messages are not charged this burn.

# %%
derived_gas_outputs, mean_base_fee_burn_decomposed = fourier_transform(derived_gas_outputs,'mean_base_fee_burn',10)
# Out:
# Fourier Transform of mean_base_fee_burn with 10 components.

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_gas_burned',kind='line',title='Mean Gas Burned')
print('The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.')
# Out:
# The overestimated units of gas to burn. It is a portion of the difference between gas_limit and gas_used.

# %%
derived_gas_outputs, mean_gas_burned_decomposed = fourier_transform(derived_gas_outputs,'mean_gas_burned',10)
# Out:
# Fourier Transform of mean_gas_burned with 10 components.

# %%
derived_gas_outputs, mean_over_estimation_burn_decomposed = fourier_transform(derived_gas_outputs,'mean_over_estimation_burn',10)
# Out:
# Fourier Transform of mean_over_estimation_burn with 10 components.

# %%
derived_gas_outputs, mean_gas_refund_decomposed = fourier_transform(derived_gas_outputs,'mean_gas_refund',10)
# Out:
# Fourier Transform of mean_gas_refund with 10 components.

# %% [markdown]
# The data is a relatively consistent, stochastic trend save for several orders of magnitude spike one June 3rd. Mean_gas_burned shows the spike in gas burned the best, with mean_gas_burned being the hourly average of the overestimated units of gas. We will need to examine the meta-information from the messages to understand in more detail to understand why the spike occured. This will also mean querying disaggregated data to understand who the actors are and what transactions they are making.

# %%
derived_gas_outputs.query('mean_gas_burned > 4000000')
# Out:
#                       timestamp  mean_gas_fee_cap  mean_gas_premium  \
# 2236  2021-06-02 13:17:00+00:00      6.880334e+09      1.028916e+05
# 3039  2021-06-03 02:40:00+00:00      6.216043e+09      1.086384e+05
# 3040  2021-06-03 02:41:00+00:00      7.759289e+09      1.063103e+05
# 3041  2021-06-03 02:42:00+00:00      6.149556e+09      5.103965e+06
# 3042  2021-06-03 02:43:00+00:00      4.483476e+09      5.208213e+06
# ...                         ...               ...               ...
# 31577 2021-06-23 17:27:00+00:00      8.369965e+09      2.512156e+05
# 31761 2021-06-23 21:05:00+00:00      7.242002e+09      9.996849e+05
# 31844 2021-06-23 22:38:00+00:00      7.312603e+09      1.097186e+05
# 31895 2021-06-23 23:40:00+00:00      9.456775e+09      1.413149e+06
# 31933 2021-06-24 00:21:00+00:00      8.204736e+09      2.695962e+05
#
#        mean_gas_limit  mean_gas_used  mean_parent_base_fee  \
# 2236     4.379041e+07   3.303338e+07          5.892028e+04
# 3039     3.943075e+07   2.905696e+07          2.320815e+08
# 3040     3.819974e+07   2.917434e+07          2.242377e+08
# 3041     4.105038e+07   2.960600e+07          2.280098e+08
# 3042     3.972884e+07   3.054804e+07          2.446428e+08
# ...               ...            ...                   ...
# 31577    5.167045e+07   4.032526e+07          9.539610e+08
# 31761    4.659185e+07   3.659056e+07          8.911160e+08
# 31844    4.506602e+07   3.517191e+07          8.382356e+08
# 31895    5.190339e+07   3.925723e+07          9.527186e+08
# 31933    4.645209e+07   3.602228e+07          9.200770e+08
#
#        mean_base_fee_burn  mean_over_estimation_burn  mean_gas_refund  \
# 2236         1.910384e+12               2.849939e+11     5.908677e+06
# 3039         6.618230e+15               1.230400e+15     5.070770e+06
# 3040         6.481789e+15               9.452613e+14     4.851530e+06
# 3041         6.650433e+15               1.428333e+15     5.200284e+06
# 3042         7.372305e+15               9.584429e+14     5.137952e+06
# ...                   ...                        ...              ...
# 31577        3.769196e+16               4.322365e+15     6.814226e+06
# 31761        3.238965e+16               3.620773e+15     5.928436e+06
# 31844        2.931989e+16               3.474440e+15     5.749167e+06
# 31895        3.701731e+16               4.077252e+15     8.366558e+06
# 31933        3.261942e+16               4.037097e+15     6.042734e+06
#
#        mean_gas_burned  mean_gas_fee_cap_decomposed  \
# 2236      4.848352e+06   6.641801e+09+5.355633e+08j
# 3039      5.303028e+06   7.546405e+09+1.386777e+08j
# 3040      4.173869e+06   7.547572e+09+1.380867e+08j
# 3041      6.244093e+06   7.548739e+09+1.374957e+08j
# 3042      4.042844e+06   7.549905e+09+1.369045e+08j
# ...                ...                          ...
# 31577     4.530966e+06   1.033908e+10-4.795601e+08j
# 31761     4.072853e+06   1.018763e+10-5.487213e+08j
# 31844     4.144944e+06   1.010729e+10-5.749244e+08j
# 31895     4.279597e+06   1.005440e+10-5.893841e+08j
# 31933     4.387082e+06   1.001330e+10-5.993224e+08j
#
#        mean_gas_premium_decomposed   mean_gas_limit_decomposed  \
# 2236    1.785046e+06+3.565792e+05j  4.010458e+07+3.012359e+05j
# 3039    2.478950e+06+1.818275e+05j  4.051069e+07+1.138098e+05j
# 3040    2.479683e+06+1.815246e+05j  4.051106e+07+1.135137e+05j
# 3041    2.480415e+06+1.812215e+05j  4.051142e+07+1.132174e+05j
# 3042    2.481148e+06+1.809182e+05j  4.051179e+07+1.129210e+05j
# ...                            ...                         ...
# 31577   1.581721e+06-1.884275e+05j  3.958466e+07-2.173753e+05j
# 31761   1.491873e+06-2.405918e+05j  3.951442e+07-2.587234e+05j
# 31844   1.447986e+06-2.619698e+05j  3.948153e+07-2.750350e+05j
# 31895   1.420107e+06-2.743614e+05j  3.946104e+07-2.842741e+05j
# 31933   1.398918e+06-2.832061e+05j  3.944566e+07-2.907554e+05j
#
#          mean_gas_used_decomposed  mean_parent_base_fee_decomposed  \
# 2236   3.136961e+07+1.191070e+05j      -2.254066e+07+6.047582e+07j
# 3039   3.156040e+07+8.250048e+04j       7.020181e+07+2.075749e+07j
# 3040   3.156069e+07+8.242131e+04j       7.034555e+07+2.069592e+07j
# 3041   3.156099e+07+8.234207e+04j       7.048933e+07+2.063433e+07j
# 3042   3.156129e+07+8.226275e+04j       7.063316e+07+2.057272e+07j
# ...                           ...                              ...
# 31577  3.239618e+07-3.111362e+04j       9.385246e+08-4.669739e+07j
# 31761  3.237520e+07-5.002543e+04j       9.139892e+08-5.485551e+07j
# 31844  3.236333e+07-5.812249e+04j       9.007513e+08-5.803834e+07j
# 31895  3.235530e+07-6.293391e+04j       8.919686e+08-5.982860e+07j
# 31933  3.234895e+07-6.643005e+04j       8.851101e+08-6.107773e+07j
#
#        mean_base_fee_burn_decomposed  mean_gas_burned_decomposed  \
# 2236     -8.351633e+14+1.945582e+15j  3.153173e+06+1.797317e+05j
# 3039      2.088543e+15+6.851644e+14j  3.407337e+06+3.564227e+04j
# 3040      2.093109e+15+6.832010e+14j  3.407441e+06+3.543293e+04j
# 3041      2.097678e+15+6.812371e+14j  3.407544e+06+3.522356e+04j
# 3042      2.102247e+15+6.792726e+14j  3.407647e+06+3.501416e+04j
# ...                              ...                         ...
# 31577     2.970309e+16-1.476914e+15j  1.377516e+06-1.768716e+05j
# 31761     2.894895e+16-1.740558e+15j  1.327075e+06-1.993370e+05j
# 31844     2.853966e+16-1.843716e+15j  1.305664e+06-2.076518e+05j
# 31895     2.826749e+16-1.901848e+15j  1.293015e+06-2.121678e+05j
# 31933     2.805465e+16-1.942466e+15j  1.283867e+06-2.152318e+05j
#
#        mean_over_estimation_burn_decomposed  mean_gas_refund_decomposed
# 2236             2.290071e+14+1.223223e+14j  5.581803e+06+2.397226e+03j
# 3039             4.251129e+14+3.211173e+13j  5.542956e+06-4.332921e+03j
# 3040             4.253717e+14+3.197720e+13j  5.542923e+06-4.340577e+03j
# 3041             4.256304e+14+3.184264e+13j  5.542891e+06-4.348228e+03j
# 3042             4.258892e+14+3.170806e+13j  5.542859e+06-4.355877e+03j
# ...                                     ...                         ...
# 31577            1.497715e+15-1.088910e+14j  5.810961e+06-9.390019e+03j
# 31761            1.451856e+15-1.247173e+14j  5.812148e+06-9.361034e+03j
# 31844            1.427840e+15-1.307213e+14j  5.812540e+06-9.260685e+03j
# 31895            1.412103e+15-1.340374e+14j  5.812730e+06-9.172400e+03j
# 31933            1.399906e+15-1.363182e+14j  5.812843e+06-9.093577e+03j
#
# [499 rows x 19 columns]

# %% [markdown]
# ### Messages calculation mapping
#
# Based on the message cost calculation outliend by Filecoin's official documentation, we will map the data obtained to this calculation.
#
# Filecoin:
# `message_cost_calculation =  GasUsage * BaseFee FIL (burned) + GasLimit * GasPremium FIL (miner reward) + OverEstimationBurn * BaseFee FIL`
#
#
# Our downloaded data:
# `message_cost = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn`

# %%
# create field
derived_gas_outputs['mean_message_cost'] = derived_gas_outputs.mean_gas_used * derived_gas_outputs.mean_base_fee_burn + derived_gas_outputs.mean_gas_limit * derived_gas_outputs.mean_gas_premium + derived_gas_outputs.mean_over_estimation_burn * derived_gas_outputs.mean_base_fee_burn

# %%
derived_gas_outputs.plot(x='timestamp',y='mean_message_cost',kind='line',title='Mean Message Cost')
# Out:
# <AxesSubplot:title={'center':'Mean Message Cost'}, xlabel='timestamp'>

# %%
derived_gas_outputs, mean_message_cost_decomposed = fourier_transform(derived_gas_outputs,'mean_message_cost',10)
# Out:
# Fourier Transform of mean_message_cost with 10 components.

# %% [markdown]
# Based on the Fourier decompositions, it appears that there is some periodicity to the data, with two spikes a week, approximately on Monday and Thursday.

# %% [markdown]
# ## Decomposed Phase Shifts Overlay
#
# To understand which signals may be leading or lagging indicators, we will overlay the fourier decomposed components, in pairs, for analysis.

# %%
phase_shift_overlay(derived_gas_outputs.timestamp,mean_gas_fee_cap_decomposed,mean_gas_premium_decomposed,
                    'mean_gas_fee_cap','mean_gas_premium')

# %% [markdown]
# Gas premium appears to be a leading indicator for gas fee cap. There is no phase shift (peak to peak distances line up).

# %%
phase_shift_overlay(derived_gas_outputs.timestamp,mean_gas_limit_decomposed,mean_gas_used_decomposed,
                   'mean_gas_limit','mean_gas_used')

# %% [markdown]
# Gas limit, at times, appears to be a slight leading indicator.

# %%
phase_shift_overlay(derived_gas_outputs.timestamp,mean_parent_base_fee_decomposed,mean_base_fee_burn_decomposed,
                   'mean_parent_base_fee','mean_base_fee')

# %%
phase_shift_overlay(derived_gas_outputs.timestamp,mean_message_cost_decomposed,mean_gas_refund_decomposed,
                   'mean_message_cost','mean_gas_refund')

# %% [markdown]
# Message cost, at times, appears to be a slight leading indicator.

# %%
phase_shift_overlay(derived_gas_outputs.timestamp,mean_gas_burned_decomposed,mean_gas_fee_cap_decomposed,
                   'mean_gas_burned','mean_gas_fee_Cap')

# %% [markdown]
# Gas burned appears to be a direct leading indicator. No phase shift present
#
# Below we will normalize the signals by their individual max peaks so we can plot on one graph. We will use Matplotlib instead of Plotly due to the fact that Matplotlib handles complex numbers better.

# %%
def peak_normalization(array):
    '''
    '''
    
    normalized = array / np.max(array)
    
    return normalized

# normalize peaks    
mean_gas_fee_cap_decomposed_normalized = peak_normalization(mean_gas_fee_cap_decomposed) 
mean_gas_premium_decomposed_normalized = peak_normalization(mean_gas_premium_decomposed) 
mean_gas_limit_decomposed_normalized = peak_normalization(mean_gas_limit_decomposed)
mean_gas_used_decomposed_normalized = peak_normalization(mean_gas_used_decomposed)
mean_base_fee_burn_decomposed_normalized = peak_normalization(mean_base_fee_burn_decomposed)
mean_message_cost_decomposed = peak_normalization(mean_message_cost_decomposed)
mean_gas_refund_decomposed = peak_normalization(mean_gas_refund_decomposed)
mean_gas_burned_decomposed = peak_normalization(mean_gas_burned_decomposed)
mean_gas_fee_cap_decomposed = peak_normalization(mean_gas_fee_cap_decomposed)

# %%
plt.figure(figsize=(15, 8))
plt.plot(timestamps,mean_gas_fee_cap_decomposed_normalized,label = 'mean_gas_fee_cap_decomposed_normalized')
plt.plot(timestamps,mean_gas_premium_decomposed_normalized, label ='mean_gas_premium_decomposed_normalized')
plt.plot(timestamps,mean_gas_limit_decomposed_normalized, label ='mean_gas_limit_decomposed_normalized')
plt.plot(timestamps,mean_gas_used_decomposed_normalized, label ='mean_gas_used_decomposed_normalized')
plt.plot(timestamps,mean_base_fee_burn_decomposed_normalized, label ='mean_base_fee_burn_decomposed_normalized')
plt.plot(timestamps,mean_message_cost_decomposed, label ='mean_message_cost_decomposed')
plt.plot(timestamps,mean_gas_refund_decomposed, label ='mean_gas_refund_decomposed')
plt.plot(timestamps,mean_gas_burned_decomposed, label ='mean_gas_burned_decomposed')
plt.plot(timestamps,mean_gas_fee_cap_decomposed, label ='mean_gas_fee_cap_decomposed')
plt.legend(bbox_to_anchor=(1.35, 1), loc='upper right', ncol=1)
plt.title('Decomposed Phase Shifts Overlay, normalize by max peaks')
# Out:
# Text(0.5, 1.0, 'Decomposed Phase Shifts Overlay, normalize by max peaks')

# %% [markdown]
# ### Data processing
#
# We will now remove the timestamp field and examine the data distributions and determine if any transformations are required prior to our VAR modeling.

# %%
timestamps = derived_gas_outputs.timestamp
del derived_gas_outputs['timestamp']

derived_gas_outputs = derived_gas_outputs[['mean_gas_fee_cap','mean_gas_premium','mean_gas_limit',
                                          'mean_gas_used','mean_parent_base_fee','mean_base_fee_burn',
                                          'mean_over_estimation_burn','mean_gas_refund','mean_gas_burned',
                                          'mean_message_cost']]

# %%
derived_gas_outputs.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We can see from the above historgrams that besides `mean_gas_used` and `mean_gas_refund` our data is not normally distributed and will need to be transformed prior to modeling. We will take the log of the data to reduce the skewness and take the first difference to make the data stationary.

# %%
log_differenced = pd.DataFrame()
## Difference and log values
for i in derived_gas_outputs.columns:
    log_differenced[i +'_log_differenced'] = np.log(derived_gas_outputs[i]).diff()

# %%
log_differenced.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'mean_gas_fee_cap_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_premium_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_limit_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_gas_used_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_parent_base_fee_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_base_fee_burn_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_over_estimation_burn_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_refund_log_differenced'}>,
#         <AxesSubplot:title={'center':'mean_gas_burned_log_differenced'}>],
#        [<AxesSubplot:title={'center':'mean_message_cost_log_differenced'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <!-- ### Data Transformations
#
# We will take the log of the data to reduce the skewness and take the first difference to make the data stationary, meaning that the distribution does not change when shifted by tie. -->

# %%
# replace any NA values with zero
log_differenced.fillna(0,inplace=True)

# %% [markdown]
# As a final check prior to modeling, we will run the Augmented Dickey-Fuller test to ensure that our data is stationary (non-unit root - A unit root is a stochastic trend in a time series). The test's hypothesis are:
#
#
# * $H_O: \textrm{Time series has a unit root}$
# * $H_A: \textrm{Time series does not have a unit root}$

# %%
for i in log_differenced.columns:
    print(i)
    result = adfuller(log_differenced[i].values)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] > 0.05:
        decision = "fail to reject - unit root present"
    else:
        decision = "reject, no unit root present"
    print(decision)
    print('----------------------------------')
# Out:
# mean_gas_fee_cap_log_differenced
# ADF Statistic: -35.361845
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_premium_log_differenced
# ADF Statistic: -37.397311
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_limit_log_differenced
# ADF Statistic: -36.649966
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_used_log_differenced
# ADF Statistic: -37.548367
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_parent_base_fee_log_differenced
# ADF Statistic: -59.525670
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_base_fee_burn_log_differenced
# ADF Statistic: -71.019424
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_over_estimation_burn_log_differenced
# ADF Statistic: -51.603579
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_refund_log_differenced
# ADF Statistic: -37.299963
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_gas_burned_log_differenced
# ADF Statistic: -39.173527
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------
# mean_message_cost_log_differenced
# ADF Statistic: -33.771683
# p-value: 0.000000
# reject, no unit root present
# ----------------------------------

# %% [markdown]
# Based on the Augmented Dickey-Fuller, our preprocessing was successful and none of our univariate time series signals as a unit root. We can now proceed to the VAR model.

# %% [markdown]
# ## Model Fit
#
# To determine the ideal number of lags for our model, we will perform a heuristic SVD. We will fit our model with an autocorrelation between 1 and 15 to ascertain which VAR order has the best Akaike information criterion(AIC) score.
#
# The **Akaike information criterion (AIC)** is an estimator of prediction error, rooted in information theory. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models as a means for model selection.
#
# When a statistical model is used to represent the process that generated the data, the representation will rarely be exact; so some information will be lost by using the model to represent the process. AIC estimates the relative amount of information lost by a given model: the less information a model loses, the higher the quality of that model.
#
# In estimating the amount of information lost by a model, AIC deals with the trade-off between the goodness of fit of the model and the simplicity of the model. In other words, AIC deals with both the risk of overfitting and the risk of underfitting.
#
# Below is the equation for AIC where $\hat L$ is the maximum value of the likelihood function for the model:
#
# $$\mathrm{AIC} \, = \, 2k - 2\ln(\hat L)$$
#
# Given a set of candidate models for the data, the **preferred model is the one with the minimum AIC value, the sign of the data does not matter**. AIC optimizes for the goodness of fit but also includes a penalty for each additional parameter, which discourages overfitting.
#
# <!-- The **Bayesian information criterion (BIC)** is a statistical method for model selection among a group of models; **the model with the lowest BIC is preferred, the sign of the data does not matter**. It is based, in part, on the likelihood function and it is closely related to the Akaike information criterion (AIC).
#
# When fitting models, it is possible to increase the likelihood by adding parameters, but doing so may result in overfitting. Both BIC and AIC attempt to resolve this problem by introducing a penalty term for the number of parameters in the model; the penalty term is larger in BIC than in AIC.
#
# $$\mathrm{BIC} = k\ln(n) - 2\ln(\widehat L)$$
# where
# $\hat L$ = the maximized value of the likelihood function of the model $M$
# $x$ = the observed data;
# $n$ = the number of data points in $x$,
# $k$ = the number of parameters estimated by the model.
#
#
# Several researchers that have studied the two metrics argue that BIC is appropriate for selecting the "true model" (i.e. the process that generated the data) from the set of candidate models, whereas AIC choices the best model amongst the alternatives. Proponents of AIC argue that this issue is negligible because the "true model" is virtually never in the candidate set. For our use cases, we will optimize for the AIC as we know the "true" model of the signal behavior is way too complex to be captured within a VAR model.
#  -->
# Paraphrased sources:
# * https://en.wikipedia.org/wiki/Akaike_information_criterion
# <!-- * https://en.wikipedia.org/wiki/Bayesian_information_criterion -->

# %%
aic = []
for i in range(1,16):
    model = VAR(log_differenced)
    results = model.fit(i)
    aic.append(results.aic)

# %%
plt.figure(figsize=(10, 8))
plt.plot(aic, 'r+')
plt.legend(['AIC'])
plt.xlabel('Autocorrelation Lag')
plt.ylabel('AIC')
plt.title('Plot of sweeps over lag depths over AIC Loss function')
plt.show()

# %% [markdown]
# Based on our analysis, a lag of 4 appears to be the optimal.

# %%
# instantiate the var model object from statsmodels
model = VAR(log_differenced)

# fit model with determined lag values
results = model.fit(4)

# %%
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 13, Jul, 2021
# Time:                     10:44:46
# --------------------------------------------------------------------
# No. of Equations:         10.0000    BIC:                   -58.6815
# Nobs:                     34269.0    HQIC:                  -58.7503
# Log likelihood:           521363.    FPE:                2.95847e-26
# AIC:                     -58.7825    Det(Omega_mle):     2.92330e-26
# --------------------------------------------------------------------
# Results for equation mean_gas_fee_cap_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.001022         0.001906           -0.536           0.592
# L1.mean_gas_fee_cap_log_differenced                 -0.926155         0.005313         -174.333           0.000
# L1.mean_gas_premium_log_differenced                  0.000452         0.001739            0.260           0.795
# L1.mean_gas_limit_log_differenced                   -0.017869         0.089412           -0.200           0.842
# L1.mean_gas_used_log_differenced                     0.610684         0.183231            3.333           0.001
# L1.mean_parent_base_fee_log_differenced              1.554425         0.348270            4.463           0.000
# L1.mean_base_fee_burn_log_differenced               -1.442938         0.288576           -5.000           0.000
# L1.mean_over_estimation_burn_log_differenced        -0.365578         0.398065           -0.918           0.358
# L1.mean_gas_refund_log_differenced                   0.008717         0.044578            0.196           0.845
# L1.mean_gas_burned_log_differenced                  -0.301226         0.316774           -0.951           0.342
# L1.mean_message_cost_log_differenced                 0.649091         0.242591            2.676           0.007
# L2.mean_gas_fee_cap_log_differenced                 -0.715314         0.006922         -103.346           0.000
# L2.mean_gas_premium_log_differenced                 -0.000468         0.002109           -0.222           0.824
# L2.mean_gas_limit_log_differenced                   -0.118562         0.102959           -1.152           0.250
# L2.mean_gas_used_log_differenced                     1.154988         0.214198            5.392           0.000
# L2.mean_parent_base_fee_log_differenced              1.188928         0.422617            2.813           0.005
# L2.mean_base_fee_burn_log_differenced               -1.016591         0.320964           -3.167           0.002
# L2.mean_over_estimation_burn_log_differenced         0.721257         0.467194            1.544           0.123
# L2.mean_gas_refund_log_differenced                  -0.048254         0.054555           -0.885           0.376
# L2.mean_gas_burned_log_differenced                  -0.627119         0.387042           -1.620           0.105
# L2.mean_message_cost_log_differenced                -0.086501         0.263407           -0.328           0.743
# L3.mean_gas_fee_cap_log_differenced                 -0.466759         0.006933          -67.321           0.000
# L3.mean_gas_premium_log_differenced                 -0.001018         0.002108           -0.483           0.629
# L3.mean_gas_limit_log_differenced                   -0.031734         0.102786           -0.309           0.758
# L3.mean_gas_used_log_differenced                     0.825099         0.214284            3.850           0.000
# L3.mean_parent_base_fee_log_differenced              0.434788         0.422464            1.029           0.303
# L3.mean_base_fee_burn_log_differenced               -0.100447         0.321037           -0.313           0.754
# L3.mean_over_estimation_burn_log_differenced         1.451959         0.466650            3.111           0.002
# L3.mean_gas_refund_log_differenced                  -0.087096         0.054533           -1.597           0.110
# L3.mean_gas_burned_log_differenced                  -0.724231         0.386950           -1.872           0.061
# L3.mean_message_cost_log_differenced                -0.698918         0.263319           -2.654           0.008
# L4.mean_gas_fee_cap_log_differenced                 -0.221804         0.005343          -41.512           0.000
# L4.mean_gas_premium_log_differenced                 -0.001852         0.001741           -1.064           0.287
# L4.mean_gas_limit_log_differenced                    0.002320         0.089063            0.026           0.979
# L4.mean_gas_used_log_differenced                     0.240474         0.183183            1.313           0.189
# L4.mean_parent_base_fee_log_differenced              0.182854         0.348691            0.524           0.600
# L4.mean_base_fee_burn_log_differenced                0.806333         0.288253            2.797           0.005
# L4.mean_over_estimation_burn_log_differenced         1.343317         0.397050            3.383           0.001
# L4.mean_gas_refund_log_differenced                  -0.036866         0.044827           -0.822           0.411
# L4.mean_gas_burned_log_differenced                  -0.256974         0.316890           -0.811           0.417
# L4.mean_message_cost_log_differenced                -1.048632         0.242361           -4.327           0.000
# ===============================================================================================================
#
# Results for equation mean_gas_premium_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                               -0.000427         0.005714           -0.075           0.940
# L1.mean_gas_fee_cap_log_differenced                 -0.025924         0.015930           -1.627           0.104
# L1.mean_gas_premium_log_differenced                 -0.824639         0.005216         -158.101           0.000
# L1.mean_gas_limit_log_differenced                    1.310590         0.268109            4.888           0.000
# L1.mean_gas_used_log_differenced                    -2.495981         0.549433           -4.543           0.000
# L1.mean_parent_base_fee_log_differenced              1.826955         1.044318            1.749           0.080
# L1.mean_base_fee_burn_log_differenced                1.252537         0.865319            1.447           0.148
# L1.mean_over_estimation_burn_log_differenced        -2.013637         1.193632           -1.687           0.092
# L1.mean_gas_refund_log_differenced                  -0.036826         0.133671           -0.275           0.783
# L1.mean_gas_burned_log_differenced                   1.974255         0.949874            2.078           0.038
# L1.mean_message_cost_log_differenced                -0.080618         0.727428           -0.111           0.912
# L2.mean_gas_fee_cap_log_differenced                 -0.035472         0.020755           -1.709           0.087
# L2.mean_gas_premium_log_differenced                 -0.660579         0.006323         -104.475           0.000
# L2.mean_gas_limit_log_differenced                    1.823688         0.308731            5.907           0.000
# L2.mean_gas_used_log_differenced                    -4.749815         0.642290           -7.395           0.000
# L2.mean_parent_base_fee_log_differenced             -2.029292         1.267252           -1.601           0.109
# L2.mean_base_fee_burn_log_differenced                2.574146         0.962437            2.675           0.007
# L2.mean_over_estimation_burn_log_differenced        -1.085607         1.400919           -0.775           0.438
# L2.mean_gas_refund_log_differenced                   0.100187         0.163586            0.612           0.540
# L2.mean_gas_burned_log_differenced                   0.433310         1.160578            0.373           0.709
# L2.mean_message_cost_log_differenced                 0.463970         0.789847            0.587           0.557
# L3.mean_gas_fee_cap_log_differenced                 -0.018523         0.020790           -0.891           0.373
# L3.mean_gas_premium_log_differenced                 -0.496837         0.006322          -78.589           0.000
# L3.mean_gas_limit_log_differenced                    1.555136         0.308213            5.046           0.000
# L3.mean_gas_used_log_differenced                    -5.620898         0.642550           -8.748           0.000
# L3.mean_parent_base_fee_log_differenced             -3.925381         1.266793           -3.099           0.002
# L3.mean_base_fee_burn_log_differenced                3.699224         0.962656            3.843           0.000
# L3.mean_over_estimation_burn_log_differenced        -1.155706         1.399289           -0.826           0.409
# L3.mean_gas_refund_log_differenced                  -0.138301         0.163523           -0.846           0.398
# L3.mean_gas_burned_log_differenced                   0.167792         1.160303            0.145           0.885
# L3.mean_message_cost_log_differenced                 0.833750         0.789584            1.056           0.291
# L4.mean_gas_fee_cap_log_differenced                 -0.012257         0.016022           -0.765           0.444
# L4.mean_gas_premium_log_differenced                 -0.271511         0.005219          -52.022           0.000
# L4.mean_gas_limit_log_differenced                    1.366734         0.267063            5.118           0.000
# L4.mean_gas_used_log_differenced                    -4.847799         0.549288           -8.826           0.000
# L4.mean_parent_base_fee_log_differenced             -2.553593         1.045578           -2.442           0.015
# L4.mean_base_fee_burn_log_differenced                2.786539         0.864351            3.224           0.001
# L4.mean_over_estimation_burn_log_differenced        -2.576801         1.190587           -2.164           0.030
# L4.mean_gas_refund_log_differenced                  -0.172571         0.134417           -1.284           0.199
# L4.mean_gas_burned_log_differenced                   1.440120         0.950222            1.516           0.130
# L4.mean_message_cost_log_differenced                 1.016928         0.726739            1.399           0.162
# ===============================================================================================================
#
# Results for equation mean_gas_limit_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000156         0.000357            0.437           0.662
# L1.mean_gas_fee_cap_log_differenced                 -0.009171         0.000995           -9.220           0.000
# L1.mean_gas_premium_log_differenced                 -0.001092         0.000326           -3.353           0.001
# L1.mean_gas_limit_log_differenced                   -0.630018         0.016741          -37.634           0.000
# L1.mean_gas_used_log_differenced                    -0.072753         0.034307           -2.121           0.034
# L1.mean_parent_base_fee_log_differenced             -0.283504         0.065208           -4.348           0.000
# L1.mean_base_fee_burn_log_differenced                0.339967         0.054031            6.292           0.000
# L1.mean_over_estimation_burn_log_differenced         0.207282         0.074531            2.781           0.005
# L1.mean_gas_refund_log_differenced                  -0.048098         0.008346           -5.763           0.000
# L1.mean_gas_burned_log_differenced                  -0.003690         0.059311           -0.062           0.950
# L1.mean_message_cost_log_differenced                -0.204852         0.045421           -4.510           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.011741         0.001296           -9.060           0.000
# L2.mean_gas_premium_log_differenced                 -0.000634         0.000395           -1.605           0.108
# L2.mean_gas_limit_log_differenced                   -0.395606         0.019277          -20.522           0.000
# L2.mean_gas_used_log_differenced                    -0.055818         0.040105           -1.392           0.164
# L2.mean_parent_base_fee_log_differenced             -0.180300         0.079128           -2.279           0.023
# L2.mean_base_fee_burn_log_differenced                0.355225         0.060095            5.911           0.000
# L2.mean_over_estimation_burn_log_differenced         0.248939         0.087474            2.846           0.004
# L2.mean_gas_refund_log_differenced                  -0.044782         0.010214           -4.384           0.000
# L2.mean_gas_burned_log_differenced                   0.016642         0.072467            0.230           0.818
# L2.mean_message_cost_log_differenced                -0.272937         0.049318           -5.534           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.008718         0.001298           -6.716           0.000
# L3.mean_gas_premium_log_differenced                 -0.000748         0.000395           -1.894           0.058
# L3.mean_gas_limit_log_differenced                   -0.275303         0.019245          -14.305           0.000
# L3.mean_gas_used_log_differenced                    -0.048327         0.040121           -1.205           0.228
# L3.mean_parent_base_fee_log_differenced             -0.143104         0.079099           -1.809           0.070
# L3.mean_base_fee_burn_log_differenced                0.325587         0.060109            5.417           0.000
# L3.mean_over_estimation_burn_log_differenced         0.240419         0.087372            2.752           0.006
# L3.mean_gas_refund_log_differenced                  -0.009404         0.010210           -0.921           0.357
# L3.mean_gas_burned_log_differenced                  -0.005218         0.072450           -0.072           0.943
# L3.mean_message_cost_log_differenced                -0.247789         0.049302           -5.026           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.005643         0.001000           -5.640           0.000
# L4.mean_gas_premium_log_differenced                 -0.000186         0.000326           -0.570           0.568
# L4.mean_gas_limit_log_differenced                   -0.063051         0.016676           -3.781           0.000
# L4.mean_gas_used_log_differenced                    -0.042732         0.034298           -1.246           0.213
# L4.mean_parent_base_fee_log_differenced             -0.033623         0.065286           -0.515           0.607
# L4.mean_base_fee_burn_log_differenced                0.149408         0.053970            2.768           0.006
# L4.mean_over_estimation_burn_log_differenced         0.152079         0.074341            2.046           0.041
# L4.mean_gas_refund_log_differenced                  -0.003736         0.008393           -0.445           0.656
# L4.mean_gas_burned_log_differenced                  -0.006643         0.059332           -0.112           0.911
# L4.mean_message_cost_log_differenced                -0.156382         0.045378           -3.446           0.001
# ===============================================================================================================
#
# Results for equation mean_gas_used_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000131         0.000314            0.417           0.677
# L1.mean_gas_fee_cap_log_differenced                 -0.007278         0.000876           -8.309           0.000
# L1.mean_gas_premium_log_differenced                 -0.000959         0.000287           -3.343           0.001
# L1.mean_gas_limit_log_differenced                   -0.047918         0.014742           -3.250           0.001
# L1.mean_gas_used_log_differenced                    -0.670484         0.030210          -22.194           0.000
# L1.mean_parent_base_fee_log_differenced             -0.234340         0.057421           -4.081           0.000
# L1.mean_base_fee_burn_log_differenced                0.282448         0.047579            5.936           0.000
# L1.mean_over_estimation_burn_log_differenced         0.168157         0.065631            2.562           0.010
# L1.mean_gas_refund_log_differenced                  -0.012201         0.007350           -1.660           0.097
# L1.mean_gas_burned_log_differenced                   0.007461         0.052228            0.143           0.886
# L1.mean_message_cost_log_differenced                -0.175799         0.039997           -4.395           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.009082         0.001141           -7.958           0.000
# L2.mean_gas_premium_log_differenced                 -0.000788         0.000348           -2.266           0.023
# L2.mean_gas_limit_log_differenced                   -0.005358         0.016975           -0.316           0.752
# L2.mean_gas_used_log_differenced                    -0.452176         0.035316          -12.804           0.000
# L2.mean_parent_base_fee_log_differenced             -0.106952         0.069679           -1.535           0.125
# L2.mean_base_fee_burn_log_differenced                0.312988         0.052919            5.914           0.000
# L2.mean_over_estimation_burn_log_differenced         0.201524         0.077029            2.616           0.009
# L2.mean_gas_refund_log_differenced                  -0.027740         0.008995           -3.084           0.002
# L2.mean_gas_burned_log_differenced                   0.046257         0.063814            0.725           0.469
# L2.mean_message_cost_log_differenced                -0.252930         0.043429           -5.824           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.007351         0.001143           -6.431           0.000
# L3.mean_gas_premium_log_differenced                 -0.000976         0.000348           -2.809           0.005
# L3.mean_gas_limit_log_differenced                   -0.067870         0.016947           -4.005           0.000
# L3.mean_gas_used_log_differenced                    -0.260640         0.035330           -7.377           0.000
# L3.mean_parent_base_fee_log_differenced             -0.017063         0.069654           -0.245           0.806
# L3.mean_base_fee_burn_log_differenced                0.253279         0.052931            4.785           0.000
# L3.mean_over_estimation_burn_log_differenced         0.131632         0.076939            1.711           0.087
# L3.mean_gas_refund_log_differenced                   0.013147         0.008991            1.462           0.144
# L3.mean_gas_burned_log_differenced                   0.072757         0.063799            1.140           0.254
# L3.mean_message_cost_log_differenced                -0.211877         0.043415           -4.880           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.004519         0.000881           -5.130           0.000
# L4.mean_gas_premium_log_differenced                 -0.000250         0.000287           -0.872           0.383
# L4.mean_gas_limit_log_differenced                    0.012939         0.014684            0.881           0.378
# L4.mean_gas_used_log_differenced                    -0.118589         0.030202           -3.926           0.000
# L4.mean_parent_base_fee_log_differenced             -0.002168         0.057491           -0.038           0.970
# L4.mean_base_fee_burn_log_differenced                0.111384         0.047526            2.344           0.019
# L4.mean_over_estimation_burn_log_differenced         0.141829         0.065464            2.167           0.030
# L4.mean_gas_refund_log_differenced                   0.006680         0.007391            0.904           0.366
# L4.mean_gas_burned_log_differenced                  -0.006196         0.052247           -0.119           0.906
# L4.mean_message_cost_log_differenced                -0.142177         0.039959           -3.558           0.000
# ===============================================================================================================
#
# Results for equation mean_parent_base_fee_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000292         0.000333            0.876           0.381
# L1.mean_gas_fee_cap_log_differenced                 -0.020773         0.000928          -22.374           0.000
# L1.mean_gas_premium_log_differenced                  0.001269         0.000304            4.175           0.000
# L1.mean_gas_limit_log_differenced                   -0.099487         0.015626           -6.367           0.000
# L1.mean_gas_used_log_differenced                    -0.071779         0.032022           -2.242           0.025
# L1.mean_parent_base_fee_log_differenced              0.204515         0.060865            3.360           0.001
# L1.mean_base_fee_burn_log_differenced               -0.125276         0.050432           -2.484           0.013
# L1.mean_over_estimation_burn_log_differenced        -0.091471         0.069567           -1.315           0.189
# L1.mean_gas_refund_log_differenced                   0.191316         0.007791           24.557           0.000
# L1.mean_gas_burned_log_differenced                  -0.021600         0.055360           -0.390           0.696
# L1.mean_message_cost_log_differenced                 0.150523         0.042396            3.550           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.015719         0.001210          -12.995           0.000
# L2.mean_gas_premium_log_differenced                  0.000364         0.000369            0.988           0.323
# L2.mean_gas_limit_log_differenced                   -0.072374         0.017993           -4.022           0.000
# L2.mean_gas_used_log_differenced                    -0.020099         0.037434           -0.537           0.591
# L2.mean_parent_base_fee_log_differenced             -0.066291         0.073858           -0.898           0.369
# L2.mean_base_fee_burn_log_differenced               -0.061928         0.056093           -1.104           0.270
# L2.mean_over_estimation_burn_log_differenced        -0.091152         0.081648           -1.116           0.264
# L2.mean_gas_refund_log_differenced                   0.120321         0.009534           12.620           0.000
# L2.mean_gas_burned_log_differenced                   0.021921         0.067641            0.324           0.746
# L2.mean_message_cost_log_differenced                 0.098449         0.046034            2.139           0.032
# L3.mean_gas_fee_cap_log_differenced                 -0.008852         0.001212           -7.306           0.000
# L3.mean_gas_premium_log_differenced                  0.000159         0.000368            0.432           0.666
# L3.mean_gas_limit_log_differenced                   -0.059282         0.017963           -3.300           0.001
# L3.mean_gas_used_log_differenced                    -0.033811         0.037449           -0.903           0.367
# L3.mean_parent_base_fee_log_differenced             -0.027145         0.073831           -0.368           0.713
# L3.mean_base_fee_burn_log_differenced                0.037003         0.056105            0.660           0.510
# L3.mean_over_estimation_burn_log_differenced        -0.022901         0.081553           -0.281           0.779
# L3.mean_gas_refund_log_differenced                   0.085433         0.009530            8.964           0.000
# L3.mean_gas_burned_log_differenced                   0.029253         0.067625            0.433           0.665
# L3.mean_message_cost_log_differenced                 0.015588         0.046018            0.339           0.735
# L4.mean_gas_fee_cap_log_differenced                 -0.005169         0.000934           -5.535           0.000
# L4.mean_gas_premium_log_differenced                  0.000051         0.000304            0.168           0.867
# L4.mean_gas_limit_log_differenced                   -0.035349         0.015565           -2.271           0.023
# L4.mean_gas_used_log_differenced                     0.021159         0.032014            0.661           0.509
# L4.mean_parent_base_fee_log_differenced             -0.093561         0.060938           -1.535           0.125
# L4.mean_base_fee_burn_log_differenced               -0.033162         0.050376           -0.658           0.510
# L4.mean_over_estimation_burn_log_differenced         0.055143         0.069390            0.795           0.427
# L4.mean_gas_refund_log_differenced                   0.025637         0.007834            3.273           0.001
# L4.mean_gas_burned_log_differenced                  -0.083413         0.055381           -1.506           0.132
# L4.mean_message_cost_log_differenced                 0.043210         0.042356            1.020           0.308
# ===============================================================================================================
#
# Results for equation mean_base_fee_burn_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000431         0.000475            0.907           0.364
# L1.mean_gas_fee_cap_log_differenced                 -0.028670         0.001324          -21.654           0.000
# L1.mean_gas_premium_log_differenced                 -0.000169         0.000434           -0.390           0.696
# L1.mean_gas_limit_log_differenced                   -0.153179         0.022284           -6.874           0.000
# L1.mean_gas_used_log_differenced                    -0.062275         0.045666           -1.364           0.173
# L1.mean_parent_base_fee_log_differenced              0.648595         0.086797            7.473           0.000
# L1.mean_base_fee_burn_log_differenced               -0.513232         0.071920           -7.136           0.000
# L1.mean_over_estimation_burn_log_differenced         0.053898         0.099207            0.543           0.587
# L1.mean_gas_refund_log_differenced                   0.180923         0.011110           16.285           0.000
# L1.mean_gas_burned_log_differenced                   0.005647         0.078948            0.072           0.943
# L1.mean_message_cost_log_differenced                -0.021844         0.060459           -0.361           0.718
# L2.mean_gas_fee_cap_log_differenced                 -0.025081         0.001725          -14.540           0.000
# L2.mean_gas_premium_log_differenced                 -0.000690         0.000526           -1.312           0.189
# L2.mean_gas_limit_log_differenced                   -0.077385         0.025660           -3.016           0.003
# L2.mean_gas_used_log_differenced                     0.005979         0.053383            0.112           0.911
# L2.mean_parent_base_fee_log_differenced              0.292649         0.105326            2.779           0.005
# L2.mean_base_fee_burn_log_differenced               -0.233888         0.079992           -2.924           0.003
# L2.mean_over_estimation_burn_log_differenced         0.094220         0.116436            0.809           0.418
# L2.mean_gas_refund_log_differenced                   0.093402         0.013596            6.870           0.000
# L2.mean_gas_burned_log_differenced                   0.069710         0.096460            0.723           0.470
# L2.mean_message_cost_log_differenced                -0.140281         0.065647           -2.137           0.033
# L3.mean_gas_fee_cap_log_differenced                 -0.016439         0.001728           -9.514           0.000
# L3.mean_gas_premium_log_differenced                 -0.000873         0.000525           -1.662           0.097
# L3.mean_gas_limit_log_differenced                   -0.134299         0.025617           -5.243           0.000
# L3.mean_gas_used_log_differenced                     0.054538         0.053405            1.021           0.307
# L3.mean_parent_base_fee_log_differenced              0.286678         0.105288            2.723           0.006
# L3.mean_base_fee_burn_log_differenced               -0.050344         0.080010           -0.629           0.529
# L3.mean_over_estimation_burn_log_differenced         0.109791         0.116300            0.944           0.345
# L3.mean_gas_refund_log_differenced                   0.098676         0.013591            7.260           0.000
# L3.mean_gas_burned_log_differenced                   0.097437         0.096437            1.010           0.312
# L3.mean_message_cost_log_differenced                -0.192680         0.065625           -2.936           0.003
# L4.mean_gas_fee_cap_log_differenced                 -0.009630         0.001332           -7.232           0.000
# L4.mean_gas_premium_log_differenced                 -0.000535         0.000434           -1.233           0.218
# L4.mean_gas_limit_log_differenced                   -0.026473         0.022197           -1.193           0.233
# L4.mean_gas_used_log_differenced                     0.116890         0.045653            2.560           0.010
# L4.mean_parent_base_fee_log_differenced              0.100862         0.086902            1.161           0.246
# L4.mean_base_fee_burn_log_differenced               -0.131146         0.071840           -1.826           0.068
# L4.mean_over_estimation_burn_log_differenced         0.205442         0.098954            2.076           0.038
# L4.mean_gas_refund_log_differenced                   0.030722         0.011172            2.750           0.006
# L4.mean_gas_burned_log_differenced                  -0.098908         0.078977           -1.252           0.210
# L4.mean_message_cost_log_differenced                -0.097838         0.060402           -1.620           0.105
# ===============================================================================================================
#
# Results for equation mean_over_estimation_burn_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000970         0.001647            0.589           0.556
# L1.mean_gas_fee_cap_log_differenced                 -0.071686         0.004592          -15.610           0.000
# L1.mean_gas_premium_log_differenced                  0.000931         0.001504            0.619           0.536
# L1.mean_gas_limit_log_differenced                    0.345645         0.077290            4.472           0.000
# L1.mean_gas_used_log_differenced                    -0.459280         0.158389           -2.900           0.004
# L1.mean_parent_base_fee_log_differenced              0.643140         0.301053            2.136           0.033
# L1.mean_base_fee_burn_log_differenced                1.396493         0.249452            5.598           0.000
# L1.mean_over_estimation_burn_log_differenced        -0.520463         0.344097           -1.513           0.130
# L1.mean_gas_refund_log_differenced                   0.149720         0.038534            3.885           0.000
# L1.mean_gas_burned_log_differenced                   0.618081         0.273827            2.257           0.024
# L1.mean_message_cost_log_differenced                -0.746657         0.209701           -3.561           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.073497         0.005983          -12.284           0.000
# L2.mean_gas_premium_log_differenced                  0.002539         0.001823            1.393           0.164
# L2.mean_gas_limit_log_differenced                    0.579445         0.089000            6.511           0.000
# L2.mean_gas_used_log_differenced                    -0.369908         0.185158           -1.998           0.046
# L2.mean_parent_base_fee_log_differenced             -0.512115         0.365320           -1.402           0.161
# L2.mean_base_fee_burn_log_differenced                1.252550         0.277449            4.515           0.000
# L2.mean_over_estimation_burn_log_differenced         0.128499         0.403853            0.318           0.750
# L2.mean_gas_refund_log_differenced                   0.008297         0.047158            0.176           0.860
# L2.mean_gas_burned_log_differenced                   0.178699         0.334568            0.534           0.593
# L2.mean_message_cost_log_differenced                -0.791818         0.227695           -3.478           0.001
# L3.mean_gas_fee_cap_log_differenced                 -0.047378         0.005993           -7.905           0.000
# L3.mean_gas_premium_log_differenced                  0.003332         0.001822            1.828           0.068
# L3.mean_gas_limit_log_differenced                    0.405657         0.088851            4.566           0.000
# L3.mean_gas_used_log_differenced                    -0.267823         0.185232           -1.446           0.148
# L3.mean_parent_base_fee_log_differenced              0.128717         0.365187            0.352           0.724
# L3.mean_base_fee_burn_log_differenced                1.192998         0.277512            4.299           0.000
# L3.mean_over_estimation_burn_log_differenced         0.086265         0.403383            0.214           0.831
# L3.mean_gas_refund_log_differenced                   0.058717         0.047140            1.246           0.213
# L3.mean_gas_burned_log_differenced                   0.485206         0.334489            1.451           0.147
# L3.mean_message_cost_log_differenced                -0.903645         0.227619           -3.970           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.032293         0.004619           -6.992           0.000
# L4.mean_gas_premium_log_differenced                  0.001875         0.001505            1.246           0.213
# L4.mean_gas_limit_log_differenced                    0.240563         0.076988            3.125           0.002
# L4.mean_gas_used_log_differenced                    -0.049606         0.158347           -0.313           0.754
# L4.mean_parent_base_fee_log_differenced             -0.252450         0.301416           -0.838           0.402
# L4.mean_base_fee_burn_log_differenced                0.533678         0.249173            2.142           0.032
# L4.mean_over_estimation_burn_log_differenced         0.240218         0.343219            0.700           0.484
# L4.mean_gas_refund_log_differenced                   0.007348         0.038749            0.190           0.850
# L4.mean_gas_burned_log_differenced                   0.005882         0.273927            0.021           0.983
# L4.mean_message_cost_log_differenced                -0.415183         0.209502           -1.982           0.048
# ===============================================================================================================
#
# Results for equation mean_gas_refund_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000146         0.000384            0.380           0.704
# L1.mean_gas_fee_cap_log_differenced                 -0.007590         0.001069           -7.097           0.000
# L1.mean_gas_premium_log_differenced                 -0.001170         0.000350           -3.342           0.001
# L1.mean_gas_limit_log_differenced                   -0.090691         0.017999           -5.039           0.000
# L1.mean_gas_used_log_differenced                     0.168854         0.036886            4.578           0.000
# L1.mean_parent_base_fee_log_differenced             -0.134777         0.070110           -1.922           0.055
# L1.mean_base_fee_burn_log_differenced                0.289225         0.058093            4.979           0.000
# L1.mean_over_estimation_burn_log_differenced         0.194971         0.080134            2.433           0.015
# L1.mean_gas_refund_log_differenced                  -0.797839         0.008974          -88.906           0.000
# L1.mean_gas_burned_log_differenced                   0.038760         0.063769            0.608           0.543
# L1.mean_message_cost_log_differenced                -0.234934         0.048835           -4.811           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.008546         0.001393           -6.133           0.000
# L2.mean_gas_premium_log_differenced                 -0.000804         0.000424           -1.893           0.058
# L2.mean_gas_limit_log_differenced                   -0.042913         0.020726           -2.070           0.038
# L2.mean_gas_used_log_differenced                     0.172441         0.043120            3.999           0.000
# L2.mean_parent_base_fee_log_differenced             -0.042779         0.085076           -0.503           0.615
# L2.mean_base_fee_burn_log_differenced                0.275809         0.064613            4.269           0.000
# L2.mean_over_estimation_burn_log_differenced         0.189340         0.094050            2.013           0.044
# L2.mean_gas_refund_log_differenced                  -0.597081         0.010982          -54.368           0.000
# L2.mean_gas_burned_log_differenced                   0.068629         0.077915            0.881           0.378
# L2.mean_message_cost_log_differenced                -0.264534         0.053026           -4.989           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.006981         0.001396           -5.001           0.000
# L3.mean_gas_premium_log_differenced                 -0.001268         0.000424           -2.988           0.003
# L3.mean_gas_limit_log_differenced                   -0.071329         0.020692           -3.447           0.001
# L3.mean_gas_used_log_differenced                     0.150856         0.043137            3.497           0.000
# L3.mean_parent_base_fee_log_differenced              0.044951         0.085045            0.529           0.597
# L3.mean_base_fee_burn_log_differenced                0.232724         0.064627            3.601           0.000
# L3.mean_over_estimation_burn_log_differenced         0.113405         0.093940            1.207           0.227
# L3.mean_gas_refund_log_differenced                  -0.372787         0.010978          -33.958           0.000
# L3.mean_gas_burned_log_differenced                   0.109360         0.077896            1.404           0.160
# L3.mean_message_cost_log_differenced                -0.232621         0.053008           -4.388           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.004795         0.001076           -4.458           0.000
# L4.mean_gas_premium_log_differenced                 -0.000318         0.000350           -0.909           0.364
# L4.mean_gas_limit_log_differenced                    0.006698         0.017929            0.374           0.709
# L4.mean_gas_used_log_differenced                     0.067576         0.036876            1.833           0.067
# L4.mean_parent_base_fee_log_differenced              0.000113         0.070194            0.002           0.999
# L4.mean_base_fee_burn_log_differenced                0.082207         0.058028            1.417           0.157
# L4.mean_over_estimation_burn_log_differenced         0.085074         0.079929            1.064           0.287
# L4.mean_gas_refund_log_differenced                  -0.179328         0.009024          -19.872           0.000
# L4.mean_gas_burned_log_differenced                   0.024237         0.063793            0.380           0.704
# L4.mean_message_cost_log_differenced                -0.115953         0.048789           -2.377           0.017
# ===============================================================================================================
#
# Results for equation mean_gas_burned_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.000679         0.001576            0.431           0.667
# L1.mean_gas_fee_cap_log_differenced                 -0.050796         0.004394          -11.560           0.000
# L1.mean_gas_premium_log_differenced                 -0.000302         0.001439           -0.210           0.834
# L1.mean_gas_limit_log_differenced                    0.443190         0.073952            5.993           0.000
# L1.mean_gas_used_log_differenced                    -0.385738         0.151550           -2.545           0.011
# L1.mean_parent_base_fee_log_differenced             -0.360432         0.288054           -1.251           0.211
# L1.mean_base_fee_burn_log_differenced                1.519548         0.238680            6.366           0.000
# L1.mean_over_estimation_burn_log_differenced         0.365795         0.329239            1.111           0.267
# L1.mean_gas_refund_log_differenced                  -0.042121         0.036870           -1.142           0.253
# L1.mean_gas_burned_log_differenced                  -0.157791         0.262003           -0.602           0.547
# L1.mean_message_cost_log_differenced                -0.894501         0.200646           -4.458           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.057585         0.005725          -10.059           0.000
# L2.mean_gas_premium_log_differenced                  0.002202         0.001744            1.263           0.207
# L2.mean_gas_limit_log_differenced                    0.649835         0.085157            7.631           0.000
# L2.mean_gas_used_log_differenced                    -0.345667         0.177163           -1.951           0.051
# L2.mean_parent_base_fee_log_differenced             -1.048353         0.349545           -2.999           0.003
# L2.mean_base_fee_burn_log_differenced                1.309796         0.265468            4.934           0.000
# L2.mean_over_estimation_burn_log_differenced         0.820242         0.386415            2.123           0.034
# L2.mean_gas_refund_log_differenced                  -0.113170         0.045122           -2.508           0.012
# L2.mean_gas_burned_log_differenced                  -0.446905         0.320122           -1.396           0.163
# L2.mean_message_cost_log_differenced                -0.887203         0.217863           -4.072           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.038305         0.005735           -6.680           0.000
# L3.mean_gas_premium_log_differenced                  0.003198         0.001744            1.834           0.067
# L3.mean_gas_limit_log_differenced                    0.467108         0.085014            5.494           0.000
# L3.mean_gas_used_log_differenced                    -0.239517         0.177234           -1.351           0.177
# L3.mean_parent_base_fee_log_differenced             -0.250054         0.349419           -0.716           0.474
# L3.mean_base_fee_burn_log_differenced                1.160822         0.265529            4.372           0.000
# L3.mean_over_estimation_burn_log_differenced         0.511727         0.385965            1.326           0.185
# L3.mean_gas_refund_log_differenced                  -0.027110         0.045104           -0.601           0.548
# L3.mean_gas_burned_log_differenced                   0.053796         0.320046            0.168           0.867
# L3.mean_message_cost_log_differenced                -0.919925         0.217791           -4.224           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.026979         0.004419           -6.105           0.000
# L4.mean_gas_premium_log_differenced                  0.001853         0.001440            1.287           0.198
# L4.mean_gas_limit_log_differenced                    0.279529         0.073664            3.795           0.000
# L4.mean_gas_used_log_differenced                    -0.072411         0.151510           -0.478           0.633
# L4.mean_parent_base_fee_log_differenced             -0.352199         0.288401           -1.221           0.222
# L4.mean_base_fee_burn_log_differenced                0.565019         0.238413            2.370           0.018
# L4.mean_over_estimation_burn_log_differenced         0.378015         0.328399            1.151           0.250
# L4.mean_gas_refund_log_differenced                  -0.018712         0.037076           -0.505           0.614
# L4.mean_gas_burned_log_differenced                  -0.104984         0.262099           -0.401           0.689
# L4.mean_message_cost_log_differenced                -0.457487         0.200456           -2.282           0.022
# ===============================================================================================================
#
# Results for equation mean_message_cost_log_differenced
# ===============================================================================================================
#                                                   coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------------------------------
# const                                                0.001392         0.001931            0.721           0.471
# L1.mean_gas_fee_cap_log_differenced                 -0.098995         0.005383          -18.389           0.000
# L1.mean_gas_premium_log_differenced                  0.000758         0.001763            0.430           0.667
# L1.mean_gas_limit_log_differenced                    0.188571         0.090603            2.081           0.037
# L1.mean_gas_used_log_differenced                    -0.523251         0.185672           -2.818           0.005
# L1.mean_parent_base_fee_log_differenced              1.265248         0.352911            3.585           0.000
# L1.mean_base_fee_burn_log_differenced                1.348172         0.292421            4.610           0.000
# L1.mean_over_estimation_burn_log_differenced         0.008322         0.403370            0.021           0.984
# L1.mean_gas_refund_log_differenced                   0.330023         0.045172            7.306           0.000
# L1.mean_gas_burned_log_differenced                   0.610596         0.320996            1.902           0.057
# L1.mean_message_cost_log_differenced                -1.229167         0.245823           -5.000           0.000
# L2.mean_gas_fee_cap_log_differenced                 -0.096859         0.007014          -13.810           0.000
# L2.mean_gas_premium_log_differenced                  0.001849         0.002137            0.866           0.387
# L2.mean_gas_limit_log_differenced                    0.497993         0.104331            4.773           0.000
# L2.mean_gas_used_log_differenced                    -0.360430         0.217052           -1.661           0.097
# L2.mean_parent_base_fee_log_differenced             -0.227184         0.428249           -0.530           0.596
# L2.mean_base_fee_burn_log_differenced                1.348084         0.325241            4.145           0.000
# L2.mean_over_estimation_burn_log_differenced         0.559496         0.473419            1.182           0.237
# L2.mean_gas_refund_log_differenced                   0.101324         0.055282            1.833           0.067
# L2.mean_gas_burned_log_differenced                   0.242263         0.392200            0.618           0.537
# L2.mean_message_cost_log_differenced                -1.261575         0.266917           -4.726           0.000
# L3.mean_gas_fee_cap_log_differenced                 -0.062465         0.007026           -8.891           0.000
# L3.mean_gas_premium_log_differenced                  0.002440         0.002136            1.142           0.253
# L3.mean_gas_limit_log_differenced                    0.268811         0.104156            2.581           0.010
# L3.mean_gas_used_log_differenced                    -0.210988         0.217140           -0.972           0.331
# L3.mean_parent_base_fee_log_differenced              0.411403         0.428094            0.961           0.337
# L3.mean_base_fee_burn_log_differenced                1.335931         0.325315            4.107           0.000
# L3.mean_over_estimation_burn_log_differenced         0.391867         0.472868            0.829           0.407
# L3.mean_gas_refund_log_differenced                   0.157244         0.055260            2.846           0.004
# L3.mean_gas_burned_log_differenced                   0.580427         0.392107            1.480           0.139
# L3.mean_message_cost_log_differenced                -1.289209         0.266828           -4.832           0.000
# L4.mean_gas_fee_cap_log_differenced                 -0.041050         0.005414           -7.582           0.000
# L4.mean_gas_premium_log_differenced                  0.001355         0.001764            0.768           0.442
# L4.mean_gas_limit_log_differenced                    0.213222         0.090250            2.363           0.018
# L4.mean_gas_used_log_differenced                     0.069071         0.185624            0.372           0.710
# L4.mean_parent_base_fee_log_differenced             -0.149896         0.353337           -0.424           0.671
# L4.mean_base_fee_burn_log_differenced                0.534873         0.292094            1.831           0.067
# L4.mean_over_estimation_burn_log_differenced         0.576818         0.402341            1.434           0.152
# L4.mean_gas_refund_log_differenced                   0.038373         0.045424            0.845           0.398
# L4.mean_gas_burned_log_differenced                  -0.091212         0.321113           -0.284           0.776
# L4.mean_message_cost_log_differenced                -0.645770         0.245591           -2.629           0.009
# ===============================================================================================================
#
# Correlation matrix of residuals
#                                              mean_gas_fee_cap_log_differenced  mean_gas_premium_log_differenced  mean_gas_limit_log_differenced  mean_gas_used_log_differenced  mean_parent_base_fee_log_differenced  mean_base_fee_burn_log_differenced  mean_over_estimation_burn_log_differenced  mean_gas_refund_log_differenced  mean_gas_burned_log_differenced  mean_message_cost_log_differenced
# mean_gas_fee_cap_log_differenced                                     1.000000                         -0.018763                       -0.116935                      -0.108710                             -0.013410                           -0.089415                                  -0.110001                        -0.095667                        -0.112260                          -0.115408
# mean_gas_premium_log_differenced                                    -0.018763                          1.000000                        0.023991                       0.007976                              0.079523                            0.060503                                   0.041368                         0.013149                         0.026792                           0.050247
# mean_gas_limit_log_differenced                                      -0.116935                          0.023991                        1.000000                       0.900473                              0.059847                            0.644901                                   0.642958                         0.772258                         0.659593                           0.706055
# mean_gas_used_log_differenced                                       -0.108710                          0.007976                        0.900473                       1.000000                              0.048682                            0.702711                                   0.435885                         0.793440                         0.445312                           0.544208
# mean_parent_base_fee_log_differenced                                -0.013410                          0.079523                        0.059847                       0.048682                              1.000000                            0.731438                                   0.311743                         0.062488                         0.114930                           0.444536
# mean_base_fee_burn_log_differenced                                  -0.089415                          0.060503                        0.644901                       0.702711                              0.731438                            1.000000                                   0.518391                         0.572406                         0.387455                           0.686933
# mean_over_estimation_burn_log_differenced                           -0.110001                          0.041368                        0.642958                       0.435885                              0.311743                            0.518391                                   1.000000                         0.446215                         0.979503                           0.977270
# mean_gas_refund_log_differenced                                     -0.095667                          0.013149                        0.772258                       0.793440                              0.062488                            0.572406                                   0.446215                         1.000000                         0.453168                           0.520129
# mean_gas_burned_log_differenced                                     -0.112260                          0.026792                        0.659593                       0.445312                              0.114930                            0.387455                                   0.979503                         0.453168                         1.000000                           0.927707
# mean_message_cost_log_differenced                                   -0.115408                          0.050247                        0.706055                       0.544208                              0.444536                            0.686933                                   0.977270                         0.520129                         0.927707                           1.000000

# %%
results.plot()

# %% [markdown]
# ## Granger causality
#
# Granger causality is a hypothesis test for determining whether one-time series is useful in forecasting another. We can say that a variable X, or variables, evolves Granger-causes another evolving variable Y if predictions of the value of Y based on its past values and the past values of X are better than predictions of Y based only on Y's past values.
#
# Granger Causality is relationship based on the following principles:
#
# * The cause happens before its effect.
# * The cause has 'unique' information about the future values of its effect.
#
#
# Given these two assumptions about causality, Granger proposed to test the following hypothesis for identification of a causal effect of $X$ on $Y$:
# $${P}[Y(t+1) \in A\mid \mathcal{I}(t)] \neq \mathbb{P}[Y(t+1) \in A\mid \mathcal{I}_{-X}(t)]$$
# where $\mathbb{P}$ refers to probability, $A$ is an arbitrary non-empty set, and $\mathcal{I}(t)$ and $\mathcal{I}_{-X}(t)$ respectively denote the information available as of time $t$ in the entire universe, and that in the modified universe in which $X$ is excluded. If the above hypothesis is accepted, we say that $X$ Granger causes $Y$.
#
# In our analysis, we present the hypothesis that gas_used is a driver of message cost. In statistical parlance, we have the following:
#
# * $H_O: \textrm{Gas used does not Granger cause message cost}$
# * $H_A: \textrm{Gas used does Granger cause message cost}$
#
#
# Granger Causality assumes that the time series are non-stationary, which we checked and passed above, and autoregressive lags greater than 1.
#
# We will perform now perform the Granger Causality hypothesis test with an $\alpha = 0.05$ value using an F test to determine if the gas used has any casual component for predicting the message cost. If the p-value (the probability of obtaining test results at least as extreme as the results observed) of the test is less than or equal to $\alpha$ we will reject the null hypothesis and determine that gas used is a driver of message cost.
#
# ### Paraphrased source:
# * https://en.wikipedia.org/wiki/Granger_causality

# %% [markdown]
# As we have many signals with the analysis, we will loop through all the signals, perform the Granger Causality test, and save the results for analysis.

# %%
alpha = 0.05
result_dfs = []
variables = list(log_differenced.columns)
for i in variables:
    for j in variables:
        if i==j:
            pass
        else:
            results_summary = results.test_causality(i,j, 
                                                     kind='f',signif=alpha).summary()


            df = pd.read_html(results_summary.as_html(),header=0, index_col=0)[0]
            df['alpha'] = alpha
            df['caused'] = i
            df['causing'] = j
            result_dfs.append(df)
        
Grangers_df = pd.concat(result_dfs)
Grangers_df.reset_index(inplace=True)
Grangers_df['result'] = Grangers_df['p-value'].apply(lambda x: 'reject H0' if x < alpha else 'fail to reject H0' )
Grangers_df
# Out:
#     Test statistic  Critical value  p-value           df  alpha  \
# 0           0.3766           2.372    0.826  (4, 342280)   0.05
# 1           0.4500           2.372    0.772  (4, 342280)   0.05
# 2           7.7580           2.372    0.000  (4, 342280)   0.05
# 3           5.3020           2.372    0.000  (4, 342280)   0.05
# 4          10.5500           2.372    0.000  (4, 342280)   0.05
# ..             ...             ...      ...          ...    ...
# 85          7.0590           2.372    0.000  (4, 342280)   0.05
# 86          7.7470           2.372    0.000  (4, 342280)   0.05
# 87          0.8097           2.372    0.519  (4, 342280)   0.05
# 88         17.4000           2.372    0.000  (4, 342280)   0.05
# 89          2.0830           2.372    0.080  (4, 342280)   0.05
#
#                                caused  \
# 0    mean_gas_fee_cap_log_differenced
# 1    mean_gas_fee_cap_log_differenced
# 2    mean_gas_fee_cap_log_differenced
# 3    mean_gas_fee_cap_log_differenced
# 4    mean_gas_fee_cap_log_differenced
# ..                                ...
# 85  mean_message_cost_log_differenced
# 86  mean_message_cost_log_differenced
# 87  mean_message_cost_log_differenced
# 88  mean_message_cost_log_differenced
# 89  mean_message_cost_log_differenced
#
#                                       causing             result
# 0            mean_gas_premium_log_differenced  fail to reject H0
# 1              mean_gas_limit_log_differenced  fail to reject H0
# 2               mean_gas_used_log_differenced          reject H0
# 3        mean_parent_base_fee_log_differenced          reject H0
# 4          mean_base_fee_burn_log_differenced          reject H0
# ..                                        ...                ...
# 85       mean_parent_base_fee_log_differenced          reject H0
# 86         mean_base_fee_burn_log_differenced          reject H0
# 87  mean_over_estimation_burn_log_differenced  fail to reject H0
# 88            mean_gas_refund_log_differenced          reject H0
# 89            mean_gas_burned_log_differenced  fail to reject H0
#
# [90 rows x 8 columns]

# %%
heatdf = Grangers_df.pivot(index='caused', columns=['causing'],values=['p-value'])

f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(heatdf, annot=True, linewidths=.5, ax=ax,cmap=['green','red'],center=0.05)
plt.suptitle('Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')
# Out:
# Text(0.5, 0.98, 'Heatmap of Granger Casuality \n Green shows causal relationship whereas red shows no causal relationship')

# %% [markdown]
# Based on the heatmap above, we can see that there are some granger causal relationships between signals. To see more granular specifics, we will examine the reject H0s below

# %%
Grangers_df.query("result == 'reject H0'").sort_values('p-value',ascending=True)
# Out:
#     Test statistic  Critical value  p-value           df  alpha  \
# 2            7.758           2.372    0.000  (4, 342280)   0.05
# 86           7.747           2.372    0.000  (4, 342280)   0.05
# 45         118.300           2.372    0.000  (4, 342280)   0.05
# 47          16.480           2.372    0.000  (4, 342280)   0.05
# 49          15.470           2.372    0.000  (4, 342280)   0.05
# 51          74.130           2.372    0.000  (4, 342280)   0.05
# 54          64.830           2.372    0.000  (4, 342280)   0.05
# 56          11.300           2.372    0.000  (4, 342280)   0.05
# 59          10.080           2.372    0.000  (4, 342280)   0.05
# 60           6.280           2.372    0.000  (4, 342280)   0.05
# 62           5.920           2.372    0.000  (4, 342280)   0.05
# 38          10.580           2.372    0.000  (4, 342280)   0.05
# 63          14.520           2.372    0.000  (4, 342280)   0.05
# 66           6.487           2.372    0.000  (4, 342280)   0.05
# 68           8.016           2.372    0.000  (4, 342280)   0.05
# 71           9.640           2.372    0.000  (4, 342280)   0.05
# 72          37.780           2.372    0.000  (4, 342280)   0.05
# 74          16.470           2.372    0.000  (4, 342280)   0.05
# 77          12.270           2.372    0.000  (4, 342280)   0.05
# 80           7.926           2.372    0.000  (4, 342280)   0.05
# 81          87.950           2.372    0.000  (4, 342280)   0.05
# 83           5.979           2.372    0.000  (4, 342280)   0.05
# 85           7.059           2.372    0.000  (4, 342280)   0.05
# 65           9.534           2.372    0.000  (4, 342280)   0.05
# 37           5.426           2.372    0.000  (4, 342280)   0.05
# 42         154.900           2.372    0.000  (4, 342280)   0.05
# 35          11.450           2.372    0.000  (4, 342280)   0.05
# 3            5.302           2.372    0.000  (4, 342280)   0.05
# 4           10.550           2.372    0.000  (4, 342280)   0.05
# 8            8.195           2.372    0.000  (4, 342280)   0.05
# 10          12.580           2.372    0.000  (4, 342280)   0.05
# 11          26.690           2.372    0.000  (4, 342280)   0.05
# 12           5.532           2.372    0.000  (4, 342280)   0.05
# 18          26.060           2.372    0.000  (4, 342280)   0.05
# 22          14.400           2.372    0.000  (4, 342280)   0.05
# 36         128.500           2.372    0.000  (4, 342280)   0.05
# 24          10.280           2.372    0.000  (4, 342280)   0.05
# 26          11.190           2.372    0.000  (4, 342280)   0.05
# 88          17.400           2.372    0.000  (4, 342280)   0.05
# 27          20.760           2.372    0.000  (4, 342280)   0.05
# 33           7.629           2.372    0.000  (4, 342280)   0.05
# 29          10.950           2.372    0.000  (4, 342280)   0.05
# 31          12.890           2.372    0.000  (4, 342280)   0.05
# 64           4.437           2.372    0.001  (4, 342280)   0.05
# 21           4.944           2.372    0.001  (4, 342280)   0.05
# 30           4.762           2.372    0.001  (4, 342280)   0.05
# 13           4.511           2.372    0.001  (4, 342280)   0.05
# 58           4.997           2.372    0.001  (4, 342280)   0.05
# 5            4.759           2.372    0.001  (4, 342280)   0.05
# 28           3.851           2.372    0.004  (4, 342280)   0.05
# 44           3.692           2.372    0.005  (4, 342280)   0.05
# 19           3.334           2.372    0.010  (4, 342280)   0.05
# 76           3.237           2.372    0.012  (4, 342280)   0.05
# 23           3.025           2.372    0.017  (4, 342280)   0.05
# 32           2.645           2.372    0.032  (4, 342280)   0.05
# 48           2.587           2.372    0.035  (4, 342280)   0.05
# 53           2.549           2.372    0.037  (4, 342280)   0.05
# 40           2.406           2.372    0.047  (4, 342280)   0.05
#
#                                        caused  \
# 2            mean_gas_fee_cap_log_differenced
# 86          mean_message_cost_log_differenced
# 45         mean_base_fee_burn_log_differenced
# 47         mean_base_fee_burn_log_differenced
# 49         mean_base_fee_burn_log_differenced
# 51         mean_base_fee_burn_log_differenced
# 54  mean_over_estimation_burn_log_differenced
# 56  mean_over_estimation_burn_log_differenced
# 59  mean_over_estimation_burn_log_differenced
# 60  mean_over_estimation_burn_log_differenced
# 62  mean_over_estimation_burn_log_differenced
# 38       mean_parent_base_fee_log_differenced
# 63            mean_gas_refund_log_differenced
# 66            mean_gas_refund_log_differenced
# 68            mean_gas_refund_log_differenced
# 71            mean_gas_refund_log_differenced
# 72            mean_gas_burned_log_differenced
# 74            mean_gas_burned_log_differenced
# 77            mean_gas_burned_log_differenced
# 80            mean_gas_burned_log_differenced
# 81          mean_message_cost_log_differenced
# 83          mean_message_cost_log_differenced
# 85          mean_message_cost_log_differenced
# 65            mean_gas_refund_log_differenced
# 37       mean_parent_base_fee_log_differenced
# 42       mean_parent_base_fee_log_differenced
# 35              mean_gas_used_log_differenced
# 3            mean_gas_fee_cap_log_differenced
# 4            mean_gas_fee_cap_log_differenced
# 8            mean_gas_fee_cap_log_differenced
# 10           mean_gas_premium_log_differenced
# 11           mean_gas_premium_log_differenced
# 12           mean_gas_premium_log_differenced
# 18             mean_gas_limit_log_differenced
# 22             mean_gas_limit_log_differenced
# 36       mean_parent_base_fee_log_differenced
# 24             mean_gas_limit_log_differenced
# 26             mean_gas_limit_log_differenced
# 88          mean_message_cost_log_differenced
# 27              mean_gas_used_log_differenced
# 33              mean_gas_used_log_differenced
# 29              mean_gas_used_log_differenced
# 31              mean_gas_used_log_differenced
# 64            mean_gas_refund_log_differenced
# 21             mean_gas_limit_log_differenced
# 30              mean_gas_used_log_differenced
# 13           mean_gas_premium_log_differenced
# 58  mean_over_estimation_burn_log_differenced
# 5            mean_gas_fee_cap_log_differenced
# 28              mean_gas_used_log_differenced
# 44       mean_parent_base_fee_log_differenced
# 19             mean_gas_limit_log_differenced
# 76            mean_gas_burned_log_differenced
# 23             mean_gas_limit_log_differenced
# 32              mean_gas_used_log_differenced
# 48         mean_base_fee_burn_log_differenced
# 53         mean_base_fee_burn_log_differenced
# 40       mean_parent_base_fee_log_differenced
#
#                                       causing     result
# 2               mean_gas_used_log_differenced  reject H0
# 86         mean_base_fee_burn_log_differenced  reject H0
# 45           mean_gas_fee_cap_log_differenced  reject H0
# 47             mean_gas_limit_log_differenced  reject H0
# 49       mean_parent_base_fee_log_differenced  reject H0
# 51            mean_gas_refund_log_differenced  reject H0
# 54           mean_gas_fee_cap_log_differenced  reject H0
# 56             mean_gas_limit_log_differenced  reject H0
# 59         mean_base_fee_burn_log_differenced  reject H0
# 60            mean_gas_refund_log_differenced  reject H0
# 62          mean_message_cost_log_differenced  reject H0
# 38             mean_gas_limit_log_differenced  reject H0
# 63           mean_gas_fee_cap_log_differenced  reject H0
# 66              mean_gas_used_log_differenced  reject H0
# 68         mean_base_fee_burn_log_differenced  reject H0
# 71          mean_message_cost_log_differenced  reject H0
# 72           mean_gas_fee_cap_log_differenced  reject H0
# 74             mean_gas_limit_log_differenced  reject H0
# 77         mean_base_fee_burn_log_differenced  reject H0
# 80          mean_message_cost_log_differenced  reject H0
# 81           mean_gas_fee_cap_log_differenced  reject H0
# 83             mean_gas_limit_log_differenced  reject H0
# 85       mean_parent_base_fee_log_differenced  reject H0
# 65             mean_gas_limit_log_differenced  reject H0
# 37           mean_gas_premium_log_differenced  reject H0
# 42            mean_gas_refund_log_differenced  reject H0
# 35          mean_message_cost_log_differenced  reject H0
# 3        mean_parent_base_fee_log_differenced  reject H0
# 4          mean_base_fee_burn_log_differenced  reject H0
# 8           mean_message_cost_log_differenced  reject H0
# 10             mean_gas_limit_log_differenced  reject H0
# 11              mean_gas_used_log_differenced  reject H0
# 12       mean_parent_base_fee_log_differenced  reject H0
# 18           mean_gas_fee_cap_log_differenced  reject H0
# 22         mean_base_fee_burn_log_differenced  reject H0
# 36           mean_gas_fee_cap_log_differenced  reject H0
# 24            mean_gas_refund_log_differenced  reject H0
# 26          mean_message_cost_log_differenced  reject H0
# 88            mean_gas_refund_log_differenced  reject H0
# 27           mean_gas_fee_cap_log_differenced  reject H0
# 33            mean_gas_refund_log_differenced  reject H0
# 29             mean_gas_limit_log_differenced  reject H0
# 31         mean_base_fee_burn_log_differenced  reject H0
# 64           mean_gas_premium_log_differenced  reject H0
# 21       mean_parent_base_fee_log_differenced  reject H0
# 30       mean_parent_base_fee_log_differenced  reject H0
# 13         mean_base_fee_burn_log_differenced  reject H0
# 58       mean_parent_base_fee_log_differenced  reject H0
# 5   mean_over_estimation_burn_log_differenced  reject H0
# 28           mean_gas_premium_log_differenced  reject H0
# 44          mean_message_cost_log_differenced  reject H0
# 19           mean_gas_premium_log_differenced  reject H0
# 76       mean_parent_base_fee_log_differenced  reject H0
# 23  mean_over_estimation_burn_log_differenced  reject H0
# 32  mean_over_estimation_burn_log_differenced  reject H0
# 48              mean_gas_used_log_differenced  reject H0
# 53          mean_message_cost_log_differenced  reject H0
# 40         mean_base_fee_burn_log_differenced  reject H0

# %% [markdown]
# Based on the above table, we can see some Granger caused relationships between signals, such as mean_gas_fee_cap Granger causes mean_gas_limit. We can't fully use Granger until we understand what the signals are and what they represent better.

# %% [markdown]
# ## Conclusion
# In this notebook, we've provided proof of workflow for using VAR and Granger Causality to analyze the relationships between variables. In a [subsequent notebook](gas_eda_v2.ipynb),  we will examine the gas data more deeply.
